# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Requirement already satisfied: bnunicodenormalizer in /usr/local/lib/python3.10/dist-packages (0.1.6)
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/'

# %%
files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_09_audio_53.wav', 'rec_09_audio_36.wav', 'rec_09_audio_30.wav', 'rec_09_audio_38.wav', 'rec_09_audio_28.wav', 'rec_09_audio_34.wav', 'rec_09_audio_46.wav', 'rec_09_audio_27.wav', 'rec_09_audio_26.wav', 'rec_09_audio_49.wav', 'rec_09_audio_35.wav', 'rec_09_audio_25.wav', 'rec_09_audio_5.wav', 'rec_09_audio_3.wav', 'rec_10_audio_4.wav', 'rec_10_audio_29.wav', 'rec_10_audio_34.wav', 'rec_09_audio_6.wav', 'rec_10_audio_32.wav', 'rec_10_audio_38.wav', 'rec_10_audio_10.wav', 'rec_10_audio_14.wav', 'rec_10_audio_26.wav', 'rec_10_audio_19.wav', 'rec_10_audio_3.wav', 'rec_10_audio_24.wav', 'rec_10_audio_6.wav', 'rec_10_audio_25.wav', 'rec_10_audio_20.wav', 'rec_10_audio_28.wav', 'rec_10_audio_23.wav', 'rec_10_audio_27.wav', 'rec_10_audio_18.wav', 'rec_09_audio_9.wav', 'rec_10_audio_41.wav', 'rec_10_audio_11.wav', 'rec_10_audio_5.wav', 'rec_10_audio_36.wav', 'rec_10_audio_1.wav', 'rec_10_audio_37.wav', 'rec_10_audio_31.wav', 'rec_10_audio_13.wav', 'rec_09_audio_7.wav', 'rec_10_audio_30.wav', 'rec_10_audio_33.wav', 'rec_10_audio_12.wav', 'rec_10_audio_15.wav', 'rec_10_audio_39.wav', 'rec_09_audio_55.wav', 'rec_09_audio_54.wav', 'rec_10_audio_16.wav', 'rec_10_audio_40.wav', 'rec_10_audio_22.wav', 'rec_10_audio_35.wav', 'rec_09_audio_8.wav', 'rec_10_audio_2.wav', 'rec_10_audio_0.wav', 'rec_10_audio_17.wav', 'rec_10_audio_21.wav', 'rec_11_audio_31.wav', 'rec_12_audio_0.wav', 'rec_11_audio_8.wav', 'rec_12_audio_11.wav', 'rec_11_audio_30.wav', 'rec_11_audio_0.wav', 'rec_11_audio_33.wav', 'rec_11_audio_26.wav', 'rec_11_audio_9.wav', 'rec_11_audio_29.wav', 'rec_12_audio_1.wav', 'rec_11_audio_20.wav', 'rec_10_audio_8.wav', 'rec_11_audio_6.wav', 'rec_11_audio_18.wav', 'rec_11_audio_24.wav', 'rec_11_audio_2.wav', 'rec_11_audio_7.wav', 'rec_11_audio_23.wav', 'rec_11_audio_1.wav', 'rec_11_audio_21.wav', 'rec_11_audio_14.wav', 'rec_11_audio_16.wav', 'rec_11_audio_15.wav', 'rec_11_audio_11.wav', 'rec_11_audio_22.wav', 'rec_11_audio_28.wav', 'rec_10_audio_7.wav', 'rec_11_audio_32.wav', 'rec_11_audio_3.wav', 'rec_11_audio_10.wav', 'rec_11_audio_36.wav', 'rec_11_audio_25.wav', 'rec_11_audio_5.wav', 'rec_11_audio_13.wav', 'rec_11_audio_4.wav', 'rec_11_audio_17.wav', 'rec_11_audio_34.wav', 'rec_11_audio_27.wav', 'rec_12_audio_10.wav', 'rec_10_audio_9.wav', 'rec_11_audio_19.wav', 'rec_11_audio_12.wav', 'rec_11_audio_35.wav', 'rec_12_audio_8.wav', 'rec_13_audio_12.wav', 'rec_13_audio_13.wav', 'rec_13_audio_33.wav', 'rec_13_audio_10.wav', 'rec_13_audio_20.wav', 'rec_13_audio_0.wav', 'rec_13_audio_1.wav', 'rec_13_audio_28.wav', 'rec_12_audio_3.wav', 'rec_12_audio_15.wav', 'rec_13_audio_2.wav', 'rec_13_audio_30.wav', 'rec_13_audio_18.wav', 'rec_12_audio_6.wav', 'rec_13_audio_16.wav', 'rec_12_audio_4.wav', 'rec_13_audio_15.wav', 'rec_13_audio_11.wav', 'rec_12_audio_14.wav', 'rec_13_audio_21.wav', 'rec_12_audio_13.wav', 'rec_12_audio_18.wav', 'rec_13_audio_29.wav', 'rec_13_audio_19.wav', 'rec_13_audio_26.wav', 'rec_13_audio_31.wav', 'rec_12_audio_2.wav', 'rec_12_audio_12.wav', 'rec_12_audio_9.wav', 'rec_12_audio_16.wav', 'rec_12_audio_17.wav', 'rec_13_audio_23.wav', 'rec_13_audio_32.wav', 'rec_13_audio_17.wav', 'rec_13_audio_14.wav', 'rec_13_audio_34.wav', 'rec_12_audio_7.wav', 'rec_13_audio_27.wav', 'rec_13_audio_22.wav', 'rec_13_audio_3.wav', 'rec_13_audio_25.wav', 'rec_13_audio_24.wav', 'rec_12_audio_5.wav', 'rec_13_audio_40.wav', 'rec_14_audio_1.wav', 'rec_14_audio_30.wav', 'rec_13_audio_37.wav', 'rec_14_audio_11.wav', 'rec_13_audio_39.wav', 'rec_14_audio_28.wav', 'rec_14_audio_32.wav', 'rec_14_audio_12.wav', 'rec_14_audio_10.wav', 'rec_14_audio_27.wav', 'rec_14_audio_22.wav', 'rec_14_audio_23.wav', 'rec_13_audio_7.wav', 'rec_14_audio_24.wav', 'rec_14_audio_19.wav', 'rec_14_audio_2.wav', 'rec_14_audio_29.wav', 'rec_14_audio_18.wav', 'rec_13_audio_42.wav', 'rec_13_audio_43.wav', 'rec_13_audio_9.wav', 'rec_13_audio_4.wav', 'rec_14_audio_17.wav', 'rec_13_audio_45.wav', 'rec_13_audio_41.wav', 'rec_14_audio_21.wav', 'rec_14_audio_20.wav', 'rec_14_audio_13.wa ...
#
# 1320

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_09_audio_53.wav', 'সেটা এখন সরকারি করেন না'],
#  ['rec_09_audio_36.wav', 'অতি বাড়ি এসি লাগে না'],
#  ['rec_09_audio_30.wav', 'মানিকের হাতেই লেখা আছে'],
#  ['rec_09_audio_38.wav', 'বেটি বলে তো বিয়ে দিয়ে'],
#  ['rec_09_audio_28.wav', 'আল্লাদের ভাত খাও মোর অভাব নাই করে না দুটো 10'],
#  ['rec_09_audio_34.wav',
#   'তালাক কেমন করে দেওয়া লাগবে না লাগবে একটা ব্যবস্থা করে টাকাটা দেওয়ার ব্যবস্থা করুন'],
#  ['rec_09_audio_46.wav',
#   'এবারকার টাকা দিয়ে কিছু করবার পারো নাই জানেন দুই সপ্তাহে 8000 টাকা পাচ্ছি ওই ডাক্তারের দোকানে যেতে মোট শেষ আর 8000 টাকা'],
#  ['rec_09_audio_27.wav', 'তোর বেটি দিয়ে পাঠাইস তোর বেটি দিয়ে পাঠাইস'],
#  ['rec_09_audio_26.wav', '<>'],
#  ['rec_09_audio_49.wav', '<>'],
#  ['rec_09_audio_35.wav', 'কমে যায়'],
#  ['rec_09_audio_25.wav', 'ওই যে সকাল কার কথা এখন কয়দিন রুটি বানাচ্ছি'],
#  ['rec_09_audio_5.wav', 'এই যে ভোটার আইডেন্টি কার্টুন করছে'],
#  ['rec_09_audio_3.wav',
#   'মানে অসাল মানুষ একটা মেয়েকে যে সংসারটা চালে খাবে নাকি 10 ঘরের খানে আলা খায় মনে করো সেটাও এখন পড়া যায় সেটাও বন্ধ হয়ে গেছে এখন কর্মসূচির কাজ করি ওই যে বোতল চেয়ারম্যান'],
#  ['rec_10_audio_4.wav',
#   'একটা গ্রামের মানুষ আর এখন বর্তমান বাংলাদেশ পরিস্থিতি সৃষ্টি হয়েছে আনন্দ'],
#  ['rec_10_audio_29.wav', 'এগুলো'],
#  ['rec_10_audio_34.wav', 'গাজীপুর বাজার আসছে না কপাল ভাই পতিরাম বাবু'],
#  ['rec_09_audio_6.wav',
#   'তাও এখন নিম্বর শারমিন এরা কি করে বহুৎ বহুৎ খাওয়া-দাওয়া করছেন'],
#  ['rec_10_audio_32.wav', 'কম হয়'],
#  ['rec_10_audio_38.wav', 'আমার হামলা দিয়েছে 5 বছর পর্যন্ত খারাপ খারাপ'],
#  ['rec_10_audio_10.wav', 'আমার সময় প্রাইভেটের কথা যদি কইছি না আমরা পারিনা'],
#  ['rec_10_audio_14.wav', '<>'],
#  ['rec_10_audio_26.wav', '<>'],
#  ['rec_10_audio_19.wav', 'আগে এই যে যোগাযোগ বিচ্ছিন্ন আছেন মেলা কম্পাস'],
#  ['rec_10_audio_3.wav',
#   'জান যে পরিবেশে থাকে তার শৈশব কাল সেদিন এখানে বর্তমানে আমার সময়'],
#  ['rec_10_audio_24.wav', 'সাত কোটি মানুষের'],
#  ['rec_10_audio_6.wav', '<>'],
#  ['rec_10_audio_25.wav',
#   'আগের মত হয় তাহলে আবার আগের চেয়ে বেশি শান্তি মানুষের'],
#  ['rec_10_audio_20.wav', 'আর এখন একসময় ফাঁকে হলেও দামের কম বেশি মোবাইল নেই'],
#  ['rec_10_audio_28.wav', 'তাহলে আগে তো ঘুরেফিরে বহুৎ করছেন না শুনছিলাম'],
#  ['rec_10_audio_23.wav',
#   'তিন দিন লাগছে আর এখন সেটাই মোটরসাইকেল যায় 60 মিনিট লাগে সুন্দর হয়েছে'],
#  ['rec_10_audio_27.wav', 'সমস্যা কি'],
#  ['rec_10_audio_18.wav', 'ক্যান ইউ উইনার ফিনাল কাপড়'],
#  ['rec_09_audio_9.wav', '<>'],
#  ['rec_10_audio_41.wav', 'ব্যাটারি সার্ভিস'],
#  ['rec_10_audio_11.wav', 'আর এখনকার মাস্টার অভাবী সংসারের মধ্যে সেই সংসার'],
#  ['rec_10_audio_5.wav',
#   'মানুষের সাথে মানুষের সম্পর্কে মনোভাব এই জিনিসটা মানুষের'],
#  ['rec_10_audio_36.wav', 'আগের জোকস'],
#  ['rec_10_audio_1.wav', 'তোর নামটা কি তোর নামটা কি তোর নামটা কি'],
#  ['rec_10_audio_37.wav', 'আদর্শের আদর্শের যুগে আদর্শ মানুষের জন্ম হয়েছিল'],
#  ['rec_10_audio_31.wav', 'এই পাগলাচোদা হয়নি'],
#  ['rec_10_audio_13.wav', 'যার শান্তি কিন্তু যারা এখন অমানবিক আচরণ করবেন'],
#  ['rec_09_audio_7.wav', 'পরিয়ে দিন তারে পাচক 100 টাকা লাগে না'],
#  ['rec_10_audio_30.wav', '<>'],
#  ['rec_10_audio_33.wav',
#   'তাও করে না খুব চালাক খুবই যার সম্পদ থাকে তার মানুষেরা মূল্যায়ন দিয়ে চলে যায়'],
#  ['rec_10_audio_12.wav',
#   'অহংকার সমাজ আর এখনকার সমাজের মধ্যে অনেক কম বেশি পরবর্তীতে আরো কি হবে'],
#  ['rec_10_audio_15.wav', 'যে সমাজের মধ্যে'],
#  ['rec_10_audio_39.wav', 'বড় মানুষ বসে বসে'],
#  ['rec_09_audio_55.wav',
#   'কিস করেন অনেক গল্প করছে পণ্য মনে কিছু করেন না ভালো থাকেন আর চাচার দিকে অসুস্থ মানুষ ওষুধপাতি ঠিক ভাবে খেল'],
#  ['rec_09_audio_54.wav',
#   '100 টাকা 50 টাকা বাজার করলে না আর এখন 500 টাকার বাজার হাত করি'],
#  ['rec_10_audio_16.wav', 'এই ফুল মুভি চেন্নাই'],
#  ['rec_10_audio_40.wav', '<>'],
#  ['rec_10_audio_22.wav',
#   'খাওয়া দাওয়া আর আগেই রংপুর এসে গেলে তিন দিন আছে তোমার বাড়ি পর্যন্ত'],
#  ['rec_10_audio_35.wav', 'আমার যুগে অথবা তার অল্প আগে আগে ধনতান্ত্রিক আর'],
#  ['rec_09_audio_8.wav', 'মতিউর রহমান'],
#  ['rec_10_audio_2.wav',
#   'তোর বয়স কত ছিল শৈশবকাল ছোটকালে কেমনে কি করল কি সমাচার এ কথা বলে না'],
#  ['rec_10_audio_0.wav', 'কেমন আছিস ভালো আছো'],
#  ['rec_10_audio_17.wav',
#   'আগের আর এখনকার এখনকার যুগের কি আর আগে কত ভালো পরিবেশ ছিল না আমার সঙ্গে আমরা অবস্থা আছে'],
#  ['rec_10_audio_21.wav', '60 কিলো এখন সকালে বাড়ালে রহমতি খরচ করে নিয়ে যাবে'],
#  ['rec_11_audio_31.wav', '<>'],
#  ['rec_12_audio_0.wav',
#   'রে মরিয়ম কেমন আছিস তোর সাথে একটা গল্প করি তোর কি সময় হবে সময় হইবে'],
#  ['rec_11_audio_8.wav',
#   'এখন ইয়া তোমার নাতি যে আছে মনে হয় আবেদনে কি নাম আছে পারি তো মেডিকেলে কাকে নিয়ে আমার বউ বসলো'],
#  ['rec_12_audio_11.wav', '15 বাচ্চা শুনলে হাঁস হলো'],
#  ['rec_11_audio_30.wav', '<>'],
#  ['rec_11_audio_0.wav',
#   'কেমন আছেন সম্বন্ধে কিছু গল্প কিছু করবো এগুলো রেকর্ড করবো'],
#  ['rec_11_audio_33.wav', '<>'],
#  ['rec_11_audio_26.wav', '<>'],
#  ['rec_11_audio_9.wav',
#   'জানিয়েছে কান্নাকাটি করে না কান্দে না লাগবে না কান্নাকাটি'],
#  ['rec_11_audio_29.wav', '<>'],
#  ['rec_12_audio_1.wav',
#   'মোবাইলে কিন্তু কোন রেকর্ডও করিনি তোর নাম তুমি জানো না তোর বয়স কত'],
#  ['rec_11_audio_20.wav', '<>'],
#  ['rec_10_audio_8.wav',
#   'সেই সাদিকা কম নাই নাই এখন মাংসের পয়সা হয়েছে তুমি মানবতা হয়েছে'],
#  ['rec_11_audio_6.wav',
#   'এখন বর্তমান ঘাস বেশি আমদানি খুব বাজাজ নিচ্ছে না মানুষের প্রভাব পড়ে গেছে খাওয়া-দাওয়া করছেন'],
#  ['rec_11_audio_18.wav', '<>'],
#  ['rec_11_audio_24.wav', '<>'],
#  ['rec_11_audio_2.wav', 'গুগলের দাম বেশি বেশি কোনটা কেমন চলবে না'],
#  ['rec_11_audio_7.wav',
#   'হাতে নিয়ে গেলাম না এখনো ভাত খাই কইবা হাত না থাকলে শুধু একটা পান খাচ্ছি না লাগবে'],
#  ['rec_11_audio_23.wav', '<>'],
#  ['rec_11_audio_1.wav',
#   'তোমার সমস্যা আছে কোন কি সমস্যা তাহলে তোমার নাম কি আসাদুল বয়স কত ছিল কোন দেখি বিভিন্ন জায়গায় হাট বাজার জান এই বাজারে সব জিনিসের দ্রব্যমূল্যের কেমন সব রেট বেশি বাজার বর্তমান বেশি'],
#  ['rec_11_audio_21.wav', '<>'],
#  ['rec_11_audio_14.wav', 'আমরা কইছে কালকে আমরা ঘুরেছি'],
#  ['rec_11_audio_16.wav', '<>'],
#  ['rec_11_audio_15.wav', 'তাহলে বসে তোমার বিচার হবে তোমার বিচার হবে'],
#  ['rec_11_audio_11.wav', '<>'],
#  ['rec_11_audio_22.wav', 'ওকে খিলে'],
#  ['rec_11_audio_28.wav', '<>'],
#  ['rec_10_audio_7.wav', 'শান্তি'],
#  ['rec_11_audio_32.wav', '<>'],
#  ['rec_11_audio_3.wav', 'গরু দুই পিস তুই নাকি'],
#  ['rec_11_audio_10.wav', 'নাইস শাকিব'],
#  ['rec_11_audio_36.wav', '<>'],
#  ['rec_11_audio_25.wav', '<>'],
#  ['rec_11_audio_5.wav',
#   'এখন বাজার মোতাবেক চলে গেলে খুব হারামি হওয়া লাগছে সাধারন মানুষের খরচা বেশি কামড়ালে বেশি সবকিছু বেশি গাছ বেচতে গেলে দাম কম ঘাসের আপাতত লস'],
#  ['rec_11_audio_13.wav', '<>'],
#  ['rec_11_audio_4.wav',
#   'এই যে এই সরকার থাকাকালীন মনে করো এমন একটা অবস্থা সৃষ্টি হয়েছে জনজীবনের অবস্থা খুব খারাপ মানুষ মানে এমন একটা জিনিসের সব দাম নাই যে কম আছে সব জিনিসের সব জিনিসের দাম বেশি'],
#  ['rec_11_audio_17.wav', '<>'],
#  ['rec_11_audio_34.wav', '<>'],
#  ['rec_11_audio_27.wav', 'আরে ছেলেদের ঘাস ছুটি দিলে কেমন হয় না'],
#  ['rec_12_audio_10.wav',
#   'দামরা দুইটা দাম দিয়ে একটা গাই একটা ছাগল আছে একটা ছাগল কয়টা একটা বাচ্চাকাচ্চা নাই হইবে হাস মুরগি আছে নাকি'],
#  ['rec_10_audio_9.wav',
#   'এই যে মানুষের মানবতা হাইছে যেটা তুমি মানুষ শান্তি পায় নাই কোন পাশে সালাম'],
#  ['rec_11_audio_19.wav', '<>'],
#  ['rec_11_audio_12.wav', '<>'],
#  ['rec_11_audio_35.wav', '<>'],
#  ['rec_12_audio_8.wav', 'কেমন হয়েছে খাওয়া-দাওয়া করলে'],
#  ['rec_13_audio_12.wav',
#   'কথা আছে এই অবস্থায় মানুষের সাহসী ভয় করার কিছু নাই কিন্তু আসলেই মানুষের এগুলি আক্কেল নাই'],
#  ['rec_13_audio_13.wav',
#   'শালার ব্যাটারা খুব খারাপ মানুষের মানুষ বলে করে না এই কারণে সমস্যাটা হয় না যে কবার পায়নি'],
#  ['rec_13_audio_33.wav',
#   'দেশের অবস্থা খুব খারাপ যদি সরকার ঠিক না হয় সরকারের যদি অবৈধ সরকার হয় জনগণের ভোটের সরকার না হয় তাহলে তো মনে করেন'],
#  ['rec_13_audio_10.wav',
#   'মীরের এটা তো খুব খারাপ মানুষের কলিজা এত বড় দিন দুনিয়া যদি চলে তাহলে মানুষ কেমনে নিরাপদে থাকতে কন তো নিরাপত্তার কোন'],
#  ['rec_13_audio_20.wav',
#   'কবর থেকে উঠে এসে আবার দেবে এলাম পার্কে পার্কে যান না'],
#  ['rec_13_audio_0.wav',
#   'হ্যাঁ কি খবর সাইদুল ভাই ভালো ভাই দিনকাল কেমন যাইতেছে তোমার সমস্যা আছে'],
#  ['rec_13_audio_1.wav',
#   'তোমার নাম তো আমি জানি তারপরও এখনো তোমার নামটা কন তো আমি আমার নাম অর্জুনের ভাবে হবো না কি নাম কি তোর নাম কইতে এতক্ষণ লাগে'],
#  ['rec_13_audio_28.wav', 'তারপরও এখন আকাশের বৃষ্টি নাই'],
#  ['rec_12_audio_3.wav',
#   'ভালো হয় কেমন হয় কয়টা করি নাই ক্লাস নেই বন্ধুদের নিয়ে এলাও না ঈদের বন্ধু দেয় নাই রোজার না দেবে'],
#  ['rec_12_audio_15.wav', 'হয় কমে কথা ফোন দেয় না'],
#  ['rec_13_audio_2.wav', 'আমার নাম সাঈদ সাঈদ বয়স কত তোমার দেখি তো মনে হয় না'],
#  ['rec_13_audio_30.wav',
#   'তাহলে ইন্ডিয়া ঘটনা গুলো দিয়ে দিন চলে যায় তোমরা দেখবে ওই যে লোকটা যে মারা গেল'],
#  ['rec_13_audio_18.wav',
#   'এই কবর থেকে উঠে এসে ভোট দিয়ে আজকে নৌকা মার্কা বলতে পারবে না'],
#  ['rec_12_audio_6.wav', 'আইসে কম পরে গিয়েছিলাম'],
#  ['rec_13_audio_16.wav',
#   'আমার বলে ভোর হয়ে গেছে পর মারা গেছে তাই হুম তাই তাই আসি কবর থেকে উঠিয়ে ভোট'],
#  ['rec_12_audio_4.wav', 'দেরি আছে রোজা মাসে কি ক্লাস চলবে না'],
#  ['rec_13_audio_15.wav',
#   'ভোট দিবার গিয়েছিলাম আমি ভোট দিবার পাই নেই খরচ করে আসলাম'],
#  ['rec_13_audio_11.wav', 'প্রসেসে নাই ভাই মনে করেন'],
#  ['rec_12_audio_14.wav', 'রোজার সময়'],
#  ['rec_13_audio_21.wav',
#   'পার্কে যাই মাঝে মাঝে ফিরলে ভালো লাগেনা খুব খারাপ এই কারণে জানিনা'],
#  ['rec_12_audio_13.wav', 'নামাজ পড়া লাগবে'],
#  ['rec_12_audio_18.wav', 'এটা কি করবেন'],
#  ['rec_13_audio_29.wav', 'এই কারণে দাম বেশি মানুষ পানির সংকেত'],
#  ['rec_13_audio_19.wav', 'সঠিকভাবে তাহলে দেখি শুনি দেখি শুনিয়া ভোট দেবো'],
#  ['rec_13_audio_26.wav',
#   'পাবলা খ্রিস্টান এর দাম বাড়তি 11 12 বছর 50 টাকা বৃষ্টি'],
#  ['rec_13_audio_31.wav',
#   'ও না ভাই মোবাইলে ফোন দিয়েছিলেন ভাই ওইটা দেখলে আমি সুরত থাকাতে একটা দেখছি বোল্ডারের ভারত'],
#  ['rec_12_audio_2.wav',
#   'তুই এখন কোন ক্লাসে পড়িস রে ক্লাস নিমি লেখাপড়া কেমন হইতেছে স্কুল'],
#  ['rec_12_audio_12.wav', 'হবা পারি না'],
#  ['rec_12_audio_9.wav', 'কেরালা সময় নেই কোচিং পড়ে তো করিস না কয়টা'],
#  ['rec_12_audio_16.wav', 'পা'],
#  ['rec_12_audio_17.wav', 'রাসেল পাঠায় দিবেন'],
#  ['rec_13_audio_23.wav', 'আমি বাড়ির কাছে তো ওই জন্য যাওয়া হয় না'],
#  ['rec_13_audio_32.wav',
#   'এদল চোটে মানুষ মারছে আর আজকে একটা দেখলাম এইভাবে যদি চলতে থাকে'],
#  ['rec_13_audio_17.wav',
#   'এই কারণে আমার ঝড় হয়ে গেছে তাই নাকি এটা কোন মার্কার দেওয়া হয়েছে'],
#  ['rec_13_audio_14.wav',
#   'দিন-দুনিয়া যেভাবে খারাপ হয়ে যাবে আছে সরকার তো এগুলো নিয়ে কিছু কইও না সরকার হলে কি নিয়ে কইবে সরকার হল অবৈধ সরকার'],
#  ['rec_13_audio_34.wav', 'নয় কথা সরকার দিয়ে সরকারি হোক'],
#  ['rec_12_audio_7.wav', 'নানা নানি ভালো আছে হ্যালো'],
#  ['rec_13_audio_27.wav', 'এমনি ঘুরে আসি না পানি কমছে'],
#  ['rec_13_audio_22.wav',
#   'ওর মজা লাগে দেখি তোমার মজা লাগে না আমার পাশে না এই কারণে মজা লাগে না'],
#  ['rec_13_audio_3.wav',
#   'তোমার বয়স তো কইলেন তোমরা নয় তো কি করেন তোমরা একটু সাধারণ ব্যবসা করি ভাই ব্যবসা করেন ব্যবসা করেন'],
#  ['rec_13_audio_25.wav',
#   'ম্যালেরিয়া ভিতরে এমন কিছু নাই এটা নিয়ে কাজ করছি এখন জিনিসের দাম বাড়তি'],
#  ['rec_13_audio_24.wav', 'তাড়াতাড়ি দেন'],
#  ['rec_12_audio_5.wav',
#   'তাহলে খাওয়া-দাওয়া করছিস কি দিয়ে খাওয়া দাওয়া করছেন না'],
#  ['rec_13_audio_40.wav', '<>'],
#  ['rec_14_audio_1.wav',
#   'তাইলে বিড়ি তোমার তো নামকরা জানো তোমার নাম কি তোমার নাম মমতা দাদা ভালোই চলবে না ভালো'],
#  ['rec_14_audio_30.wav',
#   'আমরা তো জানি হুজুর মানুষ ভালো ব্যবহার বিধি ভালো আমি তোমার মার থেকে শুনবো'],
#  ['rec_13_audio_37.wav',
#   'প্রশাসন ছাড়া মাদ্রাসা কতদূর কি করে না অবস্থা খুব খারাপ আছে'],
#  ['rec_14_audio_11.wav', 'জুলাই এখন তোমার জামাই ভালো আছেন'],
#  ['rec_13_audio_39.wav', 'ইয়ার সাথে আছে যোগাযোগ হয়নি আনারুল আনারুল হোসেন'],
#  ['rec_14_audio_28.wav',
#   'সবাই যদি সমান হয় তাহলে কেউ গরীব ও থাকতে না কেউ ধনী হতে যদি না থাকতো তাহলে কি কারো মূল্য থাকতো কেউ কাউকে দাম দিত না ওই জন্য তো আল্লাহ হিসাবে মানুষ'],
#  ['rec_14_audio_32.wav', 'না একটা শহরে পারিনা'],
#  ['rec_14_audio_12.wav', 'খাওয়া-দাওয়া করছেন'],
#  ['rec_14_audio_10.wav', '<>'],
#  ['rec_14_audio_27.wav',
#   'হাসিটা ওইটাই ভালো আরকি মানুষের সাথে মানুষের ব্যবহার ভালো বিধি ভালো করলেই ভালো আর যত খারাপ ব্যবহার করবে তত খারাপ ব্যবহার করবেন কি সমান হয়'],
#  ['rec_14_audio_22.wav', 'এলার্জি তোমার ভাই দূরে কোটা আলা মোস্তফা'],
#  ['rec_14_audio_23.wav', 'আসে লেখাপড়ার সাপ বাইরে থেকে যায় না কার সাথে করবো'],
#  ['rec_13_audio_7.wav',
#   'দাড়ি চুল পাকিয়ে গেলে কি হবে বয়স তো কম বয়স কম করলে মানুষের হিসাবটা বাদ তুই জানিস না খেলা হয়েছে আজকে যে একটা ঘটনা'],
#  ['rec_14_audio_24.wav',
#   'বাড়িটা জানি কোন জাগাত আছে নাই তাহলে ভালোভাবে থাকবে নাকি জামাই যেহেতু ভালোবেসে'],
#  ['rec_14_audio_19.wav',
#   'ইন্ডিয়া মানে কেউ শান্তি পায় না মানুষ বাজার করবে গেলে আগত 100 টাকার বাজার'],
#  ['rec_14_audio_2.wav',
#   'তারপর তোমার শৈশবকাল কেমন কাটছে কি সমাচার কন তো আমরা তো এলাকার মানুষ হলে বুঝি না এখন আগের মানুষ বলে কত সুন্দর শৈশবকাল কাটাইছে কি সমাচার আমরা যখন ছোট ছিলাম তখন তো এরকম দিন দুনিয়া ছিল না খুব ভালো ছিল'],
#  ['rec_14_audio_29.wav', 'মানুষ মাত্র'],
#  ['rec_14_audio_18.wav',
#   'আর এখন 2 লাখ টাকা তো হয়না আর আমরা যখন লেখাপড়া করছিলাম তখন পাকশি কাগজের বিস্তার ছিল 6 টাকা আর একটা ছিল 12 টাকা কর্ণফুলী টাই ছিল 12 টাকা সে কর্ণফুলী কাগজের খবর আছে সব জিনিসের দাম'],
#  ['rec_13_audio_42.wav',
#   'শালা ইন ক্যামেরাটা ব্যবহারের কথা আছে কর সেটা হলো টাকা দিয়ে টাকা ইনকাম করা বুঝেন নাই'],
#  ['rec_13_audio_43.wav', '<>'],
#  ['rec_13_audio_9.wav', 'কত কেউ নেই'],
#  ['rec_13_audio_4.wav', 'ভালো খাবার না'],
#  ['rec_14_audio_17.wav',
#   'আর ছাত্রজীবন হচ্ছে সুখের জীবন আর সে জীবন কি আর ফিরে পাবো বাবা এখন তোমরা চলাফেরা করতেছ তোমরা বুঝতে পাওনা যে দিনকাল কেমন আর কিভাবে চলতে হবে এখন আগে লেখাপড়া করতে বাচ্চাকাচ্চা একটা এসএসসি পাস করাতে 1 লাখ টাকা তে পার হয়ে গেছিল'],
#  ['rec_13_audio_45.wav', 'অল্প কিছু ঠিকানা আগে থেকে বাসে যা'],
#  ['rec_13_audio_41.wav',
#   'ও ভালো কথা তোমার সাথে একটা কথা আছে না কথা আছে কোম্পানির বিষয়ে'],
#  ['rec_14_audio_21.wav',
#   'আর একটা যে আগে দুই থেকে আমি আইসক্রিম সেই আইসক্রিম এখন 20 টাকা পাঁচ টাকা তাও আগের মতো মজা নাই এখন বেড়াতে কি আইসক্রিম মেরেছে তা তো আগের মতো মজা নাই আগের মত কি মজা ফিরে আসবে বাবা'],
#  ['rec_14_audio_20.wav',
#   'উভয় জানি 500 টাকা নিয়ে গেল ব্যাগ বুঝি অভাব নাই এক টাকা দুই টাকা না তাও নেই আমরা আইসক্রিম খাইছিলাম আলু এক কেজি 2 কেজি দিয়ে দুইটা আইসক্রিম কিনে খাই'],
#  ['rec_14_audio_13.wav',
#   'ডিম ভাজি আলু ভাজি মাছ আলু বেগুনের ঝোল মোটামুটি শৈশবকাল কোন ভালোই কাটছে মনে করো আমরা ধান ধানের আটি আবার'],
#  ['rec_13_audio_6.wav', 'করবে না কর্ম লাও সেই দিনও হয়নি'],
#  ['rec_14_audio_26.wav',
#   'আর বাপের বাড়ির লোকে কে কাছে পায় নি তার শ্বশুর-শাশুড়ি আমার তবুও আমি অবহেলা করি না আমার বাবার বাড়ি শ্বশুরবাড়ি শ্বশুরবাড়ি'],
#  ['rec_14_audio_16.wav',
#   'এখন আবাদ করে সবকিছু তোমার বাড়ির যে সামনে যে নদী আছে এই নদী মাস্টার্স ঝরেনা ধরছিলাম আগে যে আনন্দ উল্লাসে চল'],
#  ['rec_14_audio_3.wav',
#   'আগে কত গলায় চোর দাড়িয়াবান্ধা নদীতে মাছ মারা খেলাধুলা পুটি মালায় খেলা কত খেলছি কিন্তু আগের দিনের ভাই ভালো ছিল এখন তো আর নাই বাবা আগের মত আর নাই এখন'],
#  ['rec_14_audio_14.wav', 'অনেক সময়'],
#  ['rec_14_audio_0.wav', 'কেমন আছেন আমি তো কোনো সমস্যা নাই'],
#  ['rec_13_audio_8.wav',
#   'কলাবাড়ি কলাবাড়ী যে মানসিক মারি ফালাইলো এখন ইটের ঘটনা যা দেখলাম দেখি কলাবাড়ী লাশ পড়িয়ে আছে মানুষজন মানুষ আছে'],
#  ['rec_14_audio_25.wav',
#   'জামার সাথে ব্যবহার বিধি শশুর-শাশুড়ি আসে না সবাই ভালো আছে আলহামদুলিল্লাহ অসুস্থ ছিলাম ও সময় আমি আমার'],
#  ['rec_13_audio_38.wav', 'কান্দা'],
#  ['rec_13_audio_44.wav',
#   'ওইটাকে না কেনা ছাড়া একটা জিনিস কিনবেন কিনা সব শেষ হয়ে গেছে'],
#  ['rec_14_audio_31.wav', 'কে কি কইলো দেখি'],
#  ['rec_13_audio_36.wav',
#   'সারাদিন ঘুমিয়ে মিথ্যে স্বপ্ন দেখি রাইদা করিয়া স্বপ্ন দেখবি আর দোষ আছে হলো কি প্রশাসন হাত করি নেওয়া'],
#  ['rec_13_audio_5.wav',
#   'হইবে ভবিষ্যতে ভালো হবে সমস্যা কি ব্যবসা তো নিয়মে ওটা যে কয়দিন ভালো কয়দিন খারাপ তাই যে বিয়ে শাদী করছেন'],
#  ['rec_14_audio_15.wav',
#   'এখন তো বাবা হয়েছে ধান কাটিয়েছে গরু জব আছে তাও এখন নাকি মেশিনে সফল কাটে ঘাস আবাদ করা না সব পাষাণ দিয়ে তুলছিল নদীর'],
#  ['rec_13_audio_35.wav', 'সকালে মিথ্যা কথা দুপুরে মিথ্যা কথা রাতে মিথ্যা কথা'],
#  ['rec_15_audio_2.wav',
#   'সরকার থাকিয়া অভাব দাদা টাকা-পয়সা নাই একটা ওঝা সামনে কেমন করে করি না করি খুব কষ্ট লাগছে'],
#  ['rec_15_audio_28.wav',
#   'এই সরকার আসিয়া গানটা ক্ষতি মানুষের সেই ক্ষতি এই সরকার রাশিয়া খালি কালো বাজারে অন্য একটা হিসাব নিকাশ নেয় না'],
#  ['rec_15_audio_10.wav',
#   'অশূন্য যে সরকার বলে কি খেতে বেশি না কোনো নামটা আমি কিছু দেয় নাই একটা'],
#  ['rec_15_audio_1.wav', 'তোমার নাম তো জানো আমার নামটা একটা কোন'],
#  ['rec_14_audio_9.wav', 'অশনি সুস্থতা আর এখনকার জীবনে কত সুন্দর গল্প করছে'],
#  ['rec_14_audio_5.wav',
#   'এখন মনে করো সার্চ ছাড়া কিছুই নেই আছে একটা জিনিস সার্চ ছাড়া কিছুই হয় না চালের ভাত আউশ ধান গমের রুটি আবার হচ্ছে খুদির ভাত'],
#  ['rec_15_audio_25.wav',
#   'একটা কাঠের দাম 12 টাকা সেটা একটা গেল সোয়াবিন তেল এক সপ্তাহ 100 টাকা 27200 হিসাব কর বুট যদি কিনবা যায় যে বইটা ছিল 60 টাকা 70 টা সে ভুট নাই'],
#  ['rec_15_audio_30.wav',
#   'তত্ত্বাবধান টা যদি করিল হয় কার কি অবস্থা দিন দিন কয় কি দোকানদারেরা সকাল-বিকালের আলাপ কর এইদিকে একটা ওষুধ কিনবে'],
#  ['rec_15_audio_19.wav',
#   'দেখো কার কি অবস্থা কার কি অবস্থা আছে অশোক কল করো কাঠের মাল'],
#  ['rec_14_audio_34.wav', 'তাহলে একদিন যাবেন'],
#  ['rec_15_audio_33.wav',
#   'সিন্ডিকেট কালো বাঁশি বাজানো এই সরকার যদি কইলে হয় এ অমুক তমুক এর দাম কেন বারিলে এই যে আমার কি মন্ত্রী টিভি মন্ত্রীর নাম কি বাণিজ্যমন্ত্রী বাচ্চা বলে'],
#  ['rec_15_audio_34.wav',
#   'এই কি খোঁজ খবর টা নিবেন মন্ত্রী হয়েছে এই কি খোজ খবর নিবেন না দিপু মনি যে কয়দিন'],
#  ['rec_15_audio_29.wav',
#   'বলে এই জিনিসটা দাম কম করো করে জনগণের সর্বসাধারণের জন্য দেখা লাগবে কি অবস্থা দিনকাল খেটে খাওয়া মানুষ গুলোর অবস্থা'],
#  ['rec_15_audio_12.wav', 'মেম্বার কারণে'],
#  ['rec_14_audio_35.wav',
#   'আলহামদুলিল্লাহ ভালো আছে সবাই ভালো আছে মনীষা করে থাকে না জীবনকাল মোটামুটি ভালই চলছে'],
#  ['rec_15_audio_16.wav', 'আমায় সব বলি বুঝলে বাবু এই যে ঔষধের দাম সারের দাম'],
#  ['rec_15_audio_0.wav', 'ইউসা আলম ভাই কেমন আছেন আসিফ ভাইরে ভালো আছি'],
#  ['rec_15_audio_32.wav',
#   'মরিচ লবণ কত এত তেল কত এত সকাল বিকালের আলাপ কর সকালে একদম যাওয়ার পরে বিকেল এক্সাম যাওয়ার পরে আমি কি বুঝেছি'],
#  ['rec_15_audio_31.wav',
#   'শেফালী সেবা নাম ধরে কও সকাল বিকালের আলাপ করে ওষুধ কিনবে না কিনলে নাই'],
#  ['rec_14_audio_6.wav',
#   'বানেশ্বর তড়িৎ তরকারি আবাদ করার শাক সবজি আলু বেগুন টমেটো যত কিছু সব গোবর সার দিয়েই তৈরি হয়েছিল জৈব সারের মাধ্যমে সব কিছু আবাদ হয়েছিল কিন্তু এখন বাবা সবকিছু হচ্ছে রাসায়নিক সারের উপর নির্ভর সবগুলো মেডিসিন যুক্ত'],
#  ['rec_15_audio_21.wav',
#   'বাঁড়া বকুল চাচা কোথায় একটা হাজার টাকা খরচ করে এই যে ওজার খরচটা করি এই খরচটা করার জন্য 1000 টাকা খুজবেন না'],
#  ['rec_15_audio_23.wav', 'আনিক নাজির বউটার মনে করছে'],
#  ['rec_15_audio_39.wav',
#   'মানুষ সামনে ওজা এই যে জিনিস দিয়ে দেন কোন জিনিসের দাম কম'],
#  ['rec_15_audio_27.wav',
#   'আরে সুখে আছি দোকানদারের বউ গুলা এখন মনে করেন এ 50 টাকা দিয়ে চাল কিনে কতদিন'],
#  ['rec_15_audio_20.wav',
#   'বয়স্ক ভাতা পায় বিধবা ভাতা পায় সবে তাই আজ আমি পাই না বুঝিস না বিশ্বাস কর তুই আজকে পাঁচ দিন থেকে 1000 টাকার জন্য'],
#  ['rec_15_audio_13.wav',
#   'নাগো যায় ইপা ছেড়ে হামারে কিছু দেয় দেখ কিছু সরকারে সরকার আইসে থেকে কেমনে'],
#  ['rec_15_audio_36.wav',
#   'এটা খায় খালি করে দাম কত বাড়ান কিন্তু মুখ টাকা দেওয়া লাগবে'],
#  ['rec_15_audio_3.wav',
#   'জমিজমা আবাদ করি সাদ্দি বারবার না ঔষধ দিয়ে ভাত না গরিব মানুষ এদিকে করি ভাইরে আমার তো অবস্থা খুব খারাপ টাকা পয়সা'],
#  ['rec_14_audio_4.wav',
#   'ডিজে ফেসবুক লেখাপড়ার চাপ বেশি মানে খেলার দিন দুনিয়া ভালো না সব থেকে তোলা লাগে না অনেক সুখি আছি অনেক পুষ্টিকর খাদ্য ও খাইছে আর আমরা তো এরা মনে করে পুষ্টিকর খাদ্য ওইরকম'],
#  ['rec_15_audio_22.wav', 'হানিফ উদ্দিন আছে নাই'],
#  ['rec_14_audio_36.wav',
#   'এখন সামনের দিনগুলো আসবে লাগছে খুব ভয়াবহ দিন নাই এই দিনগুলো পার করা লাগবে ভালো থাকেনা'],
#  ['rec_14_audio_8.wav',
#   'ধানের বোঝার মাথায় এসেছিল মার্চ মাস ছিল কাজ কাম করছিল তাদের জীবনটাই ভালো ছিল না হাটাহাটি করবেন চাইলে শরীর ভালো'],
#  ['rec_15_audio_15.wav', 'মুই খুব কষ্টতে দিন কাটানোর সময় বিশ্বাস করুন'],
#  ['rec_15_audio_14.wav',
#   'দালাল খিদে তোমরা দালালি করে বাঙালি কষ্ট বিশ্বাস কর ভাই তুই এটা রেকর্ড করার জায়গার'],
#  ['rec_15_audio_17.wav', '<>'],
#  ['rec_15_audio_37.wav',
#   'ভাই এখন পাক ভাল করব না সমস্যা নেই সরকারি জানবে কেমনে তোর এই কথা তুই কথা তোর মনের বই'],
#  ['rec_14_audio_7.wav',
#   'ক্রান্তি সবকিছু মনে করো এর মধ্যে সবগুলো রোগব্যাধি হয় মানুষের যত কিছু সবকিছু আগের মায়েরা সবকিছু ঢেঁকিতে বান ছিল'],
#  ['rec_15_audio_24.wav',
#   'মানুষের এখন 30 টাকা এক পোয়া মাছের দাম 30 টাকা তোর একসার যে লবণ আছে 6 টাকা কেজি সেই লবণ লাগাইছে 12 টাকা'],
#  ['rec_14_audio_33.wav', 'ডিজিটাল বাংলাদেশ'],
#  ['rec_15_audio_38.wav',
#   'তোর মনের আবেগ তোর মনের ভালোবাসা তোর মনের যে দুঃখ বেদনা প্রকাশ ঘটাইছিস না তুই তো অন্য অন্য কথা নয় বুঝিসনি কোন সমস্যা নাই'],
#  ['rec_15_audio_18.wav',
#   'আমি কি করি ভাই সরকার নয় ভালো সরকার যদি ভাল হইল হয় শাসন করি নাই গরিব দেখি দেখি এই মাল গুলা দাও চেয়ারম্যানের উপরে তাগিদ দিলে পুলিশ'],
#  ['rec_15_audio_35.wav',
#   'এই কদিন 5 বছর মানুষ শান্তিতে দিন কাটাইছে কোন একটা জিনিসের দাম বাড়ে নাই পেন্সিল বরঞ্চ আর এই আসিয়া ব্যবসার খাতিরে বুঝছিস এর ব্যবসার কাজে ইনকাম করছে'],
#  ['rec_15_audio_26.wav',
#   'গুড না খেললে ইফতারি করব চিনির কেজি কত আছে তুই কত দাম নেই'],
#  ['rec_15_audio_11.wav',
#   'কোন বয়স্ক ভাতার নাম পাইনাই একটা টিস লিভের নাম পাই না একটা কার্ডের নাম পাই না মেম্বারের কাছে লেখা চেয়ারম্যানের কাছে মেম্বারের কাছে যাও'],
#  ['rec_16_audio_26.wav', 'সেটাই তো ঠিক অন আসে না'],
#  ['rec_16_audio_30.wav', '63000 তাপমাত্রা'],
#  ['rec_15_audio_4.wav', 'কৃষ্ণ সরকার ও কিছু দেয় না'],
#  ['rec_16_audio_3.wav',
#   'এলাকার কাটে না করছি ইউটিউব কিসের বলে মোবাইল দিয়ে বলে গেম খেলা'],
#  ['rec_16_audio_2.wav',
#   'ভাত খাইছেন কি দিয়ে আজকে ভাত খাইছি হইতেছে বয়লার আর কালের ডাল তোমার শৈশব কাল কেমন কাটছে আমি তো ভালোই কাটছিল দিন'],
#  ['rec_16_audio_28.wav', '<>'],
#  ['rec_16_audio_0.wav',
#   'ভাই কেমন আছেন আছো ভালোই তোমার নাম তুমি জানো তোমার নামটা কি আমার নাম মোঃ হেলাল খান ওর বয়স কত ছিল'],
#  ['rec_16_audio_12.wav', '<>'],
#  ['rec_16_audio_11.wav', '<>'],
#  ['rec_16_audio_29.wav', 'কি কারনে'],
#  ['rec_16_audio_17.wav', '<>'],
#  ['rec_16_audio_25.wav', '<>'],
#  ['rec_16_audio_16.wav',
#   'আর আমি তো সেটাও পাইনি আজকে ভর্তা দিয়ে ভাত খেয়েছি সব জিনিসের দাম 500 টাকা নিয়েছে বাজারে খরচ'],
#  ['rec_16_audio_18.wav',
#   'যে ব্যবসাটা করতেছি সেটা বাকি ব্যবসা করিয়া কত কিলোমিটার'],
#  ['rec_16_audio_32.wav', 'গাড়ি কি চালাইবেন'],
#  ['rec_16_audio_13.wav', '<>'],
#  ['rec_15_audio_8.wav', 'এখন 10-12 জন কত পড়া কি নাই'],
#  ['rec_15_audio_42.wav',
#   'কিভাবে বাঁচব সেইটা আর কি গরিব মানুষ বাঁচার কোন নীল পথ আছে গল্প করবো আবার হ্যাঁ'],
#  ['rec_16_audio_10.wav', 'আপনার কি খবর'],
#  ['rec_16_audio_34.wav', 'তেলের দামটা বাড়ছে এ তেলের দাম মুভিস'],
#  ['rec_15_audio_5.wav', 'আর কি করবি খাইছেন'],
#  ['rec_15_audio_9.wav', 'এখন যে একটা মজা আসবে'],
#  ['rec_16_audio_24.wav', 'শালার বেটি খুব খারাপ গ্রামে আন্দোলন হয় নাই'],
#  ['rec_16_audio_23.wav', 'নির্বাচন করে'],
#  ['rec_16_audio_31.wav', '<>'],
#  ['rec_16_audio_21.wav', '<>'],
#  ['rec_16_audio_37.wav',
#   'জান যেটা কয় সেটার দাম যত কইবা তো আমরা কিছু জানিনা জানিনা'],
#  ['rec_15_audio_6.wav',
#   '600 টাকা 700 টাকা কি খাবো কি দিয়ে রোজা করবো রোজা থাকে না কিছু নাই টাকা পয়সা কিছুই নাই'],
#  ['rec_16_audio_39.wav',
#   'হইবে কাম হইবে কাম হইবে কামার পকেট তাজা করে কিছুই নেই'],
#  ['rec_16_audio_35.wav', '<>'],
#  ['rec_16_audio_33.wav',
#   'পেঁয়াজের দাম হলো সারাদিনে আমার কাজ করেছে টাকায় থাকে'],
#  ['rec_16_audio_1.wav', 'দিনকাল কোন চলছে ভালো হয় দিনকাল যাচ্ছে না'],
#  ['rec_16_audio_27.wav', 'লটারি রেজাল্ট'],
#  ['rec_16_audio_14.wav', 'কালের কোনো একটি জায়গা নেই'],
#  ['rec_16_audio_36.wav', 'তখনও কি পড়ে যায় তোমার সোনা আর আমি যদি জানিনা'],
#  ['rec_16_audio_19.wav',
#   'এই সরকারের আমলে হবে না আমার জন্য খুবই খারাপ বাংলাদেশের'],
#  ['rec_16_audio_15.wav',
#   'এখন মানুষের কি অবস্থা হবে মানুষের সামনে যে আরো তুমি আজকে কি দিয়ে ভাত খাইছি'],
#  ['rec_16_audio_20.wav', 'আমি সেটা হয়নি'],
#  ['rec_15_audio_40.wav',
#   'প বলে এই জিনিসটার দাম কমছে এবং এই জিনিসটার দাম হালিম মাত্র বাংলাদেশের মধ্যে এখন শাকসবজি যেখানে দাম কম আর পানি আর পানি পানি'],
#  ['rec_15_audio_41.wav',
#   'এখন পানিটা ছাড়া সবগুলো রে তোর কি না বকে 50 টাকা 60 টাকা 70 থেকে 80 টাকা কেজি বিক্রি হয় গরিব মানুষ কিভাবে আমরা বাস'],
#  ['rec_16_audio_4.wav', 'তখন মজা হয়েছে'],
#  ['rec_15_audio_7.wav',
#   'খুব দিনকাল কঠিন অবস্থা খারাপ এই সেই খারাপ নয় সবারই একই অবস্থা সবার'],
#  ['rec_16_audio_22.wav', 'আমি ভোট দিতে পারিনা'],
#  ['rec_16_audio_38.wav',
#   'এলাকার রাস্তা খুব খারাপ ভাই এই যে কাঁদো ভাঙিয়ে যেন পাকা করে নাই'],
#  ['rec_16_audio_58.wav',
#   'ধরছিলাম ধরিয়া এবং কি কয় ভাই হইবে হইবে না এবার এই যে রেশন কার্ডের জন্য একটা হোস্টেলের নাম তার জন্য গিয়েছিলাম'],
#  ['rec_16_audio_80.wav',
#   'মানুষের বোঝা লাগবে যে আসলে বিয়ে করছো বিয়ে বউ শ্বশুর বাড়িতে থাকবে'],
#  ['rec_16_audio_53.wav',
#   'ভাই ভালো কি মন্দ এখন বিয়ে-শাদী যদি করা লাগবে এখন আপনি পাওয়ার পারেনি করব'],
#  ['rec_16_audio_73.wav',
#   'এখন মনে করে চলার গতিতে খারাপ দেখি তো চেহারা মাঝে দেখি কিভাবে করে থাকবে'],
#  ['rec_16_audio_6.wav', 'গরু নাই গরুর লস খাই খালি যে খাদ্যের দাম পড়বে না'],
#  ['rec_16_audio_48.wav',
#   'নাশু দিয়েছিলেন না বন্ধ করে থাকে তাহলে তো তোমার আরো শরীরের ক্ষতি হয়ে যাবে'],
#  ['rec_16_audio_77.wav',
#   'করে নাই তো এখন যদি তা কিছু ফেলে দেন তাহলে এটা আল্লাহর আরশ পর্যন্ত গাভী উঠবে আল্লাহ কিন্তু এগুলো সহ্য করবেন না তোমার রুজি রোজগারে বরকত খাবার নাই বিয়ে করেছে বউ নিয়ে যাবা'],
#  ['rec_16_audio_67.wav', 'বাচ্চাকাচ্চা নিছেন'],
#  ['rec_16_audio_46.wav', 'কিছু করি না জীবনে'],
#  ['rec_16_audio_41.wav',
#   'দেশের পরিস্থিতি খুব খারাপ দেশের অবস্থা খুব খারাপ হয়ে যাবে'],
#  ['rec_16_audio_8.wav', 'হেলা দিবার পাওনা'],
#  ['rec_16_audio_45.wav', 'আমি থাকি'],
#  ['rec_16_audio_71.wav', '<>'],
#  ['rec_16_audio_76.wav', 'খুব কষ্ট নিয়ে'],
#  ['rec_16_audio_74.wav', 'ঠিক আছে তোমাকে বিয়ে করা অনলাইন'],
#  ['rec_16_audio_52.wav',
#   'ঘোড়ার বিশ্বাস করার অবিশ্বাসের কি আছে মৃত মানুষের কি অবস্থা বেতন কত অবস্থা কি তার ভাইয়ের কি এটা আমি দেখলেই কপার ঠিক আছে আমি তো আগে করিনি'],
#  ['rec_16_audio_59.wav', 'ঘুষ ছাড়া কোন কাজ নেই'],
#  ['rec_16_audio_78.wav', 'বউ নিয়ে যাবে আর আজ আমাদের খবর রাখছে'],
#  ['rec_16_audio_75.wav',
#   'খুব ভালোই আছে না ব্যবহার বিধি ভালো শ্বশুর-শাশুড়ি ভালো আছে ভাই ভালো আছি'],
#  ['rec_16_audio_56.wav',
#   'চেয়ারম্যান মেম্বার টাকা দিয়ে খেলিয়ে তো মেশিন মনে করো এই জিনিসগুলো নেওয়া লাগে তাকে মনে করো কাম দেয়'],
#  ['rec_16_audio_70.wav',
#   'না না ওর জামাই থাকলে কি হবে ঘর জামাই কি থাকে না মানুষ তাহলে আবার তোমরা কি আর হয়েছে তোমার তোমার যে অবস্থা সেই হিসেবে তোমার ঘর জামাই থাকাটাই ভালো হইবে মুড়ি খাবে'],
#  ['rec_16_audio_44.wav', 'উপায় কি'],
#  ['rec_16_audio_69.wav', '<>'],
#  ['rec_16_audio_72.wav',
#   'চিংড়ির বাপ মায়ের সাথে একবার কথা কম দেখো খারাপ না চেহারা ভালো হয়েছে খারাপ না হইবে সালাম দিলে মনে হয় মোর মনে হয় ওই বেবি চেহারা ভালো আছে কিন্তু'],
#  ['rec_16_audio_61.wav', 'জোরে হয়েছে এমনিতে ভালো আছেন'],
#  ['rec_16_audio_55.wav',
#   'ক্রেজি ওরকম দেয় না সেটা তো ভাই দেয় সেটা ঠিক আছে সেটা তো সবারই হয় টাকা আগে'],
#  ['rec_16_audio_79.wav', '<>'],
#  ['rec_16_audio_54.wav', 'কিছু ডিবি ডিবি নিয়ে আসবো টাকা টুকা চায় না'],
#  ['rec_16_audio_42.wav', 'আমার বিশাল খারাপ'],
#  ['rec_16_audio_66.wav', '<>'],
#  ['rec_16_audio_82.wav',
#   'শালা নিজেকে একলা একলাই করা লাগবে যেটা কি কামটা ভালো হয়েছে ভালো থাকেন'],
#  ['rec_16_audio_43.wav',
#   'আমার ভাই ওরা জানেন না আমি দিন আনি দিন খাই আমাদের থাকমু যা সেটাও নেই খুব কষ্টে আছি'],
#  ['rec_16_audio_47.wav', 'কাজে জমির দাম কষ্ট করে থাকবেন'],
#  ['rec_16_audio_51.wav',
#   'পিভিআর এর প্রথম চাকচিক্য ভিতরের অবস্থা তো মানুষ বোঝে না যে আসলে ভিতরে কি অবস্থা তার আপনি আসি দেখি আমার বিশ্বাস করেন আপনি বন্ধু মানুষ আপনাকে আমি সঠিক কথাটা বললাম আমার জমা জমির নাই'],
#  ['rec_16_audio_57.wav', 'ধরছিলাম'],
#  ['rec_16_audio_68.wav',
#   'সেটা তো আমার নয় ভাই এটা হলো মনে করো তোমরা যে কালে কোশ্চেন সে 400 জন মাটির দাম কম ছিল এখন তো অনেক দাম আমি এখন মনে করো আমার 3 লাখ টাকা চলে গেছে'],
#  ['rec_16_audio_40.wav',
#   'আমরা কি উন্নয়নে কি করবে আমার পকেটটা যা যা মানুষ মানুষের মনুষত্ব নাই মানুষের মনুষ্যত্ব গুলো মানুষ ঠিক থাকে না তাহলে দেশ অনেক'],
#  ['rec_17_audio_1.wav', '<>'],
#  ['rec_16_audio_81.wav',
#   'নতুন বউটা জাবার দেওয়া লাগবে এটা যদি তোমরা এরকম জোকস দেখান খবরদারি করেন তাই নাকি তাহলে অডিও মানবেন না কত সুন্দর কাপড়-চোপড় ধুয়ে দিবে'],
#  ['rec_16_audio_7.wav',
#   'মনে করো আগে তোমার 100 টাকা নিয়ে বাজারে গেলে ব্যাগ বোঝাই হয়ে গেছিলাম চলে যায় আর ও তো সুনু পাউডার কত কি আছে নিব'],
#  ['rec_16_audio_65.wav',
#   '200 2 লাখ 80 হাজার টাকা আমার ঠ্যাং এর পাসওয়ার্ড দিয়েছে এক্সিডেন্ট করুন তখন ওই বাড়ি ভিডিওটা পাবে বিগেস্ট দেখিয়ে এখন আমি মনে করব'],
#  ['rec_16_audio_50.wav', 'সুন্দর'],
#  ['rec_16_audio_63.wav',
#   'খুব কষ্টে আছি ভাই আমার জীবনটা শুরু থেকে কষ্ট এ পর্যন্ত কষ্টই চলতেছে আলাদা বাড়ি একটাই খাই'],
#  ['rec_16_audio_9.wav', 'মাছেরও দাম মেলা দিবেন না'],
#  ['rec_16_audio_62.wav', '<>'],
#  ['rec_16_audio_64.wav',
#   'আমার জন্য মনে করো আমি এক্সিডেন্ট করছিলাম পড়াতে তারও কষ্ট দিয়ে আমার মনে হয় আমার বাসা তো লাগবে'],
#  ['rec_16_audio_60.wav', 'টাকা দিয়ে হয়েছে এখন গু ছাড়া'],
#  ['rec_16_audio_5.wav',
#   'আর এখন চিংড়ির সাথে কথা কইলে খালি মাইন্ড করে কি হয়েছে'],
#  ['rec_16_audio_49.wav',
#   'আমাকে দেখতে শুনতে খুবই ভালো আমার যে মনের কত কষ্ট আছে সেটা তো কেউ জানে না কাকে জানাবো জানার দরকার পরলে মনে করো নিজেকে শরম নাই'],
#  ['rec_17_audio_0.wav', 'আমার নাম তো জানি আমি আর আপনার কথা কিছু রেকর্ড করব'],
#  ['rec_18_audio_30.wav', 'বাংলাদেশের পরিস্থিতি ভালো না'],
#  ['rec_17_audio_7.wav', '300 টাকা এক কেজি সরিষার তেল পাওয়া যায় না'],
#  ['rec_18_audio_19.wav', 'ছেলেও ভালো অবস্থা ভালো আছেন'],
#  ['rec_18_audio_1.wav',
#   'এটা আর কি তোমার নামটা কন তো আপনার নামটা কি আমার নাম বিমল শর্মা বয়স কত ছেলে তোর ভাইজি বেটি বিয়ের সম্বন্ধে এখন বিয়া'],
#  ['rec_17_audio_5.wav', '<>'],
#  ['rec_17_audio_6.wav', 'বর্ষার আসবে না'],
#  ['rec_17_audio_11.wav',
#   'তুমি এখন ভাড়া দিয়ে লাভ হল কি ঘুসি খায় পুলিশ ঠিক করলো'],
#  ['rec_17_audio_16.wav', '<>'],
#  ['rec_18_audio_12.wav', 'ভালো হবে'],
#  ['rec_18_audio_32.wav',
#   'এমন একটা জিনিস তোমার খাসির মাংসের দাম কত তোমার তো খাসির মাংস খাসির মাংসের দাম বেশি 1000 টাকা 900 টাকা আছে'],
#  ['rec_17_audio_19.wav', 'সেটা সরকার চোখে ধরে না'],
#  ['rec_18_audio_11.wav', '<>'],
#  ['rec_17_audio_18.wav', 'বৃষ্টিতে বসিলা সেটা কোন দোষ নাই'],
#  ['rec_18_audio_14.wav', 'সিলেটের'],
#  ['rec_18_audio_22.wav', '<>'],
#  ['rec_18_audio_31.wav',
#   'এমন একটা জিনিসের দাম নেই যে কও এই জিনিসের দাম বেশি লাগবে'],
#  ['rec_18_audio_27.wav', 'আছে ভালো সবাই ভালো আছে খাওয়া-দাওয়া করছেন'],
#  ['rec_17_audio_9.wav', '<>'],
#  ['rec_18_audio_0.wav',
#   'কলকাতা কেমন আছেন বেশি ভালো নাই তুমি জানো আর তোমার সাথে একটা গল্প কিছু করি মেঘনা একটা মোবাইলে রেকর্ড ও করিম কোন সমস্যা হবে কি আর সমস্যা নাই'],
#  ['rec_17_audio_2.wav', 'এটাও সিস্টেম আছে'],
#  ['rec_18_audio_21.wav', 'অষ্টম শ্রেণীর'],
#  ['rec_17_audio_12.wav', '<>'],
#  ['rec_18_audio_33.wav', 'বালাম উদ্দিন আলু আড়াইশো টাকা করি'],
#  ['rec_18_audio_18.wav',
#   'তাহলে এটা ভালো আর যদি বাবা গরিব মানুষ দিন আনে দিন খায় না ভালো ফ্যামিলি আছে দেখি শুনি দেওয়া হয়েছে'],
#  ['rec_18_audio_20.wav', 'এখন কাকিরা ভালো আছে সবাই কি ভালো আছেন'],
#  ['rec_17_audio_3.wav', '<>'],
#  ['rec_18_audio_24.wav',
#   'বাড়ির সবাই ভালো আছে তোমার না একটা যে মারা গেল সম্পত্তি গুলো ভালো হয়েছে'],
#  ['rec_18_audio_26.wav',
#   'নির্মলের যে বিয়ে হলে পরে যেটা ওটা কেমন চলছে সংসার ওটা ভালো চলছে ঢাকা যেতে হবে তোমার সাথে কেমন সম্পর্ক আমার বোনের সাথে'],
#  ['rec_17_audio_13.wav', 'টাকা আছে মামলা আছে টাকা নাই মামলা নেই'],
#  ['rec_18_audio_13.wav',
#   'তোমার টাকা পয়সা দিবে তাহলে এই টাকা দিয়ে তোমার ওই যে একটা টাকা দেওয়া লাগে বড় একটা এমন দেওয়া লাগেনা 3 লাখ না কত টাকা লাগবে দেওয়ালে 2 লাখ খরচ আছে স্বর্ণ বর্ণ আছে'],
#  ['rec_18_audio_2.wav',
#   'বিয়া কোন দিন কি সমাচার বিয়ে হওয়া বৈশাখে যে অবস্থা টেনশনে আছি তাই পাগলা এইগুলো নিয়ে বহু টাকার দরকার আলো 4 লাখ টাকার দরকার খুব টেনশনে আছি'],
#  ['rec_18_audio_3.wav',
#   'কুদ দিন বিয়ে-শাদী কোন দিন ডেট হল ডেট এখনো হয়নি তো করাই লাগবে কম বেশি করাই লাগবে'],
#  ['rec_18_audio_23.wav', 'এরকম'],
#  ['rec_18_audio_17.wav', 'ভালো'],
#  ['rec_18_audio_16.wav', 'বিয়ে-শাদী লালমনিরহাটে করে'],
#  ['rec_17_audio_17.wav', 'কিভাবে তাড়াতাড়ি'],
#  ['rec_18_audio_10.wav',
#   'হাসি এখন কি যে হয় টাকা পয়সার ওপর মেসেজ করবে না ভালো করে করেন তাহলে মনে করো বড় বড় লোক বলে যাবেন'],
#  ['rec_17_audio_4.wav', 'তিক্তক মুক্ত করে শরীর দুর্বল হয়ে গেছে'],
#  ['rec_17_audio_10.wav', '<>'],
#  ['rec_18_audio_15.wav', '<>'],
#  ['rec_17_audio_14.wav', '<>'],
#  ['rec_17_audio_15.wav',
#   'বিবেচনা করে না করার কারণে এই জিনিসগুলো আরো বেশি তৈরি হওয়া লাগবে'],
#  ['rec_18_audio_28.wav', 'আছি 11:00 টার দিকে গেছে দুপুরে কি খেয়েছেন'],
#  ['rec_18_audio_29.wav', 'ঢাকায় তো শর্টকাট সংসার কেমন চলছে তোমার বাংলাদেশ'],
#  ['rec_18_audio_25.wav', '<>'],
#  ['rec_17_audio_8.wav', '<>'],
#  ['rec_19_audio_25.wav', 'বৃষ্টি হইলে আরো থাকায় যাবে না'],
#  ['rec_19_audio_1.wav', 'বয়স কত সালে 25 তারিখ'],
#  ['rec_19_audio_26.wav', 'লাভ নিয়ে গেছে কিন্তু পাখিনি আর কোন খবরই নেই'],
#  ['rec_18_audio_36.wav', 'গুয়ামারা এসে 10 সালে কেউ নেই'],
#  ['rec_19_audio_20.wav', 'আমি শুধু নিজে নিজে'],
#  ['rec_19_audio_13.wav', '20 টাকা 30 টাকা তিন কিলো যাইতেছে'],
#  ['rec_19_audio_17.wav', 'নাম রাখছেন কি মুনতাহা লোকজনের নাম রহমান'],
#  ['rec_19_audio_14.wav', 'আপনি কেমন আছেন'],
#  ['rec_18_audio_6.wav',
#   'ভাই বাংলা নিয়ে টেনশনে আছি কি করে না করে আমাকে করা লাগবে'],
#  ['rec_19_audio_18.wav', 'চেঙ্গি একটা ভালোই সংসার চলছে'],
#  ['rec_19_audio_21.wav', '<>'],
#  ['rec_19_audio_0.wav',
#   'আমার মামা কেমন আছেন ভালো আছি তোমার সাথে একটা গল্প কিছু করি তাতে কোনো সমস্যা নেই'],
#  ['rec_19_audio_10.wav', '250 সার্ভিস'],
#  ['rec_19_audio_15.wav', 'লটারি রেজাল্ট'],
#  ['rec_19_audio_29.wav', 'ঘাসের দাম কমছে'],
#  ['rec_18_audio_4.wav',
#   'বাংলা মাসের বেটি এখন টাকা পয়সা আমি বহুৎ লাগবে এক কাজ করেন তোমরা ভালোভাবে অনুষ্ঠানে করেন'],
#  ['rec_18_audio_9.wav',
#   'মেয়েরা যেন পার হয়ে যায় টাকা-পয়সা তো মেলা টাকা লাগবে দেখান'],
#  ['rec_19_audio_22.wav', 'ভালোই আছি কিন্তু পরে তো দেখি না'],
#  ['rec_18_audio_34.wav',
#   'একটা জিনিসের দাম কম আছে সেটার দাম নেই কত সালে মারা গেছে'],
#  ['rec_19_audio_16.wav', '<>'],
#  ['rec_19_audio_27.wav', 'মাদ্রাসার কি খবর এলা মাদ্রাসাটা কি হবে'],
#  ['rec_18_audio_8.wav',
#   'পরিচিত যেগুলো আছে ওগুলো দিয়ে করা লাগবে চকবাজার কালেকশন করিয়া'],
#  ['rec_18_audio_5.wav',
#   'তাহলে কিন্তু তোমার দাওয়াত খাইলে কিন্তু ক্যামেরা টাকা ঢুকে বাড়িয়ে দেবে নাই যে অবস্থা'],
#  ['rec_19_audio_19.wav', 'জয়নালের শ্বশুরবাড়ি তোমার নামটা বলুন'],
#  ['rec_19_audio_24.wav',
#   'গরিব মানুষ যে কেমনে জীবনযাপন করে সব জিনিসের দাম এই জিনিসটা তো সরকারের নজরে পড়ে না তারে বাংলাদেশের অভাবগ্রস্ত লোকগুলো থাকে না'],
#  ['rec_19_audio_11.wav',
#   'এলা হাফিজের 90 টাকা কত আছে 70 75 80 একটা জিনিসের দাম'],
#  ['rec_19_audio_23.wav',
#   'রাস্তা ভেঙ্গে গেলে সরকারি রাস্তা সরকারের বানাইবে রাস্তাগুলো সংস্করণ করা লাগে সেগুলো করেনা'],
#  ['rec_19_audio_28.wav', '<>'],
#  ['rec_19_audio_2.wav', 'বাড়িতে কয়জন খান্না'],
#  ['rec_19_audio_12.wav',
#   'বাঁচতে কেমনে কন তো সব জিনিসের রোজা থাকা মানুষের হয়ে গেছে দুঃসহ প্রশ্ন করাই লাগবে'],
#  ['rec_18_audio_7.wav',
#   'ভিডিওটা পার হয়ে গেলে ভালো নয় একটা বিয়ে-শাদী হইলে জিনিসটা ভালো হয় তাহলে বয়সও তো হয়ে গেছে পার হলে ভালো আর কি নাই'],
#  ['rec_18_audio_37.wav', 'জান নাই তাই বুঝেছিলাম'],
#  ['rec_18_audio_35.wav', '18 সালের মা মারা গেছে মা মারা গেছে কত সালে'],
#  ['rec_19_audio_31.wav', 'এখন বাড়িতে আসবে'],
#  ['rec_20_audio_15.wav', 'খাল করি না'],
#  ['rec_20_audio_0.wav', 'কেমন আছেন কি সমাচার আলহামদুলিল্লাহ'],
#  ['rec_20_audio_11.wav', 'আমরা আগে তো আগে তো খাসনি হয়েছে'],
#  ['rec_19_audio_38.wav', 'আকাশটা নাকি'],
#  ['rec_20_audio_16.wav', 'জেসমিন করেন'],
#  ['rec_19_audio_48.wav', '<>'],
#  ['rec_20_audio_20.wav', 'হাইমা আছেই ডিম ডিমের প্রচুর এলার্জি জনিত খাবার'],
#  ['rec_20_audio_1.wav', 'না বয়স কত ছিল লাগছে 40 5 বছরের বেশি হয়েছে'],
#  ['rec_19_audio_5.wav', 'আলু ভর্তা ডিম থাকে না'],
#  ['rec_20_audio_14.wav', 'দুপুরের টা এলো'],
#  ['rec_20_audio_25.wav', 'মন্ডল নাই ভাত খেলে আমারে দেখান'],
#  ['rec_19_audio_8.wav',
#   'কি করবেন সব জিনিসের দাম রোজা থাকা লাগবে খাওয়া লাগবে খাওয়া-দাওয়া করে মনে করো'],
#  ['rec_20_audio_21.wav', 'কি খাওয়া লাগে'],
#  ['rec_19_audio_39.wav', 'ও হাঁসের দাম বলেন'],
#  ['rec_20_audio_23.wav', '<>'],
#  ['rec_20_audio_22.wav', '<>'],
#  ['rec_19_audio_47.wav', 'হ্যালো হ্যালো'],
#  ['rec_19_audio_35.wav', 'ও ভাই আমি তো আমাদের বাড়ির সামনে গো বলো কেন'],
#  ['rec_19_audio_45.wav', '<>'],
#  ['rec_19_audio_43.wav', 'গরু কাটা দেন'],
#  ['rec_20_audio_12.wav',
#   'আকাশ দিয়ে গেছি তাতে তোমার নানীর ফতোয়া অর্ধেক হয়েছে'],
#  ['rec_19_audio_46.wav', 'আজকে দেনা না ম্যাডাম রাজা কয়দিন থাকবে'],
#  ['rec_19_audio_37.wav', 'যে প্রশ্ন নিবেন না'],
#  ['rec_20_audio_10.wav',
#   'ওই তোমার নানার কাছে দেখছি লোকের মধ্যে তরকারি খায় নাই'],
#  ['rec_19_audio_4.wav', 'নাই কিছু ওটাই আমার দিন আনি দিন খায় নাই'],
#  ['rec_20_audio_13.wav', 'সকালবেলা ভোরে মুখ ঘষতে দাঁত ঘষতে করছে'],
#  ['rec_19_audio_9.wav',
#   'জীবন্ত পার করা লাগবে তাই না জীবন্ত সামনার খুব সময় গুলো আসবে সামনে জিনিসের দাম আরো বাড়বে এখন যে দামগুলো বাজছে সামনে তো মনে করো তোমার আরো বাড়বে এই যে গরুর গোশত আগে কত আছিলো'],
#  ['rec_19_audio_40.wav', 'তোমার হাসপাতাল'],
#  ['rec_19_audio_3.wav', 'পাড়ায় খরচ করেন কি করবেন'],
#  ['rec_20_audio_19.wav', 'কি করবেন'],
#  ['rec_20_audio_2.wav', 'কার দেশ ফটোকপি আছে না কার্ডের ফটো গুলো কিছু হবে না'],
#  ['rec_19_audio_30.wav', 'সেটাই তুমি কও না চোখটা আছে পাওয়ারফুল'],
#  ['rec_19_audio_36.wav', 'অ্যালার্ম'],
#  ['rec_19_audio_42.wav', 'তোরা আসবেনা'],
#  ['rec_19_audio_32.wav', 'রতন বাড়িতেই আসলো'],
#  ['rec_19_audio_44.wav', 'দাবি নিয়ে হয় না সবুজের আসবেন না'],
#  ['rec_19_audio_34.wav', 'কি কি করবেন'],
#  ['rec_20_audio_18.wav', '<>'],
#  ['rec_19_audio_6.wav', 'আসবে আসবে'],
#  ['rec_19_audio_41.wav', '<>'],
#  ['rec_20_audio_17.wav', 'গাইবান্দার আমি খাইনি কোনদিন'],
#  ['rec_19_audio_7.wav', 'খাবার-দাবার বাড়ি যায় নাকি বাঁড়া খুব আদর যত্ন করে'],
#  ['rec_19_audio_33.wav', 'শুনোনা'],
#  ['rec_20_audio_24.wav', 'সেই মানুষগুলো আছে'],
#  ['rec_20_audio_37.wav', 'আর আগে টাকা ওয়ালা'],
#  ['rec_20_audio_59.wav', '<>'],
#  ['rec_20_audio_58.wav', '<>'],
#  ['rec_20_audio_3.wav', 'কি করবো এমনি ভালো বন্ধু'],
#  ['rec_20_audio_53.wav', 'কালকে মাসে লাউ দিয়ে লাউ কুনাল কোথায়'],
#  ['rec_20_audio_30.wav', '<>'],
#  ['rec_20_audio_52.wav', 'তাসলিম রোজা থাকে না'],
#  ['rec_20_audio_36.wav', 'মেয়েদের লাগানো'],
#  ['rec_20_audio_55.wav', 'খানা লাগবে'],
#  ['rec_20_audio_64.wav', 'হা এই নিয়ে যায় নাকি'],
#  ['rec_20_audio_61.wav', 'ভাইয়ার বাড়ি দিয়েছে তো যাওয়ার বাড়িতে'],
#  ['rec_20_audio_66.wav',
#   'আমার মা যেমন অভিনয় কেমন করে আমরা দেখেছি আমরা দেখছে এখন কিছু কিছু'],
#  ['rec_20_audio_33.wav', 'তাই চারটা কয় তোমরা যাও তো কি করে গেছেন'],
#  ['rec_20_audio_40.wav', 'সামনে দুর্ভোগ দেখা দিবে তার একটা লক্ষন'],
#  ['rec_20_audio_45.wav',
#   'এরা সবাই দেখছে সবাই বলে দেখবে এটাও কইছে সবাই চোখে পড়বে'],
#  ['rec_20_audio_57.wav', 'কত'],
#  ['rec_20_audio_38.wav',
#   'আল্লাহ আল্লাহ যে জমির নাই হাত পায়ের উপর দিয়েই শুকুর চালায় এটা আল্লাহর কাছে করিয়াছি'],
#  ['rec_20_audio_54.wav', 'অকাল কেমন হবে'],
#  ['rec_20_audio_31.wav', '<>'],
#  ['rec_20_audio_48.wav', 'কাকার বিয়ে করছে সাওয়া হয়েছে'],
#  ['rec_20_audio_32.wav', '<>'],
#  ['rec_20_audio_5.wav',
#   'ডিম ভাজি বেগুন ভাজি ভাজা পড়া খায় নাকি একটা আইটেম দিয়ে খাই'],
#  ['rec_20_audio_60.wav', '<>'],
#  ['rec_20_audio_51.wav', 'নাগো যাই ডিম ডাল আবার ফিরতা মাছ আছে'],
#  ['rec_20_audio_28.wav', '<>'],
#  ['rec_20_audio_67.wav', 'কথা খারাপ'],
#  ['rec_20_audio_65.wav', 'হয় এরকম হয়না মানে অবশ্যই'],
#  ['rec_20_audio_50.wav', '<>'],
#  ['rec_20_audio_46.wav',
#   'ওই যে একবার হলো চাঁদের মধ্যে কি ওরে আল্লাহ হয়েছে সাঈদী বসে গেছে'],
#  ['rec_20_audio_62.wav', 'সেলাই দিবেন'],
#  ['rec_20_audio_29.wav', '<>'],
#  ['rec_20_audio_27.wav', '<>'],
#  ['rec_20_audio_63.wav', '<>'],
#  ['rec_20_audio_49.wav', '<>'],
#  ['rec_20_audio_47.wav', 'কেমন আল্লাহ জানি'],
#  ['rec_20_audio_4.wav', 'শাক খাওয়া খুব ভালো না খাওয়া-দাওয়া করছেন'],
#  ['rec_20_audio_42.wav',
#   'এই শোনো এখন এই যে বর্তমানে এটা জানি না শুক্রবার প্রথম রমজান শুক্রবার বাজির রমজান শুক্রবার'],
#  ['rec_20_audio_26.wav', '<>'],
#  ['rec_20_audio_68.wav', '<>'],
#  ['rec_20_audio_44.wav',
#   '16 তারিখ 16 তারিখ প্রথম রমজান শুক্রবার এলো নাজির রমজানের কথা কইছে'],
#  ['rec_20_audio_41.wav',
#   'এজন্য অনেকে কইছে যে এক বছরের খাবার মজুদ রাখার জন্য মানে ইয়া করা দরকার'],
#  ['rec_20_audio_35.wav', 'সবাই সবার হাতে সাড়ে তিন হাত কেউ নাই'],
#  ['rec_20_audio_39.wav',
#   'এইবারের যদি অসহায় অনুময় বাবা কেউ কিছু দিলে না ফল তেমন তেমন'],
#  ['rec_20_audio_34.wav', '<>'],
#  ['rec_20_audio_43.wav',
#   'একটা চিহ্ন দেখা গেল দুর্ভোগের একটা লক্ষণ এটা হযরত মুহাম্মদ সাল্লাহু সাল্লাম'],
#  ['rec_20_audio_6.wav', 'জানাবে'],
#  ['rec_20_audio_56.wav', 'পড়বে'],
#  ['rec_21_audio_30.wav', 'রাকিবুল করাবো'],
#  ['rec_21_audio_40.wav', 'মশা গালি দিলে না'],
#  ['rec_21_audio_22.wav', 'পাতাগুলি নিয়ে দেখিস না ভালো আছেন'],
#  ['rec_21_audio_2.wav', '11 11 তারিখ'],
#  ['rec_21_audio_29.wav', 'শাক দেয় যখন যেটা লাগে যখন যা লাগে তখনই তা দি'],
#  ['rec_21_audio_15.wav', 'কিন্তু স্যারের সাথে কথা হয় না আর কথা না'],
#  ['rec_20_audio_8.wav', 'হা'],
#  ['rec_21_audio_3.wav', 'খাওয়া-দাওয়া ভালো হয়েছে'],
#  ['rec_21_audio_11.wav', 'নির্ধারিত মসজিদে করা হয়নি 500 600'],
#  ['rec_21_audio_23.wav', 'ও'],
#  ['rec_21_audio_20.wav', 'ছাগল আছেন'],
#  ['rec_21_audio_7.wav', 'রান্নাটা কেমন হইছে'],
#  ['rec_21_audio_5.wav', 'তাহলে খাওয়া-দাওয়া মানুষে করাই ভালো হবে'],
#  ['rec_21_audio_0.wav', 'দাদা কেমন আছিস কেমন আছিস আলহামদুলিল্লাহ ভালো আছি'],
#  ['rec_20_audio_9.wav', 'তোমরা গ্রুপ ভাবে সবাই গেছে এই বাড়ির মানুষের'],
#  ['rec_21_audio_34.wav', 'ভর্তা দিয়ে কি লাগবে হ্যালো'],
#  ['rec_21_audio_28.wav',
#   'ভালো নাইস ভালোই আছে সোহাগের গান সোহাগের বউয়ের সাথে যে খাতির মনে করে কালাই ফেলাই দে শাকসবজি দেয়নি তাতে এরকম অনেক উপকার করছে'],
#  ['rec_21_audio_38.wav', 'মোটামুটি ভালোই হইতেছে সমস্যা নাই না'],
#  ['rec_21_audio_32.wav', 'কারার ডাল খান্না'],
#  ['rec_21_audio_35.wav', 'বাচ্চাকে যে দাম'],
#  ['rec_21_audio_10.wav', '<>'],
#  ['rec_21_audio_24.wav', 'আমার কাছে'],
#  ['rec_21_audio_31.wav', 'তাহলে আজকে কার্পেট খাওয়া-দাওয়া করে'],
#  ['rec_21_audio_25.wav', 'সুমনের বেটা কোথায় বড়'],
#  ['rec_21_audio_27.wav', 'তোমার হয়তো খাওয়া-দাওয়া করছিল দিন'],
#  ['rec_21_audio_19.wav', '<>'],
#  ['rec_21_audio_4.wav', 'ইমা ইলিশ মাছ নাকি'],
#  ['rec_21_audio_13.wav', 'দাম বেশি না দাম বেশির কারণে সবাই'],
#  ['rec_21_audio_17.wav',
#   'ওই ইয়া আইসে না না বক্কর আমার একটা মসজিদ নামাজ পড়ে না'],
#  ['rec_21_audio_1.wav', 'সমস্যা হয়েছে'],
#  ['rec_21_audio_37.wav',
#   'পাশ্চাত্য মনে করে লা সাদিয়া ইউরিয়া সার পটাস পস রেট এগুলি দিয়ে শাক পড়ে না বুঝছিস এই হলো অবস্থা'],
#  ['rec_21_audio_39.wav', '<>'],
#  ['rec_21_audio_6.wav', 'তারপরে চলে যাবেন খাওয়া-দাওয়া করলেন'],
#  ['rec_21_audio_33.wav', 'অজানা জলসা'],
#  ['rec_21_audio_36.wav',
#   'রমজান মাসে যে পাটশাকের যে দাম নিয়েছে 30 টাকার পাট শাক তার হাড়ির পাট'],
#  ['rec_21_audio_12.wav',
#   'এর আগেরবার ভালো হইছে নি এবার ভালো ভালো লাগছে কোন বার ভালো ভালো লাগছে না'],
#  ['rec_21_audio_14.wav', 'ওইভাবে আর কিছু খাবার পায় না'],
#  ['rec_20_audio_69.wav', 'কুমারের গান'],
#  ['rec_20_audio_7.wav',
#   'আমি চার রমজানের মাসে চলি মাছ দিয়ে রমজান মাসে খাওয়া যায় ভাত বেশি দিয়েছি'],
#  ['rec_21_audio_21.wav', 'হা ঘাস তাস নিয়ে যাওয়া দিস না সোনা পাখি'],
#  ['rec_21_audio_18.wav', '<>'],
#  ['rec_21_audio_26.wav', 'কুলিনা'],
#  ['rec_21_audio_16.wav', 'হাউস পাগল'],
#  ['rec_22_audio_115.wav', 'এখন এলাকার একটা লোক সেটা তো মাথায়'],
#  ['rec_22_audio_100.wav', '<>'],
#  ['rec_22_audio_15.wav', 'সমর্থন করছি সেটা আমরা স্বার্থ কিন্তু'],
#  ['rec_22_audio_16.wav', '<>'],
#  ['rec_21_audio_8.wav', 'জালালীয়া খাওয়া সবচাইতে কার্বন ভালো হয়েছে'],
#  ['rec_22_audio_106.wav',
#   'এখন জসিম জসিমের বোনের বিয়েতে আমাকে ওতপ্রোতভাবে ডাকছিল এবং তার বোনের বিয়েটা আমি খাইছি এন্ড জসিমের বিয়েটা হোক খেতে হবে'],
#  ['rec_22_audio_125.wav',
#   'রুল ভাইদের উত্তরা থাকে না ধানমন্ডি ধানমন্ডি যদিও এখন ইজিলি দেখা যাচ্ছে'],
#  ['rec_22_audio_13.wav',
#   'আমি এখন খেলা পছন্দ তো অনেকগুলা তার মধ্যে ফেভারিট খেলা হচ্ছে আমার ফুটবল খেলা আমার সবকিছু ফেভারিট খেলা আমার প্রিয় প্লেয়ার মেসি এটা ভালো করে জানিস মেসিকে আমি এড করছিলাম এটা সবাই দেখছে'],
#  ['rec_22_audio_17.wav', 'এসএসসি পরীক্ষা'],
#  ['rec_22_audio_122.wav', '<>'],
#  ['rec_22_audio_1.wav',
#   'তুমি চাইলে রেকর্ড কেন আরো অন্য কিছু করতে পারো সেটা তো কোন প্রবলেম নাই তো আমরা যে জায়গাটায় আছি এটা হচ্ছে আমাদের সিটির একটা জায়গায় তোর নাম তুমি জানো'],
#  ['rec_22_audio_124.wav',
#   'সুজন ভাই আমরা এই কজন ছিলাম এবং আমরা ওখানে রাস্তায় গেলাম'],
#  ['rec_22_audio_126.wav', 'তাই কিনা'],
#  ['rec_22_audio_107.wav',
#   'ওদের ফ্যামিলির যাদের বিয়ে হোক এখন তো বাসা প্রতিদিন'],
#  ['rec_22_audio_113.wav', 'পুলিশের মতো করা যায় না'],
#  ['rec_22_audio_116.wav', '<>'],
#  ['rec_22_audio_117.wav', '<>'],
#  ['rec_22_audio_119.wav',
#   'ওই এটা ভালো পারবে ওর পাশে আমরা কয়জন লোক ছাড়া ওর পাশে আর কেউ ছিল না এটা ভালো করেই জানে'],
#  ['rec_22_audio_101.wav',
#   'লিটনের বিয়ে লিটন ফোন দিছিলাম কার্ড দিয়ে গেছে এবং আমার বাবা কাটতেছে আমাদের'],
#  ['rec_22_audio_105.wav', 'ইনশাআল্লাহ ইনশাআল্লাহ'],
#  ['rec_22_audio_108.wav', '<>'],
#  ['rec_22_audio_118.wav', 'মুর্শিদ ওই নিজের থেকে দেখছে ওরে কে কে হেল্প করছে'],
#  ['rec_22_audio_127.wav',
#   'এই যে সমস্যা নাই তুই তো আছিস না ইতিমধ্যে আছি সমস্যা নাই'],
#  ['rec_22_audio_123.wav', 'মশিউর বাবুল মামা রশিদের ভাই চাচা'],
#  ['rec_22_audio_103.wav',
#   'খাওয়া-দাওয়া করে একটা ভালোই ছিল মোটামুটি ও দিল ওর বাইরে তো বিএফ পেলাম আমরা'],
#  ['rec_22_audio_114.wav', '<>'],
#  ['rec_22_audio_130.wav',
#   'ওইখান থেকে ওই জন্য ওইভাবে করলে আমার মনে থাকবে লোক হিসেবে আমি যতটুকু খারাপ দেখি নাই'],
#  ['rec_22_audio_110.wav', '<>'],
#  ['rec_22_audio_112.wav',
#   'আমার যেটা মনে করছে আমি পাই এর মাঝে আমাকে চলতে হয় ফ্যামিলিকে দিতে হয় দিয়ে শুয়ে মনে করে চলতে হয় এখানে অনেক হিসাব আছে মাঝে মাঝে নিজে চলা'],
#  ['rec_22_audio_11.wav',
#   'রান্না করতে পারিস আমি সবই করতে পারি এই জগতে যা কাজ আছে সেটা দেখব দেখার পর আমার মনে হতে পারে যে আমি এটা করতে পারি না'],
#  ['rec_22_audio_111.wav', '<>'],
#  ['rec_22_audio_104.wav', 'তোর বোনের অনুষ্ঠান করেন'],
#  ['rec_22_audio_121.wav', '<>'],
#  ['rec_22_audio_120.wav',
#   'অ্যাম্বুলেন্স দুটা আমি ভাড়া করে দিয়েছি আমি লিঙ্গ ভাড়া করে দিয়েছি যার সঙ্গে কিছু 33 হাজার টাকা দিয়ে আসার সময় 24 হাজার টাকা দিয়ে দিয়েছি'],
#  ['rec_22_audio_0.wav',
#   'রিঙ্কু কেমন আছিস আলহামদুলিল্লাহ ভালো তোর কি অবস্থা করি'],
#  ['rec_22_audio_12.wav',
#   'বাড়ির সবাই রোজা আছে না এখন তো আম্মু নেই আব্বু করতে পারেন'],
#  ['rec_22_audio_14.wav',
#   'এবং আর্টিস্টকে এটাও তুমি ভালো করেই জানো সেই সময় আমরা কাপটা পাই নাই এটা আমরা অজস্র কান্নাকাটি করছি কিন্তু এবার আমরা এই সালে কাপটা অর্জন করছি তাই না এটা আমাদের গর্বের বিষয়'],
#  ['rec_22_audio_102.wav',
#   'তোমাদের সাথে গেছি তোমাদের সাথে একতরফা দিয়েছি কিন্তু আমি আলাদাভাবে আমার ফ্যামিলির পক্ষ থেকে'],
#  ['rec_22_audio_129.wav', '<>'],
#  ['rec_22_audio_109.wav', 'জসিমের বাবার দিচ্ছে আমার কথা কিছু কইছিলেন'],
#  ['rec_22_audio_10.wav',
#   'খাওয়া-দাওয়া হয়েছে কি কি খাওয়া দাওয়া করলি বন্ধু টেংরা মাছ কিনে নিয়ে গিয়েছিলাম'],
#  ['rec_21_audio_9.wav', 'কার বাড়ি নেই'],
#  ['rec_22_audio_128.wav',
#   'আর সময় পেলে বিদায় নিতে হবে মারা গেছে আমরা কিন্তু ছবি দিতে পারতাম কিন্তু এটা খারাপ দেখায় কথাটা আমি দেখতে চাই মরার দুই দিন পরে আমি ছবি করছি আমার বিবেকে বাড়ছে এটা মেয়ে মানুষের কান্নাকাটি'],
#  ['rec_22_audio_32.wav', 'আর ওর বড় বোন'],
#  ['rec_22_audio_18.wav',
#   'তোর সাথে দুইনাম্বারী করলো পরীক্ষা দেওয়ার আগে আমার কাছে ইংলিশ সবকিছুই ছিল আমি তো দিছি বলছি যে বেইমানদের দেখাস না বলছিলাম ওদের কেউ যেন না পায় তুই বললি যে না আমি হেল্প করলে অবশ্যই আমি একটু কাছাকাছি আমি তোমাকে বন্ধু বিশ্বাসঘাতকতা'],
#  ['rec_22_audio_41.wav',
#   'তাইতো কোনো কারণে ভাগনা রাগ করছে সে আসি আমার হাতটা টানি'],
#  ['rec_22_audio_25.wav', 'আরো'],
#  ['rec_22_audio_43.wav',
#   'রেগে আছে ওইটা আমি এখন একটা জট ছিল আমি জিনিসটা বুঝতে পারছি যদিও ছোটনের পাঁচটি আমি তার সাথে কোনদিন কথা বলি নাই'],
#  ['rec_22_audio_24.wav',
#   'তারপরে কি হলো তুমি আসি বন্ধু আমাকে দুঃখ প্রকাশ করলা আমি কি করলাম টাইগারের বোতলে তিনটা ঘুমের ট্যাবলেট ঢুকাইয়া ঢুকাইয়া তোমার খাওয়ায় দিলাম তুমি টেনশন না করো তুমি বন্ধু মানুষ তুমি কষ্ট পাইলে কিন্তু আমার কষ্ট লাগবে'],
#  ['rec_22_audio_4.wav',
#   'আগে আবাসিক ছিল একসাথে কি মজার ছিল আমার নোয়াখালীর আনোয়ার আছেন ফুটবল খেলো একসাথে এভাবে হলো মুসলিম'],
#  ['rec_22_audio_49.wav',
#   'তোর বাতি যায় এদিক দিয়ে আমরা চিনি যে এটা তোর ভাবছি এতটুকুই এর বাইরে আমরা কিছু জানিনা'],
#  ['rec_22_audio_55.wav',
#   'আমি কিন্তু কারো আশাও করি নাই কারো সাহায্য চাই নাই বা কারো সাপোর্ট চাইনি'],
#  ['rec_22_audio_52.wav', 'তোদের জন্য অনেক কিছু কইলাম না এটা কোন কথা'],
#  ['rec_22_audio_20.wav',
#   'এখন তার পরের দিন যখন অঙ্ক পরীক্ষা দ্বিতীয় সেমিস্টার অঙ্ক পরীক্ষা আমার খারাপ লাগলো'],
#  ['rec_22_audio_19.wav',
#   'তারা প্রসঙ্গে যেকোনো মুহূর্তে ভেবেই করতে পারে লাগবে'],
#  ['rec_22_audio_26.wav',
#   'পরীক্ষা দেওয়ার সময় দিলাম তাদের কি করা যায় আমি তখন তোমাকে বললাম যে বন্ধু তাদেরকে ফেল করার মতো যথেষ্ট আমার বুদ্ধি আছে'],
#  ['rec_22_audio_53.wav', 'বলি নাই এখন কথা আছে'],
#  ['rec_22_audio_33.wav',
#   'কিন্তু অনেক সুখে থাকতো তুই নিজে যা কিছু কর ওরে কিন্তু রাখছি'],
#  ['rec_22_audio_2.wav',
#   'নাম যদি আবার নতুন করে করা লাগে সমস্যা কি রাকিব খান সেটা তো তুমি জানো আমার নাম খান'],
#  ['rec_22_audio_51.wav',
#   'এখনো মামা বিষয়টা হলো তার বাপ কিন্তু সম্পর্ক খারাপ হোক হুমা স্বাভাবিক তার মানে তাই না'],
#  ['rec_22_audio_36.wav',
#   'এখন পরে কয় হ্যাঁ পরে যখন আমি টের পেয়েছি যেটা মন রয়েছে'],
#  ['rec_22_audio_27.wav',
#   'ঠিক আছে তাহলে আমাদেরকে সুযোগমতো কাজে লাগাতে হবে কোন ব্যাপার না অটোমেটিক চলি আসছে মাথায়'],
#  ['rec_22_audio_22.wav',
#   'কথাটা আমি আবার তোরে দুইটা দিছি পাঁচটা পাঁচটা মধ্যে আবার কাটিং আছে না মার কাটিং আছে না আমার সাথে সেই সময় গাদ্দারি করছে সুজন সুজন আমার থেকে শেষ সময় বন্ধ করো'],
#  ['rec_22_audio_40.wav', 'বুঝতে পারছে'],
#  ['rec_22_audio_28.wav', 'হয়ে গেছে মোটামুটি ভালোই হয়েছে'],
#  ['rec_22_audio_34.wav', '<>'],
#  ['rec_22_audio_42.wav', 'তো আমাকে বলল তুমি কি কোন কারনে আমার উপর মানে'],
#  ['rec_22_audio_48.wav',
# ...
#  ['rec_25_audio_38.wav',
#   'হ্যাঁ গাইবান্ধা তো আছে স্টেডিয়াম এখন আছে গাইবান্ধা খেলা খেলা'],
#  ['rec_25_audio_30.wav',
#   'লালমনিরহাট কুড়িগ্রাম পঞ্চগড় ঠাকুরগাঁও গাইবান্ধা দিনাজপুর পঞ্চগড় পঞ্চগড় একবার কইলো আর একটা কি জানি'],
#  ['rec_25_audio_3.wav',
#   '30 বছর হয় এখন ওই যে পাসপোর্ট করছিল এই পাসপোর্ট করবে আমার বয়স হয়ে গেছে 33 এখন যেহেতু 33 বছর হয়েছে এখন ভোটার আইডি 333'],
#  ['rec_25_audio_15.wav',
#   'এখন কি আর কই বাহু রে হয়ে গেছে বিভাগ এন্ড বিভাগের জেলাগুলোর আগের নাম গুলো শোনাও তাহলে না বুঝতে পারবেন তাহলে কোন কোন জেলা নিয়ে আমার অঙ্কুর খান হয়েছে'],
#  ['rec_24_audio_75.wav', 'আদিলের বাপ আমার মায়ের উঠে যাবে না'],
#  ['rec_24_audio_68.wav',
#   'খেলা রোজা রমজানের দিনে দেওয়া লাভ আছে রোজা রমজানের দিনে যাইয়া লাভ আছে'],
#  ['rec_25_audio_24.wav', 'মুই বিড়ির দোকান'],
#  ['rec_24_audio_70.wav', '<>'],
#  ['rec_24_audio_8.wav', 'সে ছোট মানুষ যায় না'],
#  ['rec_25_audio_19.wav',
#   'লালমনির কারো সাথে কথা হলে মনটা একেবারে খুব ছোট হয়ে যায়'],
#  ['rec_25_audio_33.wav',
#   'এ যাইবে না দেখ তোর খালি ওমারের তামশা খালি একজন আরেকজনের নামে গাছপালা আছে'],
#  ['rec_24_audio_9.wav', '<>'],
#  ['rec_25_audio_18.wav',
#   'একজন নামকরা লোক আছে ওড কার ধুম মন্ত্রী লালমনিরহাটের করে ফেলেছে'],
#  ['rec_25_audio_2.wav',
#   'বয়স কত সিলভার খেলা হিসাব করলে যখন জন্ম হয়েছে ওই থেকে শুরু করলে'],
#  ['rec_24_audio_71.wav',
#   'রোজা রমজান মাসে আর কি আনবে তোর মনে কর হ্যাঁ আর সন্ধ্যের সময় নিলে খাওয়া হয়ে যায় না'],
#  ['rec_25_audio_22.wav',
#   'যেগুলো কাঁচা আছে ইন্ডিয়ার করে নারে ভাই কি কমু আর ওই যে একটা আমার গ্রামের জায়গা আছে সোনারা কি সুন্দর নাম সেই নবীজি সাঃ এর নাতিরা যে কারবালার যুদ্ধ করছে কিন্তু সেই গেলাম খান গেল'],
#  ['rec_25_audio_0.wav', 'দোস্ত কেমন আছিস রে ভাই কোনো রকম আছো'],
#  ['rec_24_audio_69.wav', 'করে দেখি'],
#  ['rec_25_audio_25.wav',
#   'বৃষ্টি হলে এক হাটু কাঁদো হয় বাউরে এখানে যাওয়া যায় না হয়'],
#  ['rec_25_audio_13.wav', 'ঘুম হলে নাই'],
#  ['rec_25_audio_1.wav', 'সমস্যা কি মোর নাম জাহিদ'],
#  ['rec_25_audio_11.wav',
#   'হ্যাঁ একটা থানার নাম এখন তার সাথে এখন ওগুলো জেলা হয়েছে জেলার নাম গুলো কি তোমরা জানেন'],
#  ['rec_25_audio_35.wav',
#   'মনে টেকে না এখন কি করো না করো পরে চিন্তা করে আমার তো আর জমিদার বাড়ি আছে জমিদার বাড়ি যাই দেখি ওটা কি অবস্থা জমিদার বাড়ির রংপুরের তাজহাট জমিদার বাড়ি তাজহাট জমিদার বাড়ি নাম শুনছেন'],
#  ['rec_24_audio_76.wav', 'সকালবেলা একটা মোবাইল পেয়েছি'],
#  ['rec_24_audio_72.wav',
#   'আমার বাড়ির মতো নয় আমার বাড়ি আমি যে মাও গেলে আমি ফিরেছি'],
#  ['rec_25_audio_39.wav',
#   'ওই যে ক্রিকেট গার্ডেন সুরভিত রাজ্যে গেছিলে মাঠ ওটার নাম ক্রিকেট খেলায় তারপরে জাতীয় দলের'],
#  ['rec_25_audio_29.wav', 'নীলফামারী'],
#  ['rec_25_audio_26.wav', 'তাইলে তো কামই হইলে হয় না'],
#  ['rec_25_audio_21.wav',
#   'উন্নয়ন করছে সে উন্নয়ন হলে গেলে কি তোমার সাথে করি না'],
#  ['rec_25_audio_10.wav',
#   'আমার রংপুর জেলা আগে খালি জেলাটা আছে যখন আটটা থানা নিয়ে আসেন কত ভালো আছেন কত সুন্দর আছি'],
#  ['rec_25_audio_40.wav', 'তাও বলে কয়দিন থাকবে'],
#  ['rec_24_audio_73.wav', 'মানে খায় ছেলেরা খাই খাই'],
#  ['rec_25_audio_34.wav', 'এখন কি করি আর ভালোই লাগে'],
#  ['rec_25_audio_12.wav', 'এখন রামচন্দ্রপুর'],
#  ['rec_25_audio_17.wav',
#   'কুড়িগ্রাম আছে নীলফামারী আছে এই গাইবান্ধা আছে লালমারি নীলফামারী আছে লালমনিরহাট বাহে লালমনিরহাট লালমনিরহাট জেলার লালমনিরহাট'],
#  ['rec_25_audio_37.wav',
#   'সিকি ওয়াটার খুব ভালো জায়গা আরো জমিদার বাড়ি মেলাগুলো আছে বিভিন্ন জায়গায় তার মধ্যে একটা জমিদার বাড়ি'],
#  ['rec_25_audio_4.wav', 'কি আর করব রে ভাই'],
#  ['rec_25_audio_36.wav',
#   'মেলা গাছগাছালি আছে বাগান আছে ফুলের বাগান সুন্দর সুন্দর ফুলের বাগান আছে ভালোই আছেন'],
#  ['rec_25_audio_28.wav',
#   'তখন আর কিছুই করার সাহস পায় না কিছুই আর করার কপালে যা আছে তাই হবে'],
#  ['rec_24_audio_7.wav',
#   'সাজেকের মা তোমরা খাও আমার কেন আগে মোরসালিন কে যায় প্রতিদিন যায় না'],
#  ['rec_25_audio_27.wav', 'কিছু নাই উন্নয়ন করছে যখন ইতিহাস'],
#  ['rec_25_audio_32.wav',
#   'মানুষের শাবাবা নিয়ে গেছিল তার ফ্যামিলি শুদ্ধ নিয়ে গেছিলেন'],
#  ['rec_25_audio_23.wav',
#   'তোমরা মনে করবে যে কোন জায়গাতে আছি কিছুই ভালো লাগে না সেটাও ভালো লাগেনা বসে বসে'],
#  ['rec_25_audio_31.wav',
#   'রংপুর রংপুর জেলা একটা ধরি হয়েছে আগে গেছিল এত সুন্দর চিড়িয়াখানা পশু পাখি'],
#  ['rec_25_audio_41.wav', 'টিটকারি করবেন'],
#  ['rec_24_audio_74.wav', 'সাড়া দেয় না'],
#  ['rec_25_audio_16.wav',
#   'রংপুর কবার গেলে তো খালি এখন হামার রংপুর কইলে হবে না রংপুরে যে জেলাগুলি নিয়ে বিভাগ হয়েছে'],
#  ['rec_25_audio_20.wav',
#   'আর কন্যা সে কথা টিভি মন্ত্রী এই শালা তোর পুটি মাছ পুটি মাছ আছে'],
#  ['rec_25_audio_42.wav', 'ভাইরাল হয়'],
#  ['rec_26_audio_29.wav', '<>'],
#  ['rec_26_audio_19.wav', '<>'],
#  ['rec_26_audio_14.wav', 'গ্রাম নেই'],
#  ['rec_26_audio_31.wav', 'নাজমুল বাসের দোকান'],
#  ['rec_26_audio_15.wav', 'ডুঙ্গা'],
#  ['rec_25_audio_9.wav',
#   'অবশ্য একদিক দিয়ে ভালো হয়েছে অবশ্য একদিক দিয়ে ভালো হয়েছে নতুন নতুন বিল্ডিং গুলো মেলা সবার কর্মসংস্থান হয়েছে'],
#  ['rec_26_audio_16.wav', 'গঙ্গা সংগীত'],
#  ['rec_26_audio_33.wav', 'আর মুর্শিদাবাদে মিষ্টি খাবার'],
#  ['rec_27_audio_11.wav',
#   'নানা বাড়ি টু কৃষ্ণ ভাই শুরু থাকার মজাই আলাদা বুঝিস না মামাতো ভাই একটা আছিল শয়তানের শয়তান শয়তান'],
#  ['rec_26_audio_5.wav', 'বৌদির বাসা কোন জায়গায় কোন জায়গায় বিয়ে করছেন'],
#  ['rec_27_audio_1.wav',
#   'আজও তোর নাম তো জানু মুই তোমারে তোর নামটা একবার কত দাম মোর নাম হলে হানিফ বয়স কত ছিল এখন তোমার বয়স 20 বছর'],
#  ['rec_26_audio_23.wav', 'পুলিশ স্টেশন'],
#  ['rec_26_audio_0.wav', 'কি অবস্থা দাদা কেমন আছেন তাতে কোন সমস্যা হবে না'],
#  ['rec_26_audio_30.wav',
#   'নামাজের পরে আবার ফিরে মসজিদের দোকানটা ছিল আগে ওইটা আজকে নামাজের পরে দাওয়াত দিয়েছে কাহিনী'],
#  ['rec_26_audio_4.wav', '<>'],
#  ['rec_26_audio_25.wav', 'ওবিসি লাগে না'],
#  ['rec_26_audio_8.wav', 'খাবার-দাবার কি দেয়নি'],
#  ['rec_26_audio_32.wav', '<>'],
#  ['rec_26_audio_34.wav', '<>'],
#  ['rec_26_audio_9.wav', 'নিরামিষ না আমিষ বলতে পারবে না'],
#  ['rec_25_audio_7.wav',
#   'আগে হামার রংপুর খালি জেলা আছেন ভালো আছেন একটা বিবেক হয়ে গেছে'],
#  ['rec_26_audio_22.wav', 'জামতলা জামতলা কোন জায়গায়'],
#  ['rec_26_audio_13.wav', '<>'],
#  ['rec_26_audio_18.wav',
#   'রংপুর পৌরসভার মেয়র সিটি কর্পোরেশনের মেয়র মাংসের বাজার'],
#  ['rec_26_audio_1.wav', 'খাওয়াতো দুঃখ নেই'],
#  ['rec_26_audio_6.wav', '<>'],
#  ['rec_25_audio_5.wav',
#   'তোমার জেলায় কি কি আছে আমার জেলার নাম শুনতে চাই আমার জেলার নাম তো তুই জানিস না আমার জেলার নাম ভালো নাম রংপুর মানুষের রংপুর'],
#  ['rec_26_audio_2.wav', 'এলাইয়া খাওয়া-দাওয়া করছেন আজকে খাবার দাও'],
#  ['rec_26_audio_17.wav', 'কক্সবাজার'],
#  ['rec_25_audio_8.wav',
#   'রংপুর এখন বিভাগ হয়ে হইল কি কাম বাড়ি গেল আটটা জেলার দায়িত্বে এখন আমার রংপুরের উপর তারের জন্য রংপুরে জেলার নতুন নতুন বড় বড় বিল্ডিং হয়েছে নতুন নতুন অফিস-আদালত হয়েছে'],
#  ['rec_26_audio_24.wav', 'অর্ডার দেওয়া লাগবে'],
#  ['rec_26_audio_12.wav', '<>'],
#  ['rec_27_audio_10.wav', 'ভুড়ি কতই নষ্ট হয় এজন্য দেয় না'],
#  ['rec_27_audio_0.wav',
#   'কিরে কেমন আছিস আসম ভালো কিছু করি না তুই তো আমার ভাই রেকর্ড করলে কি হইবি কোন সমস্যা নাই কর'],
#  ['rec_26_audio_28.wav', 'রমজান মাস 13 তারিখ'],
#  ['rec_26_audio_11.wav', 'আয়োজিত অসুস্থ জ্বর হচ্ছে না'],
#  ['rec_26_audio_21.wav',
#   'কুড়িগ্রামের কোন বাসায় শ্বশুরবাড়ি মঞ্জু সাহেব জামতলা জামতলা না কদমতলা'],
#  ['rec_26_audio_35.wav', 'তার পরিবারে বাবা ধরে রেখেছি'],
#  ['rec_26_audio_3.wav', 'ভালো'],
#  ['rec_26_audio_10.wav', 'মিষ্টি মিষ্টি'],
#  ['rec_26_audio_27.wav', 'মুসা টি স্টল বেড়ে গেছে'],
#  ['rec_26_audio_7.wav', 'চিলমারী চিলমারী বালারহাট নদী নিয়ে গেলিনা'],
#  ['rec_26_audio_26.wav', '<>'],
#  ['rec_25_audio_6.wav', 'রংপুর জেলা নানান কাউকে শুরু হয়েছে'],
#  ['rec_26_audio_20.wav', 'টোটাল 160 টাকা করি'],
#  ['rec_16_big_audio_3.wav',
#   'তার দুঃখের সংসার দুঃখ কষ্ট করে বড় হয়েছে বাপ-মা মানুষ করছে সেই ভাবে এখন যদি তাই তোমার ঘরের থাকে আমরা যদি পরে যাবার না দেন তাহলে তো হবে না লাগবে যেটা করতে দেওয়া লাগবে তোমার একটা থাকবে তোমার থাকবে তাপমাত্রা'],
#  ['rec_27_audio_8.wav',
#   'গলায় সুরটা আমরা পছন্দ করি বেশি ভাই আর ছোটবেলায় বেশি আরো বেশি সময় গ্যাসের কিছু ঢেলে দুলে পাড়ি খাওয়া বন্ধুবান্ধবসহ'],
#  ['rec_27_audio_40.wav', 'কষ্ট লাগে না পারভেজ'],
#  ['rec_27_audio_36.wav',
#   'গাড়ি ভাড়া তো দেয়া লাগবে তিন বছর হয় নানি বাসি আছে'],
#  ['rec_27_audio_22.wav',
#   'এখন কি করবো স্বাদ না দিয়ে আল্লাহর ভাষা পরিবর্তন করব'],
#  ['rec_27_audio_32.wav', 'তিনটে তিনটে হাঁস মুরগি এসেছে আবার কি যে'],
#  ['rec_27_audio_29.wav',
#   'বেশ ফোক জিনিসের দাম এবং মানুষ খাইবে কোনটা জিনিস যদি এত দাম হয়েছে এই দামের কারণে তো মানুষ আর হয় না মানুষের যে একটা পছন্দের জিনিস আছে যে মোর এই জিনিসটা খুব পছন্দ এই রমজানে তো এই জিনিসটা খারাপ আমি রোজা থাকি এই জিনিসটা এত মনে করতাম মেল'],
#  ['rec_27_audio_43.wav',
#   'কোন কিছু নাই দিনকাল খুব খারাপ এই সময় ভালোভাবে চলাফেরা করা লাগবে না'],
#  ['rec_27_audio_42.wav',
#   'কোনরকম ভাড়ায় নাই কষ্টের দিন কাটতে লাগছে বহুৎ আলাপ-আলোচনা বল'],
#  ['rec_27_audio_14.wav',
#   'সম্মানটা আলা মানুষ দেয় না মানুষের যে বরফ যে সম্মান করা লাগবে ছোটক যে আদর স্নেহ করা লাগবে এই জিনিসটা আমরা বোঝেনা এখন ভাই'],
#  ['rec_27_audio_17.wav',
#   'বলিস না এলকার দিন কামাই রোজগার নাই ডাল আলু ভাজি দিয়ে খাইছি'],
#  ['rec_27_audio_38.wav',
#   'বিয়ে সাদি করছে এর আগে যে তোরে একটা মামাতো বোনের ছেলের নামটা জানি কি বলে গেল তোমার বিয়ে-শাদী হয়েছে সাওয়া হয়েছে'],
#  ['rec_27_audio_33.wav',
#   'এত নানা বাড়ি কোন জায়গায় ঠাকুরগাঁও ঠাকুরগাঁও ঠাকুরগাঁও না ভাই যে বাসের টিকিটের দাম তাও তো কয়দিন আগে ঘুরে আসলো'],
#  ['rec_27_audio_18.wav',
#   'তানিয়া বাইক কজন খান তোমরা বাড়িতে ভাই খাই 6 জুন অবস্থা খাওয়া না খাওয়া'],
#  ['rec_27_audio_35.wav',
#   'বেশি মিষ্টি নাথ মানে একলাই তো যাওয়ার সম্ভাবনা টাকা নাই পয়সা নাই'],
#  ['rec_27_audio_31.wav',
#   'মানুষ তো এই চিন্তায় বাঁচায় না পুরুষরাই জোরে আমার গরু গরু আছে আমার গরু নাই ভাই ছাগল আছে তোমার ছাগল হইলো ভাই'],
#  ['rec_27_audio_5.wav',
#   'মাইনসের আম চুরি করছি কত কি করছি তোর বন্ধু-বান্ধব সহকারে বন্ধু বান্ধব সহকারে করছি এখন তো বন্ধুবান্ধব নাই আগের মতন মজা নাই'],
#  ['rec_27_audio_28.wav',
#   'মানুষের অনেকের গোশত পছন্দ মানুষের অনেকের ডিম পছন্দের মাছ পছন্দ এখন তোর কোনটা পছন্দ যদি নাই খাবার পাই তাহলে কি হইলো পছন্দ তুই এরা কি করবি'],
#  ['rec_27_audio_25.wav',
#   'নদীতে মনে হয় সেরকম নদীটার নাম কি তোমার নদীটা আমার এটা নদীর নাম ভাই দুলাল নদী এই নদীর শোক নদীর ভাই ইংরেজি শাখা প্রশাখা'],
#  ['rec_27_audio_4.wav',
#   'আল্লাহ জানে শৈশব কল কেমন কাটছিলো ছোটবেলা কেমন কাটছে কি সমাচার তো শৈশবকাল ভাই শৈশব কালের মত দিন হয় শৈশবকাল সেই সুন্দর আছে কি সুন্দর খেলাধুলা করছি'],
#  ['rec_27_audio_6.wav',
#   'ছোটবেলা তো পাওয়া যায় আলাদা ছিল কয়েকজন বন্ধু একসাথে হইলে ছোটবেলার'],
#  ['rec_27_audio_3.wav', 'চলবে'],
#  ['rec_27_audio_20.wav',
#   'কৃষ্ণা উন্নত অনেক কিছু বারাইছে তোর মনে করে স্বাদ দিলে বলে আবাদ বাড়ে আবার স্প্রে করলে কি কি সার বলে বারাইছে ওগুলো দিলে বলে খুব ধান বলে বেশি হয় বেশি হয় এগুলোতো'],
#  ['rec_27_audio_16.wav',
#   'এখন কি আর করব ওটা যুগ জামানা হিসেবে মানি নেওয়ায় নাকি বুঝিস না ভাই আল্লাহর রহমতে রোজা রাখছি ভাই কি খাওয়া দাওয়া হলো'],
#  ['rec_27_audio_9.wav', 'বুঝিস নাই নাই মানুষের গালাগালি'],
#  ['rec_27_audio_21.wav',
#   'তুমি শুনবে না নাকি ব্যবহার করেন তাহলে ভাড়া সম্ভব নয় টাকা-পয়সার ব্যাপার টাকা পয়সা নাই'],
#  ['rec_27_audio_41.wav',
#   'খবর কায়দায় ঘুরে বেড়ায় একটা দোকান আছে দোকানে তে থাকে তাহলে নাই ভালো আছেন'],
#  ['rec_27_audio_30.wav', 'খায় কেমনে বুঝিস না আরো কঠিন অবস্থায় কিভাবে চলবে'],
#  ['rec_27_audio_13.wav',
#   'কিন্তু এখনকার গুলো তো মানুষের মনে করেন একটা কথা কয় এই কথাগুলো শুনে বেড়ে যায় সম্মান দিছিলি'],
#  ['rec_27_audio_26.wav', 'হাই নদী ডাইরেক্ট লাগছে'],
#  ['rec_16_big_audio_1.wav',
#   'তখন তো কম টাকাতে হয়েছে এখন তো বেশি টাকা লাগে এখন আমি বিয়ে শাদী করে গেলেও সেটা টাকাটা মানুষ থাকার মধ্যে তোমরা যেটা করলেন বিয়ে করছি এখন তো আমি সেটা করবো আমাদের অবস্থাটা খুব খারাপ ছেলের অবস্থা দেখি খারাপ দেখিয়া মানুষ তোকে ছিড়ে গেছে'],
#  ['rec_27_audio_15.wav',
#   'বিশিষ্ট যুগ জামানা কি রকম কারো ভালো কাজ দেখতে পায় না বুঝিস নাই এখন যদি একটা ভালো কথা কবু বুঝিস নাই গা থেকে যায় যায় না'],
#  ['rec_27_audio_27.wav',
#   'তাহলে তোর খাবার-দাবার কি পছন্দ সবচাইতে কোন খাবারটা বেশি তোর পছন্দ আবার তো ভাই পছন্দ অনেক কিছু কিন্তু কবার গেলে তো ফিরে এলাম মুখ থেকে ছাড়ে না দিস নাই খুব ভালো লাগে'],
#  ['rec_27_audio_2.wav', 'মা নাকি'],
#  ['rec_27_audio_7.wav',
#   'এখনকার তো মনে কর এখন বড় হইলে মন চায় যে আবার সেই ছোটবেলার জ্যাম নয় সেই ছোটবেলার কি কি খেলা খেলা কি পছন্দ ভাই পছন্দ খেলা'],
#  ['rec_27_audio_37.wav', 'মারা গেছে মামারা কয় ভাই বোন চার ভাই ভাই'],
#  ['rec_27_audio_24.wav',
#   'জাল দিয়ে আবার ছিল কারেন্ট ডাল দিয়ে হাসতে আর চার-পাঁচ কেজি মাছ মারা গিয়েছিল আর এলা একটু আম আছে মারা যায় না সারা নদী ঘুরে না ভাই নদীর মাছ নাই'],
#  ['rec_27_audio_39.wav',
#   'কটার সময় ব্যাটা আমি কি করে রে স্বামী মেকানিক সাসিল তাইতো প্যারালাইসিস ছায়া'],
#  ['rec_27_audio_23.wav',
#   'ভাই ছোট কালের কথা তো কইলে এলাও দুঃখ লাগে নদীটা আগে হাসতে হাসতে বলে গাল দিয়ে মারিয়া পাইনি ছোটবেলায় হায়রে মাছ'],
#  ['rec_27_audio_34.wav',
#   'এক টিকিটের দামের জন্য তো যাওয়ার উপায় নেই 220 টাকা করে'],
#  ['rec_27_audio_12.wav',
#   'দিনগুলি এখনো মিস করি বুঝছিস তুই কত সুন্দর আছে আর এখনকার দিন মনে করে এখন চেনা ফেনা গুলোও বান্দর আগে চারা পারা গুলো অন্যরকম'],
#  ['rec_27_audio_19.wav',
#   'খুশি নাই তাহলে কি করবো আর 8 নং 6 ঘন্টা সে জায়গায় দুদিন হয় মনে করছে তাহলে কেমনে সংসার চলে'],
#  ['rec_17_big_audio_0.wav',
#   'আমার নাম হলো দেলোয়ার হোসেন সাঈদী বয়স কত চলবে না'],
#  ['rec_23_small_audio_0.wav', 'মন্দিরা ইফতারির সময় হয়ে গেছে ডিসকভারি'],
#  ['rec_19_small_audio_0.wav', '<>'],
#  ['rec_27_small_audio_0.wav', '<>'],
#  ['rec_16_small_audio_3.wav',
#   'কন তোমরা কি করো তোমার ভালো হয় আমি এখন মনে করো পরে বাপ-মার শাড়ি যামু'],
#  ['rec_25_small_audio_0.wav', 'আচ্ছা'],
#  ['rec_11_small_audio_0.wav', '<>'],
#  ['rec_17_small_audio_4.wav', 'চোর'],
#  ['rec_17_small_audio_0.wav', 'সব সময় চলে'],
#  ['rec_09_small_audio_0.wav', 'আজ লটারি সংবাদ'],
#  ['rec_17_small_audio_1.wav', '<>'],
#  ['rec_16_small_audio_1.wav', '<>'],
#  ['rec_14_small_audio_0.wav', 'কোথায় গেল'],
#  ['rec_26_small_audio_0.wav', '<>'],
#  ['rec_24_small_audio_0.wav', 'ভালো হয়েছে'],
#  ['rec_21_small_audio_0.wav', '<>'],
#  ['rec_04_small_audio_0.wav', 'ওই সালাত করছে তারপর ডায়াল কোনা করছে'],
#  ['rec_20_big_audio_0.wav',
#   'প্রথম রমজান রমজান শুক্রবার মাঝের রমজান আছে না এটা হলো শুক্রবার প্রথম রমজান শুক্রবার হবে 16 তারিখে 16 তারিখ শুক্রবার'],
#  ['rec_22_small_audio_1.wav', 'আরো ভালো লাগতো খারাপ'],
#  ['rec_16_small_audio_2.wav', 'দেয় না'],
#  ['rec_05_small_audio_0.wav',
#   'কেবল মুক্তি শুকিয়ে গিয়েছে তোর সাথে আবার পরে কথা কমু'],
#  ['rec_17_small_audio_2.wav', '<>'],
#  ['rec_16_small_audio_0.wav', '<>'],
#  ['rec_22_small_audio_0.wav',
#   'সুমন তার প্রয়োজন জাকারিয়া এর কয়েকজনের নাম দিয়েছে বটে'],
#  ['rec_04_small_audio_1.wav',
#   'হ্যাঁ দুনিয়াতে শান্তি পাবে না আখেরাতেও শান্তি পাবেন আর সবাইকে সালাম জানান সবাই ভালো থাকেন আসসালামু আলাইকুম ওরাহমাতুল্লাহ'],
#  ['rec_18_small_audio_0.wav', 'মোটামুটি ভালো আছি'],
#  ['rec_17_small_audio_3.wav', 'আর এখন 70000 বড়লোকের জন্য খেলা'],
#  ['rec_20_small_audio_0.wav', 'হযরত মুহাম্মদ সাল্লাহু সাল্লাম'],
#  ['rec_16_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_16_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_4.wav', '<>'],
#  ['rec_16_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_16_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_5.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_3.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_4_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_4_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_3.wav', '<>'],
#  ['rec_17_big_audio_8_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_4.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_8_chunk_3.wav', '<>'],
#  ['rec_17_big_audio_8_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_5_chunk_5.wav', '<>'],
#  ['rec_17_big_audio_8_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_1_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_7_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_7_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_7_chunk_2.wav', '<>'],
#  ['rec_17_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_1_chunk_3.wav', '<>'],
#  ['rec_17_big_audio_6_chunk_3.wav', '<>'],
#  ['rec_17_big_audio_6_chunk_2.wav', '<>'],
#  ['rec_22_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_17_big_audio_6_chunk_0.wav', '<>'],
#  ['rec_17_big_audio_6_chunk_4.wav', '<>'],
#  ['rec_17_big_audio_6_chunk_1.wav', '<>'],
#  ['rec_22_big_audio_0_chunk_0.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 1320

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["Contents"] = content

# %%
df
# Out:
#               External_ID                                      Contents
# 0     rec_09_audio_53.wav                       সেটা এখন সরকারি করেন না
# 1     rec_09_audio_36.wav                         অতি বাড়ি এসি লাগে না
# 2     rec_09_audio_30.wav                        মানিকের হাতেই লেখা আছে
# 3     rec_09_audio_38.wav                       বেটি বলে তো বিয়ে দিয়ে
# 4     rec_09_audio_28.wav  আল্লাদের ভাত খাও মোর অভাব নাই করে না দুটো 10
# ...                   ...                                           ...
# 1315  rec_09_audio_31.wav                                        চলে না
# 1316  rec_09_audio_43.wav                                  যেভাবে পারেন
# 1317  rec_09_audio_22.wav                                        তারপরে
# 1318  rec_09_audio_37.wav             বকুলের সাথে যোগাযোগ হয় না তাই না
# 1319  rec_09_audio_33.wav                                            <>
#
# [1320 rows x 2 columns]

# %%
len(df)
# Out:
# 1320

# %%
df.to_excel("1.1: rangpur-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
