# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnunicodenormalizer
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22781 sha256=971f8287ee690ecfadc3d4e7902fb43b0c6f5412d544c564abcc247319d527cc
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/e9/16732a619cbf5a63fdc9f6e2f9eb5fcf73fa023735237330e9
# Successfully built bnunicodenormalizer
# Installing collected packages: bnunicodenormalizer
# Successfully installed bnunicodenormalizer-0.1.6
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.0

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/'

# %%
files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_19_audio_40.wav', 'rec_19_audio_31.wav', 'rec_19_audio_15.wav', 'rec_19_audio_3.wav', 'rec_19_audio_14.wav', 'rec_19_audio_2.wav', 'rec_19_audio_18.wav', 'rec_19_audio_28.wav', 'rec_19_audio_10.wav', 'rec_19_audio_24.wav', 'rec_20_audio_32.wav', 'rec_20_audio_21.wav', 'rec_20_audio_22.wav', 'rec_20_audio_8.wav', 'rec_20_audio_3.wav', 'rec_20_audio_15.wav', 'rec_20_audio_6.wav', 'rec_20_audio_4.wav', 'rec_20_audio_2.wav', 'rec_20_audio_41.wav', 'rec_20_audio_38.wav', 'rec_20_audio_7.wav', 'rec_20_audio_29.wav', 'rec_20_audio_1.wav', 'rec_20_audio_18.wav', 'rec_20_audio_14.wav', 'rec_20_audio_23.wav', 'rec_20_audio_11.wav', 'rec_20_audio_5.wav', 'rec_20_audio_30.wav', 'rec_20_audio_37.wav', 'rec_20_audio_28.wav', 'rec_20_audio_39.wav', 'rec_20_audio_27.wav', 'rec_20_audio_20.wav', 'rec_20_audio_26.wav', 'rec_20_audio_12.wav', 'rec_20_audio_17.wav', 'rec_20_audio_24.wav', 'rec_20_audio_34.wav', 'rec_20_audio_31.wav', 'rec_20_audio_40.wav', 'rec_20_audio_13.wav', 'rec_20_audio_25.wav', 'rec_20_audio_10.wav', 'rec_20_audio_35.wav', 'rec_20_audio_33.wav', 'rec_20_audio_36.wav', 'rec_20_small_audio_0.wav', 'rec_20_audio_0.wav', 'rec_20_audio_19.wav', 'rec_20_audio_9.wav', 'rec_20_audio_16.wav', 'rec_21_audio_32.wav', 'rec_21_audio_16.wav', 'rec_21_audio_31.wav', 'rec_21_audio_33.wav', 'rec_21_audio_26.wav', 'rec_21_audio_44.wav', 'rec_21_audio_15.wav', 'rec_21_audio_0.wav', 'rec_21_audio_2.wav', 'rec_21_audio_19.wav', 'rec_21_audio_30.wav', 'rec_21_audio_24.wav', 'rec_21_audio_14.wav', 'rec_21_audio_40.wav', 'rec_21_audio_4.wav', 'rec_21_audio_17.wav', 'rec_21_audio_37.wav', 'rec_21_audio_7.wav', 'rec_21_audio_10.wav', 'rec_21_audio_34.wav', 'rec_21_audio_12.wav', 'rec_21_audio_23.wav', 'rec_21_audio_43.wav', 'rec_21_audio_35.wav', 'rec_21_audio_27.wav', 'rec_21_audio_22.wav', 'rec_21_audio_13.wav', 'rec_21_audio_36.wav', 'rec_21_audio_38.wav', 'rec_21_audio_18.wav', 'rec_21_audio_28.wav', 'rec_21_audio_3.wav', 'rec_21_audio_11.wav', 'rec_21_audio_1.wav', 'rec_21_audio_21.wav', 'rec_21_audio_25.wav', 'rec_21_audio_41.wav', 'rec_21_audio_9.wav', 'rec_21_audio_29.wav', 'rec_21_audio_8.wav', 'rec_21_audio_6.wav', 'rec_21_audio_20.wav', 'rec_21_audio_45.wav', 'rec_21_audio_5.wav', 'rec_21_small_audio_0.wav', 'rec_21_audio_42.wav', 'rec_21_audio_39.wav', 'rec_22_audio_39.wav', 'rec_22_audio_14.wav', 'rec_22_audio_27.wav', 'rec_22_audio_29.wav', 'rec_22_audio_9.wav', 'rec_22_audio_26.wav', 'rec_22_audio_1.wav', 'rec_22_small_audio_0.wav', 'rec_22_audio_13.wav', 'rec_22_audio_16.wav', 'rec_22_audio_10.wav', 'rec_22_audio_25.wav', 'rec_22_audio_20.wav', 'rec_22_audio_5.wav', 'rec_22_audio_2.wav', 'rec_22_audio_38.wav', 'rec_22_audio_4.wav', 'rec_22_audio_7.wav', 'rec_22_audio_6.wav', 'rec_22_audio_35.wav', 'rec_22_audio_37.wav', 'rec_22_audio_23.wav', 'rec_22_audio_0.wav', 'rec_22_audio_15.wav', 'rec_22_audio_28.wav', 'rec_22_audio_33.wav', 'rec_22_audio_11.wav', 'rec_22_audio_30.wav', 'rec_22_audio_24.wav', 'rec_22_audio_34.wav', 'rec_22_audio_18.wav', 'rec_22_audio_32.wav', 'rec_22_audio_12.wav', 'rec_22_audio_17.wav', 'rec_22_audio_8.wav', 'rec_22_audio_36.wav', 'rec_22_audio_3.wav', 'rec_22_audio_22.wav', 'rec_22_audio_21.wav', 'rec_22_audio_31.wav', 'rec_22_audio_19.wav', 'rec_23_audio_75.wav', 'rec_23_audio_6.wav', 'rec_23_audio_60.wav', 'rec_23_audio_33.wav', 'rec_23_audio_68.wav', 'rec_23_audio_17.wav', 'rec_23_audio_1.wav', 'rec_23_audio_15.wav', 'rec_23_audio_24.wav', 'rec_23_audio_37.wav', 'rec_23_audio_7.wav', 'rec_23_audio_57.wav', 'rec_23_audio_64.wav', 'rec_23_audio_69.wav', 'rec_23_audio_45.wav', 'rec_23_audio_41.wav', 'rec_23_audio_58.wav', 'rec_23_audio_47.wav', 'rec_23_audio_4.wav', 'rec_23_audio_20.wav', 'rec_23_audio_53.wav', 'rec_23_audio_72.wav', 'rec_23_audio_38.wav', 'rec_23_audio_27.wav', 'rec_23_audio_34.wav', 'rec_23_audio_26.wav', 'rec_23_audio_66.wav', 'rec_23_audio_18.wav', 'rec_23_audio_9.wav', 'rec_23_audio_29.wav', 'rec_23_audio_63.wav', 'rec_23_audio_50.wav', 'rec_23_audio_49.wav', 'rec_23_audio_65.wa ...
#
# 1880

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_19_audio_40.wav', 'হঠাৎ'],
#  ['rec_19_audio_31.wav', '<>'],
#  ['rec_19_audio_15.wav', 'ইন্ডিয়ায় গেছে'],
#  ['rec_19_audio_3.wav', '<>'],
#  ['rec_19_audio_14.wav', 'ভালো নাম কি বলবে নাকি'],
#  ['rec_19_audio_2.wav',
#   'তারা চলে গেছে যে আমাকে দুই-তিনদিন আবার কিসের বস চালাক বাড়ি আমি একবার অনলাইন হবে খা মেলা ভালো মাছ'],
#  ['rec_19_audio_18.wav', 'ওয়েদারের ঘর আছে সরি'],
#  ['rec_19_audio_28.wav', '<>'],
#  ['rec_19_audio_10.wav', 'আমি যে বলাডাঙ্গা একটু রান্না তাড়াতাড়ি'],
#  ['rec_19_audio_24.wav', 'মারা গেছে'],
#  ['rec_20_audio_32.wav', 'তার কার কার সাথে কি হয়েছে'],
#  ['rec_20_audio_21.wav', 'সিগরেট সিগরেট তুমি কি কি খাও সিগারেট খাও খাও না'],
#  ['rec_20_audio_22.wav', 'একটা বিড়ি দেবো একবার যদি হাত দেব না'],
#  ['rec_20_audio_8.wav', 'আমি কালা নাকি তাই'],
#  ['rec_20_audio_3.wav',
#   'নাম কি তোমার পিতার নাম কি স্বামীর নাম কি ছিলো নাম কি'],
#  ['rec_20_audio_15.wav', 'গু খাবি গুগল'],
#  ['rec_20_audio_6.wav', 'মাইক্রোফোন আছে বিড়ি খাবে'],
#  ['rec_20_audio_4.wav', 'শালের নাম কি তুমি জানো না কয়টা হা বিড়ি দেবো নি'],
#  ['rec_20_audio_2.wav', '<>'],
#  ['rec_20_audio_41.wav', 'তুমি কি করবে'],
#  ['rec_20_audio_38.wav', 'আমার কাছে বসে যায়'],
#  ['rec_20_audio_7.wav', 'বিয়ে হয়ে গেছে না'],
#  ['rec_20_audio_29.wav',
#   'কানে কি আর করবি ভাই আমি কাজ হয়ে গেছে আমি কি করবো ভাই'],
#  ['rec_20_audio_1.wav', 'তোমার বিটার নাম'],
#  ['rec_20_audio_18.wav', 'তোমার জন্য ছল নিয়ে আইছে'],
#  ['rec_20_audio_14.wav', 'মাই বার্থডে'],
#  ['rec_20_audio_23.wav', 'না আমায় কোলে'],
#  ['rec_20_audio_11.wav', 'কাঁদতে পারি না'],
#  ['rec_20_audio_5.wav', 'সালমে কয়টা তোমার'],
#  ['rec_20_audio_30.wav', '<>'],
#  ['rec_20_audio_37.wav', 'গান কি হবে না'],
#  ['rec_20_audio_28.wav', 'তোর বাড়িতে ছিল না আমাকে লাগবে না'],
#  ['rec_20_audio_39.wav', 'সুড়সুড়ি এখনো আছে সুড়সুড়ি এখনো'],
#  ['rec_20_audio_27.wav', 'তোমরা ভাই বোন কয়টা মনে আছে আছে'],
#  ['rec_20_audio_20.wav',
#   'নাতিন নাতিন তোমার নাতিন বিড়ি নিয়ে আইছে এক প্যাকেট'],
#  ['rec_20_audio_26.wav', 'সকালে কি খাইছো আরকি আর কিছু না'],
#  ['rec_20_audio_12.wav', 'দুজন একসাথে খেতে পারি'],
#  ['rec_20_audio_17.wav',
#   'তুমি তো বুড়ো হয়ে গেছো তোমার অনেক ইচ্ছা শক্তি আছে নাকি হবে তোমার কি লজ্জা পেলে নাকি'],
#  ['rec_20_audio_24.wav', 'গান দেন'],
#  ['rec_20_audio_34.wav', 'মোটামুটি দাও'],
#  ['rec_20_audio_31.wav', '<>'],
#  ['rec_20_audio_40.wav', '<>'],
#  ['rec_20_audio_13.wav', '<>'],
#  ['rec_20_audio_25.wav',
#   'কৃষি গাব খালি গাবের বিচি যদি খায় গুদির গোড়ায় জাম বেরিয়ে যাবে না'],
#  ['rec_20_audio_10.wav',
#   'তুমি বিয়ের দিন বিড়ি নিয়েছিলে বিয়ের দিন বাসর ঘরে বাসর ঘরে বিড়ি খাইছিলেন'],
#  ['rec_20_audio_35.wav', 'মেলা শুরু হবে'],
#  ['rec_20_audio_33.wav', 'না নাই'],
#  ['rec_20_audio_36.wav', '<>'],
#  ['rec_20_small_audio_0.wav', '<>'],
#  ['rec_20_audio_0.wav', 'তোমার গায়ে হাত দিলে কিছু করার নেই'],
#  ['rec_20_audio_19.wav', 'বিয়ে করবা নাকি ওই বিয়ে করবো'],
#  ['rec_20_audio_9.wav',
#   'তোমার বিটা আমার চেয়ে কালা ছিল ভালো থাকতো ভালো থাকতো বিড়ি খাচ্ছি'],
#  ['rec_20_audio_16.wav',
#   'নাদিম রেটার দিতেই পারে এতে রাগ করতে হয় না দিলে কি হয়'],
#  ['rec_21_audio_32.wav', '50 টাকা করে সবাই চুমা দিতে হবে এই টাকা দেবে'],
#  ['rec_21_audio_16.wav', 'আমি শুনিনি'],
#  ['rec_21_audio_31.wav', 'কাকা খাবি খা'],
#  ['rec_21_audio_33.wav', 'ও প্রতি মাসে একজন মারা যায় না'],
#  ['rec_21_audio_26.wav',
#   'উদাসী আগে একবার টাকা নেয়ার জন্য 5000 টাকা করে যে টাকা দিবা সে রাজ্য সরকারের গান দেন'],
#  ['rec_21_audio_44.wav',
#   'জায়গায় গেছে বাড়ি করেছে তোমাকে এমনি এই প্রোজেক্টের আন্ডারে বেতন দেয় কতটা বেতন 16000'],
#  ['rec_21_audio_15.wav', '<>'],
#  ['rec_21_audio_0.wav', '3 কোটি টাকা দিতে হবে'],
#  ['rec_21_audio_2.wav', 'নাসার আমাকে দেখতে দিবা তোমাকে পুরো সবাই বুঝতে পারবে'],
#  ['rec_21_audio_19.wav', '<>'],
#  ['rec_21_audio_30.wav',
#   'কোন উকিল ছিল না নামকরা সরকারি তারে তারে এক সেকেন্ডের মূল্য এতো তারে ধরি সে কাজ করতেছে এত টাকা দিতে হবে আমাকে সভাপতি'],
#  ['rec_21_audio_24.wav', 'টাকা তোমাদের কাছে থাকে মিটিং ডাকবে কাজ তো হয়নি'],
#  ['rec_21_audio_14.wav',
#   '2000 টাকা করে বাকি পরীক্ষা করে ডিসেম্বরের রয়েছে কি'],
#  ['rec_21_audio_40.wav', '<>'],
#  ['rec_21_audio_4.wav', 'যেই ফটোকপি চুদাই ছিল দোকান'],
#  ['rec_21_audio_17.wav',
#   '95 জন তাহলে হিসেব করার মনে করে 80 জন টাকা দিছে আব্দুল্লাহ কোনো দিতে হবে'],
#  ['rec_21_audio_37.wav',
#   'ওই ভালো প্রথম আমিই করেছিলাম আমার বেতন 1 মাসের তারিখ'],
#  ['rec_21_audio_7.wav',
#   'একের ভিতর কি রাগ করে ফোন দিয়ে কিছু খায় আর কিছু কাজ খারাপ করেছে তারে টাকা উঠেছে এরকম 40000 দিছে'],
#  ['rec_21_audio_10.wav', 'ওই প্রতিবাদ করেছিল মহায় মোল্লার ভাই নেই'],
#  ['rec_21_audio_34.wav', 'তার কোন সমস্যা নেই'],
#  ['rec_21_audio_12.wav',
#   'তোমাকে 3 কোটি টাকা দেওয়া লাগবে কি যত উপজেলা যতজন আছে সবার বাংলাদেশ'],
#  ['rec_21_audio_23.wav', 'কে করতে দিয়েছে'],
#  ['rec_21_audio_43.wav', 'তোমাকে দেখতে'],
#  ['rec_21_audio_35.wav',
#   'কেউ কোনো অসুবিধা অসুস্থ হলে সেগুলো তো তোমরা দাও নাকি অসুস্থতা হইছে মোবাইল'],
#  ['rec_21_audio_27.wav', '<>'],
#  ['rec_21_audio_22.wav',
#   'ওই তিন বছরের চুক্তি বদ্ধ ছিল না সে তিন বছর আমরা বোনাস পাইছি তারপরে তার বোনাস দেয় না আমার'],
#  ['rec_21_audio_13.wav', 'এই নড়াইল লোহাগাড়া আছেন'],
#  ['rec_21_audio_36.wav', '<>'],
#  ['rec_21_audio_38.wav', 'হু'],
#  ['rec_21_audio_18.wav',
#   'সেরা 10 লাখ টাকা তাহলে 96 জন না আরো 16 জন আগে প্রায় মাসে মাসে ডাইকে টাকা তুলতে ওরকম টাকা জমা দিতে হতো 100 করে'],
#  ['rec_21_audio_28.wav', 'কেসের রায় বললাম'],
#  ['rec_21_audio_3.wav',
#   'কাকা ছিল ওই যে এই সেলুনে কাজ করতে হবে মোহনের দোকানে ইত্যাদি'],
#  ['rec_21_audio_11.wav',
#   'শিমুল ওর আর একটা আছে ভাই বাটি ছোট শিপনের ছোট নাকি শুনি নাই'],
#  ['rec_21_audio_1.wav',
#   'পাকা তুলেছি তুলি বেড়াইছে আন্তনি সেই দিন ঘোষণা দিয়েছে কি আমাকে যাওয়ার পরেই টাকাটা আমাকে দিবা কিন্তু না দেখাতে হবে টাকা আমাদের'],
#  ['rec_21_audio_21.wav', '<>'],
#  ['rec_21_audio_25.wav',
#   'কালের মধ্যে একজন আছে সবার প্রতি একজন সেক্রেটারী সভাপতি'],
#  ['rec_21_audio_41.wav',
#   '16 তারিখ থেকে আর 20 তারিখ 8 মাস পরে ছয় মাস পরে এরকম বেতন কত ওটার সমিতি সমিতি এই সুদি করে চালাতে হবে'],
#  ['rec_21_audio_9.wav', 'সুযোগ পেলেই তো মারা শুরু হবে'],
#  ['rec_21_audio_29.wav', '<>'],
#  ['rec_21_audio_8.wav',
#   'সত্যিকারের গান আবার এই কিছুদিন আগে আবার সাহায্য করলে 500 টাকা করে চান তাদের 100 টাকা করে দিয়েছে'],
#  ['rec_21_audio_6.wav',
#   'মাগির একটা সূরা আমাকে এইভাবে তুই বেশি তো প্রতিদিন খায় একজন মারা গিয়েছে'],
#  ['rec_21_audio_20.wav',
#   'আমরা সবাই সুলতানা 2000 টাকা আমরা তো যদি আসার কথা যায় যার পরে টাকা নেবে এটা তোমাকে সুবিধা হবে কি করে আমাদের সংবাদ পাইছে সংবাদ'],
#  ['rec_21_audio_45.wav', '2011 সব মিলিয়ে শোনো যারা আসে নাকি'],
#  ['rec_21_audio_5.wav', 'আব্দুল্লাহ সালামালেকুম'],
#  ['rec_21_small_audio_0.wav', 'খুব ভালো লোক'],
#  ['rec_21_audio_42.wav', 'আষাঢ় মাস কে ছিলেন'],
#  ['rec_21_audio_39.wav', 'ওই শাহ আলম স্যারের এমপি বাংলা'],
#  ['rec_22_audio_39.wav', '<>'],
#  ['rec_22_audio_14.wav', 'কথা আছে'],
#  ['rec_22_audio_27.wav',
#   'তোমার টার্গেট জেনে নেই তুমি তোমার মাইন্ড বলতো তুমি টের হয়ে যাবে ভালো ভালো লোকজন গুছাতে হবে সেজন্য তোমার সাথে কথা কবো জানি'],
#  ['rec_22_audio_29.wav', 'বয়স তো দেখতে হবে'],
#  ['rec_22_audio_9.wav', '11:30'],
#  ['rec_22_audio_26.wav', '<>'],
#  ['rec_22_audio_1.wav', 'আমাগো দাওনা অবস্থা'],
#  ['rec_22_small_audio_0.wav', '<>'],
#  ['rec_22_audio_13.wav', 'কনডম দিয়ে দিয়েছে'],
#  ['rec_22_audio_16.wav', 'সর্বশেষ কোনের লোক দিয়া যায় না'],
#  ['rec_22_audio_10.wav', 'কার বাড়ি চলে এসেছি'],
#  ['rec_22_audio_25.wav', '<>'],
#  ['rec_22_audio_20.wav', 'আগে মনে করো যে অনুভূতি ছাড়া হয়নি'],
#  ['rec_22_audio_5.wav', 'আমাকে দাও তো কৈ মাছ পাওয়া যায় না বলে কবিতা'],
#  ['rec_22_audio_2.wav', '<>'],
#  ['rec_22_audio_38.wav', 'রাগে দিন কি শুরু হয়েছিল গলা ধরে টান দেয় না'],
#  ['rec_22_audio_4.wav', 'গেরের মাছ দেখলাম'],
#  ['rec_22_audio_7.wav', '<>'],
#  ['rec_22_audio_6.wav', 'এ মোস্তফা আছে নেই'],
#  ['rec_22_audio_35.wav', '<>'],
#  ['rec_22_audio_37.wav', 'তোমরা তো রোদ্দুর বৃষ্টি নেই'],
#  ['rec_22_audio_23.wav', 'তোর বয়স কত হবে মোটামুটি কবিতা'],
#  ['rec_22_audio_0.wav', 'খবর কি তোমার কাজ করতেছিলাম'],
#  ['rec_22_audio_15.wav', 'আমি কলামের জন্য দলের সাথে যাইস না ও যাবে না'],
#  ['rec_22_audio_28.wav', '<>'],
#  ['rec_22_audio_33.wav', '<>'],
#  ['rec_22_audio_11.wav', '11:15'],
#  ['rec_22_audio_30.wav', 'পঙ্কজ আমাদের সাথে বাজে না দেখি আর একটা নতুন রয়েছে'],
#  ['rec_22_audio_24.wav', '<>'],
#  ['rec_22_audio_34.wav', 'মাছ'],
#  ['rec_22_audio_18.wav', 'বাড়ি নেই ডাক্তার'],
#  ['rec_22_audio_32.wav', 'ডুবলিকেট দিলেন'],
#  ['rec_22_audio_12.wav', 'মিনিট রাখুন'],
#  ['rec_22_audio_17.wav',
#   'আমাকে যে মতুয়া দল না আমাকে মরতে হবে মনে করে সুবল যদি না যায় অর্ধেক কানা হয়ে যাবে'],
#  ['rec_22_audio_8.wav', '<>'],
#  ['rec_22_audio_36.wav', 'সমস্যা নাই দরকার নেই'],
#  ['rec_22_audio_3.wav', 'আজকে মাছ দেখলাম এই মাছটা কাতলা 3 কেজি হবে না'],
#  ['rec_22_audio_22.wav', '<>'],
#  ['rec_22_audio_21.wav', 'আমি আসতেছি মির দোকানের দোকান'],
#  ['rec_22_audio_31.wav', 'এবার আনতেছি'],
#  ['rec_22_audio_19.wav',
#   'ভালো কৃষ্ণ ডাক্তার ভালো কিন্তু দেয় কি জানতে পারি না'],
#  ['rec_23_audio_75.wav',
#   'মনে করো যে তুমি যা কর তা কও এগুলো বাস্তব কথা আর অপর মতন চাল সে কি করলো না করলে ওকে কি বারাত দেবো ওকে কি বার আছে স্বাভাবিক বিষয় একটা'],
#  ['rec_23_audio_6.wav', 'তোরে কি বাসা থেকে ফোন দিয়ে নিয়ে গেছিল'],
#  ['rec_23_audio_60.wav', 'তোর বর বর নেই'],
#  ['rec_23_audio_33.wav',
#   'তোমার কি দেখি লাইন আমি কি টাকা পয়সা না না আমি কি যে টাকা পয়সা জমা দেবে মনে'],
#  ['rec_23_audio_68.wav',
#   'নানা বাসায় তুমি তুমি বাপন অভাব করার দরকার নেই তুমি ওরে বুঝাই শুনে রাখো ভালো কথা বলেছি'],
#  ['rec_23_audio_17.wav',
#   'না হতে পারে তোমারে চিনবে না তোমারে না লোকেরা চিনে আমি যে পরীক্ষা দিয়েছিলাম সে নিয়ে যায় একজন নড়াইল ভিক্টোরিয়া কলেজের পরে কথা কথা কথা কথা কইতে কইতে পরে আমি কইছি কি ভিক্টোরিয়া আমার বন্ধু একটা পড়ে অভিজিৎ লম্বা করে'],
#  ['rec_23_audio_1.wav', '<>'],
#  ['rec_23_audio_15.wav',
#   'সব শালা ঠাকুর কে মালটা কি তোমারে কিছু কইছে নাকি তোমাকে চেনে'],
#  ['rec_23_audio_24.wav',
#   'আমাদের দেশে আছে তোমার ওই যে কংক্রিটের উপর কংক্রিটের উপর ধরাতে গেলে রাস্তার মধ্যে দৌড়াতে দিয়েছে'],
#  ['rec_23_audio_37.wav',
#   'সময় এখন কত সময় পরে রয়েছে চিন্তাভাবনা করে সেটাই অপুর কি অবস্থা আছে ভালো আছে সমস্যা নাই'],
#  ['rec_23_audio_7.wav',
#   'আচ্ছা আচ্ছা আমরা আগের দিন এমনি এই যে বাবু রানতে গেলাম বাড়ি গেলে পরে চোরের সাথে দেখা করতে গেছিলাম চোর তো শেখ হাসিনা তোর বাড়ি গেছে না'],
#  ['rec_23_audio_57.wav', '<>'],
#  ['rec_23_audio_64.wav',
#   'আর এরা একজন আরেকজনের ক্যারেক্টার সার্টিফিকেট দেয় শালা এলাকার পজিশনটা এমন হয়ে গেছে আমার আসতে আসতে দৃশ্যময় ঈদের আগে দুই দিন আগে আসবানি তুমি বাড়ি যাবা কবে'],
#  ['rec_23_audio_69.wav',
#   'আমি তো ওইদিন রাতে আসছি পরে আর আমার খেয়াল নেই তারপর তো তোমার সাথে কয়েকদিন কথা হলো তুমি আর কিছু কইলে না সেজন্য আমারও খেয়াল নাই ভালো হয়েছে'],
#  ['rec_23_audio_45.wav', 'আর সেই জায়গায় একটু নিজের একটা পছন্দ হইছে'],
#  ['rec_23_audio_41.wav', '<>'],
#  ['rec_23_audio_58.wav',
#   'ওই যে আগে ছিল মার্কা মারা কিছু আর নেই নতুন কিছু পাইছি যুক্ত হইছে'],
#  ['rec_23_audio_47.wav', 'আনতে যায়'],
#  ['rec_23_audio_4.wav',
#   'তোর কি ফোন দিচ্ছে নাকি ওতো ফোন মনে হয় ভাইব্রেট করতেছে সাইলেন্ট করেন'],
#  ['rec_23_audio_20.wav',
#   'মনে করো 7:30 মিনিটে 1600 মিটার দৌড়াতে হবে তাহলে মাঠের ফাল্লা আছে তোমার আঠারোশো মিটার আর আমাদের তিন ঘন্টা নিয়ে বসে আছে রোদ ধরি ওই সময় তো কি গরম গেছে তা তো জানোই আমায় মনে করে যে এবারে'],
#  ['rec_23_audio_53.wav', '<>'],
#  ['rec_23_audio_72.wav',
#   'আমি তোমার কথা শুনতে গিয়েছিলাম বাবু সমস্যা না বাবু তো এটা আর যাই হোক একটা দায়িত্বজ্ঞানহীন ছিল না সে তো এটা জানে সে তো বুঝে'],
#  ['rec_23_audio_38.wav',
#   'হা হা হা হা হা হা হা হা ও মাজে একজন ফোন দিয়েছিল ফোন দিয়েছিলাম'],
#  ['rec_23_audio_27.wav',
#   'সকালবেলায় ঢুকছি 8:00 টার দিকে সেই সময় থেকে মানুষজন চিত হয়ে পড়েছে অসুস্থ আর চুদিরভাই তারপরও সেই ওকে ভোগান্তি কমানোর জন্য আমাকে সে কংক্রিটের উপর দিয়ে দিয়েছে'],
#  ['rec_23_audio_34.wav',
#   'পাসপোর্ট তো জমা দেয়া হয়ে গেছে পাসপোর্ট তো পাঠায় দিছে আরো আগে কি টা পাঠিয়ে দিয়েছে'],
#  ['rec_23_audio_26.wav',
#   'আরো খালিফা ধরতে গেলে ফোসকা পড়ে যাবে আমার তাই পা চলে গেছে তাই আমার পাল চলে গেছে মনে হয় আমরা আমি যে সময় ঢুকছি ওই সময় দেখি'],
#  ['rec_23_audio_66.wav',
#   'না দেখি যদি যাই আমি তোমায় জানাবো নি সমস্যা নাই পরে তো আগের থেকেও পানি আমি কবে যাচ্ছি'],
#  ['rec_23_audio_18.wav', 'ফুটবল খেলা তো খেলা হচ্ছে নাকি'],
#  ['rec_23_audio_9.wav',
#   'আরে আমি কইছি কি যে কিসের টার্নিং কাসে কি ভাই এ বাড়িয়া কৃষিতে আর্সেনিক কলেজে কি শালা আসলেও ভারী ইনকাম করতেছে জানি 1 লাখ টাকার মতন ইনকাম হবে'],
#  ['rec_23_audio_29.wav',
#   'এইসের ডাটা কালেকশনের ওই কাজটা দেখলাম সেই উদ্দেশ্যে হলো যা একবারে দুই কাজ হয়ে গেল আরকি'],
#  ['rec_23_audio_63.wav', '<>'],
#  ['rec_23_audio_50.wav', '<>'],
#  ['rec_23_audio_49.wav', 'কিছু করবি না আমি কিছু করবো তাই করছি করবে'],
#  ['rec_23_audio_65.wav',
#   'হা আমি ফোন দিবানে তোমারে তো জানাই ছিলাম আমি তো কলামে গেলে জানাবেন সমস্যা নাই'],
#  ['rec_23_audio_0.wav', '<>'],
#  ['rec_23_audio_32.wav', 'আরে বৃষ্টি পরে বাবু এসেছিলাম'],
#  ['rec_23_audio_59.wav', 'বাল ছেরা অভিনীত'],
#  ['rec_23_audio_31.wav',
#   'অন্যদিনের তুলনায় আজকে একটা ভালো হয়ে গেছে বাবুর মামু বাড়ি গিয়েছিলাম বৃষ্টিতে'],
#  ['rec_23_audio_14.wav',
#   'একগাদা কথা কইতে পরে করছে চাচতো ভাই আমার কথা শুনে কি মনে হচ্ছে আমার বাবা খাইছি তাই না একা একা কততা করছে'],
#  ['rec_23_audio_67.wav', '<>'],
#  ['rec_23_audio_54.wav',
#   'কি খাতে ছিল কি ধরনের গালে ওঠে খায় যেতো একজন না খাইলে একজন খাতনা সেই মামির সাথে কথা কয় না তাহলে বোঝো তাহলে উনার কি স্বভাব গুড মর্নিং'],
#  ['rec_23_audio_3.wav', 'এবার মনে করছি'],
#  ['rec_23_audio_12.wav',
#   'কালকে কালকে ছিল ঢাকায় এসেছে গতকালকে আইছিল আমার ধারে ছিল রাত'],
#  ['rec_23_audio_74.wav',
#   'আচ্ছা বালছাল গুনার টাইম আছে কয়টা দিন পরে গেলি বউ নিয়ে যাবে না টাকা-পয়সার তো একটা আলাদা মূল্য আছে এটা তো'],
#  ['rec_23_audio_22.wav',
#   'পড়লে এক ঘন্টার পর আর তুমি 4 ঘণ্টা ধরে পড়লে বা 4 ঘন্টা পরে তুমি এক ঘন্টার কোনরকম কাভার করে চলে যেতে হলে তো তা না এতে তোমার দৌড়াদৌড়ি সবকিছু'],
#  ['rec_23_audio_28.wav',
#   'আর ওসব নিয়ে কোন আমি আসলে ওটা নিয়ে আমি কোন প্রিপারেশন নিই নাই এটা হল বাস্তব কথা প্রিপারেশন নিয়ে বাদ গেলে খারাপ লাগত কিন্তু আমি গেছি যেন ফাইজলামি দেখতে আর কি আসলে ঘটনাটা কি আর আমার একটা কাজ ছিল একটা প্রজেক্টের কাজ ছিল'],
#  ['rec_23_audio_10.wav', 'মানে ভাতের কাহিনী'],
#  ['rec_23_audio_70.wav', 'সবাইরে সব কিছু বলা যায় না কেউই যদি পাই নাই'],
#  ['rec_23_audio_55.wav', 'গানটা কি করলো এই কাজ'],
#  ['rec_23_audio_16.wav',
#   'না কিছু কিছু কই নাই চন্দন করছিল আমার এখানে কালকে পাঠিয়েছিলাম'],
#  ['rec_23_audio_35.wav',
#   'এত টেনশন করার কোন দরকার নেই অন্য কোন বিষয় না আমি তো তোমাকে বলছি না আমি তো তোমার কাকারে ডাকে আমি বারবার আমিও দেখলাম আমার বাপও তাই করলাম'],
#  ['rec_23_audio_76.wav', '<>'],
#  ['rec_23_audio_44.wav',
#   'না তা অবশ্য ভালো কথা কই না অপর অবশ্যই সব বিষয়ে এত নজর না দিয়ে ওই সেমিনারে নিয়ে ওরে বুঝায় শুনে এইসব বিষয়ে সব মনে করো কি একটা জিনিস আছে মামা দরজাটি বাদ দেয় না কোন কিছুতে মাটির কাজে'],
#  ['rec_23_audio_13.wav',
#   'রাতে তাই এখানে আমরা ঘোরাফেরা করলাম একটু শীত থেকে খাওয়া-দাওয়া করে বাসায় আসলাম পরে ওরা খানিক মাথার মতো ঘুরে ঘুরে শাহিন তো সে মনের দরজা'],
#  ['rec_23_audio_2.wav',
#   'বাবু যে তাল আমি তো বুঝিনা কোন কিছু আমিতো লাইন বুঝলাম না'],
#  ['rec_23_audio_62.wav',
#   'পজিশনটা এমন জায়গা বাজারের মধ্যে দীপঙ্কর ঘোষের সমিতি বসে আছে'],
#  ['rec_23_audio_40.wav', '<>'],
#  ['rec_23_audio_36.wav',
#   'তোমার সঙ্গে যদি অসুবিধা হয় তোমার যদি এই জিনিস নিয়ে তোমার যদি ঠিকঠাক মতন মনে করে রাত্রে ঘুমাতে না পারো টেনশনে তাতে লাভ আছে নাকি এগুলো কোন বিষয় না এমন তো না যে আজকে না হলে আর হবে'],
#  ['rec_23_audio_19.wav',
#   'তুমি বাড়ি আছো কিসের গাঁড় মারা যায় 2 সেকেন্ড লেট হয়ে গেছে বুঝতে পেরেছ'],
#  ['rec_23_audio_25.wav',
#   'না আমি দৌড়াচ্ছি জুতো পরে তাই আমার পাতলা আগুন ধরে যাওয়ার মত অবস্থা ছিল আরেকজনের কাছ থেকে জুতো জুতো নিয়ে পড়েছে'],
#  ['rec_23_audio_61.wav', '<>'],
#  ['rec_23_audio_21.wav',
#   'আমি যদিও এমনি হওয়ার জন্য গেছিলাম না আমি গেছিলাম প্রথম অনার্স পাশ করার পরে প্রথম চাকরির সার্কুলার দেই এটা ট্রাই করে দেয় এ ছাড়া আর কিছু না কারণ ওর জন্যই তো প্র্যাকটিস ছাড়া তো সম্ভব না এই জায়গাতে তোমার এমন কিছু না যে তুমি'],
#  ['rec_23_audio_46.wav',
#   'বাড়ার আলাপ করে আর উনার সম্বন্ধে তো কোন কিছু তুমি তো না জানাতো না এসব নিয়ে আর আলোয় লাগতো নাই'],
#  ['rec_23_audio_43.wav',
#   'ও তাইতো নাহ এমনটি তো পরে চান্দুরে ফোন দিলে তো আর কি করবো'],
#  ['rec_23_audio_5.wav', '<>'],
#  ['rec_23_audio_48.wav', '<>'],
#  ['rec_23_audio_11.wav', 'বাটের বেটা বাট বিরাট বাট হয়েছে নিতেন'],
#  ['rec_23_audio_30.wav',
#   'না বাসায় বাসায় পরীক্ষা চলো পরীক্ষা দিয়ে এসে পরে বাসায় বাসায় তার বের হয় নাই বিকেল বেলা আইছি গরম আজকে তো একটু মেঘলা মেঘলা একটু কায়দা হয়েছিল মোটামুটি'],
#  ['rec_23_audio_73.wav',
#   'স্বাভাবিকভাবে আমি যে কথা কইতাম চন্দনা কি কথা কইছি শুনে ভালো লাগলো যে না অপুর আসলে এসব জিনিস নিয়ে কি আর করার কোন দরকার নেই বেতন তাহলে নেট বেতন তুই কামাইয়ারা মাসে 60-70 হাজার টাকা কামাতে পারিস তোর এত চিন্তা করে লাভ'],
#  ['rec_23_audio_39.wav', '<>'],
#  ['rec_23_audio_52.wav',
#   'ওকে কাজ আছে ক তুমি যদি 12 যদি তুমি যে মানে সাগর ভাঙ্গা বাড়ির বারোভাতারী তারপরও মনে করে যে ওকে ই হবে না ওকে কোনো বোধ বুদ্ধি হয় না যে যার আছে মাথার মধ্যে কোনো নাই তারে তুমি কি ঘিলু তো আর কায়দায় রেঞ্জি পড়ে তার মাথার মধ্যে ঢুকতে দেবে না তাই'],
#  ['rec_23_audio_42.wav', 'আরে দে মহিলার কি ভুত বুদ্ধি নাই নাকি'],
#  ['rec_23_audio_56.wav', '<>'],
#  ['rec_23_audio_71.wav', '<>'],
#  ['rec_23_audio_8.wav',
#   'তোর বাড়ি এসে মেলাদিন আগে চোর কাছে কি ভাই একটা ট্রেন্ডিং করতেছি ট্রেনিং বাট আমি ভাবছি কি উপজেলার ট্রেনিং তো মনে হয় আসলেই টাকা পয়সা পাবে'],
#  ['rec_23_audio_51.wav',
#   'পাড়ার মনে করো দিন দুনিয়ার যত কোশ্চেন আছে তাই নিয়ে বসে আছি'],
#  ['rec_23_audio_77.wav', 'মানে কি আর কবো'],
#  ['rec_23_audio_23.wav',
#   'তাহলে আর মেল কথা আছে সময় বেধে দিয়ে না সাড়ে সাত মিনিট না হলে 10 মিনিট ওলী বা 9 মিনিট হলে 8 মিনিট হলে একটা কাজ দেওয়া হয় সাড়ে সাত মিনিটে বিশাল টাফ আর তারপরে ওই জায়গায় মনে করো যে এমন এক অবস্থা ওই সময় দৌড়াতে দিয়েছিল আমাকে কিন্তু মাঠের মধ্যে দূরত্ব'],
#  ['rec_24_audio_35.wav', '<>'],
#  ['rec_24_audio_24.wav',
#   'সেলিম শরিফের দানের জন্য এক লাখ টাকা দিতাম বুঝিস তুই যদি 2 লাখ টাকা 1 লাখ টাকা দিতাম কিন্তু আমার এসিস্টেন্ট দিলেও আমি কলি আমার সাথে আমার কথা হয়েছিল'],
#  ['rec_24_audio_41.wav',
#   'এখন যদি আপনি টেনশন ওকে নামে দেন তাহলে আমি রেডি কোর্স দিয়ে দিতে হবে'],
#  ['rec_24_audio_16.wav', 'আমার সবটা দিয়েছিলাম'],
#  ['rec_24_audio_23.wav', 'কিন্তু ভাই এত মনে করত শোনেন ইনশাআল্লাহ'],
#  ['rec_24_audio_10.wav', 'বাহারিন নাচিনা'],
#  ['rec_24_audio_29.wav', '<>'],
#  ['rec_24_audio_36.wav', '<>'],
#  ['rec_24_audio_20.wav', 'সেই 24 তারিখে 28 তারিখ 28 তারিখ 28 তারিখ'],
#  ['rec_24_small_audio_0.wav', '<>'],
#  ['rec_24_audio_33.wav', 'জিজ্ঞাসাবাদ করা যায় না'],
#  ['rec_24_audio_1.wav', 'আমার কাছে নাইস অতিরিক্ত ভালো না'],
#  ['rec_24_audio_11.wav', 'আরো বেশি দিতে পারব'],
#  ['rec_24_audio_8.wav',
#   'এ তোর কি দেখি ভাব তাই কও ফুটবল খেলায় বেড়াচ্ছিস তুই দিনকাল কেমন যাচ্ছে দিলাম'],
#  ['rec_24_audio_0.wav', 'বাবলু রে'],
#  ['rec_24_audio_19.wav', 'আমি জমা করে দিচ্ছি আমি আবার জমা দেবো না'],
#  ['rec_24_audio_32.wav', '<>'],
#  ['rec_24_audio_4.wav', '<>'],
#  ['rec_24_audio_6.wav', '3 ঘন্টা কারেন্ট ছিল না'],
#  ['rec_24_audio_27.wav', '<>'],
#  ['rec_24_audio_13.wav',
#   'সামনে এনে কয়দিনের তলিয়ে যাবে না কইছে দুই মাসের ভিতরে কাগজ দিয়ে দিবে কাগজ বের করে দেবে'],
#  ['rec_24_audio_25.wav', '<>'],
#  ['rec_24_audio_34.wav', 'বাড়ি'],
#  ['rec_24_audio_42.wav', '<>'],
#  ['rec_24_audio_26.wav', 'না ভালো হয়েছে'],
#  ['rec_24_audio_9.wav', 'আপনি কি দেখে আল্লাহ কি করে জানিনা'],
#  ['rec_24_audio_38.wav', 'আপনার কাছে টাকা আপনাদের দিতে হবে কিভাবে দেবেন সবাই'],
#  ['rec_24_audio_17.wav', 'কাগজ জমা দিয়ে দিয়েছি'],
#  ['rec_24_audio_7.wav', '<>'],
#  ['rec_24_audio_2.wav', '<>'],
#  ['rec_24_audio_39.wav', 'বাক করি আর ফলাফল দিয়েছে'],
#  ['rec_24_audio_14.wav', 'পরীর কন্টাক করার সাথে সাথে'],
#  ['rec_24_audio_28.wav', '<>'],
#  ['rec_24_audio_15.wav', 'এটা কোন দেশের টাকা জমা দিয়েছে'],
#  ['rec_24_audio_3.wav', '<>'],
#  ['rec_24_audio_40.wav', 'ওর বাড়ি আমার সাথে ঝগড়া লাগে'],
#  ['rec_24_audio_5.wav', 'কিডা ব্যাটার কিনছে কিনা'],
#  ['rec_24_audio_22.wav', 'আরে তোর আর মিনহাজ আরেকজন'],
#  ['rec_24_audio_30.wav',
#   'ওই সময় যদি ওইটা না দেয় তাহলে ওই যদি ও 12 লাখের বেশি চাই বা এসব করার বেশি হয় একটা সিস্টেম আছে কিন্তু কাগজে একবার বের হতে পারিস এরপরেও'],
#  ['rec_24_audio_37.wav',
#   'আমি কিছু জানিনা আপনাদের সমস্যা সেনাবাহিনী আমাদের কিছু'],
#  ['rec_24_audio_21.wav', 'দিতে হবে'],
#  ['rec_24_audio_12.wav', '<>'],
#  ['rec_24_audio_18.wav', 'কাগজ'],
#  ['rec_24_audio_31.wav', 'আত্মীয় না হলে একটা মনে করেন'],
#  ['rec_25_audio_20.wav',
#   'জাতীয় বিশ্ববিদ্যালয় পরীক্ষা তোমার বাড়তি বাড়তি 6 মাস তো পার হয়ে গেল মে মাস আমাকে সে সরকার থাকে কিন্তু এই যে এই ডিসেম্বরে সেই ফাইনালের পরীক্ষা শুরু হবে 14 তারিখে তে'],
#  ['rec_25_audio_2.wav', 'ঝামেলা'],
#  ['rec_25_audio_6.wav', 'আশেপাশে দোকান দেখতেছি'],
#  ['rec_25_audio_3.wav', '<>'],
#  ['rec_25_audio_31.wav',
#   'জিনিয়াস জিনিয়াস আফ্রিকা তার কি অবস্থা কাজ-বাজ করে নেই'],
#  ['rec_25_audio_30.wav',
#   'এইসব তো করি আবার এক সময় করতে গেছে কিংকর্তব্যবিমূঢ় পত্রিকা'],
#  ['rec_25_audio_12.wav',
#   'প্রতিবছর হয় প্রতিবছর আগে কি পড়ায় তোমাকে আলাদা কোন কোন সাবজেক্ট আছে মানে ধরো যে আমাকে তো যেরকম কোর্স সিস্টেম না'],
#  ['rec_25_audio_17.wav',
#   'সাতটা ক্লাস ঘুরেফিরে হয়না এক বছরে কি কি পড়েছো দ্বিতীয় বছর'],
#  ['rec_25_audio_22.wav',
#   'দেরি হলে তো সমস্যা তো যারা পড়ে তাকে একটা বছর এক্সট্রা মানে বাঁড়া এক বছরের তাই না চাকরির বয়সে কমে যাবে'],
#  ['rec_25_audio_18.wav',
#   'তোমাকে তো বাংলা ক্লাস নাই মনে হয়েছে গিলিত ক্লাস হয়'],
#  ['rec_25_audio_29.wav', '<>'],
#  ['rec_25_small_audio_1.wav', 'সামনে কোম্পানি'],
#  ['rec_25_audio_13.wav',
#   'সমাজবিজ্ঞান আছে রাষ্ট্রবিজ্ঞান ও আমি বুঝতে পেরেছি অনার্স আলাদা সব সময়ই অনার্স ডিগ্রী এগুলো সমমানের আরবি লাইনে আছে না ফাজিল'],
#  ['rec_25_audio_4.wav', '<>'],
#  ['rec_25_audio_10.wav',
#   'এমনি তোমার সেকেন্ড দেন না কয় বছর চলতেছে কয় বছর পড়তে হয়েছে'],
#  ['rec_25_audio_25.wav', 'বিকাশ ছিল'],
#  ['rec_25_small_audio_2.wav', 'সুন্দর সুন্দর কথা গান তারে নিয়ে'],
#  ['rec_25_small_audio_0.wav', '<>'],
#  ['rec_25_audio_19.wav', 'সবাই নিজের কাজ বাস করে বেড়ায় হয়'],
#  ['rec_25_audio_5.wav', 'চুরি হয়নি'],
#  ['rec_25_audio_21.wav',
#   'এর পরীক্ষা দুই মাস পরে দেবে রেজাল্ট দুই পরীক্ষা শেষ হওয়ার দুই মাস পরে রেজাল্ট তাহলে এই এক বছরের মাথায় যে এগিয়ে পরীক্ষা হবে এই এক বছরের পরে জানার শেষ হওয়ার পর'],
#  ['rec_25_audio_32.wav', '<>'],
#  ['rec_25_audio_11.wav',
#   'ওটা তো সবারই গেছে ডিগ্রী সিস্টেমটা কি আমি আসলে জানিনা তোমাকে কি একবারে তিন বছর পরে যে পরীক্ষা'],
#  ['rec_25_audio_26.wav', 'বাবা মারা যাওয়ার পরে একটা টাকার দরকার'],
#  ['rec_25_audio_23.wav',
#   'ডিস্টার্ব তার মধ্যেই করোনা এসে দোকানে থাকতে ওর কি হলো উনি কিরম কি দেখে যেতো'],
#  ['rec_25_audio_27.wav', 'ও'],
#  ['rec_25_audio_8.wav', 'কোন মিস নাই মানে আমার এলাকাতে পাঠাতে মিস হবে না'],
#  ['rec_25_audio_9.wav', 'পড়ালেখা কতদূর কলেজ জাতীয় পারতেছে না'],
#  ['rec_25_audio_14.wav', 'কামিল ফাজিল কামিল'],
#  ['rec_25_audio_0.wav', '<>'],
#  ['rec_25_audio_7.wav', 'ব্যবসা আছে ট্রলার আছে এদিকে আবার নির্বাচন করে নেই'],
#  ['rec_25_audio_24.wav', 'কিসের দোকান'],
#  ['rec_25_audio_33.wav', 'মোটরসাইকেল এখন নিয়ে ঘুরে বেড়ায় টেনশনে নেই'],
#  ['rec_25_audio_15.wav', 'ফাইনাল পরীক্ষা'],
#  ['rec_25_audio_35.wav', 'গোবিন্দ কত ছোট দেশি গোবিন্দ হঠাত করে বড় হয়ে গেল'],
#  ['rec_25_audio_36.wav', 'হা হা হা হা হা তো মনে নাই তোর মত মানুষ নেই'],
#  ['rec_25_audio_34.wav', '<>'],
#  ['rec_25_audio_28.wav', 'মামা বাড়িতে পরিমাণ বসে থাকে'],
#  ['rec_25_audio_1.wav', 'ডিএসআর'],
#  ['rec_25_audio_16.wav',
#   'ধন কয়টা সাবজেক্ট এর পরীক্ষা আছে মেজর কোর্স সাতটা আলো পড়ায় হবে'],
#  ['rec_26_audio_36.wav', 'আপনি একটু জান আপনি ছোট ছেলে তোমাকে সেই সময় ছিল'],
#  ['rec_26_audio_31.wav', 'না তো কয় যে আমি এই করব না'],
#  ['rec_26_audio_47.wav', 'যাইয়ে'],
#  ['rec_26_audio_0.wav', '<>'],
#  ['rec_26_audio_14.wav', 'কিসের জন্য'],
#  ['rec_26_audio_3.wav',
#   '2.75 পাওয়ার দিয়েছে আমার হলো 1.5 ওর হলো ওর আগে যে সময় আমরা একসাথে ডাক্তার দেখলাম ক্ষতি বেশি হবে'],
#  ['rec_26_audio_38.wav', 'নদীর কূলে লঞ্চ যত নদী ছিল'],
#  ['rec_26_audio_37.wav', '<>'],
#  ['rec_26_audio_35.wav', '<>'],
#  ['rec_26_audio_8.wav', 'সিঙ্গাপুর নাকি মালয়েশিয়া নাকি যৌগিক কথা শুনছিলাম'],
#  ['rec_26_audio_15.wav',
#   '30 বছর পর্যন্ত 28 বছর পর্যন্ত পারে মুক্তিযুদ্ধের সন্তান 32 বছর 34 বছর পর্যন্ত বাড়ে'],
#  ['rec_26_audio_32.wav', '<>'],
#  ['rec_26_audio_19.wav', '<>'],
#  ['rec_26_audio_23.wav',
#   'খোকনের বেইজিংয়ে জায়গা বেশি বেশি তিন শতক না 4 শতক জায়গা মাইকেল সব জায়গায় দিয়েছে ওনাকে আমি খোকনের আরো তিন চার শতক কম একজন 28 শতক'],
#  ['rec_26_audio_4.wav', '<>'],
#  ['rec_26_audio_30.wav',
#   'তাকাচ্ছে যে ওই সব ছেলেমেয়েকে ভালো হবে সেজন্য করতেছে'],
#  ['rec_26_audio_34.wav',
#   'পাতি ধরে কিন্তু ভারি সুন্দর করে গালে দিবা কেমন যেন মিষ্টি করুন'],
#  ['rec_26_audio_41.wav', 'না লঞ্চ করেছে'],
#  ['rec_26_audio_40.wav', '<>'],
#  ['rec_26_audio_44.wav',
#   'এই রাস্তার তো আমি দেখি নাই রাস্তা বানাইছে না আমরা যাতে আমাদের বাড়ির গাছের'],
#  ['rec_26_audio_25.wav', 'বাড়ি'],
#  ['rec_26_audio_29.wav', 'আমি পাত্তা বললাম তো দরকার নাই'],
#  ['rec_26_audio_52.wav', '<>'],
#  ['rec_26_audio_21.wav', 'আছে আছে'],
#  ['rec_26_audio_28.wav', '<>'],
#  ['rec_26_audio_11.wav', 'ছিল'],
#  ['rec_26_audio_42.wav', '<>'],
#  ['rec_26_audio_50.wav', '<>'],
#  ['rec_26_audio_39.wav',
#   'সেই নদীতে আমরা লঞ্চ দাও খাতায় থাকতো লঞ্চ বিড়ি আবার বর দাও কিছু একখান থাকতো'],
#  ['rec_26_audio_13.wav', 'বউ চাকরি করবে মিলে কত নিয়েছে'],
#  ['rec_26_audio_26.wav', '<>'],
#  ['rec_26_audio_22.wav', '<>'],
#  ['rec_26_audio_24.wav',
#   'ফারুক একজনের 35 36 শতক আরেকজনের আলো 33 শতক কয় শতক থেকে বেশি পাই না তোমাকে'],
#  ['rec_26_audio_18.wav', 'উঠাই নাই কিন্তু এইবার'],
#  ['rec_26_audio_27.wav',
#   'তৌহিদের বউ লাগাইছে ওর জায়গা যেখানে সেই জায়গায় আমার মা পুরো রাস্তা কেটে রাস্তা বানায় বিল্ডিং এর পিছন দিয়ে রাস্তা বানাইয়া তুই কি গেছেন'],
#  ['rec_26_audio_16.wav',
#   'তারপরে তো টাকা লাগবে বলে এটা রাজু তো চার-পাঁচ লাখ টাকা হবে না'],
#  ['rec_26_audio_1.wav', '<>'],
#  ['rec_26_audio_43.wav', '<>'],
#  ['rec_26_audio_17.wav', 'নানার একটা আছে দাদার একটা আছে ডবল কোথায় কোথায়'],
#  ['rec_26_audio_12.wav', 'ভালো ভালো খেলা'],
#  ['rec_26_audio_48.wav', '<>'],
#  ['rec_26_audio_45.wav',
#   'ওই নদীতে মইরে গেছে বৈদ্যবাটি রৈ নদীতে লঞ্চ চলতো করলাম না'],
#  ['rec_26_audio_49.wav', '<>'],
#  ['rec_26_audio_5.wav', '<>'],
#  ['rec_26_audio_54.wav', 'দেশের মানুষের ভালো হয়েছে'],
#  ['rec_26_audio_7.wav', 'রিয়াজ কোথায় এসেছিলেন'],
#  ['rec_26_audio_33.wav',
#   'একটা বড়ই গাছ ছিল এত সুন্দর বড়ই ওতো সারা গ্রামে নাই'],
#  ['rec_26_audio_20.wav',
#   'পজেটিভ যে জায়গাটা বাগান ভবনের মত ছিল সাফ করে দিয়েছে'],
#  ['rec_26_audio_6.wav', '<>'],
#  ['rec_26_audio_2.wav', '<>'],
#  ['rec_26_audio_51.wav', '50 টাকা'],
#  ['rec_26_audio_10.wav', '<>'],
#  ['rec_26_audio_9.wav', '<>'],
#  ['rec_26_audio_46.wav', 'ল'],
#  ['rec_26_audio_53.wav', 'ঋষি কি তরকারি যাচ্ছে না'],
#  ['rec_27_audio_12.wav',
#   'মেওর আর এম্পিয়ার নেগোসিয়েশন করছে করে মনে ভাগাভাগি করে পরে এখন আবার রানিং চলতেছে তোমার ভয়েস দেখতে ডাইরেক্ট খুলনা বাস চালু হয়েছে'],
#  ['rec_27_audio_27.wav', 'একদম নিরিবিলি যাস আর কোন ঝামেলা'],
#  ['rec_27_audio_15.wav',
#   'এই আছে তোমার লাইনে কি খবর কও না শুনলাম মোটামুটি দুই জায়গার লোকেশন'],
#  ['rec_27_audio_6.wav',
#   'না কবিরুল মাতৃগাছের ড্রাইভার মারতে গেলে পরে সব থেকে দিয়েছে'],
#  ['rec_27_audio_26.wav', 'নড়াইল সরাসরি'],
#  ['rec_27_audio_19.wav',
#   'কোন কিছুই হচ্ছে না এক নাকি করি না কি করে থুয়ে দিয়েছে সোলার লাইট'],
#  ['rec_27_audio_17.wav', 'কোন ঝামেলা নাই মাজার বিয়ারিং বেয়ারিং যা আছে'],
#  ['rec_27_audio_18.wav', 'গোপালগঞ্জ পর্যন্ত বাংলাচুদাচুদি'],
#  ['rec_27_audio_1.wav',
#   'আপনি একটু আমারে দেখি কোন এলাকার কি ঘটনা কি দিয়ে কি অবস্থা কিরকম কাজ কাম করতাছে কোন কাজ বাজ নেই'],
#  ['rec_27_audio_8.wav', 'মাসুদ কালা মাসুদ হয়েছে'],
#  ['rec_27_audio_3.wav', 'ওর কি লাইন ওর দিকে দেখতে হবে'],
#  ['rec_27_audio_4.wav',
#   'ইয়াসের 150 টাকা দিতে হবে না 50 টাকা গাড়ি প্রতিবেশী দিতে হবে মানে 50 টাকা আছে মাসে একটা আলাদা হয়েছে প্রত্যেকদিন তো তোমার যেসব থাকল 50 টা বেশি দিতে'],
#  ['rec_27_audio_25.wav', '10 কিলোমিটার'],
#  ['rec_27_audio_2.wav', 'একি আপাতত কোন কাজ বাজ নেই উনার ভাই'],
#  ['rec_27_audio_10.wav', 'হবে'],
#  ['rec_27_audio_21.wav',
#   'কিন্তু আমিও দেখলাম কি এই ঝামেলার মধ্যে আমি যাইয়া উল্টে একটা গাড়ি মারা খাবে'],
#  ['rec_27_audio_14.wav', 'না পর্যন্ত আসলেই কমাচ্ছে'],
#  ['rec_27_audio_13.wav', '<>'],
#  ['rec_27_audio_5.wav', 'যারা ড্রাইভার ছিল সব একসাথে পরে করছি'],
#  ['rec_27_audio_9.wav', 'ওরা নাকি নাম ভুলে গেলাম বয়স কি আমাকে বলেছিলে পরে'],
#  ['rec_27_audio_16.wav', 'মোটামুটি ভালো বাজে জায়গা হচ্ছে বৃষ্টির সময়'],
#  ['rec_27_audio_0.wav',
#   'তাহলে বড় ভাই তাহলে আপনার নাম হচ্ছে মুজাহিদুল ইসলাম বাড়িতে আসার পরে আপনার এই বাড়ির সম্বন্ধে আমিতো মেলাদিন বাড়ি যাই না'],
#  ['rec_27_audio_22.wav',
#   'মাশরাফি ভাইয়ের সামনে বর্তমানে কিছু টিপতেছে না প্রধানমন্ত্রী'],
#  ['rec_27_audio_20.wav', '60 কোটি ডানা কয় কোটি আমাকে ছোট ভাই আমারে দিয়েছে'],
#  ['rec_27_audio_24.wav', 'আলহামদুলিল্লাহ সরাসরি'],
#  ['rec_27_audio_11.wav',
#   'যদি ইয়ার পুলিশের দায়িত্ব দিয়েছে টাকা উঠায় এমপি কইছে গালাগালি করছে দুই মাস বন্ধ ছিল পরে মনে হয়'],
#  ['rec_27_audio_23.wav',
#   'ব্রিজটা অলি আমাদের একটু ভালো হতে পারে না জিজ্ঞেস করলাম'],
#  ['rec_27_audio_28.wav', 'একটা কায়দা কায়দা হয়ে যায়'],
#  ['rec_27_audio_7.wav', 'কোন অবস্থায় এমপির মা আবার ভয় পেয়েছে কিনা'],
#  ['rec_28_audio_27.wav', '<>'],
#  ['rec_28_audio_6.wav', '<>'],
#  ['rec_28_audio_13.wav', '<>'],
#  ['rec_28_audio_0.wav', 'অফিস তারিখে কি হয় অংক করেনা স্কুলে নির্বাচন'],
#  ['rec_28_audio_5.wav', '<>'],
#  ['rec_28_audio_19.wav', '<>'],
#  ['rec_28_big_audio_0.wav', '<>'],
#  ['rec_28_small_audio_0.wav', '<>'],
#  ['rec_28_audio_24.wav', '<>'],
#  ['rec_28_audio_23.wav', 'তৃপ্তি দিবি না'],
#  ['rec_28_audio_32.wav', 'হাইট কত হাইট'],
#  ['rec_28_audio_22.wav', 'দুধে কি কি নাম হবে না জানিয়েছে'],
#  ['rec_28_audio_26.wav', 'রংপুরের খেলার দিকে বাড়ি যেতে হবে'],
#  ['rec_28_audio_28.wav', '<>'],
#  ['rec_28_audio_17.wav', '<>'],
#  ['rec_28_audio_20.wav', '<>'],
#  ['rec_28_audio_1.wav', '<>'],
#  ['rec_28_audio_10.wav', 'কলকাতাতে বলেছি রাত 10 টার সময়'],
#  ['rec_28_audio_7.wav', '<>'],
#  ['rec_28_audio_2.wav', 'ক্যাটরিনা সে ঘোষপাড়া আর ব্যান্ড আছে তোমার'],
#  ['rec_28_audio_14.wav', '<>'],
#  ['rec_28_audio_18.wav', '<>'],
#  ['rec_28_audio_25.wav', 'সূত্র শুনবো না'],
#  ['rec_28_audio_12.wav', '<>'],
#  ['rec_28_audio_9.wav', '<>'],
#  ['rec_28_audio_16.wav', '<>'],
#  ['rec_28_audio_4.wav', 'ক্লাস 6 এর বাইরে চলে যাবে'],
#  ['rec_28_audio_3.wav', 'নির্বাচনের'],
#  ['rec_28_audio_8.wav', 'ট্রেনে উঠেছি'],
#  ['rec_28_audio_30.wav', '<>'],
#  ['rec_28_audio_11.wav', 'আমি জানি না প্রসেনজিৎ'],
#  ['rec_28_audio_15.wav', '<>'],
#  ['rec_28_audio_31.wav', 'সোশ্যাল অর রোমান্স করব'],
#  ['rec_28_audio_21.wav', '<>'],
#  ['rec_28_audio_29.wav', 'কোন দিক'],
#  ['rec_28_small_audio_1.wav', '<>'],
#  ['rec_29_audio_67.wav', '<>'],
#  ['rec_29_audio_34.wav', 'আমার নাতির নিরাপদে উঠেছে গানের জায়গায় দিয়েছো'],
#  ['rec_29_audio_1.wav',
#   'গাটি আছে রাজিবের সাথে কি আছে যতদিন ছাড়া কিছু জানে না'],
#  ['rec_29_audio_9.wav', '<>'],
#  ['rec_29_audio_14.wav',
#   'আমার মনের গতি কাটছে না বিদায় চন্দন যতই খুলনার বাড়ি থাকুক কিন্তু আমি চান্দের ধরায় দিলে ওর বাড়ি কোন হালে থাকবে মামা কোন হালে থাকবে মামি কোন হালে থাকবে'],
#  ['rec_29_audio_38.wav',
#   'বাবার তো বহু করলে খাস চিন্তা করলে না যে আমি 10000 গাড়ি খাবো নাই'],
#  ['rec_29_audio_57.wav', 'বান্দা বান্দা'],
#  ['rec_29_audio_31.wav', '<>'],
#  ['rec_29_audio_73.wav', 'সেই সিস্টেম করে দিয়েছে'],
#  ['rec_29_audio_59.wav', '<>'],
#  ['rec_29_audio_45.wav',
#   'ও তাহলে মানে ধান্দা মনে হয় আছি জায়গা আমিতো জানি কোন জায়গায় তোমারে তোমারে তোমারে সাহায্যে মামা টাকা আছে তুই কথা'],
#  ['rec_29_audio_58.wav', '<>'],
#  ['rec_29_audio_70.wav', 'যারা কবে রাতে ভাল মানুষ'],
#  ['rec_29_audio_4.wav', 'কিডনির ওষুধ কি কম হয়ে যাবে'],
#  ['rec_29_audio_55.wav', 'ধরতে'],
#  ['rec_29_audio_71.wav',
#   'যে বুঝতে যে দেশে সে ঠিক পাচ্ছে যে আমি তো কমের মধ্যে পাঠিয়েছি কোন জায়গায় কি খাওয়াতে হবে সেইটা হসপিটাল'],
#  ['rec_29_audio_23.wav', '<>'],
#  ['rec_29_audio_63.wav', 'গলা সিরা গলার পরে লাখ লাখ দিলে পাওয়া যায় না'],
#  ['rec_29_audio_64.wav', 'তোমার মামা খালি'],
#  ['rec_29_audio_33.wav', 'আগে'],
#  ['rec_29_audio_24.wav',
#   'কষ্ট থাকলে কি ছন্দ বলো আমি পরের মেয়ে আমি তোমাকে আমি ভালোবাসি'],
#  ['rec_29_audio_40.wav',
#   'চান্দন বলে তো মানুষ করতে এনেছে গাটির খাইয়ে যেটুক খাইয়ে এই যেটুক ভাবে মানুষ হয়েছে তাতে তার কোনো দুঃখ নাই আজকে বাবা থাকতো'],
#  ['rec_29_audio_25.wav', 'আমার কাছে কি সিরিয়ার বউ কাছে মরে নাই শুনলাম'],
#  ['rec_29_audio_50.wav', 'তার মারানির বাড়ি কোথায়'],
#  ['rec_29_audio_27.wav', 'দেবে'],
#  ['rec_29_audio_69.wav', 'আমার জন্য কি দরকার মালিক'],
#  ['rec_29_audio_32.wav',
#   'তাহলে দাদা বাড়ি এসেছি আমি মনে করলাম সত্য আমি মনে করলাম 70 আমি যদি আরেক বাড়িতে'],
#  ['rec_29_audio_49.wav', 'তিনটে ভাই ওই যে'],
#  ['rec_29_audio_52.wav', 'অনুমতি দাও মরা যদি বেঁচে থাকে'],
#  ['rec_29_audio_53.wav',
#   'আর মারার মা যদি বেঁচে থাকে তোমার সব কাজ কি আমরা তোমার সব কাজ কেমনে ভাববো অনুমতি দাও তোমার সব কাজ ভালোভাবে করবো আমরা তুমি যে কষ্ট যে আমার চার্জ দিয়েছো আমার ভাগ্যে কি'],
#  ['rec_29_audio_11.wav',
#   'তা আমি তো কি তোর বাড়িটা কি মরে যাবে নাকি জামাইরে নিয়ে ছন্দ নিয়ে যেটুক বলবে তোর বাড়িটা কেউ বোঝেনা মরা ও কিছু বোঝে না কিছু বোঝেনা'],
#  ['rec_29_audio_10.wav', '<>'],
#  ['rec_29_audio_39.wav', 'আজকে মানুষ করিয়ে দিল তারে'],
#  ['rec_29_audio_18.wav',
#   'ব্যাটারি আমাকে দিবা যদি আমারে দে দাইসে আমার বাবা ডাকছে আমার যেটি ভালো-মন্দ বোঝে যেটি ভালো-মন্দ করতেও পারে আমি যখন আমার কাপড় পরা হয়ে গেছে'],
#  ['rec_29_audio_36.wav', 'উপকারিতা'],
#  ['rec_29_audio_22.wav', 'আমি খাই আলাদা তোমার দাদু থাকতে থাকতে'],
#  ['rec_29_audio_62.wav',
#   'একটা অপারেশন যে যে জায়গাটা হইছে আমার মাথা ঘুরছে কয়টা দিন কয়টা দিন মাথাপিছু লইনা বাচ্চা সেরা চইলা'],
#  ['rec_29_audio_48.wav', 'তিনটে ভাই'],
#  ['rec_29_audio_5.wav', '<>'],
#  ['rec_29_small_audio_0.wav', '<>'],
#  ['rec_29_audio_72.wav',
#   'কিছু না কতদিন রয়েছে আমাকে তাহলে তো পরিচিত হয়ে গেছে না'],
#  ['rec_29_audio_68.wav', '<>'],
#  ['rec_29_audio_37.wav', 'আমার ছবি যে কয়টা আছে মাথায় পারো'],
#  ['rec_29_audio_3.wav', '<>'],
#  ['rec_29_audio_12.wav',
#   'ট্রান লিভারে এই সময় তোমারে মোবাইল করেছে মোবাইল করেছে তুমি সেই মোবাইলের চার্জার চলে এসেছে তোমার সাথে যোগাযোগ করতেছে'],
#  ['rec_29_audio_13.wav',
#   'ঢাকায় খুললে বাড়ি গৌতমের সাথে যোগাযোগ করতে কৌশল জন্ম তাহলে আমি সেইভাবে ঢাকার ভাই কোন সময় থাকবে না আবার অনেক সময় ডাক্তারের মহিলা থাকবে'],
#  ['rec_29_audio_28.wav', 'মারাঠাদের মারা দেবে এক পাইয়া সিরিয়াল'],
#  ['rec_29_audio_66.wav', 'ভিডিও'],
#  ['rec_29_audio_2.wav', '<>'],
#  ['rec_29_audio_46.wav', 'তোমার নানা'],
#  ['rec_29_audio_65.wav', 'একি তোমরা নিয়ে যায়'],
#  ['rec_29_audio_26.wav', 'ওই বেটি আঁটি তলে পরে খাইয়ে ছড়িয়ে গেলো'],
#  ['rec_29_audio_51.wav',
#   'তোমার ছোট দাদু কানা কানা কানতেছে আমার দাদা আমার তিনটে ভারবি টা'],
#  ['rec_29_audio_8.wav', 'উৎপল'],
#  ['rec_29_audio_21.wav', '<>'],
#  ['rec_29_audio_61.wav',
#   'আর মামারা করতেই পারে আলোচনা করা খারাপ কিছু না আমারও তো কোনো রকম'],
#  ['rec_29_audio_0.wav', '<>'],
#  ['rec_29_audio_35.wav', 'আগামী 10 দিনের মাথায়'],
#  ['rec_29_audio_16.wav',
#   'তোমার বড় বাড়ির ওই অবস্থা আমি তোমার নাম আজকে বাড়ি তোমার মা বাড়ি যাচ্ছে আমারে কাপড় পরা নিয়ে যাচ্ছে যে আমার যেটি ভালো-মন্দ বোঝে আমিও থাকবো আমার যেটিও থাকবে ওই যে ওরে ও অপারেশন করা হয়েছে নুন'],
#  ['rec_29_audio_56.wav', 'যে মেয়ে দিয়েছে'],
#  ['rec_29_audio_41.wav',
#   'ইনকামের পাতায় গিয়েছিল থাকতে বসে 20 বছর খাইয়া যেত তারে কামাই রেখা ঠিক আছে না'],
#  ['rec_29_big_audio_0.wav',
#   'তোমার মা আমার স্ত্রী জানে আমি যদি এই বাড়ি কিছু করি তার মা ডাক দিলে ধরে গেছে'],
#  ['rec_29_audio_19.wav', 'দরকার নাই'],
#  ['rec_29_audio_43.wav', 'আমরা ভয় পাই'],
#  ['rec_29_audio_7.wav', '<>'],
#  ['rec_29_audio_42.wav', 'মানুষ সবাই নিজে নিজে কতটুকু টাকা পয়সা খরচ হয়েছে'],
#  ['rec_29_audio_20.wav',
#   'আমি খাই বটে তারা কি খায় আমি জানতে পারি সুজনের শালীর ঘরের টাকা আছে আমি কোন কিছু যাব না রাইখা বাড়িতে যাব না আমি কি লেনি দিয়ে পাঠাবো চিকিৎসা ভালো হবে চিকিৎসা ভালো হয়'],
#  ['rec_29_audio_54.wav', 'আমার ভাগ্যে কে ওনাকে সাল মেরে দাদা'],
#  ['rec_29_audio_17.wav',
#   'নাজির বাজার করতে পারবা নি ওই জায়গাটা তোমার মা পুতিয়ে গেল পুতিয়ে গেল যে আমার যেটি আমাকে সংসারে যায় ভালো-মন্দ বুঝিস আমার বাবা যে তোমার ডাক'],
#  ['rec_29_audio_44.wav', 'নানা জীবনেও হবে না আমার সাথে আমার আলোচনা হয়েছে'],
#  ['rec_29_audio_30.wav', 'সোহাগ রাত'],
#  ['rec_29_audio_60.wav', '<>'],
#  ['rec_29_audio_6.wav', 'বেটা বেটি অন্য ডাক্তার দেখান'],
#  ['rec_29_audio_15.wav',
#   'কিন্তু রাজি বুঝতেই পারে বাসবে না আমি তোমারে করলাম অলেখা আমার কথাটা শুনে তোমার মোবাইল করলাম আগের বার'],
#  ['rec_29_audio_29.wav', '<>'],
#  ['rec_29_audio_47.wav', 'ওর মা আর একটা করতে পারি না'],
#  ['rec_30_audio_18.wav', '<>'],
#  ['rec_30_audio_6.wav', '<>'],
#  ['rec_30_audio_35.wav', '<>'],
#  ['rec_30_audio_8.wav', '<>'],
#  ['rec_30_audio_20.wav', '<>'],
#  ['rec_30_audio_12.wav', '<>'],
#  ['rec_30_audio_19.wav', '<>'],
#  ['rec_30_audio_7.wav', '<>'],
#  ['rec_30_audio_13.wav', '<>'],
#  ['rec_30_audio_0.wav', '<>'],
#  ['rec_30_audio_33.wav', '<>'],
#  ['rec_30_audio_10.wav', '<>'],
#  ['rec_30_audio_5.wav', 'তারপরে'],
#  ['rec_30_audio_30.wav', 'ভিডিও'],
#  ['rec_30_audio_3.wav', 'আমি আর খাবো না নাই'],
#  ['rec_30_audio_34.wav', 'ভিডিও'],
#  ['rec_30_audio_14.wav', '<>'],
#  ['rec_30_audio_21.wav', '<>'],
#  ['rec_30_audio_31.wav', 'আমার মতন হাজার হাজার'],
#  ['rec_30_audio_17.wav', '<>'],
#  ['rec_30_audio_9.wav', '<>'],
#  ['rec_30_audio_23.wav', 'আমার দিদিকে কিভাবে মরে যাবে'],
#  ['rec_30_audio_11.wav', '<>'],
#  ['rec_30_audio_15.wav', '<>'],
#  ['rec_30_audio_25.wav', '<>'],
#  ['rec_30_audio_4.wav', '<>'],
#  ['rec_30_audio_1.wav', '<>'],
#  ['rec_30_audio_27.wav', '<>'],
#  ['rec_30_audio_29.wav', 'আমেরিকার হয়নি'],
#  ['rec_30_audio_32.wav', '<>'],
#  ['rec_30_audio_22.wav', '<>'],
#  ['rec_30_audio_16.wav', 'করে না'],
#  ['rec_30_audio_28.wav', 'আর কোনদিন'],
#  ['rec_30_audio_24.wav', '<>'],
#  ['rec_30_audio_37.wav', '<>'],
#  ['rec_30_audio_2.wav', 'কালকে আমি কিন্তু হবো না নে'],
#  ['rec_30_audio_26.wav', '<>'],
#  ['rec_30_audio_36.wav', '<>'],
#  ['rec_30_audio_39.wav', 'খাওয়া শেষ হয়েছে'],
#  ['rec_30_audio_41.wav', '<>'],
#  ['rec_30_audio_42.wav', 'লড়াইলে জানে না'],
#  ['rec_30_audio_38.wav', '<>'],
#  ['rec_30_small_audio_0.wav', 'তোকে জামাই তোর মতন তাজা কালা হয়ে গেছে'],
#  ['rec_30_audio_43.wav', 'রবি ঠাকুরের মুদিখানার দোকান'],
#  ['rec_30_audio_44.wav', 'আমি তোমাকে মারতে চাইছি'],
#  ['rec_30_audio_46.wav', '<>'],
#  ['rec_30_audio_40.wav', 'না স্নান করবো'],
#  ['rec_30_audio_45.wav', 'বাগমারা বাগমারা না'],
#  ['rec_31_audio_2.wav', 'আসসালামু আলাইকুম'],
#  ['rec_31_small_audio_1.wav', 'বাবা কি রকম সমস্যা ছিল উনারা দলিল লেখা ছিল না'],
#  ['rec_31_audio_23.wav', 'ওটার সিস্টেম নাই'],
#  ['rec_31_audio_17.wav',
#   'এর আগে কোন উকিল মুড়ির পয়সা দিয়ে কোন কাজ রেকর্ডের পয়সা হাল পর্সা তুলে আইনে কবে যেখানে আমি জয়েন পাবো এই যে ঠিক আছে'],
#  ['rec_31_audio_11.wav', 'এই মিলে মোট হয়েছিল দুই একর তোমার সাড়ে 32'],
#  ['rec_31_audio_8.wav',
#   'তোর বাবা ফটো তুলে 74 শতাংশ মোট জমি 2174 কিন্তু যদি 31 হয় তাও তো ফিরে যাবে'],
#  ['rec_31_audio_3.wav', 'কি করলাম'],
#  ['rec_31_audio_1.wav', 'উনাকে কি সঠিক জায়গা আমি তো কাগজপত্র নাই'],
#  ['rec_31_audio_22.wav', '14 টা ছেলে মেয়ে সর্বনিম্ন ডিগ্রী পাস করছে'],
#  ['rec_31_audio_12.wav',
#   'আর বাদ বাকি আছে মার নামে করেছে 22 শতক মানে হাল রেকর্ড করেছে'],
#  ['rec_31_audio_5.wav',
#   'পাকা দলিল রয়েছে তুমি যতই বক দখল করো না কেন তোমার সব কেটে যাবে যার আসল দলিল আছে কাগজপত্র বার করেছি'],
#  ['rec_31_audio_18.wav',
#   'যারা বোঝে জমি জাতির বিষয়ে সমস্যা এটা কিন্তু ভারী পাকা ছিল যেমন'],
#  ['rec_31_audio_7.wav', 'আমার তো নেই'],
#  ['rec_31_audio_20.wav', 'কোন বাড়ি কোথায়'],
#  ['rec_31_big_audio_0.wav', 'আমি জমি জায়গা জমি সম্পর্ক'],
#  ['rec_31_big_audio_2.wav', 'কতগুলো এবং হালদা কত প্রকার হয়েছে'],
#  ['rec_31_audio_13.wav',
#   'কি কইছি বুজছো তোমার বাবার কাছ থেকে আমরা এটুকুই কাইটা এনেছে রেকর্ড রেকর্ড করে 22 শতক ইন্টার যেটুক রেকর্ড হইছে'],
#  ['rec_31_audio_10.wav',
#   'তোমার বাবার কাছ থেকে অনলি যতগুলো পর্যায় আছে নিচে ওই পর্যায়ে ফটোকপি আছে মোট কতগুলো জমির জন্য করেছে তোমার বাবা আবার ওই যে আর কার কাছ থেকে লিখে নিয়েছিল সাড়ে 53 শতক'],
#  ['rec_31_big_audio_4.wav', 'না মানে ওইটার ঘটনা নতুন শুনতেছি'],
#  ['rec_31_audio_0.wav', 'এই যে শিবু'],
#  ['rec_31_audio_19.wav',
#   'ওর থেকে উপর ক্লাস হলো কুসুম খাওয়া গাছ বাড়ির ওহাব কা বরিশালে জালাল মাস্টার'],
#  ['rec_31_small_audio_0.wav', 'মনজুর ভাই মঞ্জুর বাইরা না কি হয়'],
#  ['rec_31_audio_21.wav', 'আফজাল শরীফ আফজাল আফজাল শরীফ করছে'],
#  ['rec_31_audio_9.wav', '<>'],
#  ['rec_31_small_audio_2.wav', 'ক্ষমতা নাই'],
#  ['rec_31_small_audio_3.wav',
#   'রাজবাড়ী কুসুম খান এবং কি ব্যানারের 2 টাকা দিতো না'],
#  ['rec_31_audio_15.wav', 'না আমার কাছে একটা পচা আছে আমি কি করি না'],
#  ['rec_31_audio_14.wav', 'বন্ধুরা বাবার মেলা জায়গায় সমস্যা ছিল'],
#  ['rec_31_audio_6.wav',
#   'বায়না পত্রের ফটোকপি ওর জমির ও আছে মেন কাগজ ও আছে সব দেখি শুনতেছি'],
#  ['rec_31_audio_16.wav',
#   'তাহলে ওই কাগজ পাতির মূল্য অনেক বেশি আচ্ছা এলএসডি করে কে কে সংশোধন মামলা করা হয়েছে'],
#  ['rec_31_audio_4.wav',
#   'নামে থাকলেই তো পাবে কাগজ-কলমে থাকলে কোন সিস্টেম নাই বর্তমান নিয়মে কোন সিস্টেম নাই ভোগ দখল করেন'],
#  ['rec_31_audio_24.wav', 'আমি তো জানি'],
#  ['rec_31_small_audio_4.wav', 'মেয়েদের দাগ নাম্বার'],
#  ['rec_32_audio_26.wav', '<>'],
#  ['rec_32_audio_10.wav', '<>'],
#  ['rec_32_audio_31.wav', 'সবাইকে একটা করে জমি নিয়ে করিনি'],
#  ['rec_32_audio_22.wav', 'গলায় দড়ি দিয়ে বরিশাল'],
#  ['rec_32_audio_14.wav',
#   'তোমরা খাইছো আমার বাবা তোমার বাবার আমার বাবার সাথে ভালো সম্পর্ক ছিল তোমার বাবা খাইছি সমস্যা নেই মাজা কোনো পয়সা নেই'],
#  ['rec_32_audio_41.wav',
#   'মনি করছে না আমি এরকম তো কোনো কথা কইনি আমি তো এরকম কোন কথা বলি নাই আমি এরকম টাকা-পয়সার ব্যাপারে কোন কথা বলি নাই আমি শুনতেছিলাম'],
#  ['rec_32_audio_34.wav',
#   'নেশনাল তাড়াতাড়ি গেছে এবার আমারে ডাইরেক আছে কি যে এরকম বাড়ি জমি তোমরা খাচ্ছিলাম'],
#  ['rec_32_audio_4.wav', 'আর এই দাগ নাম্বার এটা রইস এই দাগ নাম্বার'],
#  ['rec_32_audio_28.wav',
#   'আছে আসাদ মিয়া সলভ আমারে কচ্ছে বাড়ি আমরা তো এরকম জমি খাইয়া দিন ধরে'],
#  ['rec_32_audio_25.wav', 'মঞ্জুর পিঠা কণ্ঠে মঞ্জুর ভিডিও'],
#  ['rec_32_audio_15.wav', '<>'],
#  ['rec_32_audio_35.wav',
#   'মেল আগে থেকে কাকা আমাকে দিয়ে গেছিল এই জমিনে করবেন কি অবস্থা আছে তারপরে খাচ্ছেন খান আমি তাই করছি আর আমি কইছি আমি তো এগুলো করতেছি না করতেছে'],
#  ['rec_32_audio_13.wav', 'খাইছে'],
#  ['rec_32_audio_12.wav',
#   'এই একটা দাগ ওই একটা থাক তাহলে ওটা তো তুই খাচ্ছিস খালি নেই'],
#  ['rec_32_audio_21.wav', '<>'],
#  ['rec_32_audio_6.wav',
#   'বাড্ডা দেবো না সেইভাবে রাখাই কিন্তু অরজিনাল কাগজ কলমে মাঝে একজন'],
#  ['rec_32_audio_42.wav', 'আমি বাবুরে চিকিৎসা দেওয়া'],
#  ['rec_32_audio_20.wav', 'এসব যাবে'],
#  ['rec_32_audio_16.wav', 'এখন যদি আমরা নিতে চাই ওই কাগজ বের করতে হবে না'],
#  ['rec_32_audio_8.wav', '<>'],
#  ['rec_32_audio_47.wav',
#   'তুমি তো জানো তোমার কাকুর ব্যাপারে 10000 টাকা পাঠাইছিল তা তো তোমার কাকু মারে গালাগালি পারলো তারপরও আমি সে 10 হাজার টাকা আনলাম কার কাছে পাঠাইছি'],
#  ['rec_32_audio_3.wav', '<>'],
#  ['rec_32_audio_48.wav', 'মেলা টাকা পাঠাইছে দাদা দাদা'],
#  ['rec_32_audio_11.wav', 'আলাদা কাপ এইজন্য'],
#  ['rec_32_audio_2.wav', '<>'],
#  ['rec_32_audio_5.wav', 'এনে একটু তোমরাই'],
#  ['rec_32_audio_18.wav', 'তুমি আমার সাথে দিবানা না'],
#  ['rec_32_audio_54.wav', 'শিলা এসে গেছে খাইসেন'],
#  ['rec_32_audio_46.wav', 'আমরা তো পাইছি 10000 টাকা আমার আমার আমার'],
#  ['rec_32_audio_38.wav',
#   'এ বড় বড় ভাই বলে কইছেন টাকা পাঠাইছে বাবা চিকিৎসার জন্যে'],
#  ['rec_32_audio_53.wav',
#   'আগা তোমার বড় মামি আসতো বড় দিদি আমি আসতো সাহস পাই নাই'],
#  ['rec_32_audio_23.wav', 'রাখালদের রাখালকে এসেছে'],
#  ['rec_32_audio_33.wav', '<>'],
#  ['rec_32_audio_27.wav', '<>'],
#  ['rec_32_audio_7.wav', 'টাইফয়েড বিশ্বাসের কথা'],
#  ['rec_32_audio_43.wav', 'আরো শালা আছে ভালো নেই তার কথা বিশ্বাস করা যায় না'],
#  ['rec_32_audio_9.wav', 'ফোরের ভিতর যায় নি'],
#  ['rec_32_audio_40.wav',
#   'আমি কইলাম যে কি এরিসেন টাকা পয়সা তো আমরা পাইছি 10000 টা শুনলাম কত টাকা দিচ্ছে আমাকে চিকিৎসা তাহলে কি হলো আপনি খাইছেন নাহলে আমরা খাইছি তাহলে তুই লাইনে থাক আমারে লাইনে থেকে মনির সাথে কথা বলো মনির সাথে কথা কইছে যে'],
#  ['rec_32_audio_39.wav',
#   'না সুমন বলে এরকম কিছু কই নাই সুমন নিজে কইছে আমি শুনেছি'],
#  ['rec_32_audio_30.wav', '<>'],
#  ['rec_32_audio_50.wav', 'বাবলু মামাতো ভাই হয়েছে'],
#  ['rec_32_audio_45.wav',
#   'তারও তো জমি জাতির বাঘ আছে না সে যদি কয় জামা জমি ইতিহাসে আমি তারে তো কোন খবর আছে তুই যদি ভাগ পাবিনা তোর হক আছে এ নিয়ে যাবি কিন্তু তুই এই সমস্ত কথা বলবি কেন'],
#  ['rec_32_audio_1.wav', 'তুই একটু বুঝাও আমারে কি কাহিনী'],
#  ['rec_32_audio_52.wav', 'তোমার বড় দিদিমা ছোট মামি মামি হয়েছে'],
#  ['rec_32_audio_32.wav', '300'],
#  ['rec_32_audio_24.wav', 'ওয়েদার'],
#  ['rec_32_audio_37.wav', '<>'],
#  ['rec_32_audio_56.wav', '<>'],
#  ['rec_32_audio_55.wav', 'কোনটা'],
#  ['rec_32_audio_0.wav', 'তুই আমার কাহিনী'],
#  ['rec_32_audio_49.wav', 'আমরা তো খাইনি আমরা খালি খালি আমরা খাই নাই'],
#  ['rec_32_audio_19.wav', '<>'],
#  ['rec_32_audio_51.wav', 'আমার বাপ কই দিয়ে যাচ্ছি'],
#  ['rec_32_audio_29.wav', '<>'],
#  ['rec_32_audio_36.wav', 'উনি করতেছে'],
#  ['rec_32_audio_44.wav',
#   'আমি তোর তোর সাথে ওর কোন খারাপ কথা কইয়া বেড়ে আমি কিতা মজা আমি কোন সময় বাজে কথা আমি কোন সময় তুই ভালো থাকলে ভালো থাক খারাপ তাহলে টাকা পাঠানোর কথা সে গেছে মইরে তাহলে আমি কিভাবে মারবো আর এখন'],
#  ['rec_32_audio_17.wav',
#   'কাগজ বাইরের তুমি জানো না তোমার সাথে আমার ফাইলে নিতে হবে'],
#  ['rec_33_audio_3.wav', 'আচ্ছা তুমি আমাকে আসাদ মিয়া কিছু জানো আমাকে'],
#  ['rec_33_audio_4.wav', 'আমিতো কাগজে করতে পারি কাগজ দেখলাম'],
#  ['rec_33_audio_1.wav', 'ওই মাঠ ওর বাবা নিয়ে আর অন্যতম স্কুল কলেজ'],
#  ['rec_33_audio_0.wav', '<>'],
#  ['rec_33_audio_2.wav', 'আসাদ মিয়ার কোনো জমি খাইন'],
#  ['rec_33_audio_21.wav',
#   'আর ওই সময় যদি দখল করতো না আমি তাই শুনেছি যেখানে সেই ভাগির'],
#  ['rec_33_audio_45.wav', 'ও জায়গার ওই মেয়েরা জীবনে কাঁদতে হবে না'],
#  ['rec_33_audio_14.wav', '<>'],
#  ['rec_33_audio_33.wav', 'যেভাবে ফান্দে পারবে না যেটুকু কিছু না'],
#  ['rec_33_audio_37.wav', 'ফুল বিশ্বাসের উপকারিতা'],
#  ['rec_33_audio_11.wav', '<>'],
#  ['rec_33_audio_20.wav',
#   'তা সেই জায়গা রয়েছে তোর বাবা ওই যে ওই পাশে ওরা বাকি ছিল ওই জায়গার মাধ্যমে সেই জমির বদলে যাবে'],
#  ['rec_33_audio_39.wav', 'ওজনের রিসিভ তো ওই জমির দাগ এই খানে একটু পাবে'],
#  ['rec_33_audio_28.wav',
#   'আমাকেই দেখা হচ্ছে যে শিব বাবুর নামে 1356 57 থেকে মনে হয় না'],
#  ['rec_33_audio_30.wav',
#   'শিশিরের নাকি কার ধারে নোটিশ আইছিল আমাকে নামে শিশির আমাকে মেলাদিন পরে দলিল করে নিয়েছে আমাকে দেবে না এইজন্য রেকর্ড হয়ে গেছে সে আমাকে'],
#  ['rec_33_audio_10.wav', 'ওই ওই ধারে খালগুলি কাকে জায়গা হয়েছে'],
#  ['rec_33_audio_25.wav',
#   'তোর বাবারে ডাকিলাম তোর বাবা 100 বার ওখানে জায়গা মাপ হয়েছে তোর বাবা জানে যে সব জায়গা ওকে যা শুনাই নাই বুঝতেছিলাম নাই'],
#  ['rec_33_audio_9.wav', 'দলিল নাই'],
#  ['rec_33_audio_15.wav', '<>'],
#  ['rec_33_audio_29.wav',
#   'এই জন্যে লাভ হয়েছে জানিস এই জন্য লাভ হয়েছে আমি যদি ভালো কোন মেয়ে মানুষ হতো তাহলে ওকে শব্দই বের করে নিয়ে আসতে পারতো কারণ ওই সব সব জমিরি বাবা সব জমি ঝামেলা আছে মেলা জমে আছে সে সব জায়গায় খালি টাকা দিতে হয়েছে কাগজ রেখে দিয়েছে'],
#  ['rec_33_audio_24.wav', 'আমি তোর বাবার বিয়ে হয়'],
#  ['rec_33_audio_49.wav', '<>'],
#  ['rec_33_audio_40.wav', '<>'],
#  ['rec_33_audio_34.wav', '<>'],
#  ['rec_33_audio_5.wav',
#   'মাসুদ মেরে দিয়ে আইছিল কিছু বেশি বেচা আইছিল তা ওর থেকেও বেশি উনি আছে খায় তাও দখলে না উনি আমার মাথাব্যথা নাই আমি এর পিছনে ধরছি আগে ইউটিউব'],
#  ['rec_33_audio_38.wav', 'যদি একটু মানে দখলে রাখতো না'],
#  ['rec_33_audio_8.wav', 'উনি যদি পারে না'],
#  ['rec_33_audio_22.wav', 'বাঘ শিয়ালের বাবা'],
#  ['rec_33_audio_26.wav',
#   'একতারা ছাড়িয়ে পুটকি জাগা যাতে আমি কোনদিন না থাকি মানুষের কাছে হয়েছে নাকি'],
#  ['rec_33_audio_43.wav', '<>'],
#  ['rec_33_audio_42.wav',
#   'আমাকেই অত্র দেশে কি জেলা কই জেলার ভিতরে সবচেয়ে ভালো বুদ্ধিমান লোক আছে ক্যাসেট হবে না'],
#  ['rec_33_audio_31.wav', 'তোকে দেবো না'],
#  ['rec_33_audio_41.wav', 'জমিদারদের ব্যাপারে'],
#  ['rec_33_audio_48.wav', 'দুলাল সরকার'],
#  ['rec_33_audio_51.wav',
#   'ওইগুলো তো হয়েই যায় ওগুলো নিয়ে কোন ভালো জায়গা সেই বিয়েতে আমরা ছিলাম যে সময়ের সাথে বাড়ি খাতের বিয়েতে দিয়ে খাইলাম'],
#  ['rec_33_audio_36.wav', 'পুকুরপাড়ের ওই পাড়ের ভিটা কাকে ছিল না'],
#  ['rec_33_audio_47.wav', 'উনার কোন কাকার ওই মূলত এই ঘর তোকে ওকে করে দেয় না'],
#  ['rec_33_audio_7.wav', 'কিন্তু আমি তোর দৌড়াদৌড়ি করতেছি না'],
#  ['rec_33_audio_23.wav', '<>'],
#  ['rec_33_audio_17.wav', 'দফাদার'],
#  ['rec_33_audio_16.wav', 'সুব্রতকে বাড়ির বাগানের ভিতরে শুনেছিলাম'],
#  ['rec_33_audio_19.wav', '<>'],
#  ['rec_33_audio_6.wav',
#   'স্কুলের নামে যেটা সঠিক তো স্কুলের নাম ইস্কুল পাবে স্কুলের নামে 11 শতক ওঠুক বাদে জমি আছে'],
#  ['rec_33_audio_12.wav',
#   'এখন এখন যদি তুমি আসল দলিল বের করতে পারো তুমি যতই দখলে যাবে এখন নিয়ম পাল্টে গেছে যার নামে দলিল সে এখন দখল করতে পারবে অ্যাসিস্ট্যান্ট হইছে'],
#  ['rec_33_audio_27.wav', '41 জমিতে জানো'],
#  ['rec_33_audio_18.wav', 'দফাদার শতাংশ কিনা'],
#  ['rec_33_audio_50.wav',
#   'তা উনার কি ওনার তো কোন কিছুই তো টিপতেছে না চল একটা পাগল কিভাবে'],
#  ['rec_33_audio_32.wav', 'জমিতে ভালো হবে নি নাই'],
#  ['rec_33_audio_52.wav', 'রাজবাড়ী ফরিদপুর বিশাল আয়োজন করে গিয়েছিলাম'],
#  ['rec_33_audio_35.wav', '<>'],
#  ['rec_33_audio_46.wav', 'দখল করে নিয়েছে'],
#  ['rec_33_audio_44.wav', 'মেলাদিন আগে বাদ দিয়েছি'],
#  ['rec_33_audio_13.wav', '<>'],
#  ['rec_34_audio_34.wav',
#   'ওরে কপালেই তো দিলে চরম একটা ব্যথা আমার বন্ধুরে সামলাতে ব্যস্ত আছি'],
#  ['rec_34_audio_18.wav', '<>'],
#  ['rec_34_audio_10.wav',
#   'না আমি একটা কথা বলবো বলেন সেটা আমি মানলাম আর তুমি কি গান তোরে একটা বার বলতে পারিস না যে আমার সাথে তোর কি সম্পর্ক সেটা তুই তো কাল থেকে বুঝাতে পারিস'],
#  ['rec_34_audio_13.wav', '<>'],
#  ['rec_34_audio_54.wav', '<>'],
#  ['rec_34_audio_57.wav',
#   'আমার মাধ্যমিক বছর ইন্ডিয়াতে বেড়াবে আর 2 বছর আমি যাব 2 বছর যায় আমি কাগজপত্র রেডি করব ইউরোপের যে কোন দেশে ঢোকার ইচ্ছা আছে ইতালি জার্মানি'],
#  ['rec_34_audio_33.wav', 'তোমার আর কিছু সংসারে কিন্তু আগুন ধরে যাবে না'],
#  ['rec_34_audio_23.wav', 'যাক আলহামদুলিল্লাহ'],
# ...
#  ['rec_35_audio_9.wav',
#   'ওই মেশিনে নষ্ট হয়ে যাবে ওনার এত রোগ প্রথম আছে ডায়াবেটিস পরে আছে ওনার চোখেতে নালি হয়েছে'],
#  ['rec_35_audio_10.wav',
#   'এরপরে ওনার আছে পাইলসের সমস্যা তাও মেলা পুরনো সমস্যা এর পরে আছে মাজায় সমস্যা এগুলো হচ্ছে উনি প্রতিদিন কয় উপলব্ধি করে'],
#  ['rec_35_audio_36.wav',
#   'আমি 23 24 তারিখে যাবো কালকে মির্জাপুর গেছিলাম আমি আইসিএসসি আজকে সকালে কালকে সকালে আরকি পরশুদিন দিয়েছিলাম'],
#  ['rec_35_audio_37.wav',
#   'কি হয়েছে মাসি বাবা সব খায় আগের দিন মারা গেছে ছানার সন্দেশ নিয়ে যায় তো'],
#  ['rec_35_audio_64.wav', 'টাকা একটু বেশি লাগে আরকি'],
#  ['rec_35_audio_38.wav',
#   'মা যার সাথে কইছে কি সন্দেশ নিয়েছিস নিয়ে গেছি তারপর আমি মোটরসাইকেল চালায় গেলাম দুইটা নিয়ে গেছিলাম'],
#  ['rec_35_audio_63.wav',
#   'টাকা বেশি লাগে যেদিন যেদিন যাবে তার পরের দিন ফিরে আসা যায়'],
#  ['rec_35_audio_0.wav', 'আমিতো খুলনায় মাসি মা বাড়ি হয়'],
#  ['rec_35_audio_31.wav', '<>'],
#  ['rec_35_audio_56.wav', 'তাও তো পারে সবকিছু জানি সমস্যা না'],
#  ['rec_35_audio_44.wav',
#   'আমি ওদের একটু ফোন দেবো না রে ফোন দিয়ে একটু কথার অর্থ কি'],
#  ['rec_35_audio_29.wav',
#   'রাত্রে কি খেয়েছ তোমরা আমাকে বাবা খেতে খেতে ভালোবাসো'],
#  ['rec_35_audio_7.wav',
#   'ওই ব্যাংকের টা আমার কাছে কি আমারে কি পাগলে কামড়াইছে আমি গাছ টাকা ভাঙে ডাক্তার দেখাবেন পাগল ছাগল'],
#  ['rec_35_audio_50.wav',
#   'আমার কিন্তু আলচনা করে দেখা যায় যে ছেলে হবে না মেয়ে হবে না'],
#  ['rec_35_audio_47.wav', 'কালকে দেবে'],
#  ['rec_35_audio_61.wav', 'ইন্ডিয়া ইন্ডিয়ান নাগরিক অধিকার'],
#  ['rec_35_audio_73.wav', '<>'],
#  ['rec_35_audio_62.wav', '<>'],
#  ['rec_35_audio_65.wav', 'নয়ন আমি কেটে দিয়েছি'],
#  ['rec_35_audio_14.wav', '<>'],
#  ['rec_35_audio_12.wav', '<>'],
#  ['rec_35_audio_3.wav', 'নয়নের বউ কনে বাড়ি নেই'],
#  ['rec_35_audio_54.wav', '<>'],
#  ['rec_35_audio_45.wav',
#   'হা ওই কথা কও তুমি বেশি ফোন দেবো টাকা পাইছেন আজকে ফোন দিয়েছিল আমারে শিব বাবু ফোন দিয়েছিল এরকম আমি বলে আসছি টাকা গেলে দিয়ে দেবে না'],
#  ['rec_35_audio_20.wav', 'জামাই কোন জায়গা থেকে জামাই কোন জায়গা'],
#  ['rec_35_audio_67.wav', '<>'],
#  ['rec_35_audio_43.wav', 'ও মাসি'],
#  ['rec_35_audio_57.wav', '<>'],
#  ['rec_35_audio_30.wav',
#   'উনি কি মাংস কিভাবে খেলে এক এক কেজি কিনে নাকি অল্প অল্প করে'],
#  ['rec_35_audio_5.wav', 'ডাক্তার'],
#  ['rec_35_audio_55.wav', '<>'],
#  ['rec_35_audio_33.wav', 'একমাস হয়ে গেছে'],
#  ['rec_35_audio_19.wav', '<>'],
#  ['rec_35_audio_13.wav',
#   'মাধবপুরে তো বিছানাতে উঠতেই পারতো না কতবার কইছি মাসে আমি ডাক্তার মানুষ'],
#  ['rec_35_audio_68.wav', 'শশুর বাড়ির সাথে মিলমিশ হয়েছে ঠিকঠাক করে দে'],
#  ['rec_35_audio_4.wav', 'স্বর্ণের সাথে কথা বলতে হয়'],
#  ['rec_35_audio_15.wav', 'পড়তে দেবে না'],
#  ['rec_35_audio_22.wav', 'তাসের আছে বলো গরম গরম লাগছে'],
#  ['rec_35_audio_39.wav',
#   'আমার মনে হয় গেছে মামীর ধারে মামিতো গান গাচ্ছে পরশুদিন কবে গিয়েছিলাম সেদিনকে বাড়ি ছিল কলেজ আমি দেখিনি'],
#  ['rec_35_audio_59.wav', '<>'],
#  ['rec_35_audio_41.wav', '<>'],
#  ['rec_35_audio_53.wav', 'আজকে আমার জ্বালা দুইজন ছিল অনেক টেনশন হয়েছে'],
#  ['rec_35_audio_72.wav', 'জয়ন্ত তাহলে একটু দাঁড়াতে পারলি আর সমস্যা হতো না'],
#  ['rec_35_audio_66.wav', 'তন্ত্র কি রকম ইনকাম পেতে কিরম হয় ডাক্তার ডাক্তার'],
#  ['rec_35_audio_51.wav', '<>'],
#  ['rec_35_audio_28.wav', 'ও বলে কি কাজ-বাজ করতো না'],
#  ['rec_35_audio_42.wav', 'হ্যালো'],
#  ['rec_35_small_audio_0.wav', 'আচ্ছা তো মাসি'],
#  ['rec_35_audio_26.wav', 'সায়ন দেখনা শয়তান'],
#  ['rec_35_audio_2.wav', 'নয়ন খনি'],
#  ['rec_36_audio_73.wav', 'বাবারে আমি পারিনা'],
#  ['rec_36_audio_40.wav', 'আসলেই'],
#  ['rec_36_audio_1.wav', 'ওই তো ওই কজনই ফোন দিছি তোমারে আমি বলেছি'],
#  ['rec_36_audio_11.wav', '<>'],
#  ['rec_36_audio_2.wav',
#   'তুমি কি আমার মা বলেছিল না না বলেছে তার কাছে যে এরকম কালকে আড়াইহাজার টাকা নিয়ে আসো'],
#  ['rec_36_small_audio_3.wav', '<>'],
#  ['rec_36_audio_23.wav',
#   'আরে কতদিন পারবা আমি জানিনা বাবু এখনো তো মুখ সাবধানে পারে জানিনা'],
#  ['rec_36_audio_12.wav',
#   'তোমার বর দিয়ে একটু অসুস্থ হইছে এখন আমি করছি ডাক্তার দেখাবো না করছে না ডাক্তার দেখাবো না'],
#  ['rec_36_audio_5.wav', '<>'],
#  ['rec_36_audio_62.wav',
#   'খুলনায় বাড়ি মজা খুলনায় কালিয়া যত খরচ নয় খুলনা তত কম খরচে'],
#  ['rec_36_audio_71.wav',
#   'দেখার লোক হয়ে যায় কিন্তু আসলে যে কষ্ট নিজে কষ্ট ইউটিউব কাজ করি'],
#  ['rec_36_audio_81.wav',
#   'ওই আমার মা তো আমার মা আবার একটু কেমন কেমন না সে সরাসরি'],
#  ['rec_36_audio_15.wav', '<>'],
#  ['rec_36_audio_52.wav',
#   'সেটুক স্কুলের পাশে দখলে যাওয়া যায় কিন্তু খরচ করার লোক আছে সেই লোক আমাকে আছে'],
#  ['rec_36_audio_20.wav', '<>'],
#  ['rec_36_audio_63.wav',
#   'আরে ওখানে মাছ চাষ দিয়ে এইসবের সবকিছু সবজি চাষ আছে ভালো ভালোই তোমার মনে হবে কি আমি খালি আছি লোকজন আছে আর আমাদের কালিমেলা বালটা'],
#  ['rec_36_audio_32.wav', '<>'],
#  ['rec_36_audio_61.wav', 'কালিয়া থেকে পাকিস্তানের'],
#  ['rec_36_audio_50.wav',
#   'আমাকে পুকুর ছিল না পুকুর পাশে ছিল না হা হা হা হা হা হা হা হা হা ওর রক্ত ছিল'],
#  ['rec_36_audio_34.wav', 'প্রস্রাবের সমস্যা আছে তোমার মাঝে মাঝে'],
#  ['rec_36_audio_44.wav', 'ওই যে খাবার-দাবার মেইনটেন না করলেই হয় না'],
#  ['rec_36_audio_53.wav',
#   'কিন্তু সমস্যা হচ্ছে যে ওরা খায় এত বছর ধরে দেখাও আমার বাবার জন্য আমাকে ছেড়ে দাও তোমাকে তো অনেক আছে'],
#  ['rec_36_audio_26.wav', 'জন্মের মুখ সামলাতে পারে না'],
#  ['rec_36_audio_0.wav', 'ভালো আছো'],
#  ['rec_36_audio_65.wav', '<>'],
#  ['rec_36_audio_39.wav', '<>'],
#  ['rec_36_audio_18.wav',
#   'এনে দে 10000 টা আমি কইছি তোমার ব্যাংকে দিয়ে টাকা রয়েছে তার কাছে কি আমারে কি পাগলে কামড়াইছে নাকি ডাক্তার দেখান'],
#  ['rec_36_audio_17.wav',
#   'কচি কথা বল বোঝা যাচ্ছে না কথা বোঝা যাচ্ছে না কোন সময়তে করছি ডাক্তার দেখাবা না'],
#  ['rec_36_audio_45.wav', 'তাতে হয়েছে'],
#  ['rec_36_audio_30.wav',
#   'দ্বাদশ শ্রেণীর দিদিমা অসুস্থ হয়ে পড়েছিল বেশি এখন একটু মোটা কমেছে তো মোটামুটি ভালো আছে তোমার মামার মামার না তো আমার বউয়ের সমস্যা আমার বউ মেলা মোটা না'],
#  ['rec_36_audio_68.wav', '<>'],
#  ['rec_36_audio_60.wav', 'কাকার অনেক প্রভাব ছিল'],
#  ['rec_36_audio_14.wav',
#   'দেবতার বেশি রুটি খাই না দেড়টা দুটো রুটি খাই খাই খাই খাই খাই না ভাত খাই দুটো রুটি খেতে বলেছে'],
#  ['rec_36_audio_27.wav',
#   'তোমার মারতে তো শুরু হয়েছে তুমি খাচ্ছ না এত ভালো আমার মা অবশ্য কম খায় আগে কয়দিন খাটো তাই যে ডাক্তার দেখানোর পরে খায়'],
#  ['rec_36_audio_75.wav', 'ছোট বোনটার দিন একা একা দখল করেছেন'],
#  ['rec_36_audio_57.wav',
#   'তা তো হবে পৌরসভার জমির দাম আরো রাস্তাঘাটে বিক্রি করতেছে না মুসলমানরা ঢুকতেছে তাদের মধ্যে অনেকটা বাড়ি করা থাকলে আমার মনে যা বলে'],
#  ['rec_36_small_audio_2.wav',
#   'আমার সাথে ভালো সম্পর্ক পরে অনেক কি করে আমি আবার'],
#  ['rec_36_audio_70.wav', '<>'],
#  ['rec_36_audio_19.wav', '<>'],
#  ['rec_36_audio_56.wav',
#   'জামেলা হচ্ছে আর ওর বাবা কই গেছিলে এখন আমি কিরম ভুলে যায় না'],
#  ['rec_36_audio_6.wav', 'দুপুরে ভাত খাই এইভাবে রাত্রি কি খাও শরীরটা ভালো না'],
#  ['rec_36_audio_77.wav', 'আমি জেনেছি'],
#  ['rec_36_audio_59.wav',
#   'হয়তো ঢাকা টাকা জনিত মানে সিস্টেম কি হয়েছে আমাকে লোক আছে বুঝছো লোকদেরই হচ্ছে তোমার রাই টাকা দিয়ে সব জমিতে নেবে আর ওদের পাওয়ার আছে ওকে কেউ কিছু করতে পারবে না আমি সামনেও যাব না কাকা'],
#  ['rec_36_audio_72.wav', '<>'],
#  ['rec_36_audio_4.wav', 'কি করতেছ কি ভালো আছি না'],
#  ['rec_36_audio_48.wav', 'আমাকে বিটি দফাদার কে বিটি আছে না'],
#  ['rec_36_audio_22.wav', 'প্রবাসী তুমি এখানে খাবার দোকান'],
#  ['rec_36_audio_31.wav',
#   'মেলায় গিরিখাতের সমস্যা ডাক্তার সে ডাক্তার তাই এখন রুটি খায় শরীরটা একটু কম হইছে'],
#  ['rec_36_audio_41.wav', 'এটা হয়ে গেছে বংশগত তারপর আমার শাশুড়ি'],
#  ['rec_36_audio_69.wav', 'হু শুনতেছি'],
#  ['rec_36_audio_80.wav',
#   'কিন্তু উঁচু লম্বা বডি ফিগার ভালো চেহারা ভালো না চেহারা মিষ্টি ভাব নাই'],
#  ['rec_36_audio_55.wav',
#   'যাক আমাকে জায়গা কিনে সাথে মানে ওই পুকুরের অর্ধেক পর্যন্ত আমাকে জায়গা ছিল কিন্তু কোনদিন হয়েছে দখলে যাই নাই বিধায় আমরা জমি ঢুকেছে'],
#  ['rec_36_audio_64.wav',
#   'মারে কাকা তুই আসতেছে জায়গা কিনবো তারপরে বিদেশ আইইএলটিএস করে বাইরে যাওয়ার একটা ইচ্ছা ছিল তা মা একারে ফেলাইতে নেই'],
#  ['rec_36_audio_9.wav',
#   'দিলাম দেয়ার পরে 170 খাওয়ার পরে আর না খাওয়ার পরে এসেছে 1303'],
#  ['rec_36_audio_8.wav', '<>'],
#  ['rec_36_audio_21.wav', 'ডায়াবেটিস হলে লম্বা 12'],
#  ['rec_36_audio_29.wav',
#   'পরের দিন একটা এসি তোমার দুই পাশে আছে দুইটার একটা পড়বে আর একটা তিনটার ওই যে দাদু আছে তোমার'],
#  ['rec_36_audio_74.wav', 'জিনিস'],
#  ['rec_36_audio_28.wav',
#   'ওই আমাকে শোন আমার ঠাকুরদা দেখেছিল মনেই কিন্তু তার মধ্যে বড় মামার মেয়ের ছবিটা মারা গেল না'],
#  ['rec_36_audio_24.wav', 'সেটাই ঠিক আছে না তো ডায়াবেটিস নেই'],
#  ['rec_36_audio_10.wav', '<>'],
#  ['rec_36_audio_16.wav',
#   'আমাকে বংশগত হয়ে গেছে বুঝেছি তোমার কথাগুলো বুঝা যাচ্ছে না আমার সাথে'],
#  ['rec_36_audio_37.wav', '<>'],
#  ['rec_36_audio_54.wav', 'আমার বাবা আছে আকাশ করেছে সমস্যা'],
#  ['rec_36_audio_46.wav',
#   'আলকা মানে একদম মাপে মাপে ধরা পড়েছিল আমি মানে হাটা তারপরে রুটি খেতাম ওই রুম খেয়ে দেয়ে তাড়াতাড়ি'],
#  ['rec_36_audio_49.wav', 'শাকির কাকা ছিল'],
#  ['rec_36_audio_78.wav', 'জান'],
#  ['rec_36_audio_3.wav', 'কালকে তোমার মার আসতে পারিনি কালকে দিয়ে দিবানি'],
#  ['rec_36_audio_35.wav', '<>'],
#  ['rec_36_small_audio_1.wav', '<>'],
#  ['rec_36_audio_58.wav',
#   'না উনি তো আমরা জায়গা রাখব না উনি বেঁচে দেবো বেশি দেবো কি করবি'],
#  ['rec_36_audio_13.wav', '<>'],
#  ['rec_36_audio_43.wav', 'এটা আমাকে দেয়নি'],
#  ['rec_36_audio_51.wav',
#   'ওই জায়গায় জমি আছে শরীরের জমি রয়েছে আমাগে নামে নামে'],
#  ['rec_36_audio_36.wav',
#   'থাইরয়েডের জন্য একটা দিয়েছিলাম রক্ত উপাদানের একটা দিয়েছিলাম'],
#  ['rec_36_audio_42.wav', '<>'],
#  ['rec_36_audio_67.wav', 'সন্ধ্যা লাগলে মাকে প্রেম করে দাও না নাকি'],
#  ['rec_36_audio_25.wav', 'এটাকে কথা হয়েছিল'],
#  ['rec_36_audio_47.wav',
#   'আবার আমার মাঝে মাঝে এখানে এসে মাঝে একটু বাজার ছিল এসছে তোমার সুগার পুরোটা আসে যায় আর নাকা পেটে আছে তোমার আজকে 90 রাখতে হবে'],
#  ['rec_36_audio_33.wav', 'মুখটা সামলে ওষুধটা খাটি তোর আর আমার কাছে খতম লাগবে'],
#  ['rec_36_audio_82.wav',
#   'সামনাসামনি আমার মার আবার এই বদ অভ্যাস আছে কপালে যা থাকে কপালে যদি সুন্দর বর থাকে'],
#  ['rec_36_audio_66.wav',
#   'যাস না তুই একা তোর বাবা নাই তুই চলে গেলি তোর মাস শেষ এখন কোন কিছু খেতে গেলে খেতে পারতেছিনা'],
#  ['rec_36_audio_7.wav', '<>'],
#  ['rec_36_audio_38.wav', 'শুভ সকাল'],
#  ['rec_36_audio_76.wav',
#   'আমার ফোনের মায়েরে ছোটবেলায় মা দিয়েছে তো মা বলে মনে মনে আমার জন্য ঠিক করে রেখেছিল'],
#  ['rec_36_audio_79.wav',
#   'ওই পর্যন্তই তারপরে মোটামুটি উঁচু লম্বা বডি ফিগার ভালো আছো'],
#  ['rec_36_small_audio_0.wav', '<>'],
#  ['rec_37_audio_31.wav',
#   'এখন আর কত কোটি লাগবে না দিতে হবে আর আছে বারান্দায় যেসব টেবিল রয়েছে সব লাগবে না আল্লাহর রাস্তায়'],
#  ['rec_37_audio_40.wav',
#   'দয়া করে আমাকে 23 তারিখ একটু মনে করায় দিও রাত্রে কি কি কিনতে হবে ঠিক আছে'],
#  ['rec_37_audio_39.wav',
#   'আমার ইনবক্সে কল দিচ্ছিস আমিও তো তোরে দিচ্ছি নেট ছিল না এজন্য কিছু খুঁজে পাচ্ছিলাম না'],
#  ['rec_37_audio_29.wav', '<>'],
#  ['rec_37_audio_2.wav', 'কোন রেসপন্স নাই পরে যে মেয়েদের'],
#  ['rec_37_audio_42.wav', '<>'],
#  ['rec_37_audio_16.wav',
#   'দুপুরের নিয়ে গেছে বাড়ি এমনি গরিব মানুষ তার উপরে অতগুলো টাকা নিয়ে গেল কিরম লাগে'],
#  ['rec_37_audio_8.wav',
#   'এত মেজাজ খারাপ হয়ে গেছে আজকে এত আর আমি তো রাগ হয়ে গেলে শেষে লেভেলে চিল্লা নদী আমার তো অসুবিধা নেই'],
#  ['rec_37_audio_47.wav',
#   'ভালো হবে না মনে করো আমি যদি আগে আগে বাড়ি যাই তোমরা তো সবাই চলে যাবা না যার যার কাজে অফিসে আমি একা একা একদিন হায়দ্রাবাদি বিরিয়ানি রান্না করে খাওয়াবো'],
#  ['rec_37_audio_19.wav', '<>'],
#  ['rec_37_audio_14.wav', '<>'],
#  ['rec_37_audio_27.wav',
#   'সমস্যা না আমার নেটের সমস্যা আরে মা আমার নেটের সমস্যা আছে এইজন্য কথা কিছু শুনতে পারতেছি না তুমি শুনতে পারতেছো না আমি শুনতে পারতেছি কথা 14 বার বাতি আছে এতবার বাইরে যাচ্ছে'],
#  ['rec_37_audio_11.wav', '<>'],
#  ['rec_37_audio_25.wav', 'কি কি বুঝিনা'],
#  ['rec_37_big_audio_0.wav', '<>'],
#  ['rec_37_audio_37.wav',
#   'আরে মা আর মা আর একবারে দিবানা তাহলে আমি বিকালবেলা বের হলে কিন্তু আমি দেহে আসতে পারি আমার তো মনে নাই তো এখন কারেন্ট আসছে না বলে সেই জন্য আর মনেও করতে চাই না'],
#  ['rec_37_audio_22.wav', 'থেমে যাচ্ছিস অসহ্য ধরে যাচ্ছে'],
#  ['rec_37_audio_32.wav', 'বারাসাত ফুরায় দিবা মেজাজটা খারাপ হয়ে যাবে'],
#  ['rec_37_audio_30.wav', 'তুমি বাড়ি নিয়ে এসেছিল'],
#  ['rec_37_audio_12.wav', 'মেজাজটা খারাপ'],
#  ['rec_37_audio_15.wav', '<>'],
#  ['rec_37_audio_20.wav',
#   'ইয়াসমিনের আবার বিয়ে ঠিক গুহা নেই ইয়াসমিনের বিয়ে আসলে হবে না শুনে নি ইয়াসমিনের বিয়ে ইয়াসমিনের বিয়ে হতে হতে আমরা বুড়ি হয়ে গেলাম'],
#  ['rec_37_audio_35.wav', '<>'],
#  ['rec_37_audio_9.wav',
#   'সোনা বাচ্চারা ইশারা বাটি হারিয়ে গেছে তাই হচ্ছে এই করেছে যে মামনি তার উপর চিল্লায় সে তার জ্বর ছিল যে মামনি চিল্লাইস এটা কি ঠিক করেছো এসএমএস উত্তর দিলাম আমাদেরও কোন কিছু যায় আসলো'],
#  ['rec_37_audio_24.wav',
#   'হো হো একটা জার্সি পড়ে ছবি দেখাও ওরে বাবারে বাবা আসার সময় খুলনাতে আসার সময় ওর সাথে দেখা হয়েছিল'],
#  ['rec_37_audio_45.wav', '<>'],
#  ['rec_37_audio_23.wav',
#   'আর কতক্ষণ বাঁধবে তুই কি কথা শুনতে পারতেছিস নাকি কথা শুনতে পারতেছিস না'],
#  ['rec_37_audio_46.wav', '<>'],
#  ['rec_37_audio_13.wav', 'আরে কি এটা মরে গেছে'],
#  ['rec_37_audio_36.wav', 'চন্দন ভাইয়া এখানে'],
#  ['rec_37_audio_18.wav', '<>'],
#  ['rec_37_audio_28.wav',
#   'না এখনো খাইনি খাবার নেই একটু পরে রান্না করি নাই এখনো রান্না করবা নি একটু পরে বলবো'],
#  ['rec_37_audio_4.wav', '<>'],
#  ['rec_37_audio_21.wav',
#   'অনেক খালামণি বুঝতে পারতেছে না খালামণি থাকলে নেটে ঝামেলা আছে খালা বাড়ি সৃষ্টি করতেছে'],
#  ['rec_37_audio_43.wav', '<>'],
#  ['rec_37_audio_17.wav', '24 পরগনা কয় টাকা নিয়েছে বাড়ি নিয়ে এসেছেন'],
#  ['rec_37_audio_33.wav', '<>'],
#  ['rec_37_audio_41.wav', '23 তারিখের খবর'],
#  ['rec_37_audio_34.wav', 'খুঁজে পাওয়া যাচ্ছে না বা মনে থাকতেছে না কেন'],
#  ['rec_37_audio_38.wav',
#   'আচ্ছা ঠিক আছে কালকে বিকেলে বের হলেই আমি দেহে আসবানি বাইরে থেকে বিকেলবেলা তারপরে শুনেন তোমারে জানাবো নি'],
#  ['rec_37_audio_6.wav',
#   'তালগাছি কিসের তরকারি আনব বাকিয়ে রেখা বা তা তো আমার দেখার দরকার নাই আমার বাড়ি আসবে না আমি যেটা পাবো সেটাই নেবো এত মেজাজ খারাপ হয়ে গেছে তর্ক করেই যাচ্ছে করেই যাচ্ছে'],
#  ['rec_37_small_audio_1.wav',
#   'একটা গান ওটা চলবে না আমি আমারটা নিয়ে আসবানি বাড়ি'],
#  ['rec_37_audio_7.wav', 'আমি তরকারি নিয়ে এসেছি'],
#  ['rec_37_audio_44.wav', '<>'],
#  ['rec_37_audio_0.wav',
#   'তোমার পরীক্ষা আপাতত কিছু করতেছি না আপাতত আমি তোমার সাথে কথা বলছি জানু কি হইছে'],
#  ['rec_37_audio_3.wav',
#   'বাংলাদেশের মনে হয় চার তালার ভিতরে কেউ নেচে আপনি একটু ই করেন খোঁজ নিয়ে দেখেন তিনজন থেকে চারজন পাশের রুমে জিজ্ঞেস করলাম'],
#  ['rec_37_audio_5.wav', 'আমি এসএমএস দেখি নাই'],
#  ['rec_37_audio_1.wav', 'আজকে আমাদের ম্যাচে আবার জামা হয়েছে বুঝছো মানে'],
#  ['rec_37_audio_10.wav',
#   'কালকে মনে হয় ম্যাচের মিটিং হয়েছে যদি বাল থাকে তাহলে যাবা নিয়ে যদি বাল না থাকে তাহলে যাব না কারণ আমার পরীক্ষা এই তালবাহানা করে লাভ আছে আর যদি দাদার কাছে আবার নালি মেজাজটা খারাপ হয়ে যায় প্রত্যেকবার তাল বাহানা হবে'],
#  ['rec_37_audio_26.wav',
#   'হ্যালো আরে তুমি এখন নেট এত পরিমান বাড়তেছে কিছু কি পরিমান ভাত দিয়েছে'],
#  ['rec_37_small_audio_0.wav', '<>'],
#  ['rec_37_audio_59.wav',
#   'তুই উত্তর দিলি এত কিউট কেন সে রিপ্লাই দিলো সে গরিব এর সাথে এর মিল কোথায় তাই তো আমি বুঝতে পারলাম না থাক তুই এক কাজ কর তুই টেক্সট করে বাবু আমার হয়না'],
#  ['rec_37_audio_55.wav',
#   'কেমন লাগে এত বাদলি এত কথা বাদলি কথা শোনা যায় না কিছু না'],
#  ['rec_37_audio_49.wav',
#   'চিনিগুড়া চাল লাগবেনা বাসমতি চাল লাগবে দামি বাসমতি দাও তোমার মায়ের ডেলি ডেলি এইডা এই সময়টা রানতে যাই একদম ডেইলি কালকে 8:00 টায় ফোন দিছে'],
#  ['rec_37_audio_56.wav', 'বারবার বাদ দিতে হ্যালো রাখলাম'],
#  ['rec_37_audio_52.wav',
#   'দাদার কথাবার্তা শুনলে আমার রাগ হয়ে যাবে এজন্য আর ওসব নিয়ে কিছু করি নাই এমনি চিল্লাইছে এখন জানিনা কালকে মিটিং আছে জানিনা'],
#  ['rec_37_audio_53.wav', 'তোর তোর জামা পরে কিরম লাগে'],
#  ['rec_37_audio_54.wav', 'ঠিক বলেছে'],
#  ['rec_37_audio_48.wav',
#   'আমি একা একা বাড়ি থাকি মানে বাড়ি থেকে একদিন হায়দ্রাবাদি বিরিয়ানি রান্ডি হা হা হা হা হা তাই কইছি'],
#  ['rec_37_small_audio_2.wav', 'ঠিক আছে'],
#  ['rec_37_audio_58.wav', '<>'],
#  ['rec_37_audio_50.wav',
#   'কালকে তো ফোন আমি বন্ধ রেখে দিয়েছিলাম এই জন্যে আমারে খুঁজে পাই নাই'],
#  ['rec_37_audio_57.wav', 'না-না-না-না-না পুরোটা পুরোটা বল না না'],
#  ['rec_37_audio_51.wav', 'আজকের তাপমাত্রা'],
#  ['rec_25_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_25_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_31_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_25_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_25_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_31_big_audio_5_chunk_2.wav', '<>'],
#  ['rec_37_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_31_big_audio_5_chunk_0.wav', '<>'],
#  ['rec_31_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_31_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_31_big_audio_5_chunk_1.wav', '<>'],
#  ['rec_31_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_37_big_audio_1_chunk_1.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 1880

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["Contents"] = content

# %%
df
# Out:
#               External_ID                                           Contents
# 0     rec_19_audio_40.wav                                               হঠাৎ
# 1     rec_19_audio_31.wav                                                 <>
# 2     rec_19_audio_15.wav                                    ইন্ডিয়ায় গেছে
# 3      rec_19_audio_3.wav                                                 <>
# 4     rec_19_audio_14.wav                              ভালো নাম কি বলবে নাকি
# ...                   ...                                                ...
# 1875  rec_19_audio_41.wav     ইউনিট করা দরকার সেই উঠে বসতে হয় সেই জল খাচ্ছি
# 1876  rec_19_audio_26.wav           পরশুদিন কি গ্যাস ফর্ম করে চলো পরশুদিন কে
# 1877  rec_19_audio_25.wav                      না আপনার মামি কালকে আসতে পারে
# 1878   rec_19_audio_7.wav  আর এখান বাড়ি নিয়ে আসি উনি সার্কেল চালিয়ে সে...
# 1879   rec_19_audio_5.wav                                                 <>
#
# [1880 rows x 2 columns]

# %%
len(df)
# Out:
# 1880

# %%
df.to_excel("1.3: narail-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
