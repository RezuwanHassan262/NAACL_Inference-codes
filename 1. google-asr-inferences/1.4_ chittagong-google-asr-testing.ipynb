# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnunicodenormalizer
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22781 sha256=1422b11d110b024b7279185d27a0a3b6956d5ed67e7462be5e66369c6d793747
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/e9/16732a619cbf5a63fdc9f6e2f9eb5fcf73fa023735237330e9
# Successfully built bnunicodenormalizer
# Installing collected packages: bnunicodenormalizer
# Successfully installed bnunicodenormalizer-0.1.6
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.0

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/Chittagong/chittagong_chunks/chittagong_all/'

# %%
files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_20_big_audio_0.wav', 'rec_20_audio_48.wav', 'rec_20_audio_21.wav', 'rec_20_audio_0.wav', 'rec_20_audio_16.wav', 'rec_20_audio_9.wav', 'rec_20_audio_25.wav', 'rec_20_audio_37.wav', 'rec_20_audio_3.wav', 'rec_20_audio_38.wav', 'rec_20_audio_45.wav', 'rec_20_audio_36.wav', 'rec_20_audio_24.wav', 'rec_20_audio_27.wav', 'rec_20_audio_6.wav', 'rec_20_audio_46.wav', 'rec_20_audio_39.wav', 'rec_20_audio_19.wav', 'rec_20_audio_30.wav', 'rec_20_audio_22.wav', 'rec_20_audio_43.wav', 'rec_20_audio_23.wav', 'rec_20_audio_34.wav', 'rec_20_audio_11.wav', 'rec_20_audio_29.wav', 'rec_20_audio_44.wav', 'rec_20_audio_41.wav', 'rec_20_audio_2.wav', 'rec_20_audio_10.wav', 'rec_20_audio_20.wav', 'rec_20_audio_15.wav', 'rec_20_audio_28.wav', 'rec_20_audio_4.wav', 'rec_20_audio_13.wav', 'rec_20_audio_42.wav', 'rec_20_audio_32.wav', 'rec_20_audio_35.wav', 'rec_20_audio_47.wav', 'rec_20_audio_40.wav', 'rec_20_audio_7.wav', 'rec_20_audio_14.wav', 'rec_20_audio_17.wav', 'rec_20_audio_1.wav', 'rec_20_audio_8.wav', 'rec_20_audio_18.wav', 'rec_20_audio_5.wav', 'rec_20_audio_33.wav', 'rec_20_audio_31.wav', 'rec_20_audio_52.wav', 'rec_20_audio_60.wav', 'rec_20_audio_63.wav', 'rec_20_audio_50.wav', 'rec_20_audio_62.wav', 'rec_20_audio_64.wav', 'rec_20_audio_56.wav', 'rec_20_audio_66.wav', 'rec_20_audio_59.wav', 'rec_20_audio_54.wav', 'rec_20_audio_53.wav', 'rec_20_audio_58.wav', 'rec_20_audio_61.wav', 'rec_20_small_audio_0.wav', 'rec_20_audio_67.wav', 'rec_20_audio_57.wav', 'rec_20_audio_55.wav', 'rec_20_audio_68.wav', 'rec_20_audio_49.wav', 'rec_20_audio_51.wav', 'rec_20_audio_65.wav', 'rec_21_audio_16.wav', 'rec_21_audio_15.wav', 'rec_21_audio_19.wav', 'rec_21_audio_12.wav', 'rec_21_audio_1.wav', 'rec_21_audio_13.wav', 'rec_21_audio_3.wav', 'rec_21_audio_8.wav', 'rec_21_audio_4.wav', 'rec_21_audio_10.wav', 'rec_21_big_audio_1.wav', 'rec_21_audio_17.wav', 'rec_21_audio_5.wav', 'rec_21_audio_14.wav', 'rec_21_audio_18.wav', 'rec_21_small_audio_0.wav', 'rec_21_audio_2.wav', 'rec_21_audio_7.wav', 'rec_21_audio_6.wav', 'rec_21_audio_9.wav', 'rec_21_audio_11.wav', 'rec_21_audio_0.wav', 'rec_22_audio_9.wav', 'rec_22_audio_11.wav', 'rec_22_audio_19.wav', 'rec_22_audio_7.wav', 'rec_22_audio_4.wav', 'rec_22_audio_20.wav', 'rec_22_audio_16.wav', 'rec_22_audio_6.wav', 'rec_22_audio_12.wav', 'rec_22_audio_1.wav', 'rec_22_audio_10.wav', 'rec_22_audio_21.wav', 'rec_22_audio_22.wav', 'rec_22_audio_3.wav', 'rec_22_audio_2.wav', 'rec_22_audio_13.wav', 'rec_22_audio_14.wav', 'rec_22_audio_15.wav', 'rec_22_audio_5.wav', 'rec_22_audio_8.wav', 'rec_22_audio_0.wav', 'rec_22_audio_17.wav', 'rec_22_audio_18.wav', 'rec_23_audio_2.wav', 'rec_23_audio_32.wav', 'rec_23_audio_27.wav', 'rec_23_audio_31.wav', 'rec_23_audio_18.wav', 'rec_23_audio_13.wav', 'rec_23_audio_7.wav', 'rec_23_audio_26.wav', 'rec_23_audio_22.wav', 'rec_23_audio_28.wav', 'rec_23_audio_21.wav', 'rec_23_audio_15.wav', 'rec_23_audio_12.wav', 'rec_23_audio_16.wav', 'rec_23_audio_17.wav', 'rec_23_audio_23.wav', 'rec_23_audio_29.wav', 'rec_23_audio_30.wav', 'rec_23_audio_14.wav', 'rec_23_audio_19.wav', 'rec_23_small_audio_0.wav', 'rec_23_audio_9.wav', 'rec_23_audio_11.wav', 'rec_23_audio_25.wav', 'rec_23_audio_10.wav', 'rec_23_audio_24.wav', 'rec_23_audio_20.wav', 'rec_23_audio_1.wav', 'rec_23_audio_6.wav', 'rec_23_audio_3.wav', 'rec_23_audio_4.wav', 'rec_23_audio_5.wav', 'rec_23_audio_0.wav', 'rec_23_audio_8.wav', 'rec_24_audio_70.wav', 'rec_24_audio_65.wav', 'rec_24_audio_81.wav', 'rec_24_small_audio_4.wav', 'rec_24_audio_17.wav', 'rec_24_audio_3.wav', 'rec_24_audio_7.wav', 'rec_24_audio_76.wav', 'rec_24_audio_37.wav', 'rec_24_audio_50.wav', 'rec_24_audio_61.wav', 'rec_24_audio_9.wav', 'rec_24_audio_51.wav', 'rec_24_audio_62.wav', 'rec_24_big_audio_0.wav', 'rec_24_audio_47.wav', 'rec_24_audio_64.wav', 'rec_24_audio_69.wav', 'rec_24_audio_18.wav', 'rec_24_audio_0.wav', 'rec_24_audio_42.wav', 'rec_24_audio_8.wav', 'rec_24_audio_66.wav', 'rec_24_audio_33.wav', 'rec_24_audio_45.wav', 'rec_24_audio_72.wav', 'rec_24_audio ...
#
# 1774

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_20_big_audio_0.wav', '3:00 টা বাজে বাজে বাজে বাজে বাজে'],
#  ['rec_20_audio_48.wav', 'কার্টুন কার্টুন'],
#  ['rec_20_audio_21.wav', 'দুইবার ধরে খুঁজছিলাম'],
#  ['rec_20_audio_0.wav',
#   'আরা আরা কোরআন শরীফ পড়তে বই তারপরে আম্মা আম্মুরে হইবে যে দাদুরে দিবার লেটার'],
#  ['rec_20_audio_16.wav', 'হারিয়ে যাওয়া হবে বলে আলোকের দূরে হারিয়ে যায়'],
#  ['rec_20_audio_9.wav', 'ইতালি থাকতে জন্য আর খালামণি মাইয়া শয়তানি করে দেন'],
#  ['rec_20_audio_25.wav', 'তারপরে বসে বসে খাবে'],
#  ['rec_20_audio_37.wav', 'আর 100 টিয়া মহিলার 100 টিয়া বালা পাই হ্যালো'],
#  ['rec_20_audio_3.wav', '<>'],
#  ['rec_20_audio_38.wav', 'তারপরে'],
#  ['rec_20_audio_45.wav', 'এ মে তেরি বিখ্যাত না'],
#  ['rec_20_audio_36.wav', 'তোর বকশি দিয়ে আরে'],
#  ['rec_20_audio_24.wav', '<>'],
#  ['rec_20_audio_27.wav', 'ওরা বিশিষ্ট সিদ্দিকী কি কষ্ট'],
#  ['rec_20_audio_6.wav', 'খালামণি আর খালামনি মাইয়া ফেল'],
#  ['rec_20_audio_46.wav', 'নাচ'],
#  ['rec_20_audio_39.wav',
#   'আরো 200 টাকা দিয়ে মোহনা 200 টাকা দিয়ে নানু বাড়িতে শয়তানি করে গোসসা ঘুসি দেখান'],
#  ['rec_20_audio_19.wav', 'আইএনএন ট্রান্সফারের প্রথম হাসপাতাল'],
#  ['rec_20_audio_30.wav', 'ইউরিনে প্যারাসাইট গিটার বাথা দুইটা বাজে কি দিলাম'],
#  ['rec_20_audio_22.wav', 'তারপর আমাকে কিছু না দেয় হ্যালো'],
#  ['rec_20_audio_43.wav', 'দাদু হচ্ছে'],
#  ['rec_20_audio_23.wav', '<>'],
#  ['rec_20_audio_34.wav', 'পরবাসী বয়ানে আরে 500 টিয়া আরে 300 টাকা মহিনা'],
#  ['rec_20_audio_11.wav', 'সাইড দিয়া দাদু কতক্ষণ ফানি ভিডিও'],
#  ['rec_20_audio_29.wav', 'চন্দনের যমুনা মাম্মির বাসা'],
#  ['rec_20_audio_44.wav', 'আসুর আব্বুর হলে যাবি না যাবিনা'],
#  ['rec_20_audio_41.wav', 'তো ডিএনএ ব্যাস গেম জানি তারা খেলার দুলে তারপরে'],
#  ['rec_20_audio_2.wav', 'আম্মু হতে হবে হযরত মাওলানা'],
#  ['rec_20_audio_10.wav', '100 বার হা একদিন না হালিমের শান্তি নোয়া তারপরে'],
#  ['rec_20_audio_20.wav', 'সালাম গজল'],
#  ['rec_20_audio_15.wav',
#   'আবাজ না যাইও মারে তা আবার আজি আইসিসি অশান্তি তারপরে'],
#  ['rec_20_audio_28.wav', 'তারপরে'],
#  ['rec_20_audio_4.wav', '<>'],
#  ['rec_20_audio_13.wav', 'তাপস সদর চা নাস্তা খায় নাই'],
#  ['rec_20_audio_42.wav', 'ভাত খেতে বসে বাতাস'],
#  ['rec_20_audio_32.wav', 'মেজবু বকশিশ দিয়ে আর এখন বৃষ্টি দিয়ে তারপরে'],
#  ['rec_20_audio_35.wav', '<>'],
#  ['rec_20_audio_47.wav', 'তো কি হইয়ুম ভাজি তাড়াতাড়ি'],
#  ['rec_20_audio_40.wav', 'বকশিশ দিনে 50 টাকা'],
#  ['rec_20_audio_7.wav', 'ফ দিয়ে যারা গানের বাংলা'],
#  ['rec_20_audio_14.wav', 'চোদার পরে দেখান'],
#  ['rec_20_audio_17.wav',
#   'ঈদের আগের দিন এই মেয়েটি দিন না বাড়িতে পার্লারে কতক্ষণ পরে যায় না'],
#  ['rec_20_audio_1.wav', 'দাদুরে দিঘী তারপরে ফোন করে ফেলি'],
#  ['rec_20_audio_8.wav', 'গাছ লাগালি'],
#  ['rec_20_audio_18.wav', '<>'],
#  ['rec_20_audio_5.wav', '<>'],
#  ['rec_20_audio_33.wav', 'ইতারা বাড়ির দরজা'],
#  ['rec_20_audio_31.wav', '<>'],
#  ['rec_20_audio_52.wav', 'মুখের মধ্যে কিয়া তোর বিয়ে হলো কোন বুশি বাজে বাজে'],
#  ['rec_20_audio_60.wav', 'ইতে হদ্দে কিনেছেন'],
#  ['rec_20_audio_63.wav', '<>'],
#  ['rec_20_audio_50.wav', '<>'],
#  ['rec_20_audio_62.wav',
#   'ওয়ে তোমার বাথরুমে যাইয়ুম ফাদিয়া বাথরুম জানে কতক্ষণ এক ঘন্টা করে'],
#  ['rec_20_audio_64.wav',
#   'পাপা তোর মায়েরা পাপার মা আপা মারিলে ও বুক যেদিন নতুন নতুন'],
#  ['rec_20_audio_56.wav', 'তারপরে মহিন'],
#  ['rec_20_audio_66.wav', 'বাড়িতে বমি করতে করতে'],
#  ['rec_20_audio_59.wav', 'ব্যাগ গঠনে মহিন যে শয়তানি করে'],
#  ['rec_20_audio_54.wav', '<>'],
#  ['rec_20_audio_53.wav', 'দাদু অধ্যায় এসেছে করে যায়'],
#  ['rec_20_audio_58.wav', 'টিফিনের সাঈদী আর স্কুলে গেছে'],
#  ['rec_20_audio_61.wav', 'ওগো কিতা লাগে'],
#  ['rec_20_small_audio_0.wav', 'তারপরে হতা হয়ে নেন ফজরের ফজরে ফজর হয়নি'],
#  ['rec_20_audio_67.wav', 'কাপড়ের লাস্টের দিকে সোজা করে দিয়ে ফেললাম'],
#  ['rec_20_audio_57.wav', 'হাই এনে তাহলে আপনি হাঁসের হাসতে হাসতে মরে যাবে'],
#  ['rec_20_audio_55.wav', 'ইতারা নিচে আলিফ বিউটি পার্লারে তারপরে'],
#  ['rec_20_audio_68.wav', 'শুক্রবার দিন মসজিদে'],
#  ['rec_20_audio_49.wav', '<>'],
#  ['rec_20_audio_51.wav', 'বই'],
#  ['rec_20_audio_65.wav', '<>'],
#  ['rec_21_audio_16.wav', 'সাহেব বাবু'],
#  ['rec_21_audio_15.wav', '<>'],
#  ['rec_21_audio_19.wav', 'রবিবারের গান পতেঙ্গার এখানে তাপমাত্রা'],
#  ['rec_21_audio_12.wav', '27 তারিখ শনিবার একটার মধ্যে বাসা কোথায়'],
#  ['rec_21_audio_1.wav', '<>'],
#  ['rec_21_audio_13.wav', '<>'],
#  ['rec_21_audio_3.wav', '<>'],
#  ['rec_21_audio_8.wav', 'রিয়া'],
#  ['rec_21_audio_4.wav', '<>'],
#  ['rec_21_audio_10.wav', '<>'],
#  ['rec_21_big_audio_1.wav', '<>'],
#  ['rec_21_audio_17.wav', '<>'],
#  ['rec_21_audio_5.wav', 'তোমাকে আমি দেখিনি'],
#  ['rec_21_audio_14.wav', 'শনিবারে তোরা দুজন যাবে না'],
#  ['rec_21_audio_18.wav', 'রবিবারে দিলে'],
#  ['rec_21_small_audio_0.wav', 'তোমার একটা সিরিয়াল'],
#  ['rec_21_audio_2.wav', '<>'],
#  ['rec_21_audio_7.wav', 'জানিনা'],
#  ['rec_21_audio_6.wav', '<>'],
#  ['rec_21_audio_9.wav', '<>'],
#  ['rec_21_audio_11.wav', 'শনিবারের শনিবারে'],
#  ['rec_21_audio_0.wav',
#   'আচ্ছা ঠিক আছে 280 শুধু রোস্ট আর রোস্ট আর পোলাপান যে আলাদা জানি'],
#  ['rec_22_audio_9.wav', 'এই বৃষ্টিকে আরো দাও'],
#  ['rec_22_audio_11.wav', 'এবার শাহরুখ খানের গান শাহরুখ খানের গান'],
#  ['rec_22_audio_19.wav', '<>'],
#  ['rec_22_audio_7.wav', '<>'],
#  ['rec_22_audio_4.wav', 'নোয়াখাইল্লা ফানি ভিডিও'],
#  ['rec_22_audio_20.wav', 'আপনারা'],
#  ['rec_22_audio_16.wav', '<>'],
#  ['rec_22_audio_6.wav', 'সিঙ্গাপুরি সরি বাবু'],
#  ['rec_22_audio_12.wav', '<>'],
#  ['rec_22_audio_1.wav', '<>'],
#  ['rec_22_audio_10.wav', 'সিঙ্গাপুরের দৃশ্য না না ধন্যবাদ'],
#  ['rec_22_audio_21.wav', 'দোকানদার ভাই আছেন সাইফুল ভাইকে ভোট দেবেন'],
#  ['rec_22_audio_22.wav', 'সাইফুল ভাই এদিকে আসেন'],
#  ['rec_22_audio_3.wav', '<>'],
#  ['rec_22_audio_2.wav', '<>'],
#  ['rec_22_audio_13.wav', '<>'],
#  ['rec_22_audio_14.wav', '<>'],
#  ['rec_22_audio_15.wav', 'পাকিস্তান'],
#  ['rec_22_audio_5.wav', 'গাড়ির রাস্তা আছে সিঙ্গাপুরের রেসিপি'],
#  ['rec_22_audio_8.wav', 'সিঙ্গাপুর থ্যাংক ইউ'],
#  ['rec_22_audio_0.wav', '<>'],
#  ['rec_22_audio_17.wav', 'নাথ কি হারানো বাসায় যাবো'],
#  ['rec_22_audio_18.wav', 'আশিকি কুড়ার খবর আছে'],
#  ['rec_23_audio_2.wav', 'তারপরে মাতার হওয়ার উঠে দেখি মাথার মগজ পানি কি গো'],
#  ['rec_23_audio_32.wav', '<>'],
#  ['rec_23_audio_27.wav', 'হ্যাঁ ঘড়ি জাহান বাজে কোনদিন বিয়ে করি'],
#  ['rec_23_audio_31.wav', 'বাংলা'],
#  ['rec_23_audio_18.wav', 'আলিয়া ভোরবাজার গোপালগঞ্জ'],
#  ['rec_23_audio_13.wav', 'পিত্তে দলিল দেয়নি'],
#  ['rec_23_audio_7.wav', 'ডাক্তার না দেখাই নাই'],
#  ['rec_23_audio_26.wav', 'আন্ডারওয়্যার অনুযায়ী'],
#  ['rec_23_audio_22.wav', '<>'],
#  ['rec_23_audio_28.wav', 'মেয়াদ কবুল করো না মালিক আল্লাহ সহ্য না লাগে না'],
#  ['rec_23_audio_21.wav',
#   'আরে বড় গরু লইতে শাহজাহান আর একবার এক ভাগ করলে কি হয় তাই না সমস্যা নাই'],
#  ['rec_23_audio_15.wav', 'শান্তর আব্বুর হলো'],
#  ['rec_23_audio_12.wav', '<>'],
#  ['rec_23_audio_16.wav', 'ইয়াবার হারাম লাগে দেখি'],
#  ['rec_23_audio_17.wav', 'নানা জিয়া তাপমাত্রা'],
#  ['rec_23_audio_23.wav', '<>'],
#  ['rec_23_audio_29.wav', 'ভাইয়ের নগর এশিয়া তরল নগরী'],
#  ['rec_23_audio_30.wav', 'আসমা দাদা তুমি বিয়ে করবে না'],
#  ['rec_23_audio_14.wav', 'সাইফুল হাসান সিরিয়াল'],
#  ['rec_23_audio_19.wav', 'কারণ কি করে'],
#  ['rec_23_small_audio_0.wav', 'আচ্ছা খাওয়া-দাওয়া করছি'],
#  ['rec_23_audio_9.wav',
#   'ইয়াবার খারাপ লাগের মাথা ভিতর প্রাইমারি স্কুল দিয়ে বন্ধ 5 তারিখের তো নাস্তা তারিখ বন্ধ ঘোষণা'],
#  ['rec_23_audio_11.wav', 'আইপিএস আছে না নেই'],
#  ['rec_23_audio_25.wav', 'বাড়ি বাড়ি'],
#  ['rec_23_audio_10.wav', 'এ হালিয়া'],
#  ['rec_23_audio_24.wav', 'সাত ভাই'],
#  ['rec_23_audio_20.wav', '<>'],
#  ['rec_23_audio_1.wav',
#   'রোবা হালিয়া রাতে কারেন্ট যারাই যারাই রিংটোন করতে করতে'],
#  ['rec_23_audio_6.wav', 'এতে এশিয়ায় এরা ভারতের'],
#  ['rec_23_audio_3.wav', 'ওই আরো করিতেছি'],
#  ['rec_23_audio_4.wav', 'আরফান অবতার আহমেদ বিতরের নামাজের'],
#  ['rec_23_audio_5.wav', 'আগে করি না পারিস করে তো ছুটি ডলুয়া পরীক্ষার'],
#  ['rec_23_audio_0.wav', '<>'],
#  ['rec_23_audio_8.wav', 'আচারা সোনা সোনা'],
#  ['rec_24_audio_70.wav', 'ভিভো সিনারি'],
#  ['rec_24_audio_65.wav', '<>'],
#  ['rec_24_audio_81.wav', '<>'],
#  ['rec_24_small_audio_4.wav', 'গোবরডাঙ্গা'],
#  ['rec_24_audio_17.wav', 'যাবেননা'],
#  ['rec_24_audio_3.wav', '<>'],
#  ['rec_24_audio_7.wav', 'রবিবার না'],
#  ['rec_24_audio_76.wav', 'লাগা'],
#  ['rec_24_audio_37.wav', 'তোমার বাসা কোথায়'],
#  ['rec_24_audio_50.wav', 'না এতে তো মরতে মেয়ে পাওয়া তারপরে'],
#  ['rec_24_audio_61.wav', 'টু সেক্স 76 717'],
#  ['rec_24_audio_9.wav', 'আচ্ছা আমি মজা নাই তো'],
#  ['rec_24_audio_51.wav', '<>'],
#  ['rec_24_audio_62.wav', '26765 টেম্পোর মা'],
#  ['rec_24_big_audio_0.wav',
#   'আমাকে দেখতে আসতে পারবে না শুক্রবারে শুক্রবারে তাহলে আম্মু প্রত্যেক শুক্রবার আমাকে দেখতে আসবে তাহলে ভালো হয়েছে এক সপ্তাহ পরে আমি আমার আম্মুকে দেখবো'],
#  ['rec_24_audio_47.wav', '<>'],
#  ['rec_24_audio_64.wav', 'সাদিয়ার মা সাদিয়া সাদিয়া মাওনা'],
#  ['rec_24_audio_69.wav', 'লালনপালন'],
#  ['rec_24_audio_18.wav', 'আমাদের জননী আলাদা দোয়া এই মোমবাতি মোমবাতি বাজাইত'],
#  ['rec_24_audio_0.wav', 'অত্যন্ত প্রয়োজন'],
#  ['rec_24_audio_42.wav', 'সম্পত্তি ইন টোটাল দুই ভাগ হবে না'],
#  ['rec_24_audio_8.wav', 'এপার অঞ্জলি বাজার'],
#  ['rec_24_audio_66.wav', '<>'],
#  ['rec_24_audio_33.wav', '<>'],
#  ['rec_24_audio_45.wav', '<>'],
#  ['rec_24_audio_72.wav', 'নিগার না'],
#  ['rec_24_audio_1.wav', 'কন্যা পারে না'],
#  ['rec_24_audio_30.wav', '<>'],
#  ['rec_24_audio_46.wav', '<>'],
#  ['rec_24_small_audio_0.wav', '10 বছরের'],
#  ['rec_24_audio_28.wav', 'তোর নানির বিয়া নাইরে দেখছি এরকম মজা নাই'],
#  ['rec_24_audio_23.wav', 'ফেসবুক এর মাধ্যমে'],
#  ['rec_24_audio_29.wav', '<>'],
#  ['rec_24_audio_12.wav', '<>'],
#  ['rec_24_audio_39.wav', 'আলিয়া সম্পর্কে'],
#  ['rec_24_audio_16.wav', '<>'],
#  ['rec_24_audio_44.wav', '<>'],
#  ['rec_24_audio_63.wav', 'হা করে'],
#  ['rec_24_audio_32.wav', 'কিরে তুই মাইয়া ছিল না'],
#  ['rec_24_audio_38.wav', 'ইতা আছে'],
#  ['rec_24_audio_43.wav', 'আলিয়া মাদ্রাসা'],
#  ['rec_24_big_audio_4.wav', 'কামিলের দিয়ে নাম কি সাদিয়া সাদিয়া ঘটনা'],
#  ['rec_24_audio_59.wav', 'মাথার মধ্যে বোঝার কিছু নেই 011'],
#  ['rec_24_audio_36.wav', '<>'],
#  ['rec_24_audio_49.wav', 'ডিজাইনার ভিডিও'],
#  ['rec_24_audio_19.wav', 'রাগ নেই'],
#  ['rec_24_audio_24.wav', '<>'],
#  ['rec_24_audio_83.wav', '111 হবো না'],
#  ['rec_24_audio_34.wav', '<>'],
#  ['rec_24_audio_58.wav', 'আড্ডা লাগে নাকি'],
#  ['rec_24_audio_67.wav', 'ইল্লে বকিলা তো রবিবার'],
#  ['rec_24_audio_55.wav', '<>'],
#  ['rec_24_audio_4.wav', '<>'],
#  ['rec_24_audio_78.wav',
#   'রঙ্গি না দিয়ে চিন্তা কর বিছানা চিন্তা নগর দিয়ে লোকেশন'],
#  ['rec_24_audio_31.wav', 'আসিনা'],
#  ['rec_24_audio_75.wav', 'কেননা'],
#  ['rec_24_audio_15.wav',
#   'তার ভাঙ্গা যাবে গান হদ দেখান 120 টাকা কেজি বালানা না'],
#  ['rec_24_audio_20.wav', 'আচোদা বিদেশ'],
#  ['rec_24_audio_22.wav', 'সরকারের নাম কি মেনশন'],
#  ['rec_24_small_audio_1.wav', 'হ'],
#  ['rec_24_audio_53.wav', '<>'],
#  ['rec_24_audio_60.wav', '01917 8176'],
#  ['rec_24_audio_21.wav', '<>'],
#  ['rec_24_small_audio_2.wav', 'কি দাদা'],
#  ['rec_24_audio_52.wav', '<>'],
#  ['rec_24_audio_71.wav', 'কি দিতাম না'],
#  ['rec_24_audio_48.wav',
#   'না বাড়িতে মানে বড় বুক এইটার হয় এক বছর পর তোমারে না'],
#  ['rec_24_audio_77.wav', '2 তারিখ বাদ দেন'],
#  ['rec_24_audio_14.wav', 'সারে গেলে সিম নেই'],
#  ['rec_24_audio_41.wav', '<>'],
#  ['rec_24_audio_13.wav', 'সেরা করলে'],
#  ['rec_24_audio_79.wav', '<>'],
#  ['rec_24_audio_35.wav', 'চাকরি করে নাই এখন কিল্লি চাকরি যার দাম'],
#  ['rec_24_audio_56.wav', 'আর নাচ হচ্ছে'],
#  ['rec_24_audio_57.wav', 'ফোন বন্ধ করে দে'],
#  ['rec_24_audio_80.wav', 'পাতলা পায়খানা 30000 টাকার'],
#  ['rec_24_audio_26.wav', 'নানিরা যেমনি মিলে যায় না'],
#  ['rec_24_audio_73.wav', 'ইতিরে সুইমার নিরবে'],
#  ['rec_24_audio_25.wav', 'খগেন ভালো হবে না'],
#  ['rec_24_audio_54.wav', 'নুরালি খলিফার বাড়ি পত্রিকা'],
#  ['rec_24_audio_82.wav', '<>'],
#  ['rec_24_audio_40.wav', 'আজকের অধিকার আছে'],
#  ['rec_24_audio_27.wav', 'মাসিক তেলাপিয়া মাছ গুলো তুলে দে'],
#  ['rec_24_audio_5.wav', '<>'],
#  ['rec_24_audio_68.wav', 'তুই একজন এতিম বড় দায়িত্ব'],
#  ['rec_24_audio_6.wav', 'নানা তাড়াতাড়ি'],
#  ['rec_24_audio_10.wav', '<>'],
#  ['rec_24_audio_11.wav', 'ফকিং ফকিং'],
#  ['rec_24_audio_2.wav', 'বিকাশ পৌঁছাতে পারি না'],
#  ['rec_24_small_audio_3.wav', 'বলে'],
#  ['rec_24_audio_74.wav', 'মজুরি হয়েছে'],
#  ['rec_25_audio_3.wav', '<>'],
#  ['rec_25_audio_42.wav', '<>'],
#  ['rec_25_audio_23.wav', '<>'],
#  ['rec_25_audio_4.wav', '<>'],
#  ['rec_25_audio_31.wav', '<>'],
#  ['rec_25_audio_5.wav', '<>'],
#  ['rec_25_audio_18.wav', '<>'],
#  ['rec_25_audio_2.wav', '<>'],
#  ['rec_25_audio_33.wav', 'লাল লালের মধ্যে লাল ব্লাউজ কিছু হয়ে যাবে না'],
#  ['rec_25_audio_20.wav', '<>'],
#  ['rec_25_audio_0.wav', '<>'],
#  ['rec_25_audio_25.wav', 'লাল শাড়ি পরিয়া গান চালাও'],
#  ['rec_25_audio_14.wav', '<>'],
#  ['rec_25_audio_36.wav', '<>'],
#  ['rec_25_audio_28.wav', '<>'],
#  ['rec_25_audio_16.wav', 'না হচ্ছে মানে'],
#  ['rec_25_audio_39.wav', 'সামসাং সামসাং'],
#  ['rec_25_audio_32.wav', '<>'],
#  ['rec_25_audio_22.wav', '<>'],
#  ['rec_25_audio_35.wav', '<>'],
#  ['rec_25_audio_21.wav', 'বাথরুমের দরজা'],
#  ['rec_25_audio_1.wav', '<>'],
#  ['rec_25_audio_10.wav', '<>'],
#  ['rec_25_audio_34.wav', 'ফুচকার লেখা হয়নি'],
#  ['rec_25_audio_29.wav', '<>'],
#  ['rec_25_audio_7.wav', '<>'],
#  ['rec_25_audio_26.wav', 'জামদানি আনন্দবাজার'],
#  ['rec_25_audio_41.wav', '<>'],
#  ['rec_25_audio_38.wav', 'ভাইয়া ভাইয়া'],
#  ['rec_25_audio_17.wav', '<>'],
#  ['rec_25_audio_8.wav', '<>'],
#  ['rec_25_audio_15.wav', '<>'],
#  ['rec_25_audio_9.wav', '<>'],
#  ['rec_25_audio_27.wav', '<>'],
#  ['rec_25_audio_12.wav', 'শাড়ি লেবু হচ্ছে না'],
#  ['rec_25_audio_19.wav', '<>'],
#  ['rec_25_audio_37.wav', '<>'],
#  ['rec_25_audio_13.wav', '<>'],
#  ['rec_25_audio_40.wav', '<>'],
#  ['rec_25_audio_24.wav', '<>'],
#  ['rec_25_audio_11.wav', '<>'],
#  ['rec_25_audio_6.wav', 'মোটামুটি আরকি 10 পর্যন্ত'],
#  ['rec_25_audio_30.wav', 'সেম সেদিন আর এখন পর্যন্ত'],
#  ['rec_26_audio_29.wav', 'এখানে হাতাতে সুজন আছেন'],
#  ['rec_26_audio_1.wav',
#   'গাড়ি ঘোড়া শরীর কেরকম এখন পড়ালেখা ঘড়ির কিন্তু গাড়ি ঘোড়া তো শরীর ধ্যান গাড়ি করার ছবি দিয়ে কিভাবে'],
#  ['rec_26_small_audio_0.wav', 'আসলেই না জানি'],
#  ['rec_26_audio_33.wav',
#   'হামারা চেষ্টা করে পড়ালেখা করবে চেষ্টা করলে কি গরিব ছাড়েন আসলে না জানি চেষ্টা করি সার মত হয় যদি যদি যদি যদি তারে চিন্তা করিয়া রে'],
#  ['rec_26_audio_20.wav',
#   'বলতো আমি ফেলার গরি গরি হবো হারায় হারায় তোমার তুমি অভ্যাস খারাপ করে ফেলবো আলাদিন 12 তারিখের পরে শরীরের না দে'],
#  ['rec_26_audio_21.wav', 'গরু থেকে মারে হেল্প করব'],
#  ['rec_26_audio_19.wav', 'হযরত গঠন বাইরে কর তাই না'],
#  ['rec_26_audio_12.wav', 'জালাল'],
#  ['rec_26_audio_6.wav', 'জুনিয়র হলো আছি ভার্সিটির যায় ভার্সিটি'],
#  ['rec_26_audio_39.wav', 'পড়ালেখার গরিব কেন গরিব আসরের নামাজের'],
#  ['rec_26_audio_8.wav',
#   'কিছুই না জানি পড়ালেখা করি তো মনে হয় কিন্তু পড়ালেখা তো গরম পরের কি করবো জীবনে পড়ালেখা ছাড়া কোন রাস্তা নাই'],
#  ['rec_26_audio_14.wav',
#   'কেউ না হয় যে জিনিসের বালা ইয়েন কর সারাজীবনের বিজ্ঞানে হয়েছে তার কথা নয় কারণ নাই'],
#  ['rec_26_audio_37.wav', 'শিলিগুড়ি নগরের'],
#  ['rec_26_audio_24.wav',
#   'সিঙ্গাপুরের দিকে ক্যাঙ্গারু এবং নোবেল পান 1932 সালের মালাই গরিবের লাইন কিন্তু'],
#  ['rec_26_audio_16.wav',
#   'আমার বাফল ফেভারেট মি আর বড় বোন চিটাং ভার্সিটির শহরে আমার দুধ কিছু গরিব'],
#  ['rec_26_audio_22.wav',
#   'নাজানে হতে পড়ালেখা শেষ করে দে বাপ মারে কেরকম আমার মা জি এম ফাইন'],
#  ['rec_26_audio_30.wav', 'এখন যদি আমারে'],
#  ['rec_26_audio_17.wav',
#   'চৌধুরী পরিবারের বাংলা ভাষা যেন মাথার উপর থাকে প্রাইভেট ইউনিভার্সিটির'],
#  ['rec_26_audio_38.wav', 'আরমান নামের মানে চিনবো আসলে চেষ্টা করুন'],
#  ['rec_26_audio_10.wav',
#   'বারাসাত পড়াশোনার গরিবের লাইন সমচার কই কেন করি নগরীর নিজেও না'],
#  ['rec_26_audio_44.wav', 'ভার্সিটি এত বছর লস করিলেন কিল্লাই কি করিলেন'],
#  ['rec_26_audio_13.wav', 'বালা ছিলেন অন্যান্য জিনিসপত্র'],
#  ['rec_26_audio_7.wav',
#   'ভার্সিটির বন্ধু-বান্ধব হতে নাই আর যার করি জীবনে কি করবেন'],
#  ['rec_26_audio_42.wav',
#   'বন্ধুবান্ধব অক্ষর যারা আছেন স্কুল লাইফের এখন কেউ ডাক্তারকে ইঞ্জিনিয়ার হয়ে যাবে'],
#  ['rec_26_audio_11.wav', 'পড়ালেখা গরিয়া রে কি করবো জানি না'],
#  ['rec_26_audio_0.wav',
#   'পড়ালেখা পড়ালেখা এমন একটা জিনিস যে জিনিস গুলো কেউ তোর মনে হয় কিন্তু পড়ালেখা গরমে পরে পড়ালেখা ছাড়া দুনিয়াতে পড়ালেখা করিল'],
#  ['rec_26_audio_23.wav',
#   'দুই সপ্তাহ সময় সারা জীবন তো মা ই বিজ্ঞান মালাই হতে কি গ্রুপের ঘুম আসেনা জান'],
#  ['rec_26_audio_32.wav', 'আর মাল নাই কিছু করার নাই আসলে'],
#  ['rec_26_audio_35.wav',
#   'নিজেরে বাসায় রাহে রে কিছু একখান গরিবের চিন্তা করেন'],
#  ['rec_26_audio_15.wav', 'আমার বাপের মনের মত মিঠুনের লাস্ট পড়ালেখা ঠিক নেই'],
#  ['rec_26_audio_36.wav', 'বিষয়কে জীবনে'],
#  ['rec_26_audio_40.wav',
#   'স্কুল লাইফ কলেজ লাইফ এখন আরে ভার্সিটি লাইফ কিছুই তো করি না পেলে জীবনে না ভালো বন্ধু-বান্ধব বানাতে'],
#  ['rec_26_audio_2.wav',
#   'উত্তম সালাম দে আর্মি অফিসার এখন পড়ালেখা গরম ফেরত দে ল ডিপার্টমেন্ট'],
#  ['rec_26_audio_28.wav',
#   'এখানে যদি ফ্লাড ফেল করার তার এখানে দিন আমার মা যাতে বেগুনের হতে পারে ব্যারিস্টার'],
#  ['rec_26_audio_41.wav',
#   'নাবাব মারে তুমি খুশি করি রেজাল্ট বন্ধুবান্ধব গম গম বন্ধু-বান্ধবের লয় মিষ্টি কিন্তু নিজের পার্লার বালা করে নাও পারে'],
#  ['rec_26_audio_5.wav',
#   'বন্ধুবান্ধব বেগুনে পাশ করি শালার বেগুনি অনার্স শেষবারের দুইদিন পরে সরি'],
#  ['rec_26_audio_25.wav', 'পড়ালেখা শেষ নয় টাকা পয়সা দেন'],
#  ['rec_26_audio_31.wav', '<>'],
#  ['rec_26_audio_34.wav', 'রবীন্দ্রনাথ ঠাকুর কি পরীক্ষার না করে জীবনের কাহিনী'],
#  ['rec_26_audio_4.wav', 'আছে'],
#  ['rec_26_audio_9.wav', 'এখন পড়ালেখা করি দিনে বিয়ে-শাদী ফালাই'],
#  ['rec_26_audio_26.wav',
#   'প্রত্যেকটা মনে হয় কিন্তু নিজের জ্ঞানের নিজেদের নিজের বাপ মারে দেখি'],
#  ['rec_26_audio_3.wav',
#   'সারাজীবন সাঈদী সাইন্স বইয়ের গান কিন্তু নাইন টেন কমার্স ই-কমার্স একাউন্টিং তো জীবনেও বুঝি এখন শরীর দিয়ে'],
#  ['rec_26_audio_27.wav', 'অ্যামাজনের জীবনের কিভাবে স্বাধীনতা স্বাধীনতা'],
#  ['rec_26_audio_18.wav',
#   'বাপ মায়ের টিয়াদের খরচ করার নতুন হলে কিসের খেয়াল নেই ইমেইল ইমেইল দিয়ে হোতা হে'],
#  ['rec_26_audio_43.wav', 'হাসো না'],
#  ['rec_27_audio_13.wav', '<>'],
#  ['rec_27_audio_18.wav', '<>'],
#  ['rec_27_audio_3.wav', 'ধন্যবাদ ধন্যবাদ'],
#  ['rec_27_audio_47.wav', 'আপা'],
#  ['rec_27_audio_5.wav', '<>'],
#  ['rec_27_audio_12.wav', '<>'],
#  ['rec_27_audio_7.wav', '<>'],
#  ['rec_27_audio_0.wav', '<>'],
#  ['rec_27_audio_15.wav', 'হারা হারা ঈদে মিলাদুন্নবী পর্যন্ত'],
#  ['rec_27_audio_29.wav', '<>'],
#  ['rec_27_audio_21.wav', '<>'],
#  ['rec_27_audio_9.wav', '<>'],
#  ['rec_27_audio_19.wav', '<>'],
#  ['rec_27_audio_45.wav', 'বালা বালা অহংকার ভাল্লাগেনা অহংকার'],
#  ['rec_27_audio_48.wav', 'একটা স্লামালাইকুম'],
#  ['rec_27_audio_32.wav', 'মোবাইল'],
#  ['rec_27_audio_40.wav', '<>'],
#  ['rec_27_audio_11.wav', 'করবো কিভাবে'],
#  ['rec_27_audio_17.wav', 'পেট থেকে আমেরিকা'],
#  ['rec_27_audio_20.wav', '<>'],
#  ['rec_27_audio_35.wav', '<>'],
#  ['rec_27_audio_42.wav', '<>'],
#  ['rec_27_audio_23.wav', '<>'],
#  ['rec_27_audio_1.wav', '<>'],
#  ['rec_27_audio_46.wav', 'নালার একটা নাও'],
#  ['rec_27_audio_2.wav', '<>'],
#  ['rec_27_audio_8.wav', '<>'],
#  ['rec_27_audio_24.wav', 'লাল্লা লাল্লা লাল্লা লাল্লা উকিলে মানুষের'],
#  ['rec_27_audio_37.wav', '<>'],
#  ['rec_27_audio_26.wav', '<>'],
#  ['rec_27_audio_39.wav', '<>'],
#  ['rec_27_audio_33.wav', 'মোবাইল হারিয়ে দিয়েছে'],
#  ['rec_27_audio_44.wav', '<>'],
#  ['rec_27_audio_22.wav', 'দেখান না'],
#  ['rec_27_audio_16.wav', '<>'],
#  ['rec_27_audio_41.wav', '<>'],
#  ['rec_27_audio_31.wav', 'আমি বিটিভি বিটিভি আনার আমার প্রেম করি না'],
#  ['rec_27_audio_28.wav', '<>'],
#  ['rec_27_audio_34.wav', '<>'],
#  ['rec_27_audio_25.wav', 'কুরিয়ার সার্ভিসে'],
#  ['rec_27_audio_10.wav', 'শুক্রবার'],
#  ['rec_27_audio_38.wav', '<>'],
#  ['rec_27_audio_36.wav', '<>'],
#  ['rec_27_audio_30.wav', '<>'],
#  ['rec_27_audio_43.wav', '<>'],
#  ['rec_27_audio_4.wav', '15 তারিখ 28 তারিখ পর্যন্ত'],
#  ['rec_27_audio_27.wav', '<>'],
#  ['rec_27_audio_14.wav', '<>'],
#  ['rec_27_audio_6.wav', '<>'],
#  ['rec_28_audio_9.wav', 'নানা রয়েছে'],
#  ['rec_28_audio_8.wav', 'আলামিন'],
#  ['rec_28_audio_7.wav', '<>'],
#  ['rec_28_audio_30.wav', 'বাইরে তাপমাত্রা'],
#  ['rec_28_audio_31.wav', 'না হয় এটা হয়ে আমেরিকা'],
#  ['rec_28_audio_34.wav', 'রেশমা কেমন আছেন ভালো আছেন'],
#  ['rec_28_audio_20.wav', '<>'],
#  ['rec_28_audio_27.wav', '<>'],
#  ['rec_28_audio_21.wav', 'ইমোজি ভিডিও সরাসরি'],
#  ['rec_28_audio_22.wav', 'কোরবানির হাতে হারিয়ে গেছে'],
#  ['rec_28_audio_25.wav', '<>'],
#  ['rec_28_audio_26.wav', '20000 টাকার'],
#  ['rec_28_audio_24.wav', '<>'],
#  ['rec_28_audio_28.wav', '<>'],
#  ['rec_28_audio_33.wav', 'আলিয়া বাজার'],
#  ['rec_28_audio_13.wav', '<>'],
#  ['rec_28_audio_14.wav', '<>'],
#  ['rec_28_audio_29.wav', '<>'],
#  ['rec_28_audio_19.wav', 'আলা দু-তিন'],
#  ['rec_28_audio_23.wav', '<>'],
#  ['rec_28_audio_35.wav', 'পরিবর্তন'],
#  ['rec_28_audio_15.wav', 'আরাফ উদ্দিন'],
#  ['rec_28_audio_4.wav', '<>'],
#  ['rec_28_audio_2.wav', '<>'],
#  ['rec_28_audio_17.wav', '<>'],
#  ['rec_28_audio_0.wav', 'স্লামালাইকুম'],
#  ['rec_28_audio_32.wav', '<>'],
#  ['rec_28_audio_11.wav', 'নেপালের মাত্র'],
#  ['rec_28_audio_12.wav', 'বাতাস কি মন্ত্রিস'],
#  ['rec_28_audio_1.wav', '<>'],
#  ['rec_28_audio_36.wav', 'এ মাসে 3000 টাকার ওষুধ কিনে পরস গাড়ি খেলা'],
#  ['rec_28_audio_6.wav', 'জামাইয়ের খেলা বাচ্চাদের'],
#  ['rec_28_audio_10.wav', '<>'],
#  ['rec_28_audio_16.wav', '30000 নতুন নতুন'],
#  ['rec_28_audio_3.wav', '<>'],
#  ['rec_28_audio_5.wav', '<>'],
#  ['rec_28_audio_18.wav', '<>'],
#  ['rec_29_audio_25.wav', 'বলে দেখুন'],
#  ['rec_29_audio_76.wav', '<>'],
#  ['rec_29_audio_16.wav', '<>'],
#  ['rec_29_audio_98.wav', '<>'],
#  ['rec_29_audio_69.wav', '<>'],
#  ['rec_29_audio_89.wav', '<>'],
#  ['rec_29_audio_74.wav', 'ডিজে'],
#  ['rec_29_audio_59.wav', 'ওরে বাবা যে সমস্যা বলেন'],
#  ['rec_29_audio_43.wav', 'অফিস চট্টগ্রাম'],
#  ['rec_29_audio_6.wav', '<>'],
#  ['rec_29_audio_51.wav', '<>'],
#  ['rec_29_audio_3.wav',
#   'আমার হচ্ছে মানে মোটামুটি ওই মানে 5 ঘন্টায় হচ্ছে আপনার 300 মিনিট তো আমার উত্তর 200 মিনিট মতো কালেক্ট হয়েছে তো আরো 100 মিনিট কালেক্ট করা দরকার'],
#  ['rec_29_audio_9.wav', '<>'],
#  ['rec_29_audio_94.wav', '<>'],
#  ['rec_29_audio_41.wav', '17 তারিখ'],
#  ['rec_29_audio_77.wav',
#   'মুরগিরে ভর্তি আছে কি তারপরে তোমার টেনশন পাইয়া আমায় তরকারিতে'],
#  ['rec_29_audio_13.wav', '<>'],
#  ['rec_29_audio_33.wav', '<>'],
#  ['rec_29_audio_39.wav', '<>'],
#  ['rec_29_audio_46.wav', 'আলাদিন দেখা দিবে না না আরো পরে কিনে দেয়নি'],
#  ['rec_29_audio_58.wav', '<>'],
#  ['rec_29_audio_27.wav', '<>'],
#  ['rec_29_audio_91.wav', '<>'],
#  ['rec_29_small_audio_0.wav', 'হ্যালো হ্যালো'],
#  ['rec_29_audio_29.wav', 'মাইরি বেঞ্চের পরীক্ষা দিব'],
#  ['rec_29_audio_45.wav', 'ভাদাইমা শোনা যায় না'],
#  ['rec_29_audio_12.wav', '<>'],
#  ['rec_29_audio_14.wav', '<>'],
#  ['rec_29_audio_50.wav', 'বাংলা ক্যালেন্ডার'],
#  ['rec_29_audio_81.wav', 'এফডিআর একটি'],
#  ['rec_29_audio_93.wav', '<>'],
#  ['rec_29_audio_30.wav', '<>'],
#  ['rec_29_audio_80.wav',
#   'নেভানোর জামাই লকটা ভরানোর জন্য দিবো তাড়াতাড়ি লাগবে'],
#  ['rec_29_audio_8.wav', '<>'],
#  ['rec_29_audio_83.wav', 'হরমোন ঐক্য শরীর'],
#  ['rec_29_audio_2.wav', 'ডাটাবেজ তৈরি করতেছে'],
#  ['rec_29_audio_53.wav', '<>'],
#  ['rec_29_audio_95.wav', '<>'],
#  ['rec_29_audio_40.wav', 'হারিয়ে পরিবার'],
#  ['rec_29_audio_92.wav', '<>'],
#  ['rec_29_audio_7.wav', 'রেহান নাম্বার'],
#  ['rec_29_audio_21.wav', '<>'],
#  ['rec_29_audio_0.wav', 'কালকের রেজাল্ট'],
#  ['rec_29_audio_85.wav', 'চার তারিখ'],
#  ['rec_29_audio_24.wav', '<>'],
#  ['rec_29_audio_22.wav', '<>'],
#  ['rec_29_audio_11.wav', '<>'],
#  ['rec_29_audio_44.wav', '25 কেজি কিনে দেওয়া হবে না'],
#  ['rec_29_audio_70.wav',
#   'এক বছর পরে দোয়া করি সংসার 35 বছর সার্টিফিকেট দিয়ে'],
#  ['rec_29_audio_71.wav', 'মানববন্ধন করেছেন'],
#  ['rec_29_audio_19.wav', '<>'],
#  ['rec_29_audio_61.wav', '<>'],
#  ['rec_29_audio_68.wav', '<>'],
#  ['rec_29_audio_84.wav',
#   'হামারা দিন হাম করিবে আলাদিন হাম করে হিন্দি মুভি mp3'],
#  ['rec_29_audio_88.wav', '<>'],
#  ['rec_29_audio_36.wav', '<>'],
#  ['rec_29_audio_64.wav', '<>'],
#  ['rec_29_audio_78.wav', '<>'],
#  ['rec_29_audio_52.wav', 'জামানা গজল'],
#  ['rec_29_audio_37.wav', '<>'],
#  ['rec_29_audio_1.wav', 'তৈরি করতেছে'],
#  ['rec_29_audio_10.wav', '<>'],
#  ['rec_29_audio_73.wav', 'বিশ্ব আলমের দেব লাইভে যদি সরি না'],
#  ['rec_29_audio_79.wav', '<>'],
#  ['rec_29_audio_49.wav', '<>'],
#  ['rec_29_audio_4.wav', 'আচ্ছা ঠিক আছে'],
#  ['rec_29_audio_67.wav', '15 বছর পর্যন্ত'],
#  ['rec_29_audio_75.wav', '<>'],
#  ['rec_29_audio_66.wav', '<>'],
#  ['rec_29_audio_56.wav', '<>'],
#  ['rec_29_audio_38.wav', '<>'],
#  ['rec_29_audio_87.wav', 'বাড়িতে এরমধ্যে এটা আইলেন'],
#  ['rec_29_audio_60.wav', '<>'],
#  ['rec_29_audio_35.wav', '<>'],
#  ['rec_29_audio_63.wav', '<>'],
#  ['rec_29_audio_99.wav', '<>'],
#  ['rec_29_audio_32.wav', 'দিনের বারোটা বাজে না'],
#  ['rec_29_audio_54.wav', 'হ্যাঁ'],
#  ['rec_29_audio_65.wav', 'পানিতে কিভাবে নষ্ট হয়েছে'],
#  ['rec_29_audio_55.wav', 'মা হলো তোর আম্মা আম্মা করে পিকচার'],
#  ['rec_29_audio_72.wav', '<>'],
#  ['rec_29_audio_17.wav', 'যদি তোমার বাবা তোমার'],
#  ['rec_29_audio_96.wav', '<>'],
#  ['rec_29_audio_5.wav', 'হ্যালো হ্যালো'],
#  ['rec_29_audio_26.wav', '<>'],
#  ['rec_29_audio_90.wav', '<>'],
#  ['rec_29_audio_18.wav', '<>'],
#  ['rec_29_audio_20.wav', 'মানসিক কোন ডাক্তার ডাক্তার'],
#  ['rec_29_audio_47.wav', 'নরসিংদী ছবি নরসিংদী সিরিয়াল'],
#  ['rec_29_audio_57.wav', '<>'],
#  ['rec_29_audio_23.wav', '<>'],
#  ['rec_29_audio_15.wav', 'মোবাইল'],
#  ['rec_29_audio_34.wav', '<>'],
#  ['rec_29_audio_31.wav', '<>'],
#  ['rec_29_audio_97.wav', '<>'],
#  ['rec_29_audio_82.wav', '<>'],
#  ['rec_29_audio_48.wav', '<>'],
#  ['rec_29_audio_62.wav', 'ওই ব্যাটা নিয়ে নাসা আমি কিনে দিয়েছি'],
#  ['rec_29_audio_86.wav', '<>'],
#  ['rec_29_audio_28.wav', '<>'],
#  ['rec_29_audio_42.wav', '<>'],
#  ['rec_30_audio_25.wav', 'কি আর করবি পরীক্ষা'],
#  ['rec_30_audio_3.wav', '<>'],
#  ['rec_30_audio_24.wav', '<>'],
#  ['rec_30_audio_42.wav', '<>'],
#  ['rec_30_audio_4.wav', 'আর ফলাফল'],
#  ['rec_30_audio_37.wav', 'যাইবো'],
#  ['rec_30_audio_11.wav', 'বেস্ট বোরহান কি ডাক্তার ছিল দিন'],
#  ['rec_30_audio_1.wav', 'কোন রকম কা অরণ্য'],
#  ['rec_30_audio_8.wav', 'চিটাগাং কি কি করবি হবে গেলাম'],
#  ['rec_30_audio_14.wav', 'মোবাইল'],
#  ['rec_30_audio_27.wav', '<>'],
#  ['rec_30_audio_16.wav', '<>'],
#  ['rec_30_audio_28.wav', '<>'],
#  ['rec_30_audio_20.wav', 'গঙ্গোপাধ্যায়'],
#  ['rec_30_audio_23.wav', '<>'],
#  ['rec_30_audio_34.wav', 'গরদ হালকা হাম গরিবের লাইল দেবো না'],
#  ['rec_30_audio_38.wav', '<>'],
#  ['rec_30_audio_9.wav', 'আনা হায় হায় অবস্থায় গেলাম'],
#  ['rec_30_audio_33.wav', 'আমার নাম'],
#  ['rec_30_audio_19.wav', '<>'],
#  ['rec_30_audio_40.wav', '<>'],
#  ['rec_30_audio_13.wav', '<>'],
#  ['rec_30_audio_22.wav', 'কেয়া কেয়া চুদালে কোশ্চেন করব'],
#  ['rec_30_audio_36.wav', '<>'],
#  ['rec_30_audio_10.wav',
#   'হ্যাঁ বেশি ভালোই একবারে গর্ভবতীর মৃত্যু দরকার নেই হ্যাঁ'],
#  ['rec_30_audio_30.wav', '<>'],
#  ['rec_30_audio_21.wav', '<>'],
#  ['rec_30_audio_26.wav', '<>'],
#  ['rec_30_audio_31.wav', 'শেখ হাসিনা হাসার দেখা উত্তম'],
#  ['rec_30_audio_17.wav', 'হালা'],
#  ['rec_30_audio_41.wav', '<>'],
#  ['rec_30_audio_6.wav', 'মোবাইলটি দরকার নেই'],
#  ['rec_30_audio_29.wav', 'নর্মাল বাটন মোবাইল নাম্বার'],
#  ['rec_30_audio_0.wav', 'সালামুআলাইকুম ওয়ালাইকুম আসসালাম'],
#  ['rec_30_audio_32.wav', 'ঘোড়ার ডিম করা'],
#  ['rec_30_audio_2.wav', '<>'],
#  ['rec_30_audio_7.wav', '<>'],
#  ['rec_30_audio_15.wav', '<>'],
#  ['rec_30_audio_39.wav', '<>'],
#  ['rec_30_audio_18.wav', 'আনা এখন ঘর থেকে বলে যান'],
#  ['rec_30_audio_5.wav', 'শেষ শেষ শেষ শেষ শেষ শেষ নেই'],
#  ['rec_30_audio_35.wav', 'জামাই জামাই ফোনে কিছু নেই'],
#  ['rec_30_audio_12.wav', '<>'],
#  ['rec_31_audio_36.wav', '<>'],
#  ['rec_31_audio_19.wav', 'ডিয়ার লটারি রেজাল্ট'],
#  ['rec_31_audio_34.wav', '<>'],
#  ['rec_31_audio_3.wav', '<>'],
#  ['rec_31_audio_18.wav',
#   'সাইবার সকালে টেনশন না সরকারের মতো শয়তান তো মনোবিজ্ঞান আছে তো'],
#  ['rec_31_audio_9.wav', 'তুইতো'],
#  ['rec_31_audio_35.wav', 'নায়িকাদের অনলাইন হবে'],
#  ['rec_31_audio_15.wav', 'বেসরকারিতে সরকার'],
#  ['rec_31_audio_29.wav', 'এডাল নতুন না আগে খোলো আনন্দ'],
#  ['rec_31_audio_27.wav', 'এই তুই কম্পিউটার মধ্যে পার্থক্য'],
#  ['rec_31_audio_17.wav',
#   'পিয়াসা করিস না ভর্তি হয়ে যায় মনোবিজ্ঞান করবি চাইনি'],
#  ['rec_31_audio_6.wav', '<>'],
#  ['rec_31_audio_7.wav', 'আইপিসিটি মাত্র তিন দিন আর কতদিন লাগবে না বিএসএস নয়'],
#  ['rec_31_audio_4.wav', '<>'],
#  ['rec_31_audio_25.wav', 'ভালো আছি'],
#  ['rec_31_audio_46.wav', 'তোরে আচ্ছা ঠিক আছে রাখি তাহলে বাই বাই টাটা বাই বাই'],
#  ['rec_31_audio_42.wav', '<>'],
#  ['rec_31_audio_33.wav', 'না দেয় নাই'],
#  ['rec_31_audio_16.wav', '<>'],
#  ['rec_31_audio_22.wav', 'তো মানে একটা মানুষের পরিচয় সম্পর্কে'],
#  ['rec_31_audio_32.wav', 'কম্পিউটারে'],
#  ['rec_31_audio_21.wav',
#   'ভাই বোন আছে যে ব্যাগ কিন্তু আর কোনো বড় বড় তারা অনার্স বই পড়ে দেখেন'],
#  ['rec_31_small_audio_0.wav', '<>'],
#  ['rec_31_audio_1.wav',
#   'কলেজের খবর টবর কি কলেজের 22 সেকেন্ড মেয়েটা তার নাম নয় এখন কি না পারি না হাই আছি'],
#  ['rec_31_audio_41.wav', '<>'],
#  ['rec_31_audio_14.wav', 'আর পাবলিকের মধ্যে খরচ বেশি ভালো লাগে না'],
#  ['rec_31_audio_24.wav', 'সাজ্জাদ নাই'],
#  ['rec_31_audio_31.wav', '<>'],
#  ['rec_31_audio_13.wav', 'চায়নারা এখন বাড়ি ডিগ্রি চ্যানেল'],
#  ['rec_31_audio_43.wav', 'আর ইংলিশে কার্টুন দিলাম'],
#  ['rec_31_audio_12.wav', '<>'],
#  ['rec_31_audio_44.wav', 'আবার কেন দিবার কোন নিয়ম সম্বন্ধে খাওয়াচ্ছে'],
#  ['rec_31_audio_20.wav', 'ভাই বোন নাই'],
#  ['rec_31_audio_0.wav',
#   'হ্যালো কেমন আছোস এইতো ভালো আছি তুই কেমন আছিস এই তো ভালো আছি এখন বসে আছি তুই কি করস খাইয়া বইয়া আছি'],
#  ['rec_31_audio_8.wav', 'খাইসনা কিছু করার নাই'],
#  ['rec_31_audio_39.wav', '<>'],
#  ['rec_31_audio_11.wav', '<>'],
#  ['rec_31_audio_2.wav',
#   'না জানি কি রকম ফেসবুক টাকা লেগেছে না সিটি কলেজের তুই কিল্লাই'],
#  ['rec_31_audio_5.wav', '<>'],
#  ['rec_31_audio_23.wav', 'কম্পিউটার সিদ্ধান্ত কিভাবে তোমার বাড়ি কোথায়'],
#  ['rec_31_audio_10.wav', 'আই নো হয় না কেন'],
#  ['rec_31_audio_30.wav', '<>'],
#  ['rec_31_audio_37.wav', 'পদ্মা নদীতে পার্থক্য'],
#  ['rec_31_audio_38.wav', '<>'],
#  ['rec_31_audio_40.wav', 'না পারলে ডিগ্রী পরীক্ষা'],
#  ['rec_31_audio_28.wav', '<>'],
#  ['rec_31_audio_45.wav', 'অডিও'],
#  ['rec_31_audio_26.wav', 'বেশি ভালো আছে না গার্লফ্রেন্ড চলে'],
#  ['rec_32_audio_28.wav', '<>'],
#  ['rec_32_audio_18.wav', 'ওপরে ইন্ডিয়া পরীক্ষার ফলাফল'],
#  ['rec_32_audio_22.wav', 'মহানগর এক্সপ্রেস'],
#  ['rec_32_audio_24.wav', '<>'],
#  ['rec_32_audio_10.wav', 'কিছু হয়নি'],
#  ['rec_32_audio_31.wav', '<>'],
#  ['rec_32_audio_27.wav', 'দেনা পরে কল দেয় না'],
#  ['rec_32_audio_15.wav', '<>'],
#  ['rec_32_audio_9.wav', '<>'],
#  ['rec_32_audio_12.wav', 'ইন্টার ওপারেও পরীক্ষার ফলাফল'],
#  ['rec_32_audio_13.wav', 'মাথা'],
#  ['rec_32_audio_25.wav', '<>'],
#  ['rec_32_audio_5.wav', 'নাঈম আপু রিকোয়েস্ট পাঠাইল'],
#  ['rec_32_audio_19.wav', '<>'],
#  ['rec_32_audio_1.wav', '<>'],
#  ['rec_32_audio_36.wav', '<>'],
#  ['rec_32_audio_11.wav', '<>'],
#  ['rec_32_audio_34.wav', '<>'],
#  ['rec_32_audio_0.wav', 'আসসালামুয়ালাইকুম ওয়ালাইকুম'],
#  ['rec_32_audio_17.wav', 'বৃষ্টি বৃষ্টি পড়ে'],
#  ['rec_32_audio_21.wav', 'বাংলা'],
#  ['rec_32_audio_20.wav', 'ফ্যামিলি 4g তিনজন নেই'],
#  ['rec_32_audio_3.wav', '<>'],
#  ['rec_32_audio_8.wav', 'পড়াশোনা মিথ্যা'],
#  ['rec_32_audio_33.wav', 'টুডেস ওয়েদার'],
#  ['rec_32_audio_40.wav', 'হাসোস'],
#  ['rec_32_audio_30.wav', 'ঠিক আছে তুমি হাসাতে যুক্তি আসে না কল করব'],
#  ['rec_32_audio_26.wav', '<>'],
#  ['rec_32_audio_4.wav', '<>'],
#  ['rec_32_audio_39.wav', 'হ্যালো হ্যালো'],
#  ['rec_32_audio_41.wav', '<>'],
#  ['rec_32_audio_38.wav', 'চেহারা হঠাৎ দেখলাম'],
#  ['rec_32_audio_23.wav', '<>'],
#  ['rec_32_audio_2.wav', 'কিন্তু হঠাৎ একদিন'],
#  ['rec_32_audio_32.wav', 'কিছু হইতাম না'],
#  ['rec_32_audio_29.wav', '<>'],
#  ['rec_32_audio_6.wav', 'মেসি ফাংশন করে দিয়েছি'],
#  ['rec_32_audio_7.wav', 'চিটাংগা চিটাং গরম পড়লে'],
#  ['rec_32_audio_16.wav', '<>'],
#  ['rec_32_audio_37.wav', '<>'],
#  ['rec_32_audio_14.wav', '<>'],
#  ['rec_32_audio_35.wav', '<>'],
#  ['rec_33_audio_44.wav', 'হাই'],
#  ['rec_33_audio_65.wav', '<>'],
#  ['rec_33_audio_48.wav', 'শান্তা দেখতে রেজাল্ট'],
#  ['rec_33_audio_60.wav', '<>'],
#  ['rec_33_audio_42.wav', '<>'],
#  ['rec_33_audio_12.wav', 'পায়নি ইউনিভার্সিটি'],
#  ['rec_33_audio_55.wav', '<>'],
#  ['rec_33_audio_54.wav', '<>'],
#  ['rec_33_audio_36.wav', '<>'],
#  ['rec_33_audio_33.wav', 'আল্লাহতালা'],
#  ['rec_33_audio_58.wav', '<>'],
#  ['rec_33_audio_62.wav', '<>'],
#  ['rec_33_audio_66.wav', 'এটা কিন্তু এক বছরে'],
#  ['rec_33_audio_59.wav', '<>'],
#  ['rec_33_audio_4.wav', 'কবিতা'],
#  ['rec_33_audio_46.wav', 'দুলাভাই দুলাভাই'],
#  ['rec_33_audio_14.wav', '<>'],
#  ['rec_33_audio_3.wav', '<>'],
#  ['rec_33_audio_13.wav', '<>'],
#  ['rec_33_audio_35.wav', 'এটা চাইরে সমস্যা করে দিলাম'],
#  ['rec_33_audio_11.wav', '<>'],
#  ['rec_33_audio_63.wav', 'আশেপাশে বাগান'],
#  ['rec_33_audio_56.wav', 'জেরিন তারার বাসা দূরে'],
#  ['rec_33_audio_40.wav', '<>'],
#  ['rec_33_audio_47.wav', '<>'],
#  ['rec_33_audio_49.wav', '<>'],
#  ['rec_33_audio_17.wav', '<>'],
#  ['rec_33_audio_21.wav', '<>'],
#  ['rec_33_audio_31.wav', '<>'],
#  ['rec_33_audio_6.wav', 'ও আচ্ছা অন্য বান্ধবী হবে'],
#  ['rec_33_audio_25.wav', '<>'],
#  ['rec_33_audio_53.wav', '<>'],
#  ['rec_33_audio_28.wav', '<>'],
#  ['rec_33_audio_15.wav', 'অনার্স চতুর্থ বর্ষ'],
#  ['rec_33_audio_57.wav', '<>'],
#  ['rec_33_audio_51.wav', 'ভাই কল দিমু নয় আরে রিনা না জানি না'],
#  ['rec_33_audio_32.wav', '<>'],
#  ['rec_33_small_audio_0.wav', 'মে চালাক বাঙালি'],
#  ['rec_33_audio_45.wav', '<>'],
#  ['rec_33_audio_8.wav', 'তোমার কি অবস্থা দেখুন'],
#  ['rec_33_audio_22.wav', '<>'],
#  ['rec_33_audio_1.wav', '<>'],
#  ['rec_33_audio_41.wav', '<>'],
#  ['rec_33_audio_52.wav', '<>'],
#  ['rec_33_audio_30.wav', '<>'],
#  ['rec_33_audio_0.wav', 'সালামুআলাইকুম সমস্যা হয়েছে'],
#  ['rec_33_audio_19.wav', 'আজ রাজশাহী বিশ্ববিদ্যালয়'],
#  ['rec_33_audio_29.wav', '<>'],
#  ['rec_33_audio_5.wav', '<>'],
#  ['rec_33_audio_10.wav', 'টিভি'],
#  ['rec_33_audio_20.wav', '<>'],
#  ['rec_33_audio_38.wav', '<>'],
#  ['rec_33_audio_43.wav', '<>'],
#  ['rec_33_audio_16.wav', '<>'],
#  ['rec_33_audio_2.wav', 'অনেক কীর্তন'],
#  ['rec_33_audio_61.wav', 'খাটা চলছে'],
#  ['rec_33_audio_64.wav', 'বাসা কোথায়'],
#  ['rec_33_audio_24.wav', 'সাইন্সে'],
#  ['rec_33_audio_27.wav', '<>'],
#  ['rec_33_audio_9.wav', '<>'],
#  ['rec_33_audio_39.wav', '<>'],
#  ['rec_33_audio_18.wav', 'চোখের ভাষা'],
#  ['rec_33_audio_23.wav', 'আছে কোনরকম ভালো আছে ভালো আছে'],
#  ['rec_33_audio_7.wav', '<>'],
#  ['rec_33_audio_37.wav', 'পিয়া জানিনা'],
#  ['rec_33_audio_50.wav', '<>'],
#  ['rec_33_audio_26.wav', '<>'],
#  ['rec_33_audio_34.wav', 'না না বেঠিক'],
#  ['rec_24_big_audio_3.wav_chunk_0.wav', '<>'],
#  ['rec_24_big_audio_3.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_6.wav_chunk_1.wav', '<>'],
#  ['rec_24_big_audio_2.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_5.wav_chunk_2.wav', '<>'],
#  ['rec_24_big_audio_1.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_4.wav_chunk_1.wav', '<>'],
#  ['rec_14_big_audio_0.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_6.wav_chunk_2.wav', '<>'],
#  ['rec_18_big_audio_4.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_2.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_7.wav_chunk_2.wav', '<>'],
#  ['rec_18_big_audio_1.wav_chunk_1.wav', '<>'],
#  ['rec_24_big_audio_1.wav_chunk_0.wav', '<>'],
#  ['rec_14_big_audio_1.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_2.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_3.wav_chunk_2.wav', '<>'],
#  ['rec_18_big_audio_7.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_7.wav_chunk_1.wav', '<>'],
#  ['rec_21_big_audio_0.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_5.wav_chunk_3.wav', '<>'],
#  ['rec_18_big_audio_5.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_4.wav_chunk_2.wav', '<>'],
#  ['rec_18_big_audio_2.wav_chunk_2.wav', '<>'],
#  ['rec_18_big_audio_1.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_7.wav_chunk_3.wav', '<>'],
#  ['rec_20_big_audio_1.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_6.wav_chunk_0.wav', '<>'],
#  ['rec_20_big_audio_1.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_5.wav_chunk_1.wav', '<>'],
#  ['rec_21_big_audio_0.wav_chunk_0.wav', '<>'],
#  ['rec_14_big_audio_0.wav_chunk_2.wav', '<>'],
#  ['rec_14_big_audio_0.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_3.wav_chunk_1.wav', '<>'],
#  ['rec_14_big_audio_1.wav_chunk_0.wav', '<>'],
#  ['rec_18_big_audio_3.wav_chunk_0.wav', '<>'],
#  ['rec_24_big_audio_2.wav_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_18_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_11_audio_0.wav', 'এক মিনিট মাত্র'],
#  ['rec_11_audio_23.wav', '<>'],
#  ['rec_11_audio_36.wav', 'নারে ব্রাদার'],
#  ['rec_11_audio_14.wav', 'চা আসলে মজা নেই'],
#  ['rec_11_audio_35.wav', 'অনুবাদ যাও'],
#  ['rec_11_audio_31.wav', 'সোনা হারা সোনার বাংলা'],
#  ['rec_11_audio_18.wav', '<>'],
#  ['rec_11_audio_39.wav', 'না তোমার ঘটনা'],
#  ['rec_11_audio_21.wav', '<>'],
#  ['rec_11_audio_22.wav', 'ও দিয়ে দেবো'],
#  ['rec_11_audio_6.wav', '<>'],
#  ['rec_11_audio_29.wav', 'ভাই এখন নাকি কাদা কাদা করে বলেন'],
#  ['rec_11_audio_16.wav', '<>'],
#  ['rec_11_audio_30.wav', 'হ্যাঁ ভাইয়া'],
#  ['rec_11_audio_27.wav', 'কিভাবে দেখিনি'],
#  ['rec_11_audio_9.wav', '<>'],
#  ['rec_11_audio_7.wav', 'এটা আবার আইয়ের ঘটনা'],
#  ['rec_11_audio_13.wav', '<>'],
#  ['rec_11_audio_33.wav', '<>'],
#  ['rec_11_audio_8.wav', 'ছক্কা একক'],
#  ['rec_11_audio_12.wav', 'কিসের জ্বালানি হয় নাকি নাই'],
#  ['rec_11_audio_10.wav', '<>'],
#  ['rec_11_audio_17.wav', 'লবন'],
#  ['rec_11_audio_5.wav', '<>'],
#  ['rec_11_audio_4.wav', '<>'],
#  ['rec_11_audio_25.wav', 'তুই যখন আসবি তখন দেখতাম'],
#  ['rec_11_audio_28.wav', '<>'],
#  ['rec_11_audio_2.wav', '<>'],
#  ['rec_11_audio_38.wav', '<>'],
#  ['rec_11_audio_37.wav', '<>'],
#  ['rec_11_audio_11.wav', 'আসিনা'],
#  ['rec_11_audio_20.wav', 'তোমার আর কি তালতো ভাই আর একটা শোনাও'],
#  ['rec_11_audio_32.wav', '<>'],
#  ['rec_11_audio_34.wav', 'কিরণমালা বদরপুর দরকার'],
#  ['rec_11_small_audio_0.wav', 'স্যারের তো'],
#  ['rec_11_audio_26.wav', 'মাঠ খোলা'],
#  ['rec_11_audio_1.wav', '<>'],
#  ['rec_11_audio_24.wav', '<>'],
#  ['rec_11_audio_19.wav', 'কে আয় বন্ধু'],
#  ['rec_11_audio_3.wav', '<>'],
#  ['rec_11_audio_15.wav', 'আরেকবার হইলাম'],
#  ['rec_38_audio_5.wav', '<>'],
#  ['rec_38_audio_18.wav', '<>'],
#  ['rec_38_audio_32.wav', '<>'],
#  ['rec_38_audio_29.wav', '<>'],
#  ['rec_38_audio_11.wav', '<>'],
#  ['rec_38_audio_21.wav', 'কও'],
#  ['rec_38_audio_23.wav',
#   'ইয়েন খুবই দুঃখজনক তুই কি করিব আসলে খুব ভালো ভালো ফলাফল'],
#  ['rec_38_audio_8.wav',
#   'এই আসলে তবে একসময় যারা ব্যাংক করছে তবে এখন এসব মন অনেক অনেক কিছু'],
#  ['rec_38_audio_3.wav',
#   'ভালো দিক বলতে গেলে জিনিসটা ভালো দেখে তাকে খারাপ তুই এক একখান জিনিস'],
#  ['rec_38_audio_30.wav', '<>'],
#  ['rec_38_audio_10.wav', 'ষষ্ঠ'],
#  ['rec_38_audio_25.wav', '<>'],
#  ['rec_38_audio_20.wav', 'কিন্তু বেকার বেশি অনেক'],
#  ['rec_38_audio_7.wav', 'না না অবশ্যই ঠিক আছে'],
#  ['rec_38_audio_13.wav',
#   'ইয়ান মালিকা সারাদিনে খান হাঁস ঘড়ির বাহাদুরি লাগছে'],
#  ['rec_38_audio_17.wav', 'লজ্জা ইন্টারনেটের তবে বেকার যখন বেঙ্গলি'],
#  ['rec_38_audio_22.wav', 'খুব ভালো রেজাল্ট কখন লাগবে'],
#  ['rec_38_audio_28.wav', '<>'],
#  ['rec_38_audio_33.wav', '<>'],
#  ['rec_38_audio_31.wav', '<>'],
#  ['rec_38_audio_6.wav', '<>'],
#  ['rec_38_audio_16.wav',
#   'ইয়ান যারা তো সম্ভব ইতারা কিন্তু ব্যাংক খুব ভালো বলতে হয় এবং ইতালিয়ান ঠিক আছে এবং বিভিন্ন মান অপমান সোজা কথা ম্যানেজমেন্ট মান অপমান'],
#  ['rec_38_audio_2.wav',
#   'আসলে ব্যাংকিং সম্পর্কে ভালো দিক দিক দিক দিক খারাপ দিক গুগল প্রশ্ন না মানে দুয়া জিনিস আমি জানতে চাই না'],
#  ['rec_38_audio_26.wav',
#   'মোবাইলের কেসিং না লাগাইবা মোবাইলের কেসিং এর জন্য শান্তি নেই জীবনের স্বাদ বলতে'],
#  ['rec_38_audio_1.wav',
#   'আমার বয়স 34 333 ধন্যবাদ যদি অনুপ্রেরণা সম্পর্কে আরও কিছু'],
#  ['rec_38_audio_27.wav',
#   'টেনশন থাকে এবং সারাদিন হয়ে যেতেও আবার টেনশন হয়েছে'],
#  ['rec_38_audio_12.wav',
#   'পেয়ারার তুমি সবসময় চাপ দিতেই থাকে এই আজগের সন্তুষ্টি করে আসলে ম্যানেজমেন্ট ডাইরেক পাঠাতে হবে না'],
#  ['rec_38_audio_24.wav', 'কিন্তু এখানে বলেছে আলহামদুলিল্লাহ'],
#  ['rec_38_audio_9.wav', 'পৃথিবীর ব্যাপারে'],
#  ['rec_38_audio_0.wav',
#   'আসসালামুয়ালাইকুম কেমন আছেন তার আগে আমার নাম বয়স এবং পেশা সম্পর্কে'],
#  ['rec_38_audio_14.wav', 'আর কিছু নাই'],
#  ['rec_38_audio_4.wav', 'যখন কিছু করতে রাজি যখন কিছু মাইলি জীবন যাপন করছে'],
#  ['rec_38_audio_19.wav', 'ব্যাংকিং সেক্টরে'],
#  ['rec_38_audio_15.wav', 'আই আরলি থেকে একটু আত্মকেন্দ্রিক গুগল আর নেই'],
#  ['rec_39_audio_16.wav', '<>'],
#  ['rec_39_audio_0.wav', '<>'],
#  ['rec_39_audio_2.wav', 'ক্রেডিট কার্ড'],
#  ['rec_39_audio_7.wav', 'শেলটার'],
#  ['rec_39_audio_3.wav', '<>'],
#  ['rec_39_audio_1.wav', '<>'],
#  ['rec_39_audio_15.wav', '<>'],
#  ['rec_39_small_audio_0.wav', '<>'],
#  ['rec_39_audio_11.wav', '<>'],
#  ['rec_39_audio_9.wav', 'আর কেমন বাজে সেন্টার'],
#  ['rec_39_audio_17.wav', '<>'],
#  ['rec_39_audio_12.wav', '<>'],
#  ['rec_39_audio_14.wav', '<>'],
#  ['rec_39_audio_10.wav', 'ইমারজেন্সি ইমারজেন্সি ম্যানেজমেন্ট নেই'],
#  ['rec_39_audio_13.wav', 'গুড নাইট'],
#  ['rec_39_audio_6.wav', 'খাওয়া-দাওয়া পত্রিকা'],
#  ['rec_39_audio_5.wav', '<>'],
#  ['rec_39_audio_4.wav', 'তার মানে না'],
#  ['rec_39_audio_8.wav', '<>'],
#  ['rec_40_audio_10.wav', 'একসঙ্গে'],
#  ['rec_40_audio_8.wav', '<>'],
#  ['rec_40_audio_21.wav', 'অলরেডি টোটাল'],
#  ['rec_40_audio_1.wav', 'সেনাবাহিনী পর্যন্ত'],
#  ['rec_40_audio_15.wav', '<>'],
#  ['rec_40_audio_0.wav', '<>'],
#  ['rec_40_audio_2.wav', '<>'],
#  ['rec_40_audio_19.wav', '<>'],
#  ['rec_40_audio_20.wav', 'ব্যাংকের'],
#  ['rec_40_audio_16.wav', 'একদিন করবো আলোচনা করব'],
#  ['rec_40_audio_7.wav', 'তার মানে তুই কি বুঝিস না'],
#  ['rec_40_audio_9.wav', '<>'],
#  ['rec_40_audio_14.wav', '37 কোটি নতুন মুসলিম আছে হিন্দু রাষ্ট্র হয়েছিল'],
#  ['rec_40_audio_18.wav', '<>'],
#  ['rec_40_audio_17.wav', 'বানান করা শিখাতে শিখাতে হবে'],
#  ['rec_40_audio_11.wav', 'ভারতের'],
#  ['rec_40_audio_3.wav', '<>'],
#  ['rec_40_audio_4.wav', '<>'],
#  ['rec_40_audio_6.wav', 'বিয়া করার নাই'],
#  ['rec_40_audio_12.wav', 'ভারতের বাংলাদেশের'],
#  ['rec_40_audio_5.wav', 'জগন্নাথ হল দিনটা বেশি তারপরে'],
#  ['rec_40_audio_13.wav', '<>'],
#  ['rec_40_audio_29.wav', 'শুদ্ধ বাংলা'],
#  ['rec_40_audio_31.wav', 'ওখানে সমস্যা নাই'],
#  ['rec_40_small_audio_0.wav', '<>'],
#  ['rec_40_audio_24.wav', '<>'],
#  ['rec_40_audio_30.wav', 'এটা 33000'],
#  ['rec_40_audio_28.wav', 'এ বছরের রেজাল্ট'],
#  ['rec_40_audio_22.wav', 'হিসাব ফটো দেখান'],
#  ['rec_40_audio_27.wav', 'একটি বড় একটি বড় সমস্যা নাই'],
#  ['rec_40_audio_23.wav', '<>'],
#  ['rec_40_audio_25.wav', '<>'],
#  ['rec_40_audio_26.wav', '<>'],
#  ['rec_12_small_audio_2.wav', '<>'],
#  ['rec_12_audio_22.wav',
#   'আরার সময় বারা হাত লাগানোর পড়ালেখার পাশাপাশি তারা এই সমস্ত কাজে লাগানো যায় কি এই কবিতা চিত্রাংকন এর বাগান পরিচর্যা আরো অন্যান্য বহুত কাজ আছে'],
#  ['rec_12_audio_5.wav',
#   'কোন ধরনের কবিতা লিখ কবিতায় বিভিন্ন ধরনের মাতৃভাষা দিবস তারপরে বিভিন্ন প্রকৃতির সৌন্দর্য লইয়া রে পরিবেশ সুন্দর লাগে ছেলে সুন্দর ঘড়ি'],
#  ['rec_12_audio_8.wav',
#   'পরিবেশ সুন্দর তাহের আর গাছপালা সুন্দর করে রাইতের জন্য'],
#  ['rec_12_audio_14.wav', '10-12 লাইনের মতো 15 লাইনের মত করেছিলাম'],
#  ['rec_12_audio_21.wav',
#   'এই কবিতা তবে সুন্দর হয় আমার মতে এই লিখুন সুন্দর সুন্দর আরো কবিতা লিখো অবসর সময়ে নষ্ট করে মোবাইল টিভি কোরিয়ার অবসর সময়'],
#  ['rec_12_big_audio_3.wav',
#   'এই আরিয়া বিভিন্ন প্লাস্টিকের বোতল পড়িতে আলোর বোতল পানির বোতল ইঞ্জিনিয়ার গাছের'],
#  ['rec_12_audio_11.wav', '<>'],
#  ['rec_12_small_audio_1.wav',
#   'আঁকা শুরু করছি খুব ভালো তাহলে তুমি অবসর সময় চিত্রাংকন করো আর কবিতা লিখো'],
#  ['rec_12_audio_13.wav',
#   'দিয়ারা দিয়ারা বিষয় কি আছে কবিতার কবিতার বিষয় মাতৃভাষা বাংলাদেশ কবিতার নাম খুব ভালো লাগে'],
#  ['rec_12_audio_3.wav',
#   'তারপরে আবার বিভিন্ন কবিতা অবসর সময়ে খুব সুন্দর লাগে আচ্ছা তাহলে চিত্রাংকন কবিতা লিখুন'],
#  ['rec_12_audio_2.wav',
#   'বিভিন্ন সুন্দর সুন্দর চিত্র তৈরি বিভিন্ন কাগজ কাগজ দিয়ে জিনিস বানায় সুন্দর লাগে না'],
#  ['rec_12_audio_10.wav',
#   'তারপর বদলায় গাছের ছোট ছোট গাছের একদম দেখি সুন্দর লাগে কিন্তু দাম বেশি দাম এখন পড়া করব'],
#  ['rec_12_big_audio_1.wav',
#   'তাছাড়া আরো 51 নতুন বাড়ি করেছে এখন পরিষ্কার একদম সুন্দর লাগাইবো'],
#  ['rec_12_audio_16.wav',
#   'মাইক্রোন গড়িয়া রায়গঞ্জের তৃতীয় স্থান অধিকার করেছে বালা লাগে'],
#  ['rec_12_audio_7.wav',
#   'তোতা তোতা দিয়ে মত করে সুন্দর করে রাখো আর বেশি সুন্দর লাগে না সুন্দর লাগে'],
#  ['rec_12_small_audio_0.wav', '<>'],
#  ['rec_12_audio_20.wav', 'দিবার পরে আর খুব প্রশংসা করছি সুন্দর সুন্দর'],
#  ['rec_12_audio_12.wav', 'সাংস্কৃতিক প্রতিযোগিতা'],
#  ['rec_12_audio_0.wav',
#   'তুমি অবসর সময়ে কি করো আমি অবসর সময় বিভিন্ন কিছু করি যেমন চিত্র আঁকি তারপরে বিভিন্ন কারুশিল্প করি কাগজ কাগজ দিয়ে রে তারপরে'],
#  ['rec_12_audio_23.wav', 'তিন গরি গরি ওরে নিজের বালা মোবাইল টিভি চ্যানেল'],
#  ['rec_12_big_audio_2.wav',
#   'কাজ কি তুমি সরাসরি মেরে নাকি এখনো নিজে ডিজাইন পরিকল্পনা ছাড়া লইয়ারে যেমন গাঁদা ফুলের সুন্দর লাগে চরিত্র'],
#  ['rec_12_audio_6.wav',
#   'চাঁদপুর কি বিশেষ কোন কিছু দেখিয়া মনে হয় এনে নাকি কিভাবে মানে চিত্রাংকন তোমার একখান ভালো সব হইতে পারে মনে হয় এটা মোবাইলে'],
#  ['rec_12_audio_4.wav',
#   'তোর প্রিয় শখ জি খুব ভালো কোন ধরনের চিত্রাংকন পছন্দ করো তুমি আমি বিভিন্ন জল রং দিয়ে করে দেয় না'],
#  ['rec_12_audio_15.wav',
#   'এই তাই তারপরে যাচাই করছে আরা সাংস্কৃতিক প্রতিযোগিতায়'],
#  ['rec_12_audio_18.wav',
#   'আর বিভিন্ন সুতা তুতু কিনি আরে সুতা আছে ইন্ডিয়ারে সুন্দর করে'],
#  ['rec_12_audio_1.wav', 'চিত্র আঁকি চিত্রের মধ্যে অদ্ভুত কিছু দেখি মোবাইলে'],
#  ['rec_12_big_audio_0.wav',
#   'তুমি চিত্রাংকন করিবার পরে কি তুই ফেমাস বাধাই করো না নাকি রাহিদ হোসেনের'],
#  ['rec_12_audio_19.wav', 'আর আর স্কুলে তো ইয়া দিলাম কবিতা দিলাম'],
#  ['rec_12_audio_17.wav',
#   'ইঙ্গিত মনে হয় এত বেশি বেশি অবসরটা অবসর সময়ে আইন গড়িয়ে খুশি হয় বেশি এখন যেহেতু নতুন করে খোলা বাতাস আছে সুন্দর করে'],
#  ['rec_12_small_audio_3.wav',
#   'মনোরম পরিবেশে আনন্দ আরো কিছু মাথা থাকবে সুন্দর সুন্দর'],
#  ['rec_12_audio_9.wav',
#   'আইয়ারে ভূত গাছ দেখি সুন্দর সুন্দর একদম পাতাবাহারের মত সুন্দর সুন্দর দেখতে সুন্দর লাগে প্লাস্টিকের বোতলের সুন্দর লাগে কিন্তু এরা গাছের গোলাপ ফুলের গাছ দিয়ে কি গাধা ফুল'],
#  ['rec_12_audio_24.wav', 'এই বিভিন্ন অন্যান্য গড়িয়া রে অবশ্যই'],
#  ['rec_13_audio_12.wav', 'ঈদের আগের রাতে রুটি ফোড়া দিয়েছে'],
#  ['rec_13_audio_18.wav', 'সিলেট গ্রাম দত্তের সিরিয়াল'],
#  ['rec_13_audio_23.wav',
#   'সিলেটের বাংলা খুব সুন্দর লাগে এত খুব ভালো লাগে সারাদিন মোবাইল হারিয়ে গিয়েছে'],
#  ['rec_13_audio_22.wav',
#   'এটা আরও একটা খুব আরামে ঘুমিয়ে এটা খুব ফারারা আদর করছে সুন্দর ঘর আছে ঈদের সুন্দর'],
#  ['rec_13_audio_1.wav', 'আয়ের বড় সময় আর ঘরে থানায় সাজগোজ করেছিলাম'],
#  ['rec_13_audio_9.wav',
#   'আয় তবে সালাম এর বছর সালামি 99 পাইলাম বেশিরভাগ এ বছরেই পাইলাম না আত্মীয়-স্বজনের বাড়ি যাই আমার পেট ভরে যাবে নাস্তা'],
#  ['rec_13_audio_4.wav', 'পারদ উঠিলাম পারদ রিয়ারে বহুত মজা করছিলাম মজা করি'],
#  ['rec_13_audio_20.wav', 'সারাবাংলা গিলাম বাংলাদেশের'],
#  ['rec_13_audio_25.wav', 'বাংলাতে সিরিয়াল'],
#  ['rec_13_audio_10.wav', 'হ্যাঁ চালাও'],
#  ['rec_13_audio_14.wav', 'পরিষ্কার-পরিচ্ছন্ন করি না'],
#  ['rec_13_audio_17.wav',
#   'আব্বু ছাড়া করি ঈদের পরদিন বেড়াইতে যাই বিভিন্ন জায়গায় সিলেটে গেলাম'],
#  ['rec_13_audio_0.wav', 'এবার রিডার কি কি করলা কেন লাগলো খুব ভালো লাগে না'],
#  ['rec_13_audio_16.wav', 'নাস্তা বানায় চটপটি বিরানি নতুন কাপড়'],
#  ['rec_13_audio_27.wav', 'হাই ডলার বাংলাদেশি'],
#  ['rec_13_audio_11.wav', '<>'],
#  ['rec_13_audio_8.wav', 'মধ্যে বিরানি বেশি ভালো লাগে'],
#  ['rec_13_audio_6.wav',
#   'আবার আইসা করি নতুন কেনাকাটা করি তারপরে বহুত মজা করছিলাম'],
#  ['rec_13_audio_2.wav', 'আবার নানু আর কোন জায়গায় খালামণিরা রেখে গেলাম'],
#  ['rec_13_audio_3.wav', 'খুব মজা করছি'],
#  ['rec_13_audio_5.wav', 'রোজা রাখ'],
#  ['rec_13_audio_24.wav',
#   'ফারাক্কা বিষয়ের যে বসতে ড্রাইভারের নসি নিয়ে রাগারাগি নীল কই ম্যানেজারি দিয়ে তারপরে খুব চিন্তা ভাবছিলাম'],
#  ['rec_13_audio_19.wav', 'জাফলং দিলাম জাফলং জিরো মুভি'],
#  ['rec_13_audio_26.wav', 'আয় আবার আয়তে বছরে সুন্দর সুন্দর'],
#  ['rec_13_audio_7.wav', '<>'],
#  ['rec_13_audio_21.wav',
#   'গোশত হাই ডিম হাই তাহলে বোথ ফুল দিয়ে কি রেডিও খুব মজা করছি ছবি তুলি খুব মজাদার ছেলেটা খুব বড় ফুলের বাগান আছে'],
#  ['rec_13_audio_15.wav',
#   'বেশি আনন্দ করি না পারি আমার তো খুব খারাপ লাগে গতবছর বন্যার সাথে মজা করে না হারিয়ে হারাতে দুই বছর আরো মজা করি না পারি তবে বছরে'],
#  ['rec_13_audio_13.wav', '<>'],
#  ['rec_34_audio_5.wav', 'একখান তুমি একটা একটা খুঁজে পাই না আগে'],
#  ['rec_34_audio_6.wav', 'পিরিতি আপা তারপরে'],
#  ['rec_34_audio_2.wav', 'ফারদিন শায়লা আপু আই সাবাস পার্ক'],
#  ['rec_34_audio_10.wav', '<>'],
#  ['rec_34_audio_4.wav', 'আরে দাদু আছে দেখবেন'],
#  ['rec_34_audio_8.wav', '<>'],
#  ['rec_34_audio_7.wav', 'তোর নাম কি'],
#  ['rec_34_audio_3.wav', 'দাদুর দাদুর সাথে'],
#  ['rec_34_audio_0.wav', 'বাড়ির প্রাথমিক বিদ্যালয়'],
#  ['rec_34_audio_1.wav', '<>'],
#  ['rec_34_audio_9.wav', 'আরে কার্টুন সাইকেল'],
#  ['rec_35_audio_0.wav',
#   'ইকরা তুই কোনদিন শিশু পার্ক গেলে আচ্ছা তুমি শিশু পার্কে কি করছ তুমি কেমন লাগে'],
#  ['rec_35_audio_6.wav', 'আর হরে হরে'],
#  ['rec_35_audio_3.wav', 'সিরিটি উড়ে দে তারপরে করব'],
#  ['rec_35_audio_1.wav', 'বালা লাইকে কি কি করছো'],
#  ['rec_35_audio_5.wav', 'আচ্ছা ট্রেন'],
#  ['rec_35_audio_4.wav', 'তারপরে আর হনহন আছি আপু'],
#  ['rec_35_audio_2.wav', 'আর কি কি করছিস পর্বে'],
#  ['rec_36_audio_5.wav', '<>'],
#  ['rec_36_audio_8.wav', 'আম্মা সোনার বাংলায় বের হই তখন জাতীয় সংগীত'],
#  ['rec_36_audio_11.wav', '5% কয় তালা এক তালা আচ্ছা'],
#  ['rec_36_audio_4.wav', 'সেলাই তো স্যার কখন আমায়'],
#  ['rec_36_audio_1.wav', '<>'],
#  ['rec_36_audio_0.wav',
#   'তুই বলে নতুন স্কুলের ভর্তি হওয়া আচ্ছা এখন ক্লাসে পড়ো তোমার স্কুল কেমন লাগে'],
#  ['rec_36_audio_9.wav',
#   'নদী ওই এক নাম্বার ভিডিওটি কোরিয়ার ফুল ফুল লাইন গরি যাই দেখাও আর কিছু না'],
#  ['rec_36_audio_7.wav',
#   'হানাহানি রে গজল মিষ্টি তারপরে আচ্ছা এসেম্বলি তোরা কি কি করো'],
#  ['rec_36_audio_3.wav', 'তারপর আরে ম্যাডাম করে'],
#  ['rec_36_audio_2.wav', 'কি কি করস স্কলারি একটা মেয়ে আমার একটা আইবো'],
#  ['rec_36_audio_6.wav', 'ঘরে থাকলাম রিংটোন হিন্দি'],
#  ['rec_36_audio_10.wav',
#   'তোমার স্কুল দেখতে কুমিল্লা স্মরণে বড় বড় কি কি আছে তোমার শরীর আছে'],
#  ['rec_36_audio_12.wav',
#   'তোমার স্কুলের নাম কি এক নাম্বার পূর্ব পুকুরিয়া সরকার দিবা তুমি বিদ্যালয়'],
#  ['rec_37_audio_11.wav',
#   'মেয়ে মানুষ গোপী সুন্নত ফ্রী দিবো আস্তে আস্তে ফ্রী ফায়ার তামিল'],
#  ['rec_37_audio_12.wav',
#   'আরে নিজের জায়গায় তোমার সবচেয়ে পছন্দের খেলা অনলাইন'],
#  ['rec_37_audio_8.wav', 'বাজার করি খেলা হয় গোসল করিতে চাই দূরে'],
#  ['rec_37_audio_5.wav', 'কিভাবে খেলো পুলিশ খেলায় ইন হিন্দি'],
#  ['rec_37_audio_3.wav', 'বাঁচলাম খেলি তখন কুতকুত কে লিয়ে'],
#  ['rec_37_audio_10.wav', '<>'],
#  ['rec_37_audio_2.wav', 'কি কি খেলে হাসে তোমার বন্ধুর খোলার নাম হয় না'],
#  ['rec_37_audio_4.wav', 'পুলিশ খেলা খেলি তার ফটো নাচতেছে'],
#  ['rec_37_audio_0.wav',
#   'তুমি সারাদিন কি কি করো বাস করি না হায় আচ্ছা কি কি খেলো'],
#  ['rec_37_audio_6.wav', 'আচ্ছা তুমি কিভাবে খেলে একজন মানুষ কমে যাবে যদি মারি'],
#  ['rec_37_audio_7.wav', 'নামে তড়িৎ কাটিং খেলা সম্পর্কে আর কি কি খেলো তুমি'],
#  ['rec_37_audio_1.wav', 'শায়লা না থাকলে'],
#  ['rec_37_audio_9.wav', 'গরুর ডিজাইন'],
#  ['rec_41_audio_5.wav', 'আপটু এস কার্টুন বাংলা'],
#  ['rec_41_audio_3.wav', 'দরিয়ার স্যার কেমন লেগেছে'],
#  ['rec_41_audio_8.wav', '<>'],
#  ['rec_41_audio_7.wav',
#   'ঐশী টিভি সাইজ জিটিভি সাইজ তারপর বার্তা থেকে আবার আবার আবার ঠাস ঠাস করে নাস্তা খাই'],
#  ['rec_41_audio_9.wav', '<>'],
#  ['rec_41_audio_2.wav', '<>'],
#  ['rec_41_audio_1.wav',
#   'কি কি করছো কক্সবাজারে বসি তারপর ফুল গাছের ফুল দেখছি এখন'],
#  ['rec_41_audio_6.wav', 'তারপর দিয়া নিয়া রাব্বু তারপর আমি বলছি'],
#  ['rec_41_audio_0.wav', 'তোমার প্রিয় জায়গার নাম কি কক্সবাজারে'],
#  ['rec_41_audio_4.wav', 'মার্কেট মার্কেট'],
#  ['rec_41_small_audio_0.wav', 'ইতাক আমি যাব কার'],
#  ['rec_12_big_audio_4_chunk_0.wav', '<>'],
#  ['rec_12_big_audio_4_chunk_1.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 1774

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["Contents"] = content

# %%
df
# Out:
#                  External_ID  \
# 0     rec_20_big_audio_0.wav
# 1        rec_20_audio_48.wav
# 2        rec_20_audio_21.wav
# 3         rec_20_audio_0.wav
# 4        rec_20_audio_16.wav
# ...                      ...
# 1769     rec_19_audio_29.wav
# 1770    rec_19_audio_109.wav
# 1771     rec_19_audio_56.wav
# 1772     rec_20_audio_26.wav
# 1773     rec_20_audio_12.wav
#
#                                                Contents
# 0                      3:00 টা বাজে বাজে বাজে বাজে বাজে
# 1                                       কার্টুন কার্টুন
# 2                                  দুইবার ধরে খুঁজছিলাম
# 3     আরা আরা কোরআন শরীফ পড়তে বই তারপরে আম্মা আম্মু...
# 4       হারিয়ে যাওয়া হবে বলে আলোকের দূরে হারিয়ে যায়
# ...                                                 ...
# 1769                                    তো আইডির পিকচার
# 1770  ইউনিফর্ম তো আমি ব্যাক করে হোম দেয় না সাহায্য ...
# 1771  বাদ দে তুই এটা আমি তো ভুল গরম আমি তাড়াতাড়ি ব...
# 1772  অ্যাডিং দিল গোশত দিয়ে গরুর গোশত উজুরি মাছ দিয...
# 1773          ফজরের দাঁড়াইতে পারে কিন্তু কি জাতের ঘরের
#
# [1774 rows x 2 columns]

# %%
len(df)
# Out:
# 1774

# %%
df.to_excel("1.4: chittagong-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
