# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnunicodenormalizer
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22779 sha256=aea056073b1ab2754e284d66a23f311a51bc86fa18d7e5225a5a1bb8367018b9
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/e9/16732a619cbf5a63fdc9f6e2f9eb5fcf73fa023735237330e9
# Successfully built bnunicodenormalizer
# Installing collected packages: bnunicodenormalizer
# Successfully installed bnunicodenormalizer-0.1.6
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.0

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/Narsingdi/narsingdi_chunks/narsingdi_all/'

# %%
files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_07_audio_40.wav', 'rec_07_audio_65.wav', 'rec_07_audio_37.wav', 'rec_07_audio_49.wav', 'rec_07_audio_50.wav', 'rec_07_audio_54.wav', 'rec_07_audio_25.wav', 'rec_07_audio_48.wav', 'rec_07_audio_41.wav', 'rec_08_audio_3.wav', 'rec_08_audio_18.wav', 'rec_08_audio_17.wav', 'rec_08_audio_1.wav', 'rec_08_audio_4.wav', 'rec_08_audio_2.wav', 'rec_08_audio_21.wav', 'rec_08_audio_15.wav', 'rec_08_audio_19.wav', 'rec_08_audio_16.wav', 'rec_08_audio_20.wav', 'rec_08_audio_22.wav', 'rec_08_audio_12.wav', 'rec_08_audio_7.wav', 'rec_08_audio_13.wav', 'rec_08_audio_6.wav', 'rec_08_audio_5.wav', 'rec_08_audio_10.wav', 'rec_08_audio_14.wav', 'rec_08_audio_11.wav', 'rec_08_audio_8.wav', 'rec_08_audio_23.wav', 'rec_08_audio_0.wav', 'rec_08_audio_9.wav', 'rec_09_audio_59.wav', 'rec_09_audio_42.wav', 'rec_09_audio_20.wav', 'rec_09_audio_79.wav', 'rec_09_audio_23.wav', 'rec_09_audio_40.wav', 'rec_09_audio_83.wav', 'rec_09_audio_13.wav', 'rec_09_audio_44.wav', 'rec_09_audio_33.wav', 'rec_09_audio_73.wav', 'rec_09_audio_15.wav', 'rec_09_audio_16.wav', 'rec_09_audio_80.wav', 'rec_09_audio_72.wav', 'rec_09_audio_86.wav', 'rec_09_audio_41.wav', 'rec_09_audio_93.wav', 'rec_09_audio_62.wav', 'rec_09_audio_10.wav', 'rec_09_audio_9.wav', 'rec_09_audio_65.wav', 'rec_09_audio_88.wav', 'rec_09_audio_27.wav', 'rec_09_audio_34.wav', 'rec_09_audio_1.wav', 'rec_09_audio_74.wav', 'rec_09_audio_45.wav', 'rec_09_audio_70.wav', 'rec_09_audio_58.wav', 'rec_09_audio_7.wav', 'rec_09_audio_49.wav', 'rec_09_audio_91.wav', 'rec_09_audio_21.wav', 'rec_09_audio_51.wav', 'rec_09_audio_82.wav', 'rec_09_audio_68.wav', 'rec_09_audio_81.wav', 'rec_09_audio_53.wav', 'rec_09_audio_69.wav', 'rec_09_audio_5.wav', 'rec_09_audio_56.wav', 'rec_09_audio_3.wav', 'rec_09_audio_57.wav', 'rec_09_audio_84.wav', 'rec_09_audio_4.wav', 'rec_09_audio_63.wav', 'rec_09_audio_66.wav', 'rec_09_audio_48.wav', 'rec_09_audio_35.wav', 'rec_09_audio_95.wav', 'rec_09_audio_37.wav', 'rec_09_audio_75.wav', 'rec_09_audio_92.wav', 'rec_09_audio_55.wav', 'rec_09_audio_43.wav', 'rec_09_audio_52.wav', 'rec_09_audio_30.wav', 'rec_09_audio_85.wav', 'rec_09_audio_26.wav', 'rec_09_audio_0.wav', 'rec_09_audio_25.wav', 'rec_09_audio_87.wav', 'rec_09_audio_29.wav', 'rec_09_audio_38.wav', 'rec_09_audio_11.wav', 'rec_09_audio_77.wav', 'rec_09_audio_28.wav', 'rec_09_audio_17.wav', 'rec_09_audio_61.wav', 'rec_09_audio_60.wav', 'rec_09_audio_76.wav', 'rec_09_audio_39.wav', 'rec_09_audio_36.wav', 'rec_09_audio_8.wav', 'rec_09_audio_78.wav', 'rec_09_audio_50.wav', 'rec_09_audio_18.wav', 'rec_09_audio_12.wav', 'rec_09_audio_2.wav', 'rec_09_audio_71.wav', 'rec_09_audio_67.wav', 'rec_09_audio_6.wav', 'rec_09_audio_90.wav', 'rec_09_audio_64.wav', 'rec_09_audio_19.wav', 'rec_09_audio_31.wav', 'rec_09_audio_94.wav', 'rec_09_audio_47.wav', 'rec_09_audio_22.wav', 'rec_09_audio_89.wav', 'rec_09_audio_54.wav', 'rec_09_audio_14.wav', 'rec_09_audio_32.wav', 'rec_09_audio_46.wav', 'rec_09_audio_24.wav', 'rec_10_audio_13.wav', 'rec_10_audio_12.wav', 'rec_10_small_audio_0.wav', 'rec_10_audio_16.wav', 'rec_10_audio_1.wav', 'rec_10_audio_14.wav', 'rec_10_audio_20.wav', 'rec_10_audio_15.wav', 'rec_10_audio_18.wav', 'rec_10_audio_2.wav', 'rec_10_audio_8.wav', 'rec_10_audio_19.wav', 'rec_10_audio_7.wav', 'rec_10_audio_17.wav', 'rec_10_audio_5.wav', 'rec_10_audio_11.wav', 'rec_10_audio_3.wav', 'rec_10_audio_10.wav', 'rec_10_audio_9.wav', 'rec_10_audio_4.wav', 'rec_10_audio_0.wav', 'rec_10_audio_6.wav', 'rec_11_audio_20.wav', 'rec_11_audio_9.wav', 'rec_11_audio_47.wav', 'rec_11_audio_18.wav', 'rec_11_audio_1.wav', 'rec_11_audio_30.wav', 'rec_11_audio_52.wav', 'rec_11_audio_33.wav', 'rec_11_audio_22.wav', 'rec_11_audio_29.wav', 'rec_11_audio_3.wav', 'rec_11_audio_27.wav', 'rec_11_audio_2.wav', 'rec_11_audio_6.wav', 'rec_11_audio_32.wav', 'rec_11_audio_13.wav', 'rec_11_audio_54.wav', 'rec_11_audio_5.wav', 'rec_11_audio_4.wav', 'rec_11_audio_41.wav', 'rec_11_audio_16.wav', 'rec_11_audio_49.wav', 'rec_11_audio_50.wav', 'rec_11_audio_10.wav', 'rec_1 ...
#
# 1385

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_07_audio_40.wav', '<>'],
#  ['rec_07_audio_65.wav', 'ধন্যবাদ ধন্যবাদ'],
#  ['rec_07_audio_37.wav', 'কিগো রেকর্ডার দিয়ে অফিস কোন জায়গা নেই'],
#  ['rec_07_audio_49.wav',
#   'সালমান খানের গরম কারেন্ট নাই অনার্স ছাড়া যে পরীক্ষা ছিল কোন রুম খালি না লেভেল নাই যদি যাইয়া পড়াইতেছে পরে গেছি আমি কইয়া শাড়িটা কেমনে পড়াবেন'],
#  ['rec_07_audio_50.wav', '<>'],
#  ['rec_07_audio_54.wav',
#   'ইনশাআল্লাহ দোয়া করি আল্লাহ তোরে তোর মনের ইচ্ছা পূরণ করুক আমার আব্বাজান কষ্ট এক সপ্তাহ থেকে সাত দিনের মধ্যে দৌড় দিবি আমি কই দৌড় দিতাম না কষ্ট করে কষ্ট করে দেখছি না'],
#  ['rec_07_audio_25.wav', 'আমি এখন 10 টাকা খুঁজে পেয়েছি'],
#  ['rec_07_audio_48.wav',
#   'চান্দনা কেমন ভালো না আচ্ছা বিদায় অনুষ্ঠানে খুব দরকার কিনা জানিনা কিন্তু আমার মনে আমি কান্দুম আমার মায়া লাগে না'],
#  ['rec_07_audio_41.wav', '<>'],
#  ['rec_08_audio_3.wav', '<>'],
#  ['rec_08_audio_18.wav', '2 ঘন্টা সময় লাগে এখন বাড়ির কাছে বাজার মসজিদ'],
#  ['rec_08_audio_17.wav', 'বালুরঘাট'],
#  ['rec_08_audio_1.wav', 'কেরালার নুন ছাড়া অন্য কিছু কিনতেন না'],
#  ['rec_08_audio_4.wav', '<>'],
#  ['rec_08_audio_2.wav', '<>'],
#  ['rec_08_audio_21.wav', 'আসলে দুইটা মার্কেট হয়েছে নষ্ট করিস'],
#  ['rec_08_audio_15.wav',
#   'অনেক বড় লাইনে দেখতেছি আমি ঢাকার সময় অনেক বড় কি সুন্দর সুন্দর সব ধরনের সবজি উঠছে পরে আমরা আমরা এসব যে আমরা যে টাটকা টাটকা সবজি করো আমরা খুব উপকারিতা'],
#  ['rec_08_audio_19.wav',
#   'বাজারে আপনার সবাই যদি বদ রেস্টুরেন্টে সবার একটা আলোচনা করে বেশিরভাগ সময় কোন জিনিসটা নিয়ে আলোচনা করে এই আলোচনা হয়েছে'],
#  ['rec_08_audio_16.wav', 'আমরা বাজারটা কত আপনার কি মনে হয় সুবিধা অসুবিধা'],
#  ['rec_08_audio_20.wav', 'আসলে চাইলে আমরা বাঙালি'],
#  ['rec_08_audio_22.wav', 'স্মার্ট নষ্ট করেছে এটা সরকারের বন্ধ করে দিয়েছি'],
#  ['rec_08_audio_12.wav',
#   'ওপরে বাংলাদেশের বেশিরভাগ মানুষ হয়েছে কৃষি কাজ করে বাংলাদেশের'],
#  ['rec_08_audio_7.wav',
#   'এক বছরের এটা একটা গরু পালার মতো না আমরা যদি ক্ষেতের মধ্যে টাইলস'],
#  ['rec_08_audio_13.wav',
#   'তো আমরা যে নামধারি করি ও ভালো কথা ছোটবেলা দেখতাম যে আমরা বাজার থেকে সব বুঝাই করে খাঁচার মধ্যে বড় বড়'],
#  ['rec_08_audio_6.wav', 'লাগে লাগে লাগে লাগে'],
#  ['rec_08_audio_5.wav', '<>'],
#  ['rec_08_audio_10.wav',
#   'মাড়ি সারি কুবায়া এখন করা হয়েছে বালানা সুন্দর একটা বৃষ্টি হয়েছে'],
#  ['rec_08_audio_14.wav',
#   'বালিশের শিব পূজা নারায়ণপুর একটা সবজির মার্কেট দেখেছি'],
#  ['rec_08_audio_11.wav', 'বৃষ্টির পরে'],
#  ['rec_08_audio_8.wav', '2018'],
#  ['rec_08_audio_23.wav',
#   'আচ্ছা তো আমরা বাজার কৃষিকাজ সফটওয়্যার নতুন করে আরেকটা দেখি আমরা পরের কি কথা কইতা'],
#  ['rec_08_audio_0.wav', 'আমরা'],
#  ['rec_08_audio_9.wav',
#   'কল্লা লাগা জালি লাগা একটা চালের মধ্যে একটা পথ করি না'],
#  ['rec_09_audio_59.wav',
#   'সবাই অনেক খুশিতে আমার ছোট বোনের নিচে আমার আব্বারে আম্মারে আমার বড় বোনের বড় বোনের ছেলেরে আমার ভাই রিফাত রে সবাইরে তুমি যেমন সবারে দাও আর আমি আসলে সবারটা নেই'],
#  ['rec_09_audio_42.wav',
#   'এই আরকি নরসিংদীর মধ্যে মনে করো মানুষের কর্মসংস্থান ও আছে কাদের মোল্লার মিল আছে গার্মেন্টস এর মধ্যে মানুষ কাজ করে জীবিকা অর্জন করতে পারে মানুষ আমাদের দেশের যে অর্থনীতি টা আমাদের সবচাইতে বেশি ইয়া করে'],
#  ['rec_09_audio_20.wav',
#   'নামটা সঠিক মনে নাই ফারহান রে বেশি ভালো লাগে লাগে তুমি কি একটা জিনিস ভাবে দেখছো তোমার বিরহের গান শুনতে ভালো লাগে ফারহানের যত নাটক সব ছ্যাকা খাওয়ার বুঝছো অনেক তোমার'],
#  ['rec_09_audio_79.wav',
#   'শালা তোরে অনেক মজা হইছে তুমি আমার লক্ষী মেয়েরা নষ্ট করছে কিন্তু পোলাও চাল টা শক্ত শক্ত'],
#  ['rec_09_audio_23.wav',
#   'আমার লাইফে কোন সিক্রেট নাই গুজব নাই সব সবাই জানে এবার আমরা একটু বিনোদনের তে যদি একটু পানি পড়ে যাই আমরা তোমার পড়ালেখার মধ্যে যদি একটু'],
#  ['rec_09_audio_40.wav',
#   'ব্রাহ্মণ দিয়ে একটা এরিয়া মনে করো যে এই একটা ফ্ল্যাট পাইলো ওইটার মধ্যে একটা কলেজ মানে কলেজের একটা হার্ট ব্রা মন্দির মধ্যে রহমান'],
#  ['rec_09_audio_83.wav',
#   'দোস্তরা একটু নরম করলাম মনে করো নরম করার পর চালটা ধুইয়া এক কেজি চালের বিরিয়ানি করছিলাম এক কেজি গরুর মাংস দিয়ে পানি দিলাম কিন্তু সবচেয়ে বড় সমস্যাটা কি করছি জানো পানি দিছি ঠান্ডা পানি'],
#  ['rec_09_audio_13.wav',
#   'আমার আমার আব্বা আবার উপরে লাগাইছে যদি আমরা যাই তোমার উপরে কোন বিষয়ে যেতাম পারি'],
#  ['rec_09_audio_44.wav',
#   'গ্রামের মহিলারা তাঁত করে অনেক টাকা রোজগার করা প্রতিদিন স্বাবলম্বী হয় নিজের খরচ নিজে কর্তারে ছেলেমেয়েরা পড়াশোনার খরচ দিতে পারে আমাদের এদিকটা গ্রাম হওয়ার কারণে আমরা কিন্তু ওই যে কি বলে হাঁস-মুরগি গরু-ছাগল ভিডিও খুব ভালো করে'],
#  ['rec_09_audio_33.wav',
#   'সবই আছে আমরা আমরা সবচাইতে বড় যে আমরা গ্রামের মধ্যে এটা মনে হয় আমার মনে হয় যে বাজারটা আর আমরা সবজি সফটওয়্যার আমরা প্রতিদিন করার কারণে আর বেশি একটা'],
#  ['rec_09_audio_73.wav',
#   'এই সব কিছু ঝাজরা করে ফেলব একদম মাথায় ঢুকিয়ে ফেলবা যদি কইতাম স্যার এটা তো অনেক বুদ্ধিমান বুঝতে পারছি এটা যে অনেক বড় তুমি একটু উঁচু হয় আমার সাথে তোমার মাথার উপর দিয়ে যাবে না মাথার ভিতর দিয়া যাবে'],
#  ['rec_09_audio_15.wav',
#   'মনির খানের মনির খানের গান আগে শুনতাম যে সময় ছোট ছিলাম তখন থেকে শুনতাম মনির খানের গান শুনবো এখন আবার নিলয়ের গান শুনি নিলয় একটা মারা গেছে যে মারা গেছে যে'],
#  ['rec_09_audio_16.wav',
#   'খুব সুন্দর সুন্দর গান করে কোন কষ্ট নাই কিন্তু কষ্টের গান আমি শুনতে পছন্দ করি না সিরিয়াল দাও নাকি'],
#  ['rec_09_audio_80.wav',
#   'তোমার তোমার হোরে না আমার কি লাগে তোমার বিয়াই লাগে আরে তুমি আমার দাওয়াত দিতে আমি একটু হেল্প করতাম'],
#  ['rec_09_audio_72.wav', 'আঞ্চলিক ভাষায় কথা কইছি রায়পুরা কলেজ না খালি কই'],
#  ['rec_09_audio_86.wav',
#   'না তোমার এখন দিতাম না তোমার আংকেল তুমি বাড়িতে থাকবা না দিলে মনে করো না আমার একটা ভালো একটা নাম দিয়েছে কি জানো'],
#  ['rec_09_audio_41.wav',
#   'বিজ্ঞান অনেক ঘটে আর সবচেয়ে বড় কথা হয়েছে আমাদের নরসিংদীর মধ্যে যেটা সবচেয়ে মানে জানাশোনার মধ্যে এসেছে কাদির মোল্লা সিটি কলেজ এখানে খুব ভালো রেজাল্ট বাংলাদেশের দ্বিতীয় তৃতীয় টাইপ এরকম টাইপ হয় পড়াশোনার মান ও'],
#  ['rec_09_audio_93.wav', 'অনেক বিনোদন যেকোনো জায়গায় 4 মিনিট কের'],
#  ['rec_09_audio_62.wav', 'মজা লাগছে'],
#  ['rec_09_audio_10.wav',
#   'বাগনানের ফেসবুক চালাচ্ছেন পলাশতলী না ভালই লাগে কিন্তু পলাশতলী কিছু কিছু মানুষ ভালো লাগে না'],
#  ['rec_09_audio_9.wav', 'আমি কইলাম আমারে খালা বিচার'],
#  ['rec_09_audio_65.wav',
#   'আচ্ছা এবার যদি আমরা একটুখানি এবার আমরা কিভাবে কথা কইতাম আরে কয়েকদিন আগে বিশ্বকাপ গেল যদিও অনেকদিন হয়ে গেছে তোমার অনেক মজার একটা কাহিনী সম্পর্কে একটু কই'],
#  ['rec_09_audio_88.wav', '<>'],
#  ['rec_09_audio_27.wav',
#   'আচ্ছা এরপর আমরা যদি তোমার পরিবারটা সম্পর্কে যদি একটু জানতাম চাই তুমি তোমার অবস্থানরত পরিবার বা তোমার মর্যাদা পরিবর্তন আমার নানি বাড়ি তোমরা সবাই জানো এখানে আমার একটা মামা আছে আমার নানা আছে'],
#  ['rec_09_audio_34.wav',
#   'আর নতুন নতুন সবজি পাই খুব সুন্দর আমরা এলাকার সবজি আগুন লাগে না কারণ আমরা এলাকার মানুষই অনেক ক্ষেতের মধ্যে পোল্ট্রি ফার্ম অনেক বেশি বেশি'],
#  ['rec_09_audio_1.wav',
#   'আমি পড়াশোনা করি রায়পুরা সরকারি কলেজে রায়পুরা রায়পুরা রায়পুরা সরকারি কলেজ অনার্স থার্ড ইয়ারে ভর্তি হইছি সমাজকর্ম ডিপার্টমেন্ট তুমি জানো আমি নাকি'],
#  ['rec_09_audio_74.wav',
#   'স্যারের কাছ থেকে এটা আবিষ্কার করেছিলাম যে আসলে আমরা হেরে আমি এটা আমার ফ্রেন্ড বলে আমি নাকি আঞ্চলিক ভাষা আর আমার'],
#  ['rec_09_audio_45.wav',
#   'আচ্ছা তোমার একটা প্রশ্ন করি তোমার কি আঞ্চলিক ভাষায় কোনো দ্বিধা দ্বন্দ্ব কাজ করে না কখনোই না আমি যে পড়াশোনা করছি ভালো ভালো স্টুডেন্টদের সাথে উন্নত মানের স্টুডেন্টদের সাথে অন্যান্য জেলা স্টুডেন্টরা আমাদের আমি যেন নরসিংদীতে পড়ছিলাম'],
#  ['rec_09_audio_70.wav',
#   'সবচেয়ে মজার বিষয় কি জানো আমরা নরসিংদীর আঞ্চলিক ভাষায়'],
#  ['rec_09_audio_58.wav',
#   'অনেক কষ্টে একটা এরকম হাসবেন্ড যদি পাওয়া যেত খালা কি যে কও তুমি তো আবার সবার নতুন জামা কাপড় এনে দাও'],
#  ['rec_09_audio_7.wav', 'আমার মামাই বিদেশ থাকতো ডুবাই তখন তুইলা পাঠাইছে'],
#  ['rec_09_audio_49.wav',
#   'আচ্ছা এবার আমরা যদি আমরা জেলাতে আমরা জেলার মধ্যে কি জানো কমিউনিটি ক্লিনিক আছে প্রচুর প্রচুর হ্যাঁ আমাদের আমরা যে গ্রামে থাকি রায়পুরা থানার মধ্যে মনে করে পলাশতলী ইউনিয়ন রাজি থাকি আমরা'],
#  ['rec_09_audio_91.wav',
#   'আমারে কইতাছেন তোমারও অসম্পূর্ণ কাজটা আমি সম্পূর্ণ করে দেবেন'],
#  ['rec_09_audio_21.wav',
#   'আঙ্কেলের চুদাচুদি তুমি এরকম করো সরি আমি জানি অনেকেই খালু কমু ঠিক আছে আঙ্কেল মাত্র এক বছর হয় নাই আমার জীবনে আই'],
#  ['rec_09_audio_51.wav',
#   'ও ভুলে গেছি ভুলে গেছিলাম না মনো আছি এলাকার গরিব যে মানুষগুলো আছে এরারে ওষুধ দেয় ওষুধ বিতরণ করি আমার মনে হয় শেখ হাসিনার অনেকগুলো ভালো যোগের মধ্যে রাস্তা বড়'],
#  ['rec_09_audio_82.wav',
#   'মাটির চুলার মধ্যে রান্না করছি রানছি মনে করো প্রথমে একটা পাতিল ঘুমাইলাম মধ্যে তেল পিয়াজ বাটা এই আর কি রসুন বাটা আদা বাটা এগুলা দিয়া যে গরুর গোস্ত আছে এটা দিয়ে আমারে ভালো করে একটু কষাইয়া'],
#  ['rec_09_audio_68.wav',
#   'পুনায় ও মিশ্র মানে উনি আর্জেন্টিনা করে পাশ করার পরে আমরা দুজন রেস্টুরেন্টে খাওয়াইছে বিরিয়ানি খেয়েছি'],
#  ['rec_09_audio_81.wav',
#   'অবশ্যই এটা তুমি তোমার পরিবার টানতে আনতে যদি হট ফটো রক্ত গরমে একটু রেসিপি টা জানিয়েছেন'],
#  ['rec_09_audio_53.wav',
#   'এগুলা গর্ভকালীন অবস্থায় খাওয়া খুবই ভালো এগুলো আমরা ফ্রিতে হারারে দিয়ে টাকা পয়সা লাগে না বাংলাদেশ সরকার এটা খুব ভালো করছে না মনে হয়েছে আসলে আমরা কিছু শব্দ আর ভালো না কিছু খারাপ দিক অবশ্যই থাকে'],
#  ['rec_09_audio_69.wav', 'নরসিংদীর আঞ্চলিক ভাষা'],
#  ['rec_09_audio_5.wav',
#   'পলাশতলী থেকে আমার নানির বাড়ি থেকে বড় হওয়া মানে আমার শৈশব সবকিছু পলাশদের সরকারি স্কুলে যাওয়ার রাস্তা দেখান নতুন নতুন রং করছেন টিফিনের'],
#  ['rec_09_audio_56.wav',
#   'তোমার তো খুব মজার কারে ঈদের সালামি টা বলো তুমি খালা আমারে একবারও সালাম দিছো কেন ঈদের দিন তুমি ব্যস্ত থাকো নিজের হাতে রান্নাবান্না করো'],
#  ['rec_09_audio_3.wav',
#   'হ্যাঁ অবশ্যই ভালো লাগবে একটু শুনিয়েছেন আমার নানির বাড়ি থেকে রয়েছি'],
#  ['rec_09_audio_57.wav',
#   'আরে আমার ভাইয়ের দূরে কাজ করে মামা এবার আমারে 200 টাকা সালামি দিছে আমার নানাই 200 টাকা দিচ্ছে আমার হাজব্যান্ড আমার 10000 টাকা সালামি দিছে'],
#  ['rec_09_audio_84.wav',
#   'গরম পানি দিলাম বলে ভুল হয়ে গেছে গরম পানি কইরা রাখছিলাম কিন্তু মনে নাই এজন্য বিরানি যে চাইলে কিন্তু খুব মজা হয়েছে সবাই প্রশংসা করছে সাথে সালাত কাইটা দিছিলাম শসা টমেটো লেবু আমার চর্ম'],
#  ['rec_09_audio_4.wav',
#   'নানি বাড়ির প্রাইমারি স্কুলের পড়া তারপর সিরাজনগর স্কুলেতে ইন্টার এসএসসি পাস করছি নরসিংদী স্কলাস্টিকা মডেল কলেজ থেকে আইএ পাস করলাম এখন রায়পুরা সরকারি কলেজে অনার্স পড়তেছি'],
#  ['rec_09_audio_63.wav', 'পুতুল কিনতাম তুলি কিনতাম একটা মাটির ব্যাংক কিনতাম'],
#  ['rec_09_audio_66.wav',
#   'চুরানি বিশ্বকাপ মনে করো যে আমি যখন থেকে খেলা বুঝি তখন থেকে আমি আর্জেন্টিনারের সাপোর্ট করে খেলা মেসির লেগে মেসিরে ভাল্লাগে মেসির চেয়ে বেশি ভালো লাগে আমার কাছে ব্রাজিলের নেইমারের নেইমারের হাসি দেখলে আমাকে খুব ভালো লাগে'],
#  ['rec_09_audio_48.wav',
#   'অনেক বাচ্চাকাচ্চার মধ্যে একটুখানি বদলাতে কারণে মনে করো যে কিন্টারগার্ডেন স্কুল সময়ের সাথে সাথে'],
#  ['rec_09_audio_35.wav',
#   'বাইরে থেকে আসা লাগে না আমরা ন্যায্য দামি পাই আরকি আলহামদুলিল্লাহ মাশাল্লাহ অনেক কিউট আর বালা আছে আমাদের গ্রামটা খুব ভালো আছে আচ্ছা আমরা যদি গ্রামের থেকে একটুখানি বাইরে যেতাম পারি আমরা একটু জেলাটা সম্পর্কে যদি জানি তুমি তো নরসিংদী প্রতিনিয়ত করছে যে সিটি'],
#  ['rec_09_audio_95.wav',
#   'আমি যদি আমি ভয়েসটা সেন্ড করুম তারপর যদি কাজে লাগে আমরা খুব ভালো লাগলো না ভালো লাগবে করি এবার আমরা আল্লাহ হাফেজ টা'],
#  ['rec_09_audio_37.wav',
#   'এটার অবস্থা খুবই শোচনীয় খালা একটা গান আছে না বন্ধু আরে না স্টেশনে রেল গাড়িটা মাইপা চলে ঘড়ির কাটা স্টেশনে বইসা ভাবি কখন বাজে বারোটা রায়পুর থেকে'],
#  ['rec_09_audio_75.wav',
#   'আচ্ছা এরপরে এরপর আমরা আচ্ছা তোমার সবটা সম্পর্কে একটু জানি আমার শব্দ কইলামই যে আমি পড়াশোনা করে একজন বড় একজন বড় না হতে পারি যেরকমই হোক একটা সমাজ সেবক অফিসারের পদে একটা চাকরি করতে চাই যাতে আমি এলাকার মানুষের গরিবরা আর কিছু সাহায্য করতে পারি যেহেতু আমি একটা গরিব পরিবারের থেকে বড়'],
#  ['rec_09_audio_92.wav',
#   'আচ্ছা আমরা কি বাংলা সিনেমা কোন আরে একটা ঘটক নাটক আছে দেখুন আফরান নিশো আর তানজিন তিশার মনা ঘটক কি জানি আচ্ছা এবার আমরা'],
#  ['rec_09_audio_55.wav',
#   'অস্থিতিশীল পরিবেশ টা মানে ওই হরতাল টাইপ এগুলা না হইলেই আমরা মনে হয় ভালো আচ্ছা এরপর আমরা যদি যাই এবার আমরা কিভাবে কথা কইতাম পারি সম্পর্কে'],
#  ['rec_09_audio_43.wav',
#   'কন্ট্রিবিউট করা হয়েছে পোশাক শিল্প আর এই পোশাক শিল্পের ম্যাক্সিমাম অনেক কিছু আমরা নরসিংদী আছে আমাদের নরসিংদী তো এখন অনেক তাত আছে তাঁত শিল্প আছে'],
#  ['rec_09_audio_52.wav',
#   'অনেকটা ভালো একটা উদ্যোগ ওই যে মৃত্যু হার কমছে শিশু ও মৃত্যু কমছে অনেক কিছু মনে করো না কিন্তু কমিউনিটি ক্লিনিক টা বাড়ির কাছে বেধে গেলে আমরা চেকআপ করতাছি বিভিন্ন ধরনের আয়রন ক্যালসিয়াম যে ওষুধগুলো আছে'],
#  ['rec_09_audio_30.wav',
#   'এগুলা পারলে আমার আম্মায় তোমার আব্বা কিন্তু অনেক মজার মানুষ আছে এটা জানো এখনো আছে অনেক অনেক সুন্দর করে কথা কও মানুষের অনেক সুন্দর হাসায় মন ভালো করার মত একজন মানুষ আচ্ছা এর পরে আমরা যদি আমরা একটু পরিবারের একটু বড় হয়ে যদি আমরা নিজের এলাকাটা'],
#  ['rec_09_audio_85.wav',
#   'তুমি আমাকে রান্না করে তোমারে খাওয়াবো একসাথে আইতে না জানি'],
#  ['rec_09_audio_26.wav',
#   'এটাই আমার স্বপ্ন আমার সাথে কথা কইতে কেমনে তোমার বোরিং লাগতেছে যে আমি একটা একটা প্রশ্ন করতেছি না আমার বোরিং লাগতেছে না আমার ভালো লাগতাছে আর আমি আমার মানে অনেক দিনের জমানো কথাগুলো কইতাছি খুব ভালো লাগতাছে আমারে একটা ধন্যবাদ দিতে পারো অবশ্যই অনেক অনেক ধন্যবাদ'],
#  ['rec_09_audio_0.wav',
#   'খেলা ভালো আছো নাকি তুমি ভালো আছো নি ভালো আছি তোমার নামটা কইবা নাকি একটু গন্ধ যা আমার নাম রুনা তা তুমি অনেক কি করতাছো'],
#  ['rec_09_audio_25.wav',
#   'আমার উপজেলা সমাজ সেবক অফিসার হওয়ার খুব ইচ্ছা আমার বাদ বাকিটা আল্লাহ জানে না যাতে আমি ভালো একটা সমাজসেবক একটা লাইনে ভালো করে মানে ঢুকতে পারি ভালো এলাকার মানুষের উন্নয়ন করতে পারি'],
#  ['rec_09_audio_87.wav', 'সাথী ছাড়া ঘটনা আমারে দাও'],
#  ['rec_09_audio_29.wav',
#   'আমার বড় বোনের বিয়ে দিয়ে দিচ্ছে রায়পুরা থানার মধ্যে ইউনিয়নে বিয়ে দিচ্ছে আর আমি পড়াশোনা করতেছি আমার ছোটবোন ড্রাইভার ক্লাস টেনে পড়ে আর অবস্থানগত দিক দিয়ে যদি বল আমার আব্বায় কৃষি কাজ করে এই আরকি বাড়িতে গরুর খামার আছে গরু হাঁস-মুরগি'],
#  ['rec_09_audio_38.wav',
#   'সময়ের মধ্যে যাইতে পারে আমাদের টাকাও কম লাগে আমরা সিএনজি দিয়ে গেলে আমাদের আসা যাওয়া 100 150 টাকা গাড়ি বাড়ায়ে যা তো একটা ছাত্রী পক্ষে 100 টাকা 150 টাকা গাড়ি ভাড়া যাওয়া খুব কষ্ট এখন রেল গাড়িতে গেলে আমরা গাড়ি ভাড়া লাগে না'],
#  ['rec_09_audio_11.wav',
#   'কতজনে কিন্তু আমরা রায়পুরা থানার মধ্যে আমাদের পলাশতলী গ্রামটা খুবই সুন্দর খুবই ভালো সব দিক দিয়ে মানে সুবিধা জনক আর কি মনে করে স্কুল কাছে আমাদের হাট-বাজার করার লেগে বাজার কাছে'],
#  ['rec_09_audio_77.wav',
#   'আচ্ছা আমরা যদি তোমার প্রিয় খাবার টা সম্পর্কে জানতে চাই আমার সবচেয়ে প্রিয় খাবার হয়েছে বিরানি যে ধরনেরই হোক কাচ্চি বলো চিকেন বিরানি'],
#  ['rec_09_audio_28.wav',
#   'নানি আছে আমার তিনটা মামাতো বোন আছে একটা ভাই আছে এটা হচ্ছে আমার নানির বাড়ির পরিবার যেখানে আমি ছোটবেলা থেকেই পর্যন্ত বড় হয়েছি আর বাকিটা হচ্ছে মরজাল যেটা আমার নিজের বাড়ি ওইখানে আমরা চারটা বোন'],
#  ['rec_09_audio_17.wav',
#   'ইন্ডিয়ান নাটক স্টার জলসা দেখিনি জি বাংলা দেখি ইন্টার টেন বাংলা দেখি ইন্টারনেট দেখাও'],
#  ['rec_09_audio_61.wav',
#   'কিন্তু কত হয়েছে এ 7000 টাকা না খালা ঈদের পরের দিন আইতে আইতে আমি আর একটাও খুঁজে পাইনা যা আমার দশ হাজার টাকা দিছে দুইদিন আগে সালামের কারণে'],
#  ['rec_09_audio_60.wav',
#   'আমার ইজ্জত সম্পর্কে যদি কই তাহলে আমার এটা কিন্তু মাশাল্লাহ অনেক ভাল লাগে আমার কিন্তু অনেক টেস্ট আর আমি ওটা ওই 10000 টাকা দেওয়ার মানুষ নিজেকে কিছু আমার বাড়িতে আবার আমার দুইটা পরিবারের মানুষজন টিয়া দে খালা ঈদের দিনটা'],
#  ['rec_09_audio_76.wav',
#   'যেন আমি চাই যাতে গরিবরা মানে পিছনে মানে কি কইতাম মিসকিন জঙ্গল'],
#  ['rec_09_audio_39.wav',
#   'মানে কম সময়ের মধ্যে যাইতাম পারি খুব অল্প সময়ে জানতে চাও তাহলে আমি যদি আমার যতটুকু ধারনা যে অন্যান্য জ্বালাচ্ছে সবচেয়ে বেশি কলেজ হয়েছে আমাদের নরসিংদী জেলা নরসিংদী জেলা'],
#  ['rec_09_audio_36.wav',
#   'এর মধ্যে আমার খুব কম বাড়িতে বাইরে হতো তুমি যদি একটু কইতা কি এ সম্পর্কে আমার বেশি একটা ধারণা নাই নরসিংদী জেলা টা দেখতে খুবই সুন্দর কিন্তু মানে কি কইতাম নরসিংদী জেলার মধ্যে যে আমাদের যে নরসিংদী রেল স্টেশন'],
#  ['rec_09_audio_8.wav', 'ও সবাই মিল নাই'],
#  ['rec_09_audio_78.wav',
#   'বাজে কোন বিরিয়ানি গরুর মাংসের খুব গরুর কলিজার কও মুরগির কম দেশি মুরগি বয়লার মুরগি বিরানি হইলেই হয় খালা এবার আমি তাহলে তোমার কাছে শুরু করে বিরানি রেসিপি টা একটু তুমি রানতে পারো নাকি বিরিয়ানি রান্না করছি'],
#  ['rec_09_audio_50.wav',
#   'আমরা ইউনিয়নের ক্লিনিক আসছে হসপিটালে উপজেলা স্বাস্থ্য কমপ্লেক্স আমরা বাড়ির কাছেই আমরা এটা কিন্তু ও কয়েকদিন আগে এমএসবি নিয়োগ দিল'],
#  ['rec_09_audio_18.wav',
#   'একটু আগেও দেখাইলাম আই লাভ ইউ ভাইয়া দেখাইলাম খুব সুন্দর একটা নাটক দেখাও আঞ্চলিক ভাষা দিয়ে সুন্দর একটা নাটক দুইটা ভাই বোনের মধ্যে কি রকম সম্পর্ক'],
#  ['rec_09_audio_12.wav',
#   'প্রতিদিনের সবজি আমরা প্রতিদিন আনবেন না খাই তারই ফ্রিজ নতুন লাগে না'],
#  ['rec_09_audio_2.wav',
#   'এটা আমার একটা সিনারি দিছে আমার ইউনিভার্সিটি বড় ভাই দিয়েছে নরসিংদী যে আঞ্চলিক ভাষা নরসিংদীর আঞ্চলিক ভাষায় একটু রেকর্ড করে দেওয়া লাগে আর কি যে কোন একটা সফটওয়্যার তৈরি করবে তোমার অনুমতি আছে না আছে ভালো লাগবে ওটা যদি দেশের উপকারিতা'],
#  ['rec_09_audio_71.wav', 'ডিমের কি খবর সরিষার তেলের বালা তেল কও রাত্রে'],
#  ['rec_09_audio_67.wav',
#   'আমার মোবাইলে মনে করো আমি নেইমারের ছবি রাখছি নেইমারের হাসির বিভিন্ন ভিডিওতে আমি দেখি মানে খেলার দিক দিয়ে আমার আর্জেন্টিনা ভালো লাগে আমার দল পাস করার পরে মনে কর আমার একটা বান্ধবী আছে সালমা উনার স্বামী যে থাকে'],
#  ['rec_09_audio_6.wav', 'সারা তোমার একটা ছবি আছে আমার কাছে'],
#  ['rec_09_audio_90.wav', 'করবে স্যার আমি তো জানিনা জীবনের শেষ গান'],
#  ['rec_09_audio_64.wav',
#   'ওনে তো মনে করো বড় হয়ে গেছে গাড়িদের মেলার মধ্যে যাওয়া না ছোটবেলার তুমি কিন্তু সিরিয়াল ধইরা'],
#  ['rec_09_audio_19.wav',
#   'এক হালা কি মাটি মারে কয়েকদিন আগে দেখছি রিলিজ হওয়ার পরে তোমার নাটকের মধ্যে সবচেয়ে বেশি খেলা কারে ভালো লাগে আমার নাটকের মধ্যে সবচেয়ে বেশি ভালো লাগে হচ্ছে'],
#  ['rec_09_audio_31.wav',
#   'এলাকার আমরা এই এলাকার উন্নয়ন ডালে তোমার সবার আগে কি মনে হয় যে করলে ভালো হইবো আমরা এলাকার উন্নয়নের যদি করতে চাও তাহলে আমাদের এলাকায় সব ধরনের উন্নয়নী আছে আমাদের এলাকায় রাস্তাঘাট টাও ভালো আছে করা দরকার'],
#  ['rec_09_audio_94.wav',
#   'আমি চার ঘন্টা কথা কইতাম আমার নরসিংদী আঞ্চলিক ভাষায় কথা কইতে আমার তো ভালো লাগে সব সময় তার এই সুযোগটা পাই না খুব ভালো লাগছে'],
#  ['rec_09_audio_47.wav',
#   'কেন পড়াশোনা করে যতই বড় হই ভবিষ্যতে বড় চাকরি করি কিন্তু নিজের যে আঞ্চলিক যে একটা ভাষা নিজের একটা সংস্কৃতি এটা যেমন রক্তে মিশে আছে বিরক্ত হইলে মানুষ মনে করো যে সবকিছু বিলুপ্ত হয়ে যাবে কিন্তু আমাদের আঞ্চলিক ভাষা'],
#  ['rec_09_audio_22.wav', 'মনটা একটু চেঞ্জ হইছে না'],
#  ['rec_09_audio_89.wav',
#   'বিবাহিত পুরুষের মতো আর একটা গল্প কইছে একটা বিয়া আরকি একটা ছেলে মেয়েরা কেরে বিয়ের দিন কান্দে ছেলেরা করে আসে'],
#  ['rec_09_audio_54.wav',
#   'ভালো খারাপ মিলিয়েই মনে করো মনে হয় যে হ্যাঁ আমার দেশের যারা ক্ষমতা নাই তারা তো কিছু পাইতাছে এটা ভাবলে মনে হয়েছে সরকার এখন ঠিক আছে আচ্ছা যাই হোক আমরা একজন সরকার প্রধান দেশের জনগণের কথা হবে তখন ওই দেশটার খুব সুন্দর আর স্থ'],
#  ['rec_09_audio_14.wav',
#   'তোমার বিনোদনের মাধ্যমটা সবচেয়ে আমি মনে হয় সবচেয়ে বড় বিনোদনের মাধ্যমে সবাই আছে আমাদের বাড়ি আশপাশের সবার সাথে চলত ভালো লাগে বিনোদন লাগে কিন্তু আমার কাছে সবচেয়ে বেশি ভালো লাগে কি জানো বিরহের গান শুনতে'],
#  ['rec_09_audio_32.wav',
#   'এই রাস্তাটার মানে করলে ভালো হয় আমরা কলেজে যাইতে অনেক ধরনের সমস্যা হয় গাড়ি চলতে বেশি একটা গাড়ি ও চলতেছে না যে ঠিক হয় তাহলে আমাদের এলাকার আর বেশি উন্নয়নের দরকার নেই এখন আমাদের স্কুল কলেজ প্রাইমারি স্কুল কিনটা ঘাট'],
#  ['rec_09_audio_46.wav',
#   'মনে কর নোয়াখালীতে আইছে চিটাগং এর আসিন তারপর কুমিল্লার অনেকগুলো দূরদূরান্ত থেকে মনে করে আমার আঞ্চলিক ভাষায় কথা বলেন আমার কাছে খুব ভালো লাগে কারণ এটা আমার ঐতিহ্য আমার ভাষাটা যখন আমার রক্তে মিশে আছে মনের শান্তি লাগে'],
#  ['rec_09_audio_24.wav',
#   'তোমার ফিউচার সরি ভবিষ্যৎ পরিকল্পনা আমার ভবিষ্যৎ পরিকল্পনা যদি জানতে চাও তাহলে আমার সমাজের মানুষের সেবা করার খুব ইচ্ছা এজন্য আমি সোশ্যাল ওয়ার্ক আমি সমাজকর্ম নিয়ে পড়াশোনা করতেছি'],
#  ['rec_10_audio_13.wav',
#   'প্রশ্ন সময় নষ্ট করে ঘুমাই আর কি করবো সব সময় কত এমন কেউ আছে মানে'],
#  ['rec_10_audio_12.wav',
#   'ডিজাইন একটা দেখলে আরেকটা ভরা যায় এটা খুব সুন্দর একটা মানে একটা দেখছি এটা একটু মডিফাই করে অন্যরকম মডেল করানো যায় আপনি অবসর সময় কি করেন'],
#  ['rec_10_small_audio_0.wav', 'আপনার ইয়াটা বইটা'],
#  ['rec_10_audio_16.wav',
#   'নরসিংদীতে অনেক গার্মেন্টস আছে অনেক বালা টোলা নরসিংদী ভালোই তারপরে'],
#  ['rec_10_audio_1.wav',
#   '2016 এরকম এর মধ্যে যারা একটু নিজে স্বাবলম্বী করে আমরা এলাকার মোটামুটি এখন দাঁত আছে কিছুটা না কাজ করে কাজ করতেন আপনি খুব সুন্দর জামা কাপড় বানায়'],
#  ['rec_10_audio_14.wav',
#   'রুনা খালার লগে মানুষ সবসময় খালি কথা করে তুমি আমারে একটা ফোনও দিছো না সায়ন ভাই ফোন দিছে তোমার নাম্বারটা নাই'],
#  ['rec_10_audio_20.wav',
#   'কামনা কারেন্ট বিলাই দিমু না আর আমার ফোনটা করুন আপনারে অনেকগুলো ধন্যবাদ'],
#  ['rec_10_audio_15.wav',
#   'আচ্ছা লেডিস মশাই আপনারা বিড়াল ধরতেছে যদি আমরা হাঁস মুরগি আর সেলাইয়ের কথা কইছি দাঁত আছে যেটা আমরা বাড়িতে নাই কিন্তু তাত্তা'],
#  ['rec_10_audio_18.wav', 'লোডশেডিং গুলো যদি লাইন'],
#  ['rec_10_audio_2.wav', 'কাজটা কাকির কাছ থেকে শিখছি বিদ্যালয়'],
#  ['rec_10_audio_8.wav',
#   'গ্রামের মহিলার আরেকটা স্বাবলম্বী রয়েছে হাঁস-মুরগির ডিম বেচা হাঁস-মুরগি বেচে না আর বছরের শেষে একটা গরু বেচা না'],
#  ['rec_10_audio_19.wav', 'একটা কথা'],
#  ['rec_10_audio_7.wav', 'আমরা কি কবুতর পালন নাকি করলাম'],
#  ['rec_10_audio_17.wav', 'আমার তো না আমি তো আর ভালো লাগে না'],
#  ['rec_10_audio_5.wav',
#   'ইশারায় কাজ করবার লাগে কি কি দরকার হয় মেশিন কাপড় সবচেয়ে বেশি যেটা দরকার আরো বেশি দরকার মানুষের'],
#  ['rec_10_audio_11.wav',
#   'আনন্দ বড় মেশিন কমন পড়ে আগের মত বেশি না আপনারা খুব সুন্দর ডিজাইন'],
#  ['rec_10_audio_3.wav',
#   'না অকর্মার নাতাহে সবাই যার যার পোশাক যাতে বানায় না একটা সুজা একটা কাপড়ের'],
#  ['rec_10_audio_10.wav', '<>'],
#  ['rec_10_audio_9.wav', 'আপনি হাঁস মুরগি পারেন নাই'],
#  ['rec_10_audio_4.wav',
#   'ও কাইটা আমাদের নতুন করে সেলাই করে নতুন একটা রূপ দেওয়া এই কি একটা সুন্দর গান শোনাও আর কত সুন্দর লাগে একটা মানুষের আরো সুন্দর করে তুলে'],
#  ['rec_10_audio_0.wav',
#   'আমরা গ্রামের বেশিরভাগ মেয়েদের ক বেশি একটা কাজ টাজ করে না অশিক্ষিত জামাইয়ের টাকা'],
#  ['rec_10_audio_6.wav',
#   'মানুষের মাপ নিয়ম লাগে কাপড় বানানো যাইব আজ আমরা একটা কাপড় ধরে অনেকটা কাপড়ের সেলাই কতদিন কাপড়'],
#  ['rec_11_audio_20.wav', 'মানে না জানার জন্য হয়েছে'],
#  ['rec_11_audio_9.wav', 'বারো বিষয়ে বলে মেটিক পাস করতাছেন না উঠছিলাম'],
#  ['rec_11_audio_47.wav', 'তাড়াতাড়ি তাড়াতাড়ি'],
#  ['rec_11_audio_18.wav', 'আপনি জানেন নি'],
#  ['rec_11_audio_1.wav',
#   'হালকা করে ছ্যাকা খাইয়া গেলাম কিন্তু কাকিরে দেখলাম অনেক সুন্দর করে দেখেন'],
#  ['rec_11_audio_30.wav', '<>'],
#  ['rec_11_audio_52.wav', 'হাই আমি প্রায় সময় দেখি শপিং করে ফেলতেছে'],
#  ['rec_11_audio_33.wav', 'বিরানি লাগে আমি এক নাম্বার পরবর্তী'],
#  ['rec_11_audio_22.wav', 'আপনার কি নিজেরা লর্ড কলেজ'],
#  ['rec_11_audio_29.wav', 'ও আপনার বাড়ির নাম্বার'],
#  ['rec_11_audio_3.wav', '<>'],
#  ['rec_11_audio_27.wav', 'পরমের বদনাম করতেছে'],
#  ['rec_11_audio_2.wav', 'আচ্ছা এবার আমরা আজান শেষ হয়েছে'],
#  ['rec_11_audio_6.wav', 'আমরা কি কি জানি কয়টায় আমার অনেক মানুষের'],
#  ['rec_11_audio_32.wav', 'দাওয়াত দিবেন নাকি একটা শুক্রবার'],
#  ['rec_11_audio_13.wav',
#   'শেয়ার বয়সের টুনি খাইলে হইলে নাতি হেডফোন লইয়া শান্তি মতনে বিছানার মধ্যে ঘোরাঘুরি করতেছে'],
#  ['rec_11_audio_54.wav', 'সব খাওয়াই'],
#  ['rec_11_audio_5.wav', 'স্মার্টফোন ও আপনার ছোটবেলার এমন কোন মজার কাহিনী'],
#  ['rec_11_audio_4.wav', 'আপনার বাড়িটা আপনার বাড়িটা কোথায়'],
#  ['rec_11_audio_41.wav', '<>'],
#  ['rec_11_audio_16.wav', 'পরে আর পরীক্ষা দিতে আসছি না পরের বছর'],
#  ['rec_11_audio_49.wav', 'ফার্স্ট ইয়ার 10 টা 15 টি বলে 10 টাকা করে না'],
#  ['rec_11_audio_50.wav', 'হাই প্রেসারটা করলাম খুবই ডেনজারাস করুন'],
#  ['rec_11_audio_10.wav', 'আগে তো বসন্তপুর অনেক ইয়াসিন ভয়ঙ্কর আছেন'],
#  ['rec_11_audio_53.wav',
#   'আরে লেডিস মশায় কামড় দিলে গলায় কামড় দিলে গর্ভবতী ওভার মশা কামড় দিলাম গর্ভবতী আছে'],
#  ['rec_11_audio_55.wav',
#   'খাইয়া আমি সুস্থ সবল লইয়া দোয়া করুম না বেশি করে দেন আমরা চাই ইনশাআল্লাহ ইনশাআল্লাহ'],
#  ['rec_11_audio_31.wav', '<>'],
#  ['rec_11_audio_24.wav',
#   'আমরা অনেক বেশি না কম লাগে আচ্ছা আপনি তো অনেক সুন্দর যেহেতু রান করেন না অনেক সুন্দর কি আর আমার খালি মুরগি খাইলাম মজা লাগে না'],
#  ['rec_11_audio_46.wav',
#   'এ এলাকা এ লাগে আপনারে দেখতে অনেক কম দাম কিন্তু আপনি আমি সত্যি কইতাছি অনেক সুন্দর করে দেখলাম'],
#  ['rec_11_audio_51.wav', '<>'],
#  ['rec_11_audio_7.wav', 'গাছতলা খালি পড়ছি কলম পাতাল লিখছি'],
#  ['rec_11_audio_43.wav', 'আম্মু আপনি পাবেন শুটকি দিয়ে তরকারি সামনে'],
#  ['rec_11_audio_40.wav', 'কেলাবি জানলাম মনে করেন'],
#  ['rec_11_small_audio_0.wav',
#   'ও 15 মিনিট হয়ে গেছে গা এবার আমরা টাটা আল্লাহ হাফেজ'],
#  ['rec_11_audio_45.wav', 'পরে আমরা যদি রানতে হাঁড়ি আপডেট কেমন লাগে না'],
#  ['rec_11_audio_37.wav', '<>'],
#  ['rec_11_audio_15.wav',
#   'আচ্ছা এরপর আমি যদি আপনার কাহিনীর মধ্যে ফিরে এসেছে পরে কি কর'],
#  ['rec_11_audio_19.wav',
#   'রায়পুরার মানুষের একটা কথা কইলেন আপনার নামটা একটু ফলো করে দিতেন'],
#  ['rec_11_audio_34.wav',
#   'আলাদা কোনো সিক্রেট আছে যেটা বললে অটোমেটিকলি মজা হয়ে যাবে'],
#  ['rec_11_audio_44.wav', 'জানিনা'],
#  ['rec_11_audio_0.wav',
#   'আপনার নাম কি আমার নাম শিরিনা আক্তার সে ডাক্তার ছিলেন কত বয়স টা 34 36 আমার কাকাকে'],
#  ['rec_11_audio_21.wav', 'ওটা নিয়ে আমরা কবে কবে যামু নে কোন সমস্যা নাই'],
#  ['rec_11_audio_28.wav', 'দেখি একটা খাই না বাজার কত বাজার'],
#  ['rec_11_audio_35.wav', 'বিরানির দোকান'],
#  ['rec_11_audio_14.wav',
#   'পা ভেঙ্গে গেছে না ডাক্তার দেখাইছি ভৈরব দেখাইছি খুলনার কবিরা সব দেখেছি'],
#  ['rec_11_audio_36.wav', 'আদা জিরা লিওন কইতেছে'],
#  ['rec_11_audio_38.wav', '<>'],
#  ['rec_11_audio_26.wav',
#   'আমরা ফারাম পারলাম না বয়লার যেটা বয়লার টানে দিয়া বানায় খাবার দোকান'],
#  ['rec_11_audio_23.wav', 'আছে কি গান দেন'],
#  ['rec_11_audio_25.wav', 'আচ্ছা পল্টি পল্টি মুরগি করে না'],
#  ['rec_11_audio_12.wav', 'দোয়া করুন যাতে তাড়াতাড়ি ভালো করে দাও'],
#  ['rec_11_audio_42.wav',
#   'না আমার আব্বা বলছে আমি কইতাছি কি যে অনেকটা রাইন্দা ফ্রিজের থুম গরম গরম আর খাম কতদিন ধরে বিরানী রান্না কি করেন'],
#  ['rec_11_audio_39.wav', 'গরমকাল মানুষটা আমি এতদিন কেরে পাইলাম না'],
#  ['rec_11_audio_8.wav', 'কারা খালি করছি'],
#  ['rec_11_audio_48.wav', 'বাজারে জায়গা কিছু মজার মজার'],
#  ['rec_11_audio_17.wav',
#   'এর পরে আপনি যদি কোন কথা কইতেন চানগা আচ্ছা তো এরপরে আমরা যদি অনেক অনেক অনেক অনেক খারাপ'],
#  ['rec_11_audio_11.wav',
#   'আব্বা আম্মা সম্পর্কে যদি একটু জানতে চাই আমার আব্বার চাকরি'],
#  ['rec_12_audio_25.wav',
#   'না মাঝে মধ্যে একটু ভালো লাগে একটু আড্ডা মারতে ভালো লাগে কিন্তু প্রায় সময় আমার একলা একলা থাকতে ভালো লাগে অনে এটা আমি যেটা কথা কইতাছি এটা মনে থেকে খুশি হয়ে কথা কইতেছো আমি অনেক এইটারে কি কয় আঞ্চলিক ভাষা আমি অনেক লাকি খুশি'],
#  ['rec_12_audio_28.wav',
#   'নয়টি কিছু লেখা সবচেয়ে বড় কথা যেটা মোবাইল টিপতে ভালো লাগে না একটা গল্পের বই ভালো লাগলো দেখতে'],
#  ['rec_12_audio_9.wav',
#   'তোমার আঞ্চলিক ভাষাটা নিয়ে ও কেমন লাগে তোমার সাথে কথা বলতে কি তোমার সাথে সন্দেহ তো ভালোই লাগে আমার তো ভালোই লাগবে সারাদিনের মন ভরে কথা কইতাছি'],
#  ['rec_12_audio_10.wav',
#   'নরসিংদীর একটা কয়েকটা স্থান লইয়া কথা কইতাম পারি তুমি কোথাও ঘুরতে নরসিংদীর সরি নরসিংদীর নরসিংদীর মন খারাপ তেমন কোনখানে গেছি না'],
#  ['rec_12_audio_16.wav',
#   'এ ফুল ভিডিও এত সুন্দর ফুল ভিডিও কেমনে কেমনে শিক্ষা হয়েছে'],
#  ['rec_12_audio_32.wav',
#   'তোমার পরীক্ষার অভিজ্ঞতা আমার পরীক্ষার মধ্যে আমি গণিত পরীক্ষার'],
#  ['rec_12_audio_44.wav', 'আমি কি সুন্দর করে কথা কইতেছি'],
#  ['rec_12_audio_17.wav',
#   'এই আমার কাছ থেকে বেশি আর কি ভালো লাগে আমি আমার কাছ থেকে শিখছি আরো আরো অনেক কিছু মনে'],
#  ['rec_12_audio_3.wav',
#   'আমাদের দেশে মনে করো স্কুলের মতই খালি কয়টা আরবি সাবজেক্ট আছে ঈদুল ফিতর একটা কুরআন আছে আর বাকি সব স্কুলের মত'],
#  ['rec_12_audio_43.wav',
#   'তোমারে অনেকটি কথা কইছি যদিও বেশিরভাগ কতই আমি কইছি তুমি খুব কম কথা কইছো অন আমার লগে থাকলে তোমার ভালো না লাগলে তুমি কইবা না ভালোই লাগছে'],
#  ['rec_12_audio_31.wav', 'এটা কেমনে হয় না কি করলাম'],
#  ['rec_12_audio_18.wav',
#   'তোমার অনেক আলাদা আলাদা মানে শরীর পিক জাতীয় অনেক জিনিসপাতি তুমি করো বইসা বইসা আর্ট করার মত যেটা সবচেয়ে বড় কথা দুইজন সহকারে মানুষের প্র্যাকটিক্যাল খাতা রাখতে পারো এসাইনমেন্ট ডাক্তার স্বামী জীবনেও পারিনা'],
#  ['rec_12_audio_6.wav',
#   'নাইনে তেল লেখাপড়া ভালোই মাদ্রাসার মধ্যে যার যার কাছে স্কুলের মধ্যে যেরকম আছে তো মাদ্রাসার মধ্যে আর কি তোমার কাছে আমরা তো অনেক কথার মধ্যে আমরা কথা কও আমরা কথা কই না আমরা যেহেতু প্রতিদিন অন্যান'],
#  ['rec_12_audio_0.wav',
#   'নামটা কি আমি খাব না তোমার নাম আমার নাম তাহমিনা আক্তার আমরা বলে নরসিংদীর আঞ্চলিক ভাষায় কথা বলি কষ্ট করে আঞ্চলিক ভাষাটি মনে করছি'],
#  ['rec_12_audio_2.wav',
#   'আমি তোমারে একটা আলাদা বিষয় জিগায় তুমি তো আলিয়া মাদ্রাসা সম্পর্কে তেমন জানিনা একটু আলোচনা করতাম'],
#  ['rec_12_audio_8.wav',
#   'সময়ের সাথে সাথে ভাষা পাল্টে আমার নামটা অনেকটা ভুইলা যাইতেছে খুব সুন্দর করে কথা কও এটা মনে হয় সবচাইতে বড় কথা এটা আগে তো আমরা এখন গুড়ি গুড়ি গুড়ি উঠতেছে'],
#  ['rec_12_audio_37.wav', 'বিশ্বাস উঠে যাবে না'],
#  ['rec_12_audio_12.wav',
#   'কফি হাউজের একটা গান আছে নাকি কফি হাউজের সেই আড্ডাটা আজ আর নেই'],
#  ['rec_12_audio_41.wav', 'লিখছি তো দেখলে খালি'],
#  ['rec_12_audio_39.wav',
#   'আকাশে অনেক সুন্দর বইনের জন্য আঞ্চলিক ভাষা গুলো সুন্দর ভাবে ভালই লাগে'],
#  ['rec_12_audio_23.wav', 'উদাসীন বাউন্ডুলে তোমার কি করতে ভালো লাগে'],
#  ['rec_12_audio_47.wav',
#   'তো তুমি যে কথাগুলো আমার লগে কতক্ষণ কথা কইছে তোমারে অনেকগুলা ধন্যবাদ'],
#  ['rec_12_audio_19.wav',
#   'না আমার কাছে দেখালে এটা ভালো লাগে তো ভালোই লাগে না তারপরও ভালো লাগে কি করে একটা কিছু করে দিতে পারলে ভালো'],
#  ['rec_12_audio_36.wav', 'সবাই বুঝে না অন্য মানুষ অদ্ভুত সবাইকে রেজাল্ট'],
#  ['rec_12_audio_22.wav',
#   'তৈলার তেমন কেউ নাই গো আমি কইরা দিছি অনেকটি খাতায় আমি লিখে দিচ্ছি'],
#  ['rec_12_audio_42.wav', 'কোন বাংলা একটা ছবির মধ্যে জানি ছিল'],
#  ['rec_12_audio_14.wav',
#   'একটা একটা মেহেদি দিয়া দিবার লাগে একা একা দিয়া অনুভূতিটা করে দাও আমার কাছে ভালো লাগে ভালো লাগে না'],
#  ['rec_12_audio_7.wav',
#   'জেলার মানুষের লগে কথা কইতাম রে একটু বইয়ের ভাষাটাকে আমরা গিয়েছিলাম তোমার কি মোটামুটি মনে আছে নাকি তোমার আমার মত প্রায় ভুইলা যাও ঘরে বসে গেছে'],
#  ['rec_12_audio_29.wav', 'পরীক্ষা'],
#  ['rec_12_audio_15.wav',
#   'একদিন ঈদের আগের দিন এটা সবার একটা খুশি তো এই জায়গায় ভালোই লাগে ভালোই কারন বিভিন্ন ধরনের পিঠা এসে অনেক কিছুই তৈরি করে তুমি তো অনেক সুন্দর ফুল পিঠা বানাতে'],
#  ['rec_12_audio_30.wav', 'আমি সকালে দেখেছি'],
#  ['rec_12_audio_5.wav', 'পরকিয়া দেখা দেখি অনেক উন্নত করেছে'],
#  ['rec_12_audio_27.wav',
#   'ভীষণ হয়েছে হাতপাখার হয়ে গেছে গা আর কি করতে ভালো লাগে না লিখতে ভালো লাগে'],
#  ['rec_12_audio_26.wav', 'আরে অনেকেরে ঘুরতে'],
#  ['rec_12_audio_13.wav',
#   'আমি তোমার আঞ্চলিক ভাষায় আছি তোমার তোমার একটা গুণ নিয়ে যদি আমি কথা কই তুমি খুব সুন্দর মেহেদী মানুষেরা তো ঈদের আগের দিন রাতে পোলাপাইন হয়ে থাকে অবশ্য সব বড় মানুষের কাছে বল তোমার কাছে আয়'],
#  ['rec_12_audio_11.wav',
#   'এই প্রান্ত শালা মাদারচোদ একটা কফি হাউজ আছে এটার মধ্যে গিয়েছিলাম'],
#  ['rec_12_audio_1.wav',
#   'আজকের পরে তোমার বয়সটা কত হইবো 17 তুমি কি করো লেখাপড়া করি কিয়া পড়ো ইন্টার ফার্স্ট ইয়ার ফার্স্ট ইয়ার'],
#  ['rec_12_audio_34.wav',
#   'শুধু 11 জন পরীক্ষা দিয়েছে নাকি কেউ বিদেশ গেছে না খুব কম বয়সে বিয়ে করে খুব কম সবাই সামনে একটা কিছু করুক এরপরে বিয়া শ'],
#  ['rec_12_audio_40.wav',
#   'গতর দোয়া পেলেন তোমার কি রাখতে বেশি ভালো লাগে মানে মন'],
#  ['rec_12_audio_24.wav',
#   'সত্যি কথা কি তোমার বান্ধবীরা সবাই জানে যে আমি তোমারে কথা কইতাছি এটা কি জোর করে'],
#  ['rec_12_audio_45.wav',
#   'বেশি বেশি আচ্ছা তোমার কি ওর ইচ্ছা আছে অলরেডি বড় যদি মানে এইচএসসির পরে কি করার জন্য কলেজে অনার্সে ভর্তি হওয়ার ইচ্ছা আছে'],
#  ['rec_12_audio_20.wav',
#   'অনেক ভালো লাগে আছে মোটামুটি আমি যদি আগে জানতাম আমার ইন্টারনেটের এসাইনমেন্ট আগে জানতাম না'],
#  ['rec_12_audio_46.wav', 'মানে কি কিসের সরি করেছেন'],
#  ['rec_12_audio_35.wav', 'এটা একটু কম চান'],
#  ['rec_12_audio_38.wav',
#   'এবার হার্ড মনে করো প্রচুর হার্ড হয়েছে এমন একটা দিন নাই'],
#  ['rec_12_audio_33.wav',
#   '5 নাম্বারটা শুধু আনসার করে দিয়েছে শুধু 11 জন পাস করেছে 43 জন পরীক্ষা'],
#  ['rec_12_small_audio_0.wav', '<>'],
#  ['rec_12_audio_4.wav',
#   'সিনেমা একসাথেই আছে আরকি তোমরা আমাদের সাথে দেখছি অনেক সুন্দর সুন্দর অনেক অনেক সুন্দর করছেন আমি অনেকদিন ছিলাম প্রায় 7-8 বছর পরে'],
#  ['rec_12_audio_21.wav', 'আমার টি মনে করো ভাইজান'],
#  ['rec_13_audio_39.wav',
#   'তারপরে মানে জ্বর আইলো দাদুর কাছ থেকে আম চুরি করে খাই'],
#  ['rec_13_audio_3.wav',
#   'তোর ভবিষ্যতেই একই ভাবনা কি যে কি করবি ঢাকা বিশ্ববিদ্যালয় পড়াশোনা যদি যাইতে পারি তাহলে পরমু আর'],
#  ['rec_13_audio_48.wav', 'বুলবুল স্কুলের পরীক্ষা'],
#  ['rec_13_audio_6.wav', 'পরে তারপর আমি মোদির সাথে রিলেশন করি তুমি শেখ হাসিনা'],
#  ['rec_13_audio_1.wav',
#   'কি কি করতে পারেন তোমার বেস্ট ফ্রেন্ড আছে না ভালো বান্ধবী নেই'],
#  ['rec_13_audio_0.wav',
#   'তোমার নাম কি কোন স্কুলে পড়ো স্কুলে তোমার কি কি করতে ভালো লাগে স্কুলে থাকতে ভালো লাগে'],
#  ['rec_13_audio_10.wav',
#   'স্মার্টফোন তো মানে যে যেদিকে আর কি মানে যে যেমন তার ফোনে কিন্তু ঠিক তেমনি আসবো যদি তুমি স্মার্টফোনে কিন্তু ভালো দিকও আছে খারাপ দিকও আছে তুমি যদি ভালো হয়ে থাকো তাহলে তুমি কিন্তু ভালো দিকটাই নিতে পার'],
#  ['rec_13_audio_47.wav',
#   'তোমাকে অসংখ্য ধন্যবাদ মজার একটা আড্ডা দিতে সবাই স্মৃতিচারণ হয়েছে আমরা কিন্তু কোরবানি ঈদের সময় খেলতেছি'],
#  ['rec_13_audio_8.wav', 'টিভি দেখাস কি দেখসোস কি সিরিয়াল লাগে'],
#  ['rec_13_audio_18.wav', '<>'],
#  ['rec_13_audio_36.wav',
#   'ঢাকা থেকে এটা কি এটা মানে চুরি করছি চুরির উপর ডাকাতি একপ্রকার হায় হায় আমিতো কইয়া দিমু সিঙ্গার করছে নি অনেকগুলোই'],
#  ['rec_13_audio_40.wav', 'দাদু কই আছিল বাপের বাড়িতে গিয়েছিলাম'],
#  ['rec_13_audio_13.wav',
#   'আমার সবচেয়ে বেশি ভালো লাগে মেয়ে তার ইংলিশ টাইপ করতে আরকি ম্যাথ পারস না তোর শৈশব সম্পর্কে কিছু কও আমার যে শব্দ মানে খুবই মজাদার কি মানে সবার সাথে ঝগড়া করতাম কি বাড়িতে খেতে দিতাম না'],
#  ['rec_13_audio_11.wav',
#   'স্মার্টফোন যে খারাপ এটা কিন্তু না স্মার্টফোনে অনেকে মানে ইসলামী সংগীত অনেক কিছুই আছে ইসলামী বিষয়ে অন্য কিছু মানে স্মার্টফোন দিয়ে খারাপ কিছু করলেই খারাপ আরকি এখন তো অনলাইনে স্মার্টফোন দিয়ে ছেলেরা ফ্রী ফায়ার তারপরে আরো পাবজি অনেক খেলায় অনলাইনে এইসব না করে যদি তারা পড়ালেখার প্রতি মনোযোগী তো তাহলে দেশটা আরো উন্নত হয়'],
#  ['rec_13_audio_31.wav',
#   'যদি মানে এতটাই মানে যদি বাড়ি থেকে তাড়াতাড়ি বের করার সাথে আমার বাপের বাড়ি যতদিন থাকবে ততদিন কিন্তু আপনার সব সময় আদর করে আর ছোট মেয়ে আর বড় মেয়ে নাই পরিবারের সবাই বাপ-মার কাছে সবাই সমান সমান অধিকার হিসেবে একটা উল্লেখ করছো কিন্তু সবাই সমান'],
#  ['rec_13_audio_25.wav', 'মানে'],
#  ['rec_13_audio_14.wav',
#   'মাইরা দিতাম আরো মানে সবার সাথে ঝগড়া করতাম এখন স্বভাবটা নাই তারপরও কিছুটা আছে আরকি'],
#  ['rec_13_audio_19.wav',
#   'পারিনা মানে যেটা আমি খাইতে পারি ওইটাই রান্না করতে পারি কি খাইতে পারস নুডুলস খাইতে পারি নুডুলস খাই রান্না করি চিংড়ি মাছ চিংড়ি মাছ আমি নিজে রান্না করতে পারি রান সস'],
#  ['rec_13_audio_24.wav',
#   'ঈদ সম্পর্কে কিছু সবচেয়ে ভালো কাটছে এরকম যে ছোটবেলায় সবগুলাই অনেক স্পেশাল ছিল অনেক ভালো লাগতো তখন তো ঈদে যাইতে পারতাম কিন্তু এখন তো বাড়িতে থাকতে হয়'],
#  ['rec_13_audio_2.wav',
#   'তোমার কোন পিকচার ভালো লাগে কোন স্যার ম্যাডাম আর কি ভালো লাগে তোমার কি খাইতে ভালো লাগে ফুচকা'],
#  ['rec_13_audio_42.wav', '<>'],
#  ['rec_13_audio_30.wav', '<>'],
#  ['rec_13_audio_23.wav',
#   'মানে এত ভালো আছিল যে আমি যদি কোনদিন না খাইতাম ওর আমারে খাওয়াই দিত রাত্রে 1:00 টা বাজে খাওয়ায় দিতো কিছু দিন আগে ছিল কিন্তু এখন নাই'],
#  ['rec_13_audio_38.wav',
#   'অনেক মজা যদি কোনদিন কিছুদিন আগে আচ্ছা অনেক কিছু সবজি সবজি চুরি করে তারপরে'],
#  ['rec_13_audio_7.wav',
#   'মোদির সাথে রিলেশন দেওয়ার পরে স্কুলের মানে ক্লাসের সবাই আর কি মোদির বউ বলে ডাকে আমারে সেলিব্রেটি আমার তো ইন্ডিয়া জনসংখ্যা'],
#  ['rec_13_audio_37.wav', 'অনেকগুলো বলতে কতদিন বাচ্চা 6 বছরের টাকা চুরি করেছে'],
#  ['rec_13_audio_45.wav',
#   'এটা নিয়ে যত ঠাট্টা-তামাশা সবকিছু করে ওরা আর বাড়ির যারা আছে সবারই মজা মারে আমারে জামা লইয়া নাই'],
#  ['rec_13_audio_22.wav',
#   'স্কুল জীবন বা বাইরে বেড়াতে গেছো শিমুল হিমুর কয়টা ফ্রেন্ড আছে এগুলা নিয়ে কিছু কও স্কুলের রাইপুর মডেল স্কুল আমি 10 বছর পর লেখাপড়া করছি তার মাঝে এক বছরে মাদ্রাসায় গিয়েছিলাম'],
#  ['rec_13_audio_26.wav',
#   'সর্বোচ্চ সালামি উঠছে এরকম সর্বোচ্চ কত ছিল 1200 নাকি 1315 টাকা কত জনে উঠছিল সেটি খেয়াল নাই এবার না গতবারের আগের বার মানে আগেরবার রোজার ঈদ আর'],
#  ['rec_13_audio_4.wav',
#   'পড়ানোর সোনা যখন আর্টস নিয়ে করতাছি তাহলে মোবাইল চালাস না ফেসবুক চালাস ফেসবুক সম্পর্কে কিছু ক'],
#  ['rec_13_audio_28.wav',
#   'আমি সবাইকে মিস করছি এটা তো ছোট না পায় কিন্তু ছোটদের থেকে বেশি বড়ো না বলতে পারেনা'],
#  ['rec_13_audio_33.wav',
#   'বেশি দিন তো নাই আমার বয়সটা 15 আর আমার ছোট বোনের বয়সটা মাত্র 15 মাস তখন আদরটা তো ওই বেশি পাইবো মেয়েরা সবচেয়ে পরিবারের বড় মেয়ের বাবা-মা সবাই'],
#  ['rec_13_audio_9.wav',
#   'শংকর শংকর খুব ভালো লাগে না তুই তো মোবাইল চালাস মোবাইলের ফেসবুক ভালো দিয়ে ইতিবাচক আর ইতিবাচক দিক আছে এগুলো সম্পর্কে কিছু কও তোর কি মনে'],
#  ['rec_13_audio_5.wav',
#   'ফেসবুক ইউজ করে মানে সবাইরে বিনোদন দেওয়ার লাইগা আর কি আমার ফেসবুক আইডির নাম শেখ হাসিনা দিয়ে খুলছি তারপর ডাক্তার দীপু মনি দিয়েছিলাম শেখ হাসিনা দিয়ে তারপর নরেন্দ্র মোদির লগে রিলেশনশিপ দিয়েছিলাম'],
#  ['rec_13_audio_20.wav',
#   'লাস্ট কবে রাত্রে ডিম ভাজি করছি তারপর চিংড়ি মাছ বিরান করছি এগুলো আর কি'],
#  ['rec_13_small_audio_0.wav',
#   'আচ্ছা এবার আমরা শেষ দুইটা করো তোর লগে আর একটা কথা'],
#  ['rec_13_audio_41.wav', 'সরাসরি করছি'],
#  ['rec_13_audio_12.wav',
#   'বা যদি অনলাইনে ক্লাস করতো অনেকে কোচিং করতে পারত তাহলে তো ইয়া দেশটা আরো উন্নতি হতো কিন্তু তারা এটা না করে তারা অযথা সময় নষ্ট করে তোর কোন সাবজেক্ট টা বেশি ভালো লাগে পড়তে পারো'],
#  ['rec_13_audio_35.wav',
#   'তোর এমন কোন সিক্রেট আছে যে তুই ঘরে একটা আকাম করছো আয় হায় তুই তো ছোট বোনের ব্যাংক ডাকাতি করলি'],
#  ['rec_13_audio_32.wav',
#   'বাপ মা একটু এলো চুল উঠার এই বেশি আদর করে এটা যত পরিমাণ বাচ্চা মানে কিছুদিন আগে হয়েছে সবাই আদর করবো'],
#  ['rec_13_audio_21.wav',
#   'সবাই খাইছে অনেক ভালো হয়েছে ভালো হয়েছে সান্তনা দেয় না'],
#  ['rec_13_audio_27.wav',
#   '2021 এ সবচেয়ে আদর কেডা করে বেশি আমার আম্মু তোমার আব্বু পরিবার সবাই খাওয়া দরকার'],
#  ['rec_13_audio_17.wav',
#   'মানে আমার একটা ফ্রেন্ডের বার্থডে সময় কে কেন ছিল তারপর কেক কাটার আগে'],
#  ['rec_13_audio_44.wav',
#   'সব সময় ওর খারাপ দিকটা এ বিষয়ে বার করে প্রশংসা করত না যদিও আরো আরো সুন্দর লাগে সুন্দর লাগে না যদি একটা নতুন জামা নেতার কবিতাটি দিয়ে গেছে মানে আরো কত কিছুই জি'],
#  ['rec_13_audio_29.wav',
#   'ছোটরা বেশি আদর করে আমার বাসায় গিয়ে আর আমারে 20 বছর হয় তাহলে ছোটটা যদি 10 বছর হয় তাহলে কিন্তু কেন বড় রাত 10 বছর বেশি আদর পায় না'],
#  ['rec_13_audio_15.wav',
#   'কেউ সাথে এখন করিনা এমন একটা কাজের কথা কও যেটা তোর মনে রাখার মতো'],
#  ['rec_13_audio_49.wav',
#   'আচ্ছা আমাদের বাড়িটা অফ করে দে সবাইরে থ্যাঙ্ক ইউ তোমার জন্য করে রান্না করতাছি প্রশ্ন করছি'],
#  ['rec_13_audio_43.wav',
#   'তোর আমারে কেমন লাগে সারাদিন যেত আপনার সাথে তাই আর খারাপ হলেও তো খারাপ কমু না আমি খারাপ তার মানে খারাপ বলতেছি না মানে একটা ফ্রেন্ডের আর একটা ফ্রেন্ড কোনদিনই ভালো হয় নাই বেস্ট ফ্রেন্ড তো জীবনেও কয়না'],
#  ['rec_13_audio_16.wav', 'এবার মে মাসের 3 তারিখে লাস্ট একটা করেছিলাম'],
#  ['rec_13_audio_46.wav', 'আচ্ছা যাই হোক তোমাদের সবাইকে অনেক ধন্যবাদ'],
#  ['rec_13_audio_34.wav', 'তুই সহ বড়দের ভাইবোন খেয়েছো'],
#  ['rec_14_audio_60.wav', 'হ্যাঁ হ্যাঁ ভুল করছে বিরাট কোহলি ভুল করছি'],
#  ['rec_14_audio_32.wav', 'বেশি কিছু করতেছে'],
#  ['rec_14_audio_59.wav', 'বিরাট কোহলি লোকেশন'],
#  ['rec_14_audio_48.wav', 'তোমার সাথে একটা মানুষ করতে হবে আর্জেন্টিনা'],
#  ['rec_14_audio_38.wav', 'বাংলাদেশে আরকান আছে বলেন'],
#  ['rec_14_audio_62.wav', 'অন্ধকার অন্ধকার'],
#  ['rec_14_audio_50.wav', 'রেডি ভালো লাগে না'],
#  ['rec_14_audio_42.wav', '<>'],
#  ['rec_14_audio_26.wav', '<>'],
#  ['rec_14_audio_69.wav', 'ইয়েস আমি কি করবো না'],
#  ['rec_14_audio_37.wav', 'ভালো ভালো প্লেয়ার'],
#  ['rec_14_audio_39.wav',
#   'হ্যাঁ না তাই আমি প্রথমে তামিমের লগে পরে আরেকজন আছে বলি'],
#  ['rec_14_audio_9.wav',
#   'তুই তো জীবনে ক্রিকেট খেলা যে সময় ফাস্ট বাংলাদেশের মনে করেন'],
#  ['rec_14_audio_7.wav',
#   'অন্তত 4 নাম্বার 3 নাম্বার আমি ঠিক আছে আমি তিন নাম্বার'],
#  ['rec_14_audio_53.wav', '<>'],
#  ['rec_14_small_audio_0.wav', 'সেঞ্চুরি আছে ফাস্ট ট্রান্সলেটর'],
#  ['rec_14_audio_65.wav', 'প্রাচীনতম লাগবে'],
#  ['rec_14_audio_63.wav',
#   'দেশের মধ্যে দিয়ে একটা ভালো বোলিং এরিয়াতে এটা থানায় এশিয়া কাপ বিশ্বকাপ ক্রিকেট'],
#  ['rec_14_audio_45.wav', '<>'],
#  ['rec_14_audio_14.wav',
#   'শাকিব খানের লগে অভিষেক ম্যাচ শুরু হয়েছে মুস্তাফিজের ঠিক আছে'],
#  ['rec_14_audio_70.wav', 'ঘোষণা করেছে'],
#  ['rec_14_audio_11.wav', 'থ্যাংক ইউ'],
#  ['rec_14_audio_44.wav', 'তামিল বাংলা'],
#  ['rec_14_audio_47.wav', '<>'],
#  ['rec_14_audio_4.wav', 'আমি একদিন আনছি তোর সুদীপের দিলাম'],
#  ['rec_14_audio_15.wav', 'বাংলাদেশের খেলা হয়েছিল'],
#  ['rec_14_audio_54.wav', 'শফিকুল ইসলাম আল আমিন হোসেন'],
#  ['rec_14_audio_21.wav', 'সোহাগ গাজী আব্দুর রাজ্জাক খেলা'],
#  ['rec_14_audio_58.wav',
#   'বিরাট কোহলি আর নতুন মেম্বার কি একটা ঝগড়া গেছে মানে আগের থেকেও মানুষ'],
#  ['rec_14_audio_12.wav', '<>'],
#  ['rec_14_audio_27.wav', 'হোস্টেল কি বিশ্বকাপ সম্ভাবনা'],
#  ['rec_14_audio_19.wav', 'শাকিবের নাই'],
#  ['rec_14_audio_57.wav', 'রসগোল্লা রে কাজে লাগছিল বিপিএল'],
#  ['rec_14_audio_52.wav', '<>'],
#  ['rec_14_audio_1.wav', '<>'],
#  ['rec_14_audio_40.wav', 'মাহমুদ দুলাল বিশ্বকাপ'],
#  ['rec_14_audio_49.wav', 'সাব্বিরের খেলা ভালো লাগবে'],
#  ['rec_14_audio_46.wav', 'রোহিত শর্মা 26 সালের মাধ্যমিক'],
#  ['rec_14_audio_36.wav', 'এত সুন্দর কেন দিচ্ছে হয়েছে আমাদের দেশের অবস্থা'],
#  ['rec_14_audio_55.wav', '<>'],
#  ['rec_14_audio_17.wav', 'একুরিয়ামের চরফ্যাশন'],
#  ['rec_14_audio_28.wav', 'নেদারল্যান্ড আর হয়েছিল'],
#  ['rec_14_audio_16.wav', '<>'],
#  ['rec_14_audio_22.wav', 'ইন্ডিয়া অস্ট্রেলিয়া স্কোর'],
#  ['rec_14_audio_2.wav', 'তোর মনে করো'],
#  ['rec_14_audio_18.wav', 'বোলিং দেখছিলাম'],
#  ['rec_14_audio_3.wav', 'আমার জীবনে আমি টিকিট কেটে রেখেছি'],
#  ['rec_14_audio_20.wav', 'একটা সমস্যা হয়েছে'],
#  ['rec_14_audio_33.wav', 'নতুন বছর ইন্ডিয়া পাকিস্তান'],
#  ['rec_14_audio_6.wav', '<>'],
#  ['rec_14_audio_41.wav', 'সিনিয়র প্লেয়ার থাকলে'],
#  ['rec_14_audio_10.wav', 'বাংলাদেশ মানে একটা সাফল্য মুভি'],
#  ['rec_14_audio_64.wav', 'বাংলাদেশের'],
#  ['rec_14_audio_51.wav', 'জিম্বাবুয়ের'],
#  ['rec_14_audio_66.wav', '<>'],
#  ['rec_14_audio_56.wav', '<>'],
#  ['rec_14_audio_5.wav', 'প্রতিযোগিতার মাধ্যমে স্কুল মাঠে খেলছিলাম'],
#  ['rec_14_audio_30.wav', '<>'],
#  ['rec_14_audio_67.wav', '<>'],
#  ['rec_14_audio_13.wav',
#   'হুন এর আগে যে সময় মুস্তাফিজের ফাস্ট অভিষেক ম্যাচ হয়েছে'],
#  ['rec_14_audio_68.wav', '<>'],
#  ['rec_14_audio_8.wav', 'তো এটা দুঃখজনক ফলাফল'],
#  ['rec_14_audio_43.wav', '<>'],
#  ['rec_14_audio_34.wav', 'পাপনের লইছে না বৃষ্টি হবে না'],
#  ['rec_14_audio_61.wav', '<>'],
#  ['rec_14_audio_31.wav', '<>'],
#  ['rec_14_audio_35.wav', 'শ্রীলংকার রিয়াদি দেখলাম'],
#  ['rec_14_audio_0.wav', 'খেলতাম'],
#  ['rec_14_audio_25.wav', 'বিরাট কোহলি সম্মান অস্ট্রেলিয়া ইন্ডিয়া শ্রীলঙ্কা'],
#  ['rec_14_audio_29.wav', 'ডলারের মাধ্যমে'],
#  ['rec_14_audio_24.wav',
#   'অস্ট্রেলিয়ার ইন্ডিয়া খেলবো নাকি ইন্ডিয়ার নাম্বার'],
#  ['rec_14_audio_23.wav',
#   'এডিটরস স্পন্সর আছে না ফুটবলের মধ্যে একটা জার্সি তৈরি করেছেন'],
#  ['rec_15_audio_3.wav', 'সবজি সিরিয়াল'],
#  ['rec_15_audio_11.wav',
#   'কি অবস্থা বাড়িতে থাকতে ভালো লাগে না ঘুরতে যেতে ভালো লাগে না কি যে একটা অবস্থা কারেন্টটা সকালবেলায় আচ্ছা কি আর করা আচ্ছা কি আর করার জন্য যাইতাছে এমনি যাইবো'],
#  ['rec_15_audio_6.wav',
#   'কুত্তা যদি না থাকে তাহলে যাওনের একটা প্ল্যান করাই যাইতে পারে এখন কত হয়েছে তোর দিনকাল কেমন যাইতেছে'],
#  ['rec_15_audio_10.wav',
#   'বিদ্যুৎ তৈরি করার জন্য একদম কলা নায়িকা ভিতর তৈরি করতে পারতাছে না কারেন্টও নাই সে বোঝেনা মানুষের ভোগান্তিও তো আর কম না বুঝবো কেরে কেরে বুঝবো'],
#  ['rec_15_audio_4.wav',
#   'আরে জাহেল বাবুজি ঘটনাগুলো অনেক মনে পড়ে অনেক মিস করি রে দোস্ত আইরো স্যারের লগে দেখা কইরা'],
#  ['rec_15_audio_2.wav',
#   'কেমিস্ট্রি ক্লাস ফাঁকি দিয়েছে একবার যে সরকারি কলেজের ফুসকুড়ি হয়েছিলো'],
#  ['rec_15_audio_5.wav',
#   'আমি জীবনের যেতাম না পিকনিকের দিন স্যারের বাড়ির খাইছি এটা আমার মনে আছে আমি জীবনে আর কোন ফ্রিজে স্যারের বাড়ি যেতাম না আচ্ছা আগে আয় জানি খোজ খবর লই'],
#  ['rec_15_audio_0.wav',
#   'গেছিলাম নরসিংদী জেলা নরসিংদী গিয়া ফর স্টেশনের ভাবি আমি কই'],
#  ['rec_15_audio_9.wav',
#   'ডলারের দাম বেড়ে গেল পরে তো হয়েছে কয়লা কিন্তু আসছে না'],
#  ['rec_15_audio_7.wav',
#   'আরে খালি তোগো বাড়িতে আমার পারতাছি না এমনি চললে কি পাস করতে পারবে মনে হয় না তো গরমের ছুটি হইতে পারছি না তো'],
#  ['rec_15_audio_1.wav',
#   'এমন এক সময় তো আমগোরে আছি আমরাও তো আরো খুলে মেলায় গিয়ে বসে বসে'],
#  ['rec_15_small_audio_0.wav', 'এটা ওই অঙ্গ সহ্য করা লাগ'],
#  ['rec_15_audio_8.wav',
#   'আর যে দেখলাম পায়রা বিদ্যুৎ কেন্দ্রগুলো কালের লেগে বন্ধ করে দিয়েছে কারেন্ট করতে আইবো আরে দোস্ত আর কইস না গরমের লাগি তো সব মানুষ অসুস্থ হয়ে পড়ছে'],
#  ['rec_16_audio_19.wav', 'আর কার্ডের মধ্যে রান করা যায় না খুব কষ্ট'],
#  ['rec_16_audio_0.wav', 'প্রতিদিন তারিখ'],
#  ['rec_16_audio_31.wav', 'নারীরা চক্রবর্তী'],
#  ['rec_16_audio_42.wav', 'লিসেন কি'],
#  ['rec_16_audio_24.wav', 'পুদিনা কলকাতা কলকাতা'],
#  ['rec_16_audio_55.wav', 'শেষে আমরা তৌহিদ হৃদয় লটারি'],
#  ['rec_16_audio_21.wav',
#   'আমিতো ডিপার্টমেন্টের ইয়ামিনি খেলছি পরে লাস্ট দুইবার আগে নাম কি খেলা দেখলাম অনেক খেলা দে হিন্দি'],
#  ['rec_16_audio_25.wav',
#   'খেলা দেখলে অন্য রকম একটা কি খেলা শুরু করছে বুঝিনা যত সুন্দর'],
#  ['rec_16_audio_1.wav', 'তোর উইকেট তুলে নিলাম সবাই'],
#  ['rec_16_audio_52.wav', 'সারাদিনের খেলা বিশ্বকাপ'],
#  ['rec_16_audio_14.wav', '<>'],
#  ['rec_16_audio_32.wav', 'এবার কি শাক খেলে ক্ষমতা নাই হেলিকপ্টার'],
#  ['rec_16_audio_22.wav', 'বিপিএল ঢাকা বিশ্ববিদ্যালয়'],
#  ['rec_16_audio_20.wav',
#   'মানে না তুই এসব পইড়া তোর ইয়া টিয়া পইড়া তোর পেট হেলমেট তোর গাটিতে সব কিছু পইরা দিবি করতে গেলে প্রথম প্রথম'],
#  ['rec_16_audio_15.wav', 'কি আর বলদা ইউটিউব লাগেনা ডিউটি থেকে'],
#  ['rec_16_audio_54.wav', 'এবার কিসের পরে বাংলাদেশি'],
#  ['rec_16_audio_61.wav',
#   'বাংলাদেশের কিছু একটা ভালো খেলা খেলতে পারবো আমাদের লটক শান্ত শান্ত মোটামুটি সমস্যা বিশ্ব'],
#  ['rec_16_audio_46.wav', 'মারে ঠিক আছে কিন্তু মিন বলার'],
#  ['rec_16_audio_5.wav', 'আইপিএলের দিল্লির মাঝে দিল্লির মাঝে একটা দেখি'],
#  ['rec_16_audio_47.wav',
#   'রশিদ খানের একেবারে তিন ছক্কা দিয়া বিষ ধরাই দিয়েছে'],
#  ['rec_16_audio_39.wav', 'ইয়ার দা শেয়ারের জাগাত দীপক গো দাখিল পরীক্ষা'],
#  ['rec_16_audio_33.wav', 'এমোনিয়ার কামাইরা দিছে'],
#  ['rec_16_audio_38.wav', 'তোর কি খেলা দেখাও'],
#  ['rec_16_audio_60.wav',
#   'হেরুর ব্যথা পাবা ডিজে গান বাংলাদেশের তুলনামূলকভাবে চলে যদি ওপেনিং এ তোর লিটন এরিয়া জায়গা'],
#  ['rec_16_audio_40.wav', '<>'],
#  ['rec_16_audio_13.wav', 'আরে বে'],
#  ['rec_16_audio_3.wav', 'আইপিল'],
#  ['rec_16_audio_43.wav', 'বিরাট কোহলি পড়ে যায়'],
#  ['rec_16_audio_41.wav', 'বিরাট কোহলি পরেনা হলে সিস্টেম বিরাট কোহলি কি'],
#  ['rec_16_audio_6.wav', 'এত আরিয়ানা'],
#  ['rec_16_audio_49.wav', 'গিলসিল বা তন্ত্র ফিড আছে হেরে নাম লইয়া বাউন্ডারি'],
#  ['rec_16_audio_57.wav', 'সুমন আসলে হ্যালো একটা কি কইতাম বেশি ভাব থাকে'],
#  ['rec_16_audio_2.wav', 'কোন'],
#  ['rec_16_audio_30.wav', 'ক্রিকেট ক্রিকেট'],
#  ['rec_16_audio_59.wav',
#   'তুই যখন তুই আগে থেকে তুই যদি লেগে যাস না কোন সাইটে আমি এখন শামীম পাটোয়ারী জিম্বাবুর বলাটা বাইরে থাকবে'],
#  ['rec_16_audio_11.wav', '<>'],
#  ['rec_16_audio_23.wav', 'রাসেল'],
#  ['rec_16_audio_29.wav',
#   'আমার মতে আছে না ফেক কার সঙ্গে আছে না হেরে বয়া বেটিং লাইন'],
#  ['rec_16_audio_16.wav', '111 মিরাজ বলেছি'],
#  ['rec_16_audio_9.wav',
#   'বিদেশি একটা কিপিং পাইলে বিদেশি তো কিপিনের বাজার আছে ভালো আর দেখিনা'],
#  ['rec_16_audio_51.wav', 'গিল একটা ব্রা আর কত খেলতো না আমার মনে নেই অপশন'],
#  ['rec_16_audio_34.wav', 'রিশব পান্ডার'],
#  ['rec_16_audio_48.wav', 'গিলে'],
#  ['rec_16_audio_4.wav', 'হ্যাঁ কোন বেটি স্টাইল'],
#  ['rec_16_audio_17.wav', '<>'],
#  ['rec_16_audio_35.wav', 'রাহুলে কি পিনক করলে তোরে আমাদের'],
#  ['rec_16_audio_50.wav', 'বিপিএল ম্যাচ ইন্ডিয়া আসেন কিন্তু ফিটনেস'],
#  ['rec_16_audio_53.wav', 'মিসেল মাস্টার নিচে গা কি আনন্দময় আনন্দ করছি'],
#  ['rec_16_audio_12.wav', 'তেলের আনকমন উইকেট পড়ার সম্ভাবনা'],
#  ['rec_16_audio_18.wav', 'খেলা বন্ধ ভিডিও দেখতেছি'],
#  ['rec_16_audio_44.wav', 'ওরে লইয়া বিরাট কোহলি পড়ে আছে আমাদের'],
#  ['rec_16_audio_8.wav', 'ডিভিলিয়ার্স চেনেন'],
#  ['rec_16_audio_27.wav',
#   'হ্যাঁ করে দেখলে রান যদি কম থাকে বাড়ি না দিয়ে পারা'],
#  ['rec_16_audio_37.wav', 'সিরাজে মোহাম্মদ সামির রইলো ভুবনেশ্বর তিনটা খেলবে'],
#  ['rec_16_audio_45.wav',
#   'আর হার্দিক পান্ডিয়া হলে তো ফুল বোলিং খেলে আর দেখবেন'],
#  ['rec_16_audio_10.wav', '<>'],
#  ['rec_16_audio_58.wav',
#   'তুই ব্যাটসম্যানের তুই দেখা দিতাছস বলিং আমি অফিস নাম্বার ডেলিভারি সাথে সাথে ডেলিভারি দিব ওই টাইমে তোর গিয়া লিখছে'],
#  ['rec_16_audio_36.wav', 'সম্ভাবনা'],
#  ['rec_16_audio_28.wav', 'বুঝছো এটা কি কইতাম পরের মাসে রিংটোন'],
#  ['rec_16_audio_26.wav', 'কি বাড়ি বাড়ি ভারতে নাম'],
#  ['rec_16_audio_56.wav',
#   'হার্দিক পান্ডিয়ার খেলাইবো হার্দিক পান্ডিয়া সোয়ান হার্দিক পান্ডিয়া আমার খেলবে'],
#  ['rec_16_audio_7.wav', 'ডিভিডি কিনতে চাই তাহলে ব্যাটসম্যান'],
#  ['rec_17_audio_0.wav',
#   'কেজিপিটি কি কেমনে ব্যবহার করবেন এটা এ আই বা কৃত্রিম বুদ্ধিমত্তা দিকে ঝুকছে টেকজন প্রতিষ্ঠানগুলি বর্তমানে সবচেয়ে জনপ্রিয় এ আই চ্যাট বট হইতেছে চারটি ভিডিও এটা চালু করছে ওপেন এ আর্টিফিশিয়াল ইন্টেলিজেন্স বা কৃত্রিম বুদ্ধিমত্তা নিয়ে'],
#  ['rec_17_audio_2.wav',
#   'ছাইড়া গেছে যা হইতাছে চারটি ভিডিও মুক্ত করার মাত্র এক সপ্তাহের কম সময়ের মধ্যে পরিসংখ্যান বলতাছে মাত্র পাঁচ দিনে 10 লাখ ব্যবহারকারীর রেজিস্ট্রেশন করছে চ্যাটবট প্ল্যাটফর্মে চ্যাট বট হলো এক ধরনের'],
#  ['rec_17_audio_6.wav',
#   'যেটা কোন কিছুর বিষয়ে সাহায্য বুঝতে পারে 4 জিবি হলো আসলে একটি চ্যাট বট ওপেন দিয়ে তৈরি করা হয়েছে জিপিডি 3.5 এর উপর ভিত্তি করে তৈরি হয়েছে এটি যা'],
#  ['rec_17_audio_4.wav',
#   'ফলে কোন ডিভাইসের মাধ্যমে কয়েক সেকেন্ডের মধ্যে মানুষের মত কইরা যোগাযোগ স্থাপন করতে পারে অর্থাৎ ম্যাসেঞ্জার রিপ্লাই দিতে পারে 15 হইতেছে জেনার'],
#  ['rec_17_audio_9.wav',
#   'কারণ আপনি যখন গুগল এ যখন গুগল এ সার্চ করবেন তখন এটি এটা আপনাকে গুগলের মত অনেকগুলো লিংক দেখায় না তার পরিবর্তে সঙ্গে সঙ্গে সেকেন্ডের মধ্যে'],
#  ['rec_17_audio_1.wav',
#   'কাজ করা যুক্তরাষ্ট্রভিত্তিক একটি কোম্পানি যার একজন প্রতিষ্ঠাতা হলো দান কুবের ইলন মাস্ক আপাতত পাবলিক টেস্টিং এর জন্য এটার ব্যবহার মুক্ত করা হয়েছে এরই মধ্যে এলন মাস্কের এই চ্যাটবট চ্যাট বট ব্যবহারকারীর সংখ্যা 1 মিল'],
#  ['rec_17_audio_5.wav',
#   'ব্রিটেন ট্রান্সফর্মার এর পূর্ণরূপ এখানে জেনারেটিভ শব্দের অর্থ তৈরি করা পিচ এন্ড অর্থাৎ প্রশিক্ষিত ট্রানসফর্মার 4gb তে ট্রান্সফর্মার এমন একটি মেশিন রানিং মডেল'],
# ...
#  ['rec_25_audio_14.wav',
#   'এরপর দাঁত তরকারি উঠাইলাম ধন্যবাদ আচ্ছা আম্মুর কাছ থেকে শুনলাম'],
#  ['rec_25_audio_15.wav',
#   'যে বেগুনের ইলিশ এখন আমার মামী আছে তো মামীর কাছ থেকে শুনি অন্য কিছু আমি আপনার নামটা আগে কন আমি গৃহিণী আচ্ছা আমি আপনার পছন্দের একটা খাবার কি বিরিয়ানি মামীর কাছ থেকে বিরিয়ানি রেসিপি'],
#  ['rec_25_audio_73.wav',
#   'রসুন পিয়াজ দিবা আর এক দুইটা দুই একটা শুকনা মরিচ দিবা শুকনা মরিচ দিয়ে শুকনা মরিচ টা লাল হলে বা ভিডিও বাদামি কালার মধ্যে সবজি'],
#  ['rec_25_audio_80.wav',
#   'সাবু পিঠা আর কি পিডামু অনেক কষ্টের কিন্তু দেখা যায় অনেকেই দেয় আসলে খুব মজা কিন্তু এটা কিসে যে পরিশ্রমটা থাকে ওইটা তো আমার মা খালার এই পড়ে'],
#  ['rec_25_audio_27.wav', 'আজ কি শক্তি'],
#  ['rec_25_audio_48.wav',
#   'আমার নাইরে টাইরা ঢাকনা দিয়ে ঢেকে রাখবো কসাইয়া পরে কষানো হলে পানি দিয়ে পানি দিলে পানি যদি বাগুনে তাইলে লবণে যদি মানে লবণ যদি হয় তাহলে আর দেওয়ার মতোই তো না আবার যদি না হয় তাহলে একটু দিতে হই'],
#  ['rec_25_audio_40.wav',
#   'আচ্ছা আন্টি তোর পছন্দের খাবার কি মানে যেটা তোর ভালো লাগে যেটা খাইতে ইচ্ছা করে সব সময় নুডুলস নুডুলস স্যার'],
#  ['rec_25_audio_51.wav',
#   'আচ্ছা থ্যাঙ্ক ইউ আচ্ছা আমার লগে আমার আরেকটা মামি আছে তো শুটকি মামি মামির পছন্দ শুটকি বোনা তোমার কাছ থেকে শুনি শুটকি বোন আর রেসিপি মামি কন'],
#  ['rec_25_audio_17.wav', 'রাধুনী মানে মসলা বিরিয়ানি মসলা তোমার মাংস গুলো'],
#  ['rec_25_audio_70.wav',
#   'মরিচটা হল বাদামি কালার হইলে পরে ডলার সবজি এটা কি পানি ঝরানো পানি পানি'],
#  ['rec_25_audio_53.wav',
#   'মরিচটা আবার আলাদা কাঁচা মরিচ না শুকনা মরিচ শুকনা মরিচ বাটন একটু পানি অল্প পানি দিয়ে তারপরে শুটকি টা দিয়া'],
#  ['rec_25_audio_68.wav', 'দিয়ে দি'],
#  ['rec_25_audio_91.wav',
#   'ওইটা হইবো তো এই আরকি আচ্ছা আমি আপনারে অসংখ্য ধন্যবাদ যে আমাদের আঞ্চলিক ভাষা টারে আবার এমনি প্রকাশ করার জন্য যে সুযোগটা দিছেন ওইটার জন্য তো আসসালামুয়ালাইকুম'],
#  ['rec_25_audio_26.wav', 'মাংসটা'],
#  ['rec_25_audio_29.wav', 'যতটুকু পার্থক্য দরকার'],
#  ['rec_25_audio_56.wav',
#   'অনেক কষ্টে আসলে এরা আসলে রান্না টান্না নিয়ে অনেক গবেষণা করছে কোনটা বেশি মজা কোনটা বেশি না আচ্ছা মামা আমি আরেকটা আরেকটা আপনার পছন্দের কি খাবার এটা কন ওটা রেসিপি না করলে আপনার কি খাইতে ভালো লাগে'],
#  ['rec_25_audio_46.wav',
#   'আরো লং টং এসব দিয়া তেজপাতা দিয়া একটু নাড়াচাড়া ভাজা হইলে এটার মাঝে জিরা আদা বাটা রসুন বাটা দিয়ে আবার একটু নাড়াচাড়া হলুদের গুঁড়া মরিচের গুড়া আবার অনেকে দিলে হজের গুড়া'],
#  ['rec_25_audio_83.wav',
#   'খেজুরের রস খেজুরের গুড় সব কিছুই পাওয়া যায় আখ প্রচুর আখ হয় আবার এদিকে সে সবাইরে অনেক ধন্যবাদ আমার এসাইনমেন্টের সাহায্য করার লাইগা ওরা ছাড়া আসলে অ্যাসাইনমেন্টটা সম্পন্ন হতো না আর অবশ্যই আপনার অনেক থ্যাংক ইউ'],
#  ['rec_25_audio_28.wav',
#   'হালিম পাক করার আগে তোমার গরম পানি দিয়ে হালিমা বাজার দিয়ে ডিজাইন'],
#  ['rec_25_audio_64.wav', 'লাউ শাক কালার'],
#  ['rec_25_audio_4.wav', 'কি পছন্দ না আগে কি ইলিশ মাছ ভাজবো'],
#  ['rec_25_audio_82.wav',
#   'বাপিদা আসলে নরসিংদীর ভাষায় ডুপি পিটা কয় বাবা ভিটা কয় না তো পাটিসাপটা এগুলা আর এদিকে খেজুর খেজুরের রস পাওয়া যায়'],
#  ['rec_25_audio_85.wav',
#   'যাতে আমরা খুব ইনজয় করতে পারি আসলে আঞ্চলিক ভাষাটা আমরা অনেকেই আর কি কথা কইতে লজ্জা পাই আমি দেখছি ভার্সিটিতে যে অনেকে আঞ্চলিক ভাষায় কথা কয়না বা অনেকে এটা নিয়ে মজা করে শরীরটা ঠিক না যার যার আঞ্চলিক ভাষা এটা আমার মায়ের ভাষা তো অবশ্যই এটা'],
#  ['rec_25_audio_72.wav', 'জিপিএস টেস্টে যেতে হয় না'],
#  ['rec_25_audio_25.wav',
#   'ক্লাস এইট ওরা আসলে তেমন রান্না টান্না পারে না আচ্ছা মামির মামীর কাছে আরেকটা রান্নার রেসিপি জানি মামি হালিমও খুব মজা করে বানাইতে পারে আমি হালিমের রেসিপি দেখান'],
#  ['rec_25_audio_58.wav',
#   'ওইটা ওইটা আসলে আমি দেখছি যে সব জায়গায় হয় না ফুলকপি ডালের যে রান্নাটা ওই তরকারি সব জায়গায় হয় না'],
#  ['rec_25_audio_67.wav',
#   'পর্দায় ঢাকনা দিয়ে ঢেকে রাখুন লাগে রসুন কাইটা পিয়াজ কাইটা যা মসলা লাগে'],
#  ['rec_25_audio_13.wav',
#   '10 মিনিট বা 20 মিনিট পরে ঢাকনাটা উড়াইয়া দেখমু এটা জালাইছে নাকি দিয়া ধইনা পাতা দিয়ে আর কিছুক্ষণ 10 মিনিট বা পাঁচ মিনিট রাইখা'],
#  ['rec_25_audio_35.wav',
#   'পরে আবার লবন দেই তো একটু পরিমানই লবন দিয়া যায় লবন দেওয়ার পরে ওইটা কষানো হলে পরে মাংসটা যেটা মেরিনেট করে রাখছিলাম ওইটা দেই ওইটা দিয়ে তারপরে পরিমাণমতো আবার একটু পানি দেই পানি দিয়ে তারপরে আবার ওইটা কসাই ওটা ঢাইকা রাইখা'],
#  ['rec_25_audio_87.wav',
#   'যে আঞ্চলিক ভাষায় কথা কইতাম মাঝে মাঝে কই চান চুলকায় তো অনেকে কয় যে তোর আসলেই তুই মানে আঞ্চলিক ভাষায় কথা কস অনেকে আমার ভাবনায় তা আমাদের ভাব নেওয়ার অভ্যাস সেই ভাব নিয়ে যে একদম শুদ্ধ ভাষায় কথা কমু বন্ধন করলে মাঝে মাঝে অবশ্যই ফর্মালিটির একটা ব্যাপার আছে সব জায়গায় তার আঞ্চলিক ভাষা চলে'],
#  ['rec_25_audio_6.wav', 'কোরআনে যে তেল দিয়া তেলটা গরম হলে পরে মাছ ইলিশ মাছ'],
#  ['rec_25_audio_61.wav',
#   'চিড়া হলুদের ফটো আর আর আম্মুর কাছে আরেকটা জিনিস আমার আম্মু যে নিরামিষ টা রান্না করে গ্রামের দিকে আসলে সবজি সবজি অনেক বেশি পাওয়া যায় তবে ওই দিনে আর কি এগুলা পিওর সবজি'],
#  ['rec_25_audio_1.wav',
#   'এটি হচ্ছে আমার এসাইনমেন্ট আজকে আমি আমার টপিক সিলেক্ট করছি রেসিপি কুকিং আর আমার সাথে আমার ফ্যামিলি আছে আমার সাথে এখন আমার সাথে আমার আম্মু আছে আম্মু তোমার নাম'],
#  ['rec_25_audio_43.wav',
#   'কাঁচা মরিচ পরে আবার ডিম আবার নুডুলসের মসলা পরে এটা একটু নাইরা মাইরা নুডুলস দিয়া পরে এটা আবার নুডুলসের মসলা দিব নাকি আলাদা আবার লবন টবন লাগে না এটাই তার পছন্দের'],
#  ['rec_25_audio_2.wav',
#   'আমার নাম কামরুন নাহার হেনা আচ্ছা আম্মু হচ্ছে গৃহিণী আমি আমার আঞ্চলিক ভাষায় কথা কই তুমি যেমনে কথা কও মানে তোমার আঞ্চলিক ভাষায় তো তুমি এমনি তোমার যে রান্নার রেসিপি দাও যেটা তোমার খুব ভালো লাগে মানে যেটা তুমি অনেক ভালো পারো'],
#  ['rec_25_audio_3.wav',
#   'জানি তুমি সবকিছুই অনেক আম্মুর রান্না আসলে অনেক মজা হয় তো তুমি যেটা খুব ভালো পারো ওইটা তুমি কও মানে রেসিপিটা খালি করবা কেমনে কি করো আমার কাছে তোমার'],
#  ['rec_25_audio_60.wav',
#   'কত সহজ আছে ফুলকপি আর ডাল এরিয়াটা আমারও খুব মজা লাগে'],
#  ['rec_25_audio_39.wav',
#   'আঞ্চলিক ভাষায় আমি যেমনে কথা কইছি এমনেই তাহমিনা আক্তার কোন ক্লাসে পড়ো ইন্টার সেকেন্ড ইয়ারে ও আন্টি আবার আমার ছোট আবার তুই কইতাছি দেখি আমি কিছু মনে কইরেন না ও কিন্তু আমার ছোট ও ইন্টার সেকেন্ড ইয়ারে পড়ে'],
#  ['rec_25_audio_18.wav', 'তারপরে তোমার আদা রসুন মানে সব মসলা দিয়ে একটু'],
#  ['rec_25_audio_52.wav',
#   'শুটকি পছন্দ করে না সবাই শুঁটকি খুব পছন্দ করে আমি শুটকি রেসিপি দেখান'],
#  ['rec_25_audio_81.wav',
#   'যাইহোক কষ্টের ফল আসলেই মিঠাই যেটা ফিডার ক্ষেত্রে বেশি বুঝা যায় যে ফিদা অনেক কষ্ট করে বানায় কিভাবে অবশ্য গ্রামবাংলায় শীতের মধ্যে অনেক মজার পিঠা এটা বাংলাদেশে হয় বাংলাদেশের'],
#  ['rec_25_audio_11.wav', 'পানি দিয়ে এরপর দাদার নাকি আসবে না'],
#  ['rec_25_audio_50.wav',
#   'অনুযায়ী বুইঝা মুরগা কতটুকু এইটুকু বুইঝা ও আচ্ছা মুরগি চট্টোপাধ্যায়'],
#  ['rec_25_audio_22.wav', 'তোমাকে হাত দিয়ে অনুমান করুন'],
#  ['rec_25_audio_5.wav',
#   'হলুদ বাটো হলুদের গুড়া দিয়ে মরিচের গুড়া দিয়া মাছটা মাখাম মাকায়া কি রাখতে হইবো কতক্ষণ চলবে'],
#  ['rec_25_audio_33.wav',
#   'কাইটা কাইটা তারপরে রাখি মানে সময় বাঁচানোর লেগে আরকি তেল দিয়ে পেঁয়াজ পেঁয়াজ মরিচ রসুন এগুলা কাটার পরে একটা কড়াইতে তেল ঢালী পরিমাণমতো তেল নেই আর কি তো তেলটা গরম হলে তারপরে পেঁয়াজ রস'],
#  ['rec_25_audio_59.wav', 'তেল রসুন পেঁয়াজের ডিজাইন'],
#  ['rec_25_audio_76.wav',
#   'আচ্ছা আম্মুরে অনেক ধন্যবাদ আর কি এত মজার মজার খাবার রান্না কইরা খাওয়ায় সব সময় তো কম হয় নাই তো হয়না'],
#  ['rec_25_audio_36.wav',
#   'তারপর এটা সিদ্ধ হলে আবার লবন দেই একটুও তারপর এটা আবার ঢেকে রাইখা দেই তারপরে কি হয়ে যায় পানি দিয়ে ঢেকে রেখে দিই তারপর একটু পর পর নাড়তে থাকে আবার তো এমনিতেই মাংসটা যখন হয়ে যায় মানে একটু নরম হয় তখন আবার একটু খাইয়া তো অবশ্যই দেখি'],
#  ['rec_25_audio_75.wav',
#   'তেলাইন দিয়ে পড়ো কিছু করবার 5 মিনিট আবার জ্বাল দিতে হবে পাঁচ মিনিট যদি না হয় তাহলে যতক্ষণ পর্যন্ত না হয় ততক্ষণ পর্যন্ত'],
#  ['rec_25_audio_31.wav',
#   'অতো ভালো পারিনা তাও যেহেতু বাসায় বাসায় থাকি বাইরে থাকলে টুকটাক কিছু রান্না করাই লাগে তা গরুর মাংসের রেসিপি দেই কই প্রথমে গরুর মাংস'],
#  ['rec_25_audio_79.wav',
#   'এ পিঠা রে হল জলটা যেই চলটা থাকে ওইটা এখনো আছে আপনি অনেক ঈদের সময় বিশেষ করে ঈদের সময় সবাই অনেক বেশি বেশি পিঠা ফুল পিডা পাতা পিঠা সিরিজ ফিদা'],
#  ['rec_25_audio_47.wav',
#   'এইসব দিয়া নাইরে টাইরা একটু পানি দিয়ে কসাইয়া পরে আলু দিলে আলু দিয়ে আবার সব কষে আলু কি সিদ্ধ আলু না কাঁচা আলু দিয়ে যদি আলু দেয় অনেকে আবার অনেকে দেয় না পরে আলুটা কষাইয়া পরে একটু পরে আবার মাংসটা দিব এটার'],
#  ['rec_25_audio_42.wav', 'তেলের মাঝে'],
#  ['rec_25_audio_8.wav',
#   'টাকনু মরিচ কাটবো মরিচ কাটে হলুদের গুড়া মরিচের গুড়া'],
#  ['rec_25_audio_32.wav',
#   'কুচিকুচি করে কাইটা তারপর আদা মানে আদানা হলুদ মরিচ যা আছে ওইগুলা দিয়ে মেরিনেট কইরা মানে কতক্ষণ আধা ঘন্টার মত রাইখা দেই কি আমি যেমনে রান্না করি তো আধা ঘন্টার মত রাইখা দেই তারপরে ওটা রাইখাই পিঁয়াজ মরিচ মানে যা যা লাগে ওই গুলার ব্যবস্থা করে ওগুলো আগে কাই'],
#  ['rec_25_audio_57.wav',
#   'আপনার পছন্দের কি খাবার আছে পছন্দের খাবার নাই আমি একটা পছন্দের খাবার ফুলকপি আর ডালের রেসিপি'],
#  ['rec_25_audio_71.wav',
#   'ও আচ্ছা ওই ডালের মধ্যে কেমনে দেই না পাতা দিয়ে দিবে'],
#  ['rec_25_audio_55.wav',
#   'আচ্ছা চিংড়ি মাছের শুটকি বলে চিংড়ি মাছ ও দেওয়া যায় অনেক কিছু আসলে শিখতাছি এসাইনমেন্ট এর লাইগা মরিচ বাইতুল হইলে মরিচের গুড়া না দিয়ে মরিচটা বাইতে লইলে বেশি মজা লাগে না'],
#  ['rec_25_audio_88.wav',
#   'তো সবকিছুই দরকার আসলে আমি তো বাড়িতে হঠাৎ করে আমি যে আমার মা আঞ্চলিক ভাষায় কথা কইলে আমি আমার মারে যে বাইরে নিতাম না যে কিল্লিগা আঞ্চলিক ভাষায় কথা কয় এটা যার যার ব্যক্তিগত ব্যাপার মানে ওরা এটা শিক্ষাই আইছে এটা আমার মায়ের বাসা তো আমিও আমার কাছ থেকে একটা আঞ্চলিক ভাষায় শিখছি অনেকে দেখি এটা করে যে মা বা ফ্যামিলির যারা'],
#  ['rec_25_audio_0.wav',
#   'সালামুআলাইকুম আমি ইশরাত আমিন ঐশী আমার বাড়ি নরসিংদী আমার এসাইনমেন্ট হচ্ছে আমার আঞ্চলিক ভাষায় আমরা যে আঞ্চলিক ভাষায় কথা বলি মানে নরসিংদীর ভাষায় ওই ভাষায় হচ্ছে একটা টপিক নিয়ে দুইজন বা আরো বেশি কাউকে নেয়া একটা ভয়েস রেকর্ড'],
#  ['rec_25_audio_30.wav',
#   'ব্যারিস্টারি কাঁচা মরিচ দেই লেবু ধনে পাতা শসা এগুলি দিয়ে পরিবেশন করুন আচ্ছা আমি একটা রান্নার রেসিপি কই আমি যেটা পারি আর কি আম্মুর কাছ থেকে যেটা শিখলাম গরুর মাংস'],
#  ['rec_25_audio_65.wav',
#   'অসীমের টা খুব ভালো লাগে সিমের বিচি টা আমার খুব পছন্দের এগুলো সবজি দিয়া এরপর দ্বারা কিছুক্ষণ মসলা দিয়ে আধা মসলা যা আছে সব দিয়া'],
#  ['rec_25_audio_69.wav',
#   'এরপর তাহলে আসি দইলে পানির ছানির সবকিছু হয়ে আসলে পরে কাঁচা মরিচ কাটবা আবার শুকনা মরিচ দুইটা বাচবা পিয়াজ কাটবা কসাই দাও'],
#  ['rec_25_audio_66.wav', 'পর্দা লাগ না'],
#  ['rec_25_audio_62.wav',
#   'তৈরি নিয়ে আম্মু একটা নিরামিষ রান্না করে ওই নিরামিষ টা আসলে অনেক মজার এটা কি আম্মুরে জিগাইছে আসলে কেমনে কি করে আম্মু কও কি কি সবজি দাও আর কি নিরামিষ টা যেটা আনন্দ যেটা খুব ভালো লাগে অনেক কিছু লাগে'],
#  ['rec_25_audio_37.wav',
#   'যে হইছে কিনা তো এটার পরে আবার খাইয়া টাই দেখি যে হয়েছে কিনা হইলে তারপরে আবার মাঝে মাঝে আম্মুরে কল দিয়ে জিগাই যে হইছে নাকি কেমনে কি করে তা আম্মু কই আমার মাঝে মাঝে হয় আবার হয় না তো হল লাইফে এমনই হয় আসলে রান্নাবান্না সবকিছু যেমন'],
#  ['rec_25_audio_77.wav',
#   'আমি একটা সুযোগ করে দিয়েছে সেই সুযোগের জন্য যায় আমরা অনেক কিছু শিখলাম আরকি আমি অনেক কিছু শিখলাম আচ্ছা আমাদের নরসিংদীর আরো কিছু কই যেন নরসিংদীর যে বিখ্যাত নটকান আর এস এ'],
#  ['rec_25_audio_44.wav',
#   'আচ্ছা আর আর কি পারো নুডুলস ছাড়া নুডুলস তো এটা সবাই পারে বাচ্চা পোলাপানে পারে ওই এটা আমার ছোট ভাই ও পারিনা'],
#  ['rec_25_audio_45.wav',
#   'সব কবি মানে যেমনে যেমনে তুই রান বলছ যা যা লাগে সব কবি মুরগা কাইটা কাইটা ধুইয়া বালা কইরা তারপরে পিএসটিএস কাইটা রসুন বাটা দিয়ে তেলের মধ্যে পরে আবার এলাচ আবার খাল'],
#  ['rec_25_audio_86.wav',
#   'মানে এটা নিয়ে লজ্জা পাওয়া শরমের তো এমন কিছু নাই তুমি আমাকে ধন্যবাদ কারণ আপনি যে অ্যাসাইনমেন্টটা দিছেন এটার মাধ্যমে আসলে আমরা অনেক কিছু শিখতে পারলাম যে আঞ্চলিক ভাষার যে একটা গুরুত্ব বা এটা নিয়ে কথাটা আসলে আমি নিজে অনেক কমফোর্ট ফিল করি'],
#  ['rec_25_audio_9.wav',
#   'এরপর দা মসলাটা কষান আলু আলু বেগুন ভাজলাম যায় আবার কষানো মরিচের লগে বিয়া করে মাছটা কি পরে নাকি'],
#  ['rec_25_audio_89.wav',
#   'দাদি নানিরা বিশ্বাস করে ওরা তো আর শুদ্ধ ভাষা পারে না বা বাইরে গিয়া মাইনষের লগে কথা কইব এমন ইয়া নাই তো অনেকে দেখা যায় যে ওদের আর কি বাইরে নিতে চায় না এই জিনিসটা আসলেই খুব খারাপ কারণ আমরা মায়ের ভাষা শিখছি ওরা যে আঞ্চলিক ভাষায় কথা'],
#  ['rec_25_audio_21.wav', 'বারাদিয়া নামাজ নামাজ দিয়ে দি আমি কোন মানে বুঝিনা'],
#  ['rec_25_audio_74.wav',
#   'এরপর সবজি পাক করা হয়ে গেল এটা কতক্ষণ রাখুন লাগবো আর কিছু লাগবে না'],
#  ['rec_25_audio_20.wav',
#   '10 মিনিট পরে পরে 10 মিনিট পর ঢেকে রাখলে আমার কথা শুনে'],
#  ['rec_25_audio_12.wav',
#   'আগে ইলিশ মাছ দিয়ে তারপরে আবার টমেটো টমেটো আর ইলিশ মাছ একসাথেই দিনে কি করমু'],
#  ['rec_25_audio_84.wav',
#   'কারণ আপনি না থাকলে এত মানে সুন্দর একটা মুহূর্ত হয়তো আমরা কাটাইতে পারতাম না তুমি আমার জন্য আপনার অসংখ্য ধন্যবাদ আসলে আমরা আসলেই অনেক মজা করছি বিশেষ করে আমি অনেক কিছু শিখছি তবে আপনার জন্য এটা সম্ভব হয়েছে এমন আরো মজার মজার এসাইনমেন্ট'],
#  ['rec_25_audio_63.wav',
#   'কি কি কি কি কি কি কি কি সবজি কি কি লাগে গাজর লাউ ফুলকপি পাতাকপি কলা কাঁচা কলা এর পর্দা লাউ শ'],
#  ['rec_25_audio_24.wav',
#   'ছোট বোনের নাম নাম বল আমার নাম ইসরাত জাহান লুবনা আচ্ছা তুই কোন ক্লাসে পড়ো এবার এসএসসি পরীক্ষা দিমু এসএসসি পরীক্ষা দেবে আমার আরেক বোনের নাম নাম বলবা কোন ক্লাসে পড়ো'],
#  ['rec_25_audio_49.wav',
#   'আর পরে তো ফাগুনরে যদি জ্বালিয়ে তাহলে উঠায় লিবো আচ্ছা এটা কি পানি টানির কোন কিছু পরিমাণ আছে'],
#  ['rec_25_audio_10.wav', 'বেগুন বাজার'],
#  ['rec_25_audio_38.wav',
#   'ফোড়া হাফসি দেয় মনে হয় তেমনি খাওয়া লাগে যেমন হয় আরকি তো এই মাংসের রেসিপি আচ্ছা আমার আমার লাগে আমার একটা আন্টি ও আছে তো আন্টির নাম'],
#  ['rec_25_audio_16.wav',
#   'তারপরে পিয়াজ কাটবো রসুন বাটা আদা বাটা গাজর ফুল মুভি মটরশুটি'],
#  ['rec_25_audio_34.wav',
#   'মরিচ সবগুলো একসাথে দিয়া ওটা বাদামি বর্ণের হইলে তারপরে ওইখানে আছে একটু পানি দেই আদা রসুন বাটা যা যা থাকে ওই আদা রসুন আদা বাটা রসুন বাটা পেঁয়াজ বাটা এগুলা দিয়ে তারপর এটা কসাই আরকি সামান্য পরিমান লবণ'],
#  ['rec_25_audio_19.wav',
#   'পোলাও চাউল টা দিমু পোলার চাল কি ভিজিয়ে রাখতে হয় আগে নাকি'],
#  ['rec_25_audio_54.wav',
#   'কতক্ষণ বেড়া টেরা পানি শুকিয়ে গেলে সব চুপ করলে শুটকি ভুনা শুটকি ভুনা টা আসলে সহজ কিন্তু পারি না'],
#  ['rec_25_audio_7.wav', 'আচ্ছা ঠিক আছে সব কি আলাদা আলাদা'],
#  ['rec_25_audio_41.wav',
#   'আচ্ছা আর তুই কি রানতে পারো সেটা কও আন্টি আবার রান্না টান্না ভালোই পারে আবার ডিম ভুনা রানতে পারি নুডুলস কেমনে রান দিয়েছে প্রথমে গরম পানি বসাইয়া পরে'],
#  ['rec_26_audio_13.wav',
#   'ভাই বাজারে অনেক মিতালিতে অনেক সুন্দর সুন্দর হবে না কারণ বর্তমানে যুগ সৌরভের জন্য ওস্তাদ'],
#  ['rec_26_audio_27.wav', '<>'],
#  ['rec_26_audio_0.wav', '<>'],
#  ['rec_26_audio_2.wav', 'কার বাসা'],
#  ['rec_26_audio_5.wav', '<>'],
#  ['rec_26_audio_34.wav', '<>'],
#  ['rec_26_audio_7.wav', '<>'],
#  ['rec_26_small_audio_3.wav', '<>'],
#  ['rec_26_audio_17.wav', 'গরম অনেক গরম'],
#  ['rec_26_audio_8.wav', 'আরে না যা হয় ভালোর জন্য বুঝছস'],
#  ['rec_26_audio_28.wav', '<>'],
#  ['rec_26_audio_11.wav', '<>'],
#  ['rec_26_audio_15.wav', 'মিতালি জামাটা অনেক সুন্দর হয়েছিল'],
#  ['rec_26_audio_22.wav', 'বাপি সরদার না 2 দিন পরে গিয়ে টাকা জমা হইবো'],
#  ['rec_26_audio_32.wav', 'এনি এলিয়েনের মৃত্যুর আগে তো কিছু নাই'],
#  ['rec_26_audio_18.wav', 'আমি আগের মাসে গ্যাস বিল দিতে গিয়েছিলাম'],
#  ['rec_26_audio_26.wav', '<>'],
#  ['rec_26_audio_25.wav', '<>'],
#  ['rec_26_small_audio_0.wav', '<>'],
#  ['rec_26_audio_33.wav', '<>'],
#  ['rec_26_audio_29.wav', '<>'],
#  ['rec_26_audio_14.wav',
#   'আমি শুধু বাচ্চার জন্য এখান থেকে কিনছি একটা কারণে নানির বাড়ির জন্য প্যান্ট দেখে দেখে সুন্দর সুন্দর আমিও ইতালিতে অনেক সুন্দর সুন্দর জামা দেখছি'],
#  ['rec_26_audio_30.wav', '<>'],
#  ['rec_26_audio_12.wav',
#   'শুনলেই বা এই বাচ্চার জামা বাইরে তো একটা দেন এটা তো হতে পারে না'],
#  ['rec_26_audio_3.wav', '<>'],
#  ['rec_26_audio_21.wav', '<>'],
#  ['rec_26_audio_31.wav', 'একটু সময় লাগে আমি কইলাম না আমি বাইরে থাকি ঘরে'],
#  ['rec_26_audio_4.wav', '<>'],
#  ['rec_26_audio_20.wav', 'দুইদিন পরে জমা হয় টাকা অনেক সময় টাকা জমা'],
#  ['rec_26_audio_24.wav', '<>'],
#  ['rec_26_small_audio_1.wav', 'এ বাবুরা বাবুরা'],
#  ['rec_26_audio_9.wav', '<>'],
#  ['rec_26_small_audio_2.wav', 'শিবা শিবা শিবা শিবা সুমা গেছে'],
#  ['rec_26_audio_23.wav', 'কই'],
#  ['rec_26_audio_6.wav', 'বাবুরে নিয়ে আসবো না'],
#  ['rec_26_audio_19.wav', 'নরসিংদী কোনদিন'],
#  ['rec_26_audio_16.wav', '<>'],
#  ['rec_26_audio_1.wav', '<>'],
#  ['rec_26_audio_10.wav', '<>'],
#  ['rec_04_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_26_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_26_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_26_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_26_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_04_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_04_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_04_big_audio_1_chunk_1.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 1385

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["contents"] = content

# %%
df
# Out:
#               External_ID Contents  \
# 0     rec_07_audio_40.wav      NaN
# 1     rec_07_audio_65.wav      NaN
# 2     rec_07_audio_37.wav      NaN
# 3     rec_07_audio_49.wav      NaN
# 4     rec_07_audio_50.wav      NaN
# ...                   ...      ...
# 1380  rec_07_audio_36.wav      NaN
# 1381   rec_07_audio_6.wav      NaN
# 1382  rec_07_audio_58.wav      NaN
# 1383  rec_07_audio_22.wav      NaN
# 1384  rec_07_audio_15.wav      NaN
#
#                                                contents
# 0                                                    <>
# 1                                       ধন্যবাদ ধন্যবাদ
# 2               কিগো রেকর্ডার দিয়ে অফিস কোন জায়গা নেই
# 3     সালমান খানের গরম কারেন্ট নাই অনার্স ছাড়া যে প...
# 4                                                    <>
# ...                                                 ...
# 1380                                  একটা কইছে গেছিলাম
# 1381                 নুডুলস সাধারণ কয়বার চাওয়া হয়েছে
# 1382   আনজা সৌমিতা ম্যাডামে তোমারে মারণে ভালো হয়ে গেছে
# 1383  সব দিন সুন্দর লাগে আমি সেকেন্ড ইয়ারের ফার্স্ট...
# 1384  রাতের বেলা আমার বাসা কিরকম হাহাহাহাহাহাহাহা আম...
#
# [1385 rows x 3 columns]

# %%
len(df)
# Out:
# 1385

# %%
df.to_excel("1.5: narsingdi-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
