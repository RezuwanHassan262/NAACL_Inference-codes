# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data_dir = '/content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/'

# %%
# !pip install audiosegment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73460 sha256=3db8225b766bfe6dad8e742795d0986307510ae6d97243d359f162ea650ce213
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built webrtcvad
# ...

# %%
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()

# %%
x = os.listdir(data_dir)
x
# Out:
# ['rec_19_audio_40.wav',
#  'rec_19_audio_31.wav',
#  'rec_19_audio_15.wav',
#  'rec_19_audio_3.wav',
#  'rec_19_audio_14.wav',
#  'rec_19_audio_2.wav',
#  'rec_19_audio_18.wav',
#  'rec_19_audio_28.wav',
#  'rec_19_audio_10.wav',
#  'rec_19_audio_24.wav',
#  'rec_20_audio_32.wav',
#  'rec_20_audio_21.wav',
#  'rec_20_audio_22.wav',
#  'rec_20_audio_8.wav',
#  'rec_20_audio_3.wav',
#  'rec_20_audio_15.wav',
#  'rec_20_audio_6.wav',
#  'rec_20_audio_4.wav',
#  'rec_20_audio_2.wav',
#  'rec_20_audio_41.wav',
#  'rec_20_audio_38.wav',
#  'rec_20_audio_7.wav',
#  'rec_20_audio_29.wav',
#  'rec_20_audio_1.wav',
#  'rec_20_audio_18.wav',
#  'rec_20_audio_14.wav',
#  'rec_20_audio_23.wav',
#  'rec_20_audio_11.wav',
#  'rec_20_audio_5.wav',
#  'rec_20_audio_30.wav',
#  'rec_20_audio_37.wav',
#  'rec_20_audio_28.wav',
#  'rec_20_audio_39.wav',
#  'rec_20_audio_27.wav',
#  'rec_20_audio_20.wav',
#  'rec_20_audio_26.wav',
#  'rec_20_audio_12.wav',
#  'rec_20_audio_17.wav',
# ...

# %%
len(x)
# Out:
# 1880

# %%
x.index("rec_01_audio_0.wav")
# Out:
# 1026

# %%
f"{data_dir}{x[1026]}"
# Out:
# '/content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_01_audio_0.wav'

# %%
import audiosegment

audio_path = f"{data_dir}{x[1026]}"
print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_01_audio_0.wav
# /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_01_audio_0.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.100s long

# %% [markdown]
# # Bangla Wav2Vec2-large

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/auditi41/wav2vec2-large-xlsr-53-Bangla"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# %%
external_id = []
contents = []
errors = []
c = 0

def once(output):

    if len(output['text']) == 0:
        contents.append("<>")
    else:
        contents.append(output['text'])


def again(audio):

    global c

    try:
        output = query(audio)

        if 'error' in output.keys():
            if c != 5:
                c += 1
                again(audio)
            else:
                c = 0
                contents.append("<>")
                pass
        else:
            once(output)


    except Exception as e:
        errors.append(i)
        pass


for i in x:

    audio = f"{data_dir}{i}"
    external_id.append(i)

    try:
        output = query(audio)
        once(output)

    except:
        if c != 5:
            c +=1
            again(audio)
        else:
            c = 0
            contents.append("<>")
            continue

# %%
print(errors)
print()
print(len(errors))
# Out:
# []
#
# 0

# %%
print(external_id)
print()
print(len(external_id))
print()
print("=======================")
print()
print(contents)
print()
print(len(contents))
# Out:
# ['rec_19_audio_40.wav', 'rec_19_audio_31.wav', 'rec_19_audio_15.wav', 'rec_19_audio_3.wav', 'rec_19_audio_14.wav', 'rec_19_audio_2.wav', 'rec_19_audio_18.wav', 'rec_19_audio_28.wav', 'rec_19_audio_10.wav', 'rec_19_audio_24.wav', 'rec_20_audio_32.wav', 'rec_20_audio_21.wav', 'rec_20_audio_22.wav', 'rec_20_audio_8.wav', 'rec_20_audio_3.wav', 'rec_20_audio_15.wav', 'rec_20_audio_6.wav', 'rec_20_audio_4.wav', 'rec_20_audio_2.wav', 'rec_20_audio_41.wav', 'rec_20_audio_38.wav', 'rec_20_audio_7.wav', 'rec_20_audio_29.wav', 'rec_20_audio_1.wav', 'rec_20_audio_18.wav', 'rec_20_audio_14.wav', 'rec_20_audio_23.wav', 'rec_20_audio_11.wav', 'rec_20_audio_5.wav', 'rec_20_audio_30.wav', 'rec_20_audio_37.wav', 'rec_20_audio_28.wav', 'rec_20_audio_39.wav', 'rec_20_audio_27.wav', 'rec_20_audio_20.wav', 'rec_20_audio_26.wav', 'rec_20_audio_12.wav', 'rec_20_audio_17.wav', 'rec_20_audio_24.wav', 'rec_20_audio_34.wav', 'rec_20_audio_31.wav', 'rec_20_audio_40.wav', 'rec_20_audio_13.wav', 'rec_20_audio_25.w
# ...

# %%
num = x.index("rec_19_audio_40.wav")
num
# Out:
# 0

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_40.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_40.wav
# /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_40.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.040s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'text': 'সুলীগার শিক্াসললেই এনদেন্ড সাপ ধটেগার্দুটি র্মধ্যে গিরমীয় ব্যাতাহয়রিরে হনিরিববযা থায় নাত জ্যানে দার্সেমানে কো্র জল দেশেইগরমা জলতে ছৈজি আসনিকে সামাটা গধিয় বারাআনেগেনদলতে জলতি হনাককােরন।'}

# %%
num = x.index("rec_19_audio_31.wav")
num
# Out:
# 1

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_31.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_31.wav
# /content/drive/MyDrive/local_speech/Narail/Narail_Chunks/all/rec_19_audio_31.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.172s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'text': 'ভুয়া মাঝের চৃদির দায় বয়়াসাএদের দা়মামটাম পাড়িটাডিনীশিও রয়েছেকঠাৎ কারামার কেষবিএড গীতি মাতাতাটাইয়েএর নানেটা গীতি মাথে এখানী গীটি পাটাঠায়তাটাইয়ে মাথাথাতা বাহর করে নিয়ে আসে।'}

# %% [markdown]
# # Making Dataframes

# %%
import pandas as pd

df = pd.DataFrame(list(zip(external_id, contents)), columns =['External_ID', 'Contents'])
df.head()
# Out:
#            External_ID                                           Contents
# 0  rec_19_audio_40.wav  সুলীগার শিক্াসললেই এনদেন্ড সাপ ধটেগার্দুটি র্ম...
# 1  rec_19_audio_31.wav  ভুয়া মাঝের চৃদির দায় বয়়াসাএদের দা়মামটাম পা...
# 2  rec_19_audio_15.wav  গণ্ডৌলাত্ব মা়ের্ঘাত ঢাচামাচার্বপর্থ অকিথকলী প...
# 3   rec_19_audio_3.wav  ঝোহ়ালা তালিত কষেবননা মোলা আভিরে কয়েচল থাঁতো...
# 4  rec_19_audio_14.wav  ধ্ ব্রধাকীত কাল ছের মগেলিনেনেগুলোবদিয়ে ছল নাবই...

# %%
df
# Out:
#               External_ID                                           Contents
# 0     rec_19_audio_40.wav  সুলীগার শিক্াসললেই এনদেন্ড সাপ ধটেগার্দুটি র্ম...
# 1     rec_19_audio_31.wav  ভুয়া মাঝের চৃদির দায় বয়়াসাএদের দা়মামটাম পা...
# 2     rec_19_audio_15.wav  গণ্ডৌলাত্ব মা়ের্ঘাত ঢাচামাচার্বপর্থ অকিথকলী প...
# 3      rec_19_audio_3.wav  ঝোহ়ালা তালিত কষেবননা মোলা আভিরে কয়েচল থাঁতো...
# 4     rec_19_audio_14.wav  ধ্ ব্রধাকীত কাল ছের মগেলিনেনেগুলোবদিয়ে ছল নাবই...
# ...                   ...                                                ...
# 1875  rec_19_audio_41.wav                                                 <>
# 1876  rec_19_audio_26.wav                                                 <>
# 1877  rec_19_audio_25.wav                                                 <>
# 1878   rec_19_audio_7.wav                                                 <>
# 1879   rec_19_audio_5.wav                                                 <>
#
# [1880 rows x 2 columns]

# %%
df.to_csv("4.3: Bangla-wav2vec2-narail-inference.csv")

# %% [markdown]
# # Experimental Zone

# %%
a = output['text']

# %%
b = "আমিত সলে আসলাম তোমারে এমনে করজায়ের মধ্যে কালকেদে তোমারা ফরন্ধি লান্তমি কলে যা আফ তিনিপরে আসলের হয়েদিনি মলে মনেছিলযা জামলা গেসিন়েরাশনকরমিি সাপ্তনে আশরার অজবনটা বলা হিসেবন সমন সাপ্তে দে দিলানা টাউনিয় নিটতত কলেছিল।"

# %%
a == b
# Out:
# True

# %%
output = query(f"{data_dir}{x[1025]}")

output
# Out:
# {'text': "শৈদিকতেঅনে তুইজুরী চিট্যে দেলে নয়েদেহাসেতানতে ভাল কেলাস্র রীমনের লোলইমনজের লাষ্ট্রে ডিয়ের স হলে দেয়েরা খিটিকে এটি কে আছে নাখি গেছে।'হহমাপরে আরাক্টা কণ্য ন সেটে আছে মেয়ে ঐছে।"}

# %%
output = query(f"{data_dir}{x[1025]}")

output
# Out:
# {'text': "শৈদিকতেঅনে তুইজুরী চিট্যে দেলে নয়েদেহাসেতানতে ভাল কেলাস্র রীমনের লোলইমনজের লাষ্ট্রে ডিয়ের স হলে দেয়েরা খিটিকে এটি কে আছে নাখি গেছে।'হহমাপরে আরাক্টা কণ্য ন সেটে আছে মেয়ে ঐছে।"}

# %%
output = query(f"{data_dir}{x[1027]}")

output
# Out:
# {'text': 'তুলদে দিযয়ে আমারা দেনে আইটিহাসে সারওই ও কয়ানেজয় জুল আছালকি ডার কোয়আনেতন বাজন্দার সালকরা য়েগা দিঘী জামিতান্ত তুইহাশ লীগী তাকে তা তরে বাদ্যে জননে দখকে রখা ময় েমাকনিষরা নিযয়ে সাথমানের মার ম্তকস্কিক়ম্যে ও কারিনি  সাপটিমকেকুটকা আমস্ নাবে নি।'}

# %%
len(output)
# Out:
# 1

# %%
output = query(f"{data_dir}{x[1030]}")

output['text']
# Out:
# 'মম্জে দিনি হয়ফাল্তেযিনি স্টাশলের থিগি এ মরমন্তি ওওপা় ও সতকৃচিতফবকারী দে ই এগ দিগিজে ঢে়ছেকিন্তু তার বাবভিনি তার অনকর্ঞতি নরঅরযোজের পরিমাণ হতাশ হয়ে গেছে।'

# %%
output.keys()
# Out:
# dict_keys(['text'])

# %%
'text' in output.keys()
# Out:
# True

# %%
'error' in output.keys()
# Out:
# False

# %%
output = query(f"{data_dir}{x[1281]}")

output
# Out:
# {'text': 'তব চাকরি না উভাপ্রযোজনতর েবর্তে ়না থাককেকাযিতট্য এদিও রাা আটই় জিনে আজি পুর্ডরাজইততৌধরভ আগে রাজবীলে বিয়েহা দি করী রে করত্র তারে এট কাজাগা দুইডিও কৃষুরে সেতেচাকটই প্রথম।'}
